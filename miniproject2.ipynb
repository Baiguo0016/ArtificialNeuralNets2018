# %% [markdown]
# # Miniproject 2: Melody generation
#
# ## Introduction
#
# ### Description
#
# To develop a model employing ANN on real-world data requires going through several major steps, each of which with important design choices that directly impact the end results. In this project, we guide you through these choices starting from a large database of [Irish folk melodies](https://github.com/IraKorshunova/folk-rnn/tree/master/data) to your own model of symbolic music composition.
#
#
# ### Prerequisites
#
# - You should have a running installation of [tensorflow](https://www.tensorflow.org/install/) and [keras](https://keras.io/).
# - You should know the concepts "recurrent neural networks", "LSTM", "training and validation data", "overfitting" and "early stopping".
#
# ### What you will learn
#
# - You will be guided through a data processing procedure and understand the importance of design choices in ANN modeling
# - You will learn how to define recurrent neural networks in keras and fit them to data.
# - You will be guided through a prototyping procedure for the application of deep learning to a specific domain.
# - You will get in contact with concepts discussed later in the lecture, like "overfitting", "LSTM network", and "Generative model".
# - You will learn to be more patient :) Some fits may take your computer quite a bit of time; run them over night.
#
# ### Evaluation criteria
#
# The evaluation is (mostly) based on the figures you submit and your answer sentences.
# We will only do random tests of your code and not re-run the full notebook. Please ensure that your notebook is fully executed before handing it in.

# %% [markdown]
# ## Functions and imports
#
# For your convenience we import some libraries and provide some functions below. Some libraries (`midi` and `music21==5.1.0`) should be added. If you work with the docker image, pull it `docker pull zifeo/artificial-neural-networks:cpu` before to get the latest version where these libraries are added and stop/relaunch the container (as stated in the instructions https://github.com/zifeo/artificial-neural-networks). If you work locally, be sure to import them. If you do not find the midi library for python3, install it with `python setup.py install` inside the `python3-midi` folder after cloning https://github.com/louisabraham/python3-midi.git.
#
# Finally, fill in your sciper number(s) for the random seed and simply run the following cell.

# %%
sciper = {'student_1': 250726, 
          'student_2': 238122}
seed = sciper['student_1'] + sciper['student_2']

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import os, sys

plt.rcParams['font.size'] = 28
plt.style.use('ggplot')
plt.rcParams["axes.grid"] = False
c = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams['figure.figsize'] = 8, 4

import keras
from keras.models import Model, load_model
from keras.layers import Input, Masking, TimeDistributed, Dense, Concatenate, Dropout, LSTM, GRU, SimpleRNN
from keras.optimizers import Adam
from keras.utils import np_utils
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import ModelCheckpoint

import midi
import music21

import copy
from collections import defaultdict

from keras.models import model_from_json
from pathlib import Path
import pickle

# %%
def plotMelody(P, T, dictionaries, PrP=None, PrT=None, H=None):
    """
    P: The pitch array (integer representation) or matrix (one-hot encoding)
    T: The duration array (integer representation) or matrix (one-hot encoding)
    dictionaries: The dictionaries relating integer to a pitch or duration
    PrP: (Optional) If provided with PrT, plot the transition probabilities
    PrT: (Optional) If provided with PrP, plot the transition probabilities
    H: (Optional) Add a plot with the hidden state dynamic sorted by frequency
    """
    P = np.asarray(P)
    T = np.asarray(T)
    if len(P.shape) == 1:#if array
        P = np_utils.to_categorical(P, len(dictionaries['P']))
    if len(T.shape) == 1:#if array
        T = np_utils.to_categorical(T, len(dictionaries['T']))
    
    xlim = [-1,np.where(P==1)[0][-1]+1]
    
    activeidxes = np.where(np.sum(P, axis=0)>1.)[0]
    plt.figure(figsize=(8,4))
    if PrP is not None:
        targets = np.where(P[:,activeidxes]==1)
        plt.imshow(PrP[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
        plt.scatter(targets[0]-1,targets[1], color='red',s=10, marker='.') 
    else:
        plt.imshow(P[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
    plt.ylim([-0.5,len(activeidxes)-0.5])
    plt.yticks(range(len(activeidxes)),[dictionaries["P"][i] for i in activeidxes])
    plt.tight_layout()
    plt.xlabel("$n$")
    plt.ylabel("$P[n]$")
    plt.xlim(xlim)
    plt.show()
    
    activeidxes = np.where(np.sum(T, axis=0)>1.)[0]
    plt.figure(figsize=(8,4))
    if PrT is not None:
        targets = np.where(T[:,activeidxes]==1)
        plt.imshow(PrT[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
        plt.scatter(targets[0]-1,targets[1], color='red',s=10, marker='.')
    else:
        plt.imshow(T[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
    plt.ylim([-0.5,len(activeidxes)-0.5])
    plt.yticks(range(len(activeidxes)),[dictionaries["T"][i] for i in activeidxes])
    plt.tight_layout()
    plt.xlabel("$n$")
    plt.ylabel("$T[n]$")
    plt.xlim(xlim)
    plt.show()
    
    
    if H is not None:
        diff = np.mean([[abs(j-i) for i,j in zip(H[:xlim[1]-1,k], H[1:xlim[1],k])] for k in range(H.shape[1])], axis=1)
        sortidx = np.argsort(-diff)
        H = H[:,sortidx]
        plt.figure(figsize=(8,4))
        plt.imshow(H.T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.seismic, vmin=-1, vmax=1)
        plt.xlim([-1,np.where(T==1)[0][-1]+1])
        plt.tight_layout()
        plt.xlabel("$n$")
        plt.ylabel("$H[n]$")
        plt.show()


def plotLearningCurves(History):
    
    log = History.history
    
    plt.figure(figsize=(8,4))
    plt.plot(log['YP_loss'], '--', c=c[0], label='Pitch train loss')
    plt.plot(log['val_YP_loss'], c=c[0], label='Pitch val loss')
    
    plt.plot(log['YT_loss'], '--', c=c[1], label='Dur train loss')
    plt.plot(log['val_YT_loss'], c=c[1], label='Dur val loss')
    plt.legend(loc='best')
    
    plt.figure(figsize=(8,4))
    plt.plot(log['YP_acc'], '--', c=c[0], label='Pitch train acc')
    plt.plot(log['val_YP_acc'], c=c[0], label='Pitch val acc')
    
    plt.plot(log['YT_acc'], '--', c=c[1], label='Dur train acc')
    plt.plot(log['val_YT_acc'], c=c[1], label='Dur val acc')
    plt.legend(loc='best')

def sample(preds, temperature=1.):
    """Helper function to sample an index from a probability array"""
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

def writeMIDI(xP, xT, dictionaries, label):

    # Instantiate a MIDI Pattern (contains a list of tracks)
    pattern = midi.Pattern(format = 0, resolution=480)
    # Instantiate a MIDI Track (contains a list of MIDI events)
    track = midi.Track()
    # Append the track to the pattern
    pattern.append(track)
    Events = []
    
    pseq = [dictionaries['P'][p] for p in xP]
    tseq = [dictionaries['T'][t] for t in xT]
    for t, p in zip(tseq, pseq):
        e = midi.NoteOnEvent(tick=0, velocity=90, pitch=p)
        track.append(e)
        e = midi.NoteOffEvent(tick=t, velocity=0, pitch=p)
        track.append(e)
        
    eot = midi.EndOfTrackEvent(tick=1)
    track.append(eot)
    # Save the pattern to disk
    midi.write_midifile(label, pattern)

# %% [markdown]
# ## Exercise 1 : Data processing
# ### Description
#
# For a real world application of ANNs, the original data should be translated into a representation understandable by an ANN. This step is often neglected but is of outmost importance. In order for you to better understand how ANN are applied to real world problems, the first step of this miniproject will guide you through a possible representation.
#
# Note that in general, your representation should be normalized in order to obtain homogeneous data from which a structure can be extracted by your ANN model. Importantly, all processing steps toward your representation should not (or minimally) distort your original data.
#
# To represent MIDI files, we provide you with a Python MIDI library. You should then
#
# 0. Download the MIDI tar file from [this link](https://github.com/IraKorshunova/folk-rnn/tree/master/data) and put it in a folder named "chorpus" at the same level of this notebook.
# 1. Parse the chorpus to extract the label of (a random subset of) the data (code is provided)
# 2. Read each MIDI file in the subset with the midi [library](https://github.com/louisabraham/python3-midi)
# 3. For each data sequence extract the sequence of MIDI notes defined by two dimensions ("P": the sequence of note pitches (integer between 0 and 127 representing a piano key), "T": the sequence of note durations.
# 4. Select two melodies and display them both as sequences of MIDI events and sequence of notes in two dimensions. Control that your representation is correct.
#
# For step 3, you should learn how MIDI files are constructed. Below, we give a minimal explanation and some code for this particular project. For a more complete explanation, look for MIDI in your favorite search engine. Given this dataset, you can observe that it is monophonic (one note at a time) and there's a small delay (1 tick) inbetween each note. You could decide to ignore this delay or correct (recommanded) for it.
#
# A MIDI files is composed of timed events of many kinds. For this project, we focus on the events related to notes being played or stopped. Those are MIDI events "Note Off" and "Note On". Each event is timed with respect with the previous one (dt). The duration of a note is therefore given by the cummulated dt inbetween the event associated to a note's onset and the event associated with the same note's offset.

# %% [markdown]
# ### Minimal code to read MIDI files

# %%
def display(midi_file="chorpus/sessiontune0.mid"):
    #index 0 for first track only
    events = midi.read_midifile(midi_file)[0] 
    tick = 0
    print(midi_file)
    print("#"*40)
    print("tick \t pitch \t message \t velocity")
    print("#"*40+'\n')
    for n, event in enumerate(events):
        tick += event.tick
        if event.name in ['Note On', 'Note Off']:
            if n<13 or n>len(events)-10:
                print("%i \t %i \t %s \t %i"%(tick, event.data[0], event.name, event.data[1]))
            if n in range(20,23):
                print(". \t . \t . \t \t .")
    print("#"*40+'\n')

display()

datapath = "chorpus/"
dataset = {}
np.random.seed(seed)

for filename in os.listdir(datapath):
    if filename.endswith("mid"):
        label = filename[:-4]
        #Down sample dataset
        if np.random.rand() < 0.1:
            dataset[label] = {"T":[], "P": []}
print("%i/%i melodies retained"%(len(list(dataset.keys())), len(os.listdir(datapath))))
# Out:
# chorpus/sessiontune0.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 67 	 Note On 	 105
# 240 	 67 	 Note Off 	 0
# 241 	 64 	 Note On 	 80
# 480 	 64 	 Note Off 	 0
# 481 	 64 	 Note On 	 80
# 720 	 64 	 Note Off 	 0
# 721 	 64 	 Note On 	 95
# 1200 	 64 	 Note Off 	 0
# 1201 	 62 	 Note On 	 80
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 33601 	 67 	 Note On 	 80
# 33840 	 67 	 Note Off 	 0
# 33841 	 69 	 Note On 	 95
# 34080 	 69 	 Note Off 	 0
# 34081 	 71 	 Note On 	 80
# 34320 	 71 	 Note Off 	 0
# 34321 	 72 	 Note On 	 80
# 34560 	 72 	 Note Off 	 0
# ########################################
#
# 4586/45853 melodies retained

# %% [markdown]
# ### Solution

# %%
def parseMIDI(midi_file):
    events = midi.read_midifile(midi_file)[0] #index 0 for first track only  
    T = []
    P = []
    for n, event in enumerate(events):
        if event.name == 'Note Off':
            pitch = event.data[0]
            time = event.tick
            if time > 0:
                P.append(pitch)
                T.append(time - 1)
            
    assert len(P) == len(T)
    return P, T

for label in list(dataset.keys()):
    Pseq, Tseq = parseMIDI(datapath+label+".mid")
    dataset[label]['T']= Tseq
    dataset[label]['P']= Pseq

for label in np.random.choice(list(dataset.keys()), 2):
    print(label)
    print("MIDI events")
    display(datapath+label+".mid")
    print("Note representation")
    print(dataset[label])
    print('/n')
# Out:
# sessiontune17751
# MIDI events
# chorpus/sessiontune17751.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 72 	 Note On 	 105
# 240 	 72 	 Note Off 	 0
# 241 	 69 	 Note On 	 80
# 480 	 69 	 Note Off 	 0
# 481 	 69 	 Note On 	 80
# 720 	 69 	 Note Off 	 0
# 721 	 72 	 Note On 	 80
# 960 	 72 	 Note Off 	 0
# 961 	 71 	 Note On 	 95
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 44881 	 71 	 Note On 	 80
# 45120 	 71 	 Note Off 	 0
# 45121 	 72 	 Note On 	 95
# 45600 	 72 	 Note Off 	 0
# 45601 	 72 	 Note On 	 80
# 45840 	 72 	 Note Off 	 0
# 45841 	 71 	 Note On 	 80
# 46080 	 71 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238], 'P': [72, 69, 69, 72, 71, 67, 69, 71, 72, 67, 64, 65, 64, 62, 67, 72, 67, 69, 72, 67, 64, 65, 64, 62, 64, 65, 67, 69, 71, 72, 69, 69, 72, 71, 67, 69, 71, 72, 67, 64, 65, 64, 62, 67, 60, 64, 64, 60, 64, 67, 64, 65, 67, 69, 71, 72, 72, 71, 72, 67, 72, 74, 76, 74, 76, 77, 79, 81, 79, 77, 76, 74, 72, 67, 72, 74, 76, 77, 76, 67, 74, 76, 76, 74, 72, 67, 69, 71, 72, 67, 72, 74, 76, 74, 76, 77, 79, 81, 79, 77, 76, 74, 72, 67, 69, 72, 67, 64, 65, 64, 62, 64, 65, 67, 69, 71, 72, 74, 76, 74, 72, 67, 69, 72, 67, 64, 65, 64, 62, 67, 72, 74, 76, 74, 72, 74, 76, 77, 79, 81, 79, 77, 76, 74, 72, 74, 76, 74, 72, 67, 69, 72, 67, 64, 65, 64, 62, 67, 60, 64, 64, 60, 64, 67, 64, 65, 67, 69, 71, 72, 72, 71]}
# /n
# sessiontune19457
# MIDI events
# chorpus/sessiontune19457.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 59 	 Note On 	 105
# 240 	 59 	 Note Off 	 0
# 241 	 62 	 Note On 	 80
# 480 	 62 	 Note Off 	 0
# 481 	 62 	 Note On 	 80
# 960 	 62 	 Note Off 	 0
# 961 	 64 	 Note On 	 95
# 1200 	 64 	 Note Off 	 0
# 1201 	 62 	 Note On 	 80
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 60241 	 62 	 Note On 	 80
# 60480 	 62 	 Note Off 	 0
# 60481 	 64 	 Note On 	 95
# 60720 	 64 	 Note Off 	 0
# 60721 	 67 	 Note On 	 80
# 60960 	 67 	 Note Off 	 0
# 60961 	 67 	 Note On 	 80
# 61440 	 67 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478], 'P': [59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 69, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 69, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 71, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 62, 67, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 71, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 62, 67, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67]}
# /n

# %% [markdown]
# ## Exercise 2: Tokenzation and translation to integer
# ### Description
#
# Now you should have a "dataset" dictionary where each entry corresponds to one melody example from a subset of the full dataset. In turn, every melody example is represented by a dictionary with two sequences: the "P" entry being the sequence of pitches and the "T" entry, the sequence of durations. Here, you will implement the first steps to translate this dataset in a language that can be read by your ANN models. To achieve that, we will later use the [one-hot encoding scheme](https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/), which will associate each input (and output) unit of your network to a unique pitch or duration. In your network, these units will then be sequentially activated in the same order as their corresponding pitch/duration in your dataset. And at each note, the model will be trained to approximate the probability distributions of the upcoming pitch and duration.
#
# 1. Gather in a list of all possible pitches and durations in your dataset. These two lists will be your "dictionaries" translating a pitch/duration to a unique integer between 0 and the number of entries (-1) in the pitch/duration dictionary.
# 2. Translate the pitch/duration sequence of each melody to the integer representation.
# 3. Select randomly two melodies and display them in the note representation and translated to integer. Check that the translation is correct.

# %% [markdown]
# ### Solution

# %%
def get_dicts(dataset):
    set_T = set()
    [set_T.update(dataset[label]['T']) for label in dataset.keys()]
    set_P = set()
    [set_P.update(dataset[label]['P']) for label in dataset.keys()]
    dict_T = {k: v for v, k in enumerate(list(set_T))}
    dict_P = {k: v for v, k in enumerate(list(set_P))}
    return {'T': dict_T, 'P': dict_P}, {'T': {v: k for k, v in dict_T.items()}, 'P': {v: k for k, v in dict_P.items()}}

# %%
def tokenize(dataset):
    dictionaries, inv = get_dicts(dataset)
    dataset_int = copy.deepcopy(dataset)
    for label in dataset_int.keys():
        dataset_int[label]['T'] = [dictionaries['T'][v] for v in dataset_int[label]['T']]
        dataset_int[label]['P'] = [dictionaries['P'][v] for v in dataset_int[label]['P']]
    return dataset_int, inv

# %%
dataset_int, dicts = tokenize(dataset)

# %%
for label in np.random.choice(list(dataset.keys()), 2):
    print(label)
    print("MIDI events")
    display(datapath+label+".mid")
    print("Note representation")
    print(dataset_int[label])
    print('/n')
# Out:
# sessiontune22329
# MIDI events
# chorpus/sessiontune22329.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 79 	 Note On 	 105
# 240 	 79 	 Note Off 	 0
# 241 	 77 	 Note On 	 80
# 480 	 77 	 Note Off 	 0
# 481 	 74 	 Note On 	 105
# 720 	 74 	 Note Off 	 0
# 721 	 67 	 Note On 	 80
# 960 	 67 	 Note Off 	 0
# 961 	 67 	 Note On 	 80
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 61681 	 81 	 Note On 	 80
# 61920 	 81 	 Note Off 	 0
# 61921 	 79 	 Note On 	 95
# 62400 	 79 	 Note Off 	 0
# 62401 	 79 	 Note On 	 80
# 62640 	 79 	 Note Off 	 0
# 62641 	 77 	 Note On 	 80
# 62880 	 77 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61], 'P': [31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 17, 17, 17, 17, 12, 17, 21, 24, 26, 19, 19, 19, 19, 23, 26, 31, 33, 34, 33, 31, 29, 26, 31, 31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 19, 17, 19, 21, 23, 24, 29, 26, 31, 31, 28, 29, 28, 26, 24, 21, 17, 24, 21, 19, 31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 17, 17, 17, 17, 12, 17, 21, 24, 26, 19, 19, 19, 19, 23, 26, 31, 33, 34, 33, 31, 29, 26, 31, 31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 19, 17, 19, 21, 23, 24, 29, 26, 31, 31, 28, 29, 28, 26, 24, 21, 17, 24, 21, 19, 26, 28, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 31, 29, 33, 31, 26, 28, 28, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 33, 38, 40, 38, 36, 33, 35, 36, 33, 35, 38, 36, 33, 31, 26, 28, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 31, 29, 33, 31, 26, 28, 28, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 33, 38, 40, 38, 36, 33, 35, 36, 33, 35, 38, 36, 33, 31, 31, 29]}
# /n
# sessiontune36502
# MIDI events
# chorpus/sessiontune36502.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 63 	 Note On 	 105
# 240 	 63 	 Note Off 	 0
# 241 	 62 	 Note On 	 80
# 480 	 62 	 Note Off 	 0
# 481 	 63 	 Note On 	 80
# 720 	 63 	 Note Off 	 0
# 721 	 65 	 Note On 	 80
# 960 	 65 	 Note Off 	 0
# 961 	 66 	 Note On 	 95
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 18001 	 72 	 Note On 	 80
# 18240 	 72 	 Note Off 	 0
# 18241 	 73 	 Note On 	 95
# 18480 	 73 	 Note Off 	 0
# 18481 	 70 	 Note On 	 80
# 18720 	 70 	 Note Off 	 0
# 18721 	 68 	 Note On 	 80
# 18960 	 68 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 52, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 12, 12, 12, 61, 61, 52, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 12, 12, 12, 61, 61, 52, 61, 61, 52, 61, 61, 61, 61, 61], 'P': [15, 14, 15, 17, 18, 25, 20, 22, 25, 20, 17, 18, 15, 15, 15, 13, 18, 20, 22, 24, 25, 25, 20, 17, 13, 13, 13, 13, 8, 13, 17, 13, 17, 18, 20, 22, 24, 25, 24, 25, 22, 25, 20, 17, 15, 15, 13, 18, 20, 22, 24, 25, 25, 20, 17, 13, 13, 13, 13, 8, 13, 17, 13, 17, 18, 20, 22, 24, 25, 24, 25, 27, 27, 24, 25, 22, 20]}
# /n

# %% [markdown]
# ## Exercise 3: Data reprocessing
# ### Description
#
# Before moving to the implementation of your RNN generative model of note transition, you will perform data exploration and modification. This step will allow your model to get the most out of your original data as well as ensuring some features such as transposition invariance.
#
# To further improve your model, you might want to reconsider your original data. Many different approaches can be undertaken. Here you are asked to implement the a rare event suppression method and transposition invariance.
#
# **Rare event suppression** If a unit in your network is associated to a duration that happens very rarely in your data, a possible simplification consists in removing the melodies conaining these rare events from your dataset.
# 1. Plot and comment the histogram of durations in your entire dataset. Use the labels from the original duration values (rather than the integer representation).
# 2. Based on your observations, remove from your dataset melodies containing very rare durations. Adjust the rejection threshold such that at most 5% of the melodies are dicarded with this step.
# 3. Recompute the duration dictionary based on your filtered dataset and plot the new histogram of durations.
#
# **Transposition invariance** A melody is perceived similarly by the human ear if it's shifted up or down by a constant offset (see [transposition](https://en.wikipedia.org/wiki/Transposition_(music))). Here, you will force your model to be transposition invariant. For this you can choose to use one of two orthogonal methods. The first consists in transposing every melody into a common tonality (C Major/A minor). On the other hand, the second consists in transposing each melody in all possible keys. The second method will increase your dataset size by a factor bigger than 11! As the training time is directly related with the dataset size, to save computing time, we recomand that you implement the first option.
#
# ***Pitch normalization***
# 1. Use the provided function to create a new dataset where all melodies are transposed to C Major/A minor.
# 2. Plot the histograms of the pitches before and after transposition.
#
# Finally, you shoud recompute the tokenization step for your brand new filtered and normalized dataset.

# %% [markdown]
# ### Solution

# %%
def transposeDataset(dataset):
    transposed_dataset = {}

    for label in list(dataset.keys()):
        transposed_dataset[label] = {}
        score = music21.converter.parse(datapath+label+".mid")
        key = score.analyze('key')
        if key.mode == "major":
            i = music21.interval.Interval(key.tonic, music21.pitch.Pitch('C'))
        elif key.mode == "minor":
            i = music21.interval.Interval(key.tonic, music21.pitch.Pitch('A'))
        i = i.semitones
        transposed_dataset[label]['P'] = [p+i for p in dataset[label]['P']]
        transposed_dataset[label]['T'] = dataset[label]['T']
        
    return transposed_dataset

# %%
plt.hist([e for label in dataset.keys() for e in set(dataset[label]['T'])], bins=50);

# %%
tot_nb_melody = len(dataset.keys())

dataset_cleaned = copy.deepcopy(dataset)

d = defaultdict(list)

[d[e].append(label) for label in dataset.keys() for e in set(dataset[label]['T'])];

# %%
labels_to_remove = set()
duration_to_remove = 0
for time in sorted(d, key=lambda k: len(d[k]), reverse=False):
    if len(set(labels_to_remove).union(set(d[time]))) < 0.05 * tot_nb_melody:
        labels_to_remove = labels_to_remove.union(d[time])
        duration_to_remove += 1
    else:
        break

# %%
for label in labels_to_remove:
    del dataset_cleaned[label]

# %%
duration_to_remove/len(d.keys())
# Out:
# 0.7536231884057971

# %%
dataset_cleaned = (dataset_cleaned)

# %%
len(set([(dataset_cleaned[label]['T'][i], dataset_cleaned[label]['P'][i]) for label in dataset_cleaned for i in range(len(dataset_cleaned[label]['T']))]))
# Out:
# 582

# %% [markdown]
# **Question**: How much did you reduce the space of possible durations with your rare event suppression procedure? What is the impact in term of training time?
#
# **Answer**: We reduced the number of possible durations by a factor of around 4. TODO: IMPACT ON TRAINING TIME
#
# **Question**: Explain why and how both transposition to a single tonality and to all possible tonalities can yield transposition invariance in your model.
#
# **Answer**:
#
# **Question**: In terms of number of dimensions, what would have been the impact of keeping the joint represenation of a note duration and pitch (vs separating the two features)?
#
# **Answer**: After preprocessing, we would have had a bit less than 600 dimensions vs around 70 when we separate.
#
# **Question**: How would the distribution of notes in the joint representation differ from the distributions in the pitch and duration only representations (as shown by your histograms above)?
#
# **Answer**:

# %% [markdown]
# ## Exercise 4: One-hot and zero-padding
# ### Description
#
# The last few steps to be able to feed (note by note) your music scores to a RNN model are
# 1. Transform the sequence of integers into a sequence of vectors in the one-hot encoding scheme.
# 2. Homegenize the length of each sequence
#
# **One-hot encode** You can implement your own integer to one-hot code. For this use the numpy library and the suitable datatype. Alternatively, Keras provides a [built in one-hot encoding scheme](https://keras.io/utils/#to_categorical). After this step, for each melody, you should have two similar length matrices with one representing the sequence of note pitches and the other the sequence of note durations.
# 1. Code the integer representation into matrices of one-hot vectors
#
# **Zero-padding** Most deep learning libraries, including Keras, require that you specify the shape of the input data. As such, you cannot have variable length inputs per-se. The trick to handle them is [zero-padding](https://keras.io/preprocessing/sequence/#pad_sequences). Provided with the [Masking Layer](https://keras.io/layers/core/#masking) Keras will then ignore time steps where all inputs are 0.
# 1. Extend the end of each melody matrices with vectors containing only zeros until all melodies have the same size. For simplicity, use the Keras pad_sequences function. There might be some rare very long melodies in your dataset, a possible choice is to set the 'maxlen' argument of pad_sequences to the mean+2std of the melody lengths. This ensure that 95% of your melodies would end before being truncated.
# 2. Check and display the dimension of the resulting tensors. Typically, the tensor representing the sequence of pitches should be of shape [number of melodies x number of notes x number of entries in the pitch dictionary] and the tensor representing the sequence of durations [number of melodies x number of notes x number of entries in the duration dictionary]
#
# To check if this step was done correctly use the provided plotMelody function. For two randomly selected melodies, call the plotMelody function before and after one-hot/zero-pad. You should obtain the same plots (or slightly truncated if you randomly selected one belonging to 5% longest).
#
# Finally, we strongly suggest that you save your preprocessed data now.

# %% [markdown]
# ### Solution

# %%
dataset_cleaned_int, dicts = tokenize(dataset_cleaned)

# %%
seq = [len(dataset_cleaned_int[label]['T']) for label in dataset_cleaned_int.keys()]
mean = np.mean(seq)
std = np.std(seq)

n_notes = int(mean + 2*std)

# %%
for label in dataset_cleaned_int.keys():
    dataset_cleaned_int[label]['T'] = np_utils.to_categorical(dataset_cleaned_int[label]['T'], len(dicts['T'].keys()))
    dataset_cleaned_int[label]['P'] = np_utils.to_categorical(dataset_cleaned_int[label]['P'], len(dicts['P'].keys()))

# %%
label = np.random.choice(list(dataset.keys()), 1)[0]

plotMelody(dataset_cleaned_int[label]['P'], dataset_cleaned_int[label]['T'], dicts)

# %%
for label_ in dataset_cleaned_int.keys():
    dataset_cleaned_int[label_]['T'] = pad_sequences(dataset_cleaned_int[label_]['T'].T, maxlen=n_notes, padding='post', truncating='post').T
    dataset_cleaned_int[label_]['P'] = pad_sequences(dataset_cleaned_int[label_]['P'].T, maxlen=n_notes, padding='post', truncating='post').T

# %%
plotMelody(dataset_cleaned_int[label]['P'], dataset_cleaned_int[label]['T'], dicts)

# %%
dim_p = len(dicts['P'].keys())
dim_t = len(dicts['T'].keys())

# %% [markdown]
# ## Exercise 5: Building and training a generative model of  note transition with the Keras functional API
# ### Description
#
# The Keras Sequential model is very efficient for fast prototyping, however suffers from a lack of design liberty. The Keras Functional API is only slightly more complex but allows for more control on the different parts of your model. You will be using the Functional API for the rest of this project. Please read carefully the [documentation](https://keras.io/getting-started/sequential-model-guide/).
#
# Here, you will be constructing your RNN model of note transition. To achieve that, your model should be trained to approximate the probability distribution of the upcoming note (observed as two output softmax layers - one for pitch and one for duration) given the current note (given as input) and the model internal representation of the history of notes (its hidden state). To achieve that, set the Keras RNN layer argument "return_sequences" to True when building your model. Doing this will give you an output for each note, rather than a single output at the end of the sequence. During training, the target at each time step is the next note pitch and duration.
#
# You are free to use your own architecture but make sure to use at least 128 hidden units, Masking, and dropout to prevent overfitting. Your model should have two output (softmax) layers, one related to the pitch predictions that you should name `YP`, and the other related to the duration predictions `YT`. You should monitor both the loss (categorical_crossentropy) and the accuracy. For your best model, you should reach 40%/75% accuracy on the pitch/duration predictions.
#
# 1. Train your first model composed of SimpleRNN cells for min 250 epochs and save the model/parameters that lead to the higher accuracy on the validating set. Use a validation split of 0.2. Try  If you correctly named the output layers (`YP` and `YT`) use the provided `plotLearningCurves(History)` function to plot the learning curves by giving the History object returned by the Keras fit function as argument.
# 2. Train a second model where you replaced the SimpleRNN units with GRUs (LSTM unit equivalent that requires less parameters). Make sure you use the same hyperparameters as before. Plot the learning curves.
# 3. On a single plot, adapt the `plotLearningCurves(History)` function to compare the validation learning curves of the simpleRNN and GRU models. In other words, plot the validation loss vs epoch for pitch/duration for the simpleRNN and GRU models. Do the same for accuracies.

# %% [markdown]
# ### Solution

# %%
def buildModel(dictionaries, batch_length, dropout=0.2, activation='GRU', Hsize=128):
    X = dict()
    H = dict()
    M = dict()
    Y = dict()
    
    X['T'] = Input(shape=(batch_length, len(dictionaries['T'])), name="XT")
    X['P'] = Input(shape=(batch_length, len(dictionaries['P'])), name="XP")
    
    M['T'] = Masking(mask_value=0., name="MT")(X['T'])
    M['P'] = Masking(mask_value=0., name="MP")(X['P'])
    
    H['1'] = Concatenate(name="MergeX")([M['T'], M['P']])
    if activation == 'GRU':
        H['2'] = GRU(128, return_sequences=True)(H['1'])
        H['2'] = Dropout(0.3)(H['2'])
        H['2'] = GRU(128, return_sequences=True)(H['2'])
        H['2'] = Dense(128)(H['2'])
        H['2'] = Dropout(0.3)(H['2'])
    elif activation == 'LSTM':
        #Your hidden layer(s) architecture with LSTM (For your own curiosity, not required for the project)
        print('Sorry, not implemented yet')
        return None
    elif activation == 'RNN':
        H['2'] = SimpleRNN(128, return_sequences=True)(H['1'])
        H['2'] = Dropout(0.3)(H['2'])
        H['2'] = SimpleRNN(128, return_sequences=True)(H['2'])
        H['2'] = Dense(128)(H['2'])
        H['2'] = Dropout(0.3)(H['2'])

    Y['T'] = TimeDistributed(Dense(len(dictionaries['T']), activation='softmax'), name='YT')(H['2'])
    Y['P'] = TimeDistributed(Dense(len(dictionaries['P']), activation='softmax'), name='YP')(H['2'])
    
    model = Model(inputs = [X['T'], X['P']], outputs = [Y['T'], Y['P']])
    opt = Adam() 
    model.compile(
        loss='categorical_crossentropy', 
        optimizer=opt,
        metrics=['acc'])
    
    
    return model

print('RNN model')
RNNmodel = buildModel(dicts, 
                      batch_length=n_notes-1,
                      activation='RNN')
RNNmodel.summary()

print('GRU model')
GRUmodel = buildModel(dicts, 
                      batch_length=n_notes-1,
                      activation='GRU')
GRUmodel.summary()
# Out:
# RNN model
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# XT (InputLayer)                 (None, 387, 17)      0
# __________________________________________________________________________________________________
# XP (InputLayer)                 (None, 387, 47)      0
# __________________________________________________________________________________________________
# MT (Masking)                    (None, 387, 17)      0           XT[0][0]
# __________________________________________________________________________________________________
# MP (Masking)                    (None, 387, 47)      0           XP[0][0]
# __________________________________________________________________________________________________
# MergeX (Concatenate)            (None, 387, 64)      0           MT[0][0]
#                                                                  MP[0][0]
# __________________________________________________________________________________________________
# simple_rnn_3 (SimpleRNN)        (None, 387, 128)     24704       MergeX[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 387, 128)     0           simple_rnn_3[0][0]
# __________________________________________________________________________________________________
# simple_rnn_4 (SimpleRNN)        (None, 387, 128)     32896       dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 387, 128)     16512       simple_rnn_4[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 387, 128)     0           dense_7[0][0]
# __________________________________________________________________________________________________
# YT (TimeDistributed)            (None, 387, 17)      2193        dropout_6[0][0]
# __________________________________________________________________________________________________
# YP (TimeDistributed)            (None, 387, 47)      6063        dropout_6[0][0]
# ==================================================================================================
# Total params: 82,368
# Trainable params: 82,368
# Non-trainable params: 0
# __________________________________________________________________________________________________
# GRU model
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# XT (InputLayer)                 (None, 387, 17)      0
# __________________________________________________________________________________________________
# XP (InputLayer)                 (None, 387, 47)      0
# __________________________________________________________________________________________________
# MT (Masking)                    (None, 387, 17)      0           XT[0][0]
# __________________________________________________________________________________________________
# MP (Masking)                    (None, 387, 47)      0           XP[0][0]
# __________________________________________________________________________________________________
# MergeX (Concatenate)            (None, 387, 64)      0           MT[0][0]
#                                                                  MP[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 387, 128)     74112       MergeX[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 387, 128)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 387, 128)     98688       dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 387, 128)     16512       gru_4[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 387, 128)     0           dense_10[0][0]
# __________________________________________________________________________________________________
# YT (TimeDistributed)            (None, 387, 17)      2193        dropout_8[0][0]
# __________________________________________________________________________________________________
# YP (TimeDistributed)            (None, 387, 47)      6063        dropout_8[0][0]
# ==================================================================================================
# Total params: 197,568
# Trainable params: 197,568
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
data = {'XT': [], 'XP': []}
for label in dataset_cleaned_int.keys():
    data['XT'].append(dataset_cleaned_int[label]['T'])
    data['XP'].append(dataset_cleaned_int[label]['P'])
data['XT'] = np.array(data['XT'])
data['XP'] = np.array(data['XP'])

# %%
y = {'YT': [], 'YP': []}
y['YT'] = data['XT'][:,1:,:]
y['YP'] = data['XP'][:,1:,:]

x = {'YT': [], 'YP': []}
x['XT'] = data['XT'][:,:-1,:]
x['XP'] = data['XP'][:,:-1,:]

# %%
class SavedHistory(object):
    pass

# %%
rnn_file = Path("model_rnn.json")
if not rnn_file.is_file():
    history = RNNmodel.fit(x, y, batch_size=512, epochs=250, validation_split=0.2)
    with open('rnn_history', 'wb') as file_pi:
        pickle.dump(history.history, file_pi)
    model_json = RNNmodel.to_json()
    with open("model_rnn.json", "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    RNNmodel.save_weights("model_rnn.h5")
    print("Saved rnn model to disk")
else:
    with open('rnn_history', 'rb') as file_pi:
        h = pickle.load(file_pi)
    history = SavedHistory()
    history.history = h
    
    # load json and create model
    json_file = open('model_rnn.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    
    RNNmodel = model_from_json(loaded_model_json)
    # load weights into new model
    RNNmodel.load_weights("model_rnn.h5")
    print("Loaded model from disk")
# Out:
# Train on 3503 samples, validate on 876 samples
# Epoch 1/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 5.4708 - YT_loss: 1.5579 - YP_loss: 3.9129 - YT_acc: 0.6007 - YP_acc: 0.0318 - val_loss: 4.5054 - val_YT_loss: 1.0506 - val_YP_loss: 3.4548 - val_YT_acc: 0.7219 - val_YP_acc: 0.0692
# Epoch 2/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 4.5363 - YT_loss: 1.0319 - YP_loss: 3.5044 - YT_acc: 0.7294 - YP_acc: 0.0672 - val_loss: 4.1306 - val_YT_loss: 0.9143 - val_YP_loss: 3.2163 - val_YT_acc: 0.7421 - val_YP_acc: 0.0888
# Epoch 3/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 4.2364 - YT_loss: 0.9403 - YP_loss: 3.2961 - YT_acc: 0.7462 - YP_acc: 0.0885 - val_loss: 3.8494 - val_YT_loss: 0.8892 - val_YP_loss: 2.9602 - val_YT_acc: 0.7458 - val_YP_acc: 0.1312
# Epoch 4/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 3.9590 - YT_loss: 0.9258 - YP_loss: 3.0332 - YT_acc: 0.7483 - YP_acc: 0.1157 - val_loss: 3.6248 - val_YT_loss: 0.8659 - val_YP_loss: 2.7589 - val_YT_acc: 0.7488 - val_YP_acc: 0.1510
# Epoch 5/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 3.7576 - YT_loss: 0.8942 - YP_loss: 2.8634 - YT_acc: 0.7542 - YP_acc: 0.1313 - val_loss: 3.4622 - val_YT_loss: 0.8492 - val_YP_loss: 2.6130 - val_YT_acc: 0.7539 - val_YP_acc: 0.1618
# Epoch 6/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 3.6234 - YT_loss: 0.8835 - YP_loss: 2.7398 - YT_acc: 0.7547 - YP_acc: 0.1425 - val_loss: 3.3481 - val_YT_loss: 0.8290 - val_YP_loss: 2.5191 - val_YT_acc: 0.7567 - val_YP_acc: 0.1808
# Epoch 7/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.5163 - YT_loss: 0.8636 - YP_loss: 2.6527 - YT_acc: 0.7586 - YP_acc: 0.1534 - val_loss: 3.2534 - val_YT_loss: 0.8126 - val_YP_loss: 2.4407 - val_YT_acc: 0.7583 - val_YP_acc: 0.1910
# Epoch 8/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 3.4163 - YT_loss: 0.8500 - YP_loss: 2.5663 - YT_acc: 0.7603 - YP_acc: 0.1645 - val_loss: 3.1768 - val_YT_loss: 0.8050 - val_YP_loss: 2.3718 - val_YT_acc: 0.7586 - val_YP_acc: 0.2033
# Epoch 9/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 3.3383 - YT_loss: 0.8347 - YP_loss: 2.5036 - YT_acc: 0.7625 - YP_acc: 0.1726 - val_loss: 3.1121 - val_YT_loss: 0.7895 - val_YP_loss: 2.3227 - val_YT_acc: 0.7611 - val_YP_acc: 0.2143
# Epoch 10/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 3.2691 - YT_loss: 0.8206 - YP_loss: 2.4485 - YT_acc: 0.7641 - YP_acc: 0.1806 - val_loss: 3.0573 - val_YT_loss: 0.7802 - val_YP_loss: 2.2771 - val_YT_acc: 0.7629 - val_YP_acc: 0.2231
# Epoch 11/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.2121 - YT_loss: 0.8087 - YP_loss: 2.4033 - YT_acc: 0.7658 - YP_acc: 0.1877 - val_loss: 3.0111 - val_YT_loss: 0.7724 - val_YP_loss: 2.2387 - val_YT_acc: 0.7637 - val_YP_acc: 0.2320
# Epoch 12/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.1600 - YT_loss: 0.7982 - YP_loss: 2.3617 - YT_acc: 0.7675 - YP_acc: 0.1957 - val_loss: 2.9668 - val_YT_loss: 0.7622 - val_YP_loss: 2.2046 - val_YT_acc: 0.7651 - val_YP_acc: 0.2400
# Epoch 13/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.1142 - YT_loss: 0.7864 - YP_loss: 2.3278 - YT_acc: 0.7695 - YP_acc: 0.2030 - val_loss: 2.9264 - val_YT_loss: 0.7525 - val_YP_loss: 2.1739 - val_YT_acc: 0.7667 - val_YP_acc: 0.2482
# Epoch 14/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.0719 - YT_loss: 0.7756 - YP_loss: 2.2963 - YT_acc: 0.7706 - YP_acc: 0.2109 - val_loss: 2.8911 - val_YT_loss: 0.7447 - val_YP_loss: 2.1464 - val_YT_acc: 0.7680 - val_YP_acc: 0.2560
# Epoch 15/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 3.0353 - YT_loss: 0.7671 - YP_loss: 2.2683 - YT_acc: 0.7720 - YP_acc: 0.2167 - val_loss: 2.8573 - val_YT_loss: 0.7362 - val_YP_loss: 2.1212 - val_YT_acc: 0.7697 - val_YP_acc: 0.2632
# Epoch 16/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.9997 - YT_loss: 0.7577 - YP_loss: 2.2420 - YT_acc: 0.7738 - YP_acc: 0.2241 - val_loss: 2.8255 - val_YT_loss: 0.7282 - val_YP_loss: 2.0974 - val_YT_acc: 0.7716 - val_YP_acc: 0.2666
# Epoch 17/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.9689 - YT_loss: 0.7504 - YP_loss: 2.2185 - YT_acc: 0.7753 - YP_acc: 0.2284 - val_loss: 2.7978 - val_YT_loss: 0.7213 - val_YP_loss: 2.0765 - val_YT_acc: 0.7732 - val_YP_acc: 0.2718
# Epoch 18/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.9393 - YT_loss: 0.7417 - YP_loss: 2.1975 - YT_acc: 0.7771 - YP_acc: 0.2347 - val_loss: 2.7721 - val_YT_loss: 0.7142 - val_YP_loss: 2.0579 - val_YT_acc: 0.7761 - val_YP_acc: 0.2753
# Epoch 19/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.9132 - YT_loss: 0.7353 - YP_loss: 2.1779 - YT_acc: 0.7788 - YP_acc: 0.2391 - val_loss: 2.7499 - val_YT_loss: 0.7091 - val_YP_loss: 2.0407 - val_YT_acc: 0.7772 - val_YP_acc: 0.2803
# Epoch 20/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.8889 - YT_loss: 0.7290 - YP_loss: 2.1600 - YT_acc: 0.7807 - YP_acc: 0.2442 - val_loss: 2.7292 - val_YT_loss: 0.7035 - val_YP_loss: 2.0257 - val_YT_acc: 0.7797 - val_YP_acc: 0.2847
# Epoch 21/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.8668 - YT_loss: 0.7227 - YP_loss: 2.1441 - YT_acc: 0.7823 - YP_acc: 0.2484 - val_loss: 2.7094 - val_YT_loss: 0.6972 - val_YP_loss: 2.0122 - val_YT_acc: 0.7818 - val_YP_acc: 0.2875
# Epoch 22/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.8450 - YT_loss: 0.7154 - YP_loss: 2.1296 - YT_acc: 0.7845 - YP_acc: 0.2530 - val_loss: 2.6922 - val_YT_loss: 0.6923 - val_YP_loss: 2.0000 - val_YT_acc: 0.7834 - val_YP_acc: 0.2922
# Epoch 23/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.8268 - YT_loss: 0.7115 - YP_loss: 2.1153 - YT_acc: 0.7857 - YP_acc: 0.2566 - val_loss: 2.6770 - val_YT_loss: 0.6880 - val_YP_loss: 1.9890 - val_YT_acc: 0.7846 - val_YP_acc: 0.2954
# Epoch 24/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.8088 - YT_loss: 0.7059 - YP_loss: 2.1029 - YT_acc: 0.7869 - YP_acc: 0.2609 - val_loss: 2.6612 - val_YT_loss: 0.6828 - val_YP_loss: 1.9784 - val_YT_acc: 0.7878 - val_YP_acc: 0.2986
# Epoch 25/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.7913 - YT_loss: 0.7009 - YP_loss: 2.0904 - YT_acc: 0.7886 - YP_acc: 0.2647 - val_loss: 2.6497 - val_YT_loss: 0.6795 - val_YP_loss: 1.9702 - val_YT_acc: 0.7887 - val_YP_acc: 0.3023
# Epoch 26/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.7787 - YT_loss: 0.6976 - YP_loss: 2.0811 - YT_acc: 0.7899 - YP_acc: 0.2680 - val_loss: 2.6421 - val_YT_loss: 0.6796 - val_YP_loss: 1.9626 - val_YT_acc: 0.7890 - val_YP_acc: 0.3043
# Epoch 27/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.7679 - YT_loss: 0.6961 - YP_loss: 2.0718 - YT_acc: 0.7913 - YP_acc: 0.2704 - val_loss: 2.6296 - val_YT_loss: 0.6750 - val_YP_loss: 1.9546 - val_YT_acc: 0.7924 - val_YP_acc: 0.3072
# Epoch 28/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.7543 - YT_loss: 0.6919 - YP_loss: 2.0624 - YT_acc: 0.7925 - YP_acc: 0.2741 - val_loss: 2.6208 - val_YT_loss: 0.6719 - val_YP_loss: 1.9489 - val_YT_acc: 0.7925 - val_YP_acc: 0.3114
# Epoch 29/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.7425 - YT_loss: 0.6875 - YP_loss: 2.0550 - YT_acc: 0.7935 - YP_acc: 0.2759 - val_loss: 2.6126 - val_YT_loss: 0.6697 - val_YP_loss: 1.9429 - val_YT_acc: 0.7935 - val_YP_acc: 0.3135
# Epoch 30/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.7298 - YT_loss: 0.6836 - YP_loss: 2.0462 - YT_acc: 0.7947 - YP_acc: 0.2798 - val_loss: 2.6045 - val_YT_loss: 0.6665 - val_YP_loss: 1.9380 - val_YT_acc: 0.7945 - val_YP_acc: 0.3154
# Epoch 31/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.7210 - YT_loss: 0.6813 - YP_loss: 2.0397 - YT_acc: 0.7954 - YP_acc: 0.2821 - val_loss: 2.5967 - val_YT_loss: 0.6645 - val_YP_loss: 1.9321 - val_YT_acc: 0.7953 - val_YP_acc: 0.3181
# Epoch 32/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.7113 - YT_loss: 0.6783 - YP_loss: 2.0331 - YT_acc: 0.7963 - YP_acc: 0.2845 - val_loss: 2.5896 - val_YT_loss: 0.6622 - val_YP_loss: 1.9274 - val_YT_acc: 0.7965 - val_YP_acc: 0.3191
# Epoch 33/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.7019 - YT_loss: 0.6749 - YP_loss: 2.0269 - YT_acc: 0.7975 - YP_acc: 0.2868 - val_loss: 2.5863 - val_YT_loss: 0.6632 - val_YP_loss: 1.9231 - val_YT_acc: 0.7972 - val_YP_acc: 0.3220
# Epoch 34/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.6951 - YT_loss: 0.6747 - YP_loss: 2.0205 - YT_acc: 0.7978 - YP_acc: 0.2890 - val_loss: 2.5793 - val_YT_loss: 0.6601 - val_YP_loss: 1.9193 - val_YT_acc: 0.7971 - val_YP_acc: 0.3235
# Epoch 35/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.6872 - YT_loss: 0.6721 - YP_loss: 2.0152 - YT_acc: 0.7987 - YP_acc: 0.2902 - val_loss: 2.5762 - val_YT_loss: 0.6601 - val_YP_loss: 1.9161 - val_YT_acc: 0.7989 - val_YP_acc: 0.3242
# Epoch 36/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.6804 - YT_loss: 0.6693 - YP_loss: 2.0111 - YT_acc: 0.7996 - YP_acc: 0.2919 - val_loss: 2.5683 - val_YT_loss: 0.6560 - val_YP_loss: 1.9123 - val_YT_acc: 0.7995 - val_YP_acc: 0.3264
# Epoch 37/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.6726 - YT_loss: 0.6678 - YP_loss: 2.0048 - YT_acc: 0.8003 - YP_acc: 0.2950 - val_loss: 2.5660 - val_YT_loss: 0.6559 - val_YP_loss: 1.9100 - val_YT_acc: 0.7990 - val_YP_acc: 0.3263
# Epoch 38/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.6653 - YT_loss: 0.6655 - YP_loss: 1.9997 - YT_acc: 0.8006 - YP_acc: 0.2961 - val_loss: 2.5621 - val_YT_loss: 0.6559 - val_YP_loss: 1.9062 - val_YT_acc: 0.8005 - val_YP_acc: 0.3294
# Epoch 39/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.6565 - YT_loss: 0.6628 - YP_loss: 1.9937 - YT_acc: 0.8014 - YP_acc: 0.2982 - val_loss: 2.5554 - val_YT_loss: 0.6527 - val_YP_loss: 1.9027 - val_YT_acc: 0.8014 - val_YP_acc: 0.3299
# Epoch 40/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.6510 - YT_loss: 0.6617 - YP_loss: 1.9893 - YT_acc: 0.8017 - YP_acc: 0.2994 - val_loss: 2.5517 - val_YT_loss: 0.6519 - val_YP_loss: 1.8998 - val_YT_acc: 0.8010 - val_YP_acc: 0.3316
# Epoch 41/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.6449 - YT_loss: 0.6599 - YP_loss: 1.9850 - YT_acc: 0.8024 - YP_acc: 0.3011 - val_loss: 2.5450 - val_YT_loss: 0.6481 - val_YP_loss: 1.8968 - val_YT_acc: 0.8022 - val_YP_acc: 0.3325
# Epoch 42/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.6418 - YT_loss: 0.6591 - YP_loss: 1.9828 - YT_acc: 0.8023 - YP_acc: 0.3026 - val_loss: 2.5433 - val_YT_loss: 0.6487 - val_YP_loss: 1.8946 - val_YT_acc: 0.8026 - val_YP_acc: 0.3339
# Epoch 43/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.6332 - YT_loss: 0.6554 - YP_loss: 1.9777 - YT_acc: 0.8032 - YP_acc: 0.3040 - val_loss: 2.5363 - val_YT_loss: 0.6458 - val_YP_loss: 1.8905 - val_YT_acc: 0.8026 - val_YP_acc: 0.3349
# Epoch 44/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.6320 - YT_loss: 0.6568 - YP_loss: 1.9753 - YT_acc: 0.8033 - YP_acc: 0.3047 - val_loss: 2.5397 - val_YT_loss: 0.6486 - val_YP_loss: 1.8911 - val_YT_acc: 0.8031 - val_YP_acc: 0.3347
# Epoch 45/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.6283 - YT_loss: 0.6560 - YP_loss: 1.9722 - YT_acc: 0.8043 - YP_acc: 0.3057 - val_loss: 2.5367 - val_YT_loss: 0.6468 - val_YP_loss: 1.8899 - val_YT_acc: 0.8038 - val_YP_acc: 0.3351
# Epoch 46/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.6202 - YT_loss: 0.6532 - YP_loss: 1.9670 - YT_acc: 0.8046 - YP_acc: 0.3081 - val_loss: 2.5276 - val_YT_loss: 0.6432 - val_YP_loss: 1.8845 - val_YT_acc: 0.8033 - val_YP_acc: 0.3370
# Epoch 47/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.6139 - YT_loss: 0.6497 - YP_loss: 1.9642 - YT_acc: 0.8050 - YP_acc: 0.3091 - val_loss: 2.5247 - val_YT_loss: 0.6427 - val_YP_loss: 1.8820 - val_YT_acc: 0.8032 - val_YP_acc: 0.3381
# Epoch 48/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.6090 - YT_loss: 0.6485 - YP_loss: 1.9605 - YT_acc: 0.8049 - YP_acc: 0.3104 - val_loss: 2.5195 - val_YT_loss: 0.6404 - val_YP_loss: 1.8790 - val_YT_acc: 0.8040 - val_YP_acc: 0.3389
# Epoch 49/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.6027 - YT_loss: 0.6469 - YP_loss: 1.9558 - YT_acc: 0.8054 - YP_acc: 0.3119 - val_loss: 2.5193 - val_YT_loss: 0.6427 - val_YP_loss: 1.8766 - val_YT_acc: 0.8055 - val_YP_acc: 0.3398
# Epoch 50/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5983 - YT_loss: 0.6464 - YP_loss: 1.9519 - YT_acc: 0.8060 - YP_acc: 0.3133 - val_loss: 2.5153 - val_YT_loss: 0.6405 - val_YP_loss: 1.8748 - val_YT_acc: 0.8049 - val_YP_acc: 0.3425
# Epoch 51/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5943 - YT_loss: 0.6447 - YP_loss: 1.9497 - YT_acc: 0.8061 - YP_acc: 0.3139 - val_loss: 2.5143 - val_YT_loss: 0.6364 - val_YP_loss: 1.8779 - val_YT_acc: 0.8041 - val_YP_acc: 0.3406
# Epoch 52/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5934 - YT_loss: 0.6441 - YP_loss: 1.9493 - YT_acc: 0.8067 - YP_acc: 0.3153 - val_loss: 2.5117 - val_YT_loss: 0.6377 - val_YP_loss: 1.8740 - val_YT_acc: 0.8053 - val_YP_acc: 0.3428
# Epoch 53/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5862 - YT_loss: 0.6421 - YP_loss: 1.9440 - YT_acc: 0.8068 - YP_acc: 0.3163 - val_loss: 2.5081 - val_YT_loss: 0.6374 - val_YP_loss: 1.8707 - val_YT_acc: 0.8056 - val_YP_acc: 0.3424
# Epoch 54/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.5829 - YT_loss: 0.6411 - YP_loss: 1.9418 - YT_acc: 0.8074 - YP_acc: 0.3178 - val_loss: 2.5044 - val_YT_loss: 0.6363 - val_YP_loss: 1.8681 - val_YT_acc: 0.8059 - val_YP_acc: 0.3462
# Epoch 55/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5783 - YT_loss: 0.6399 - YP_loss: 1.9384 - YT_acc: 0.8076 - YP_acc: 0.3183 - val_loss: 2.5016 - val_YT_loss: 0.6357 - val_YP_loss: 1.8659 - val_YT_acc: 0.8061 - val_YP_acc: 0.3449
# Epoch 56/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5744 - YT_loss: 0.6395 - YP_loss: 1.9349 - YT_acc: 0.8074 - YP_acc: 0.3200 - val_loss: 2.5000 - val_YT_loss: 0.6352 - val_YP_loss: 1.8648 - val_YT_acc: 0.8066 - val_YP_acc: 0.3444
# Epoch 57/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5700 - YT_loss: 0.6379 - YP_loss: 1.9321 - YT_acc: 0.8078 - YP_acc: 0.3217 - val_loss: 2.4968 - val_YT_loss: 0.6340 - val_YP_loss: 1.8628 - val_YT_acc: 0.8069 - val_YP_acc: 0.3460
# Epoch 58/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5663 - YT_loss: 0.6360 - YP_loss: 1.9303 - YT_acc: 0.8079 - YP_acc: 0.3221 - val_loss: 2.4940 - val_YT_loss: 0.6335 - val_YP_loss: 1.8605 - val_YT_acc: 0.8064 - val_YP_acc: 0.3481
# Epoch 59/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5647 - YT_loss: 0.6367 - YP_loss: 1.9281 - YT_acc: 0.8086 - YP_acc: 0.3226 - val_loss: 2.4923 - val_YT_loss: 0.6324 - val_YP_loss: 1.8599 - val_YT_acc: 0.8065 - val_YP_acc: 0.3472
# Epoch 60/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5624 - YT_loss: 0.6356 - YP_loss: 1.9268 - YT_acc: 0.8089 - YP_acc: 0.3236 - val_loss: 2.4938 - val_YT_loss: 0.6337 - val_YP_loss: 1.8601 - val_YT_acc: 0.8064 - val_YP_acc: 0.3480
# Epoch 61/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5606 - YT_loss: 0.6353 - YP_loss: 1.9253 - YT_acc: 0.8090 - YP_acc: 0.3241 - val_loss: 2.4891 - val_YT_loss: 0.6319 - val_YP_loss: 1.8572 - val_YT_acc: 0.8067 - val_YP_acc: 0.3477
# Epoch 62/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5554 - YT_loss: 0.6337 - YP_loss: 1.9218 - YT_acc: 0.8094 - YP_acc: 0.3251 - val_loss: 2.4857 - val_YT_loss: 0.6300 - val_YP_loss: 1.8557 - val_YT_acc: 0.8072 - val_YP_acc: 0.3473
# Epoch 63/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.5509 - YT_loss: 0.6324 - YP_loss: 1.9185 - YT_acc: 0.8093 - YP_acc: 0.3254 - val_loss: 2.4855 - val_YT_loss: 0.6314 - val_YP_loss: 1.8541 - val_YT_acc: 0.8076 - val_YP_acc: 0.3481
# Epoch 64/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5525 - YT_loss: 0.6326 - YP_loss: 1.9199 - YT_acc: 0.8097 - YP_acc: 0.3260 - val_loss: 2.4846 - val_YT_loss: 0.6315 - val_YP_loss: 1.8531 - val_YT_acc: 0.8075 - val_YP_acc: 0.3512
# Epoch 65/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.5490 - YT_loss: 0.6329 - YP_loss: 1.9161 - YT_acc: 0.8102 - YP_acc: 0.3271 - val_loss: 2.4826 - val_YT_loss: 0.6304 - val_YP_loss: 1.8522 - val_YT_acc: 0.8064 - val_YP_acc: 0.3497
# Epoch 66/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5440 - YT_loss: 0.6311 - YP_loss: 1.9128 - YT_acc: 0.8101 - YP_acc: 0.3287 - val_loss: 2.4786 - val_YT_loss: 0.6287 - val_YP_loss: 1.8500 - val_YT_acc: 0.8072 - val_YP_acc: 0.3507
# Epoch 67/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.5401 - YT_loss: 0.6286 - YP_loss: 1.9114 - YT_acc: 0.8105 - YP_acc: 0.3288 - val_loss: 2.4764 - val_YT_loss: 0.6272 - val_YP_loss: 1.8491 - val_YT_acc: 0.8066 - val_YP_acc: 0.3517
# Epoch 68/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.5380 - YT_loss: 0.6285 - YP_loss: 1.9095 - YT_acc: 0.8107 - YP_acc: 0.3295 - val_loss: 2.4736 - val_YT_loss: 0.6258 - val_YP_loss: 1.8478 - val_YT_acc: 0.8072 - val_YP_acc: 0.3529
# Epoch 69/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.5361 - YT_loss: 0.6272 - YP_loss: 1.9088 - YT_acc: 0.8103 - YP_acc: 0.3296 - val_loss: 2.4753 - val_YT_loss: 0.6273 - val_YP_loss: 1.8480 - val_YT_acc: 0.8078 - val_YP_acc: 0.3527
# Epoch 70/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5335 - YT_loss: 0.6265 - YP_loss: 1.9071 - YT_acc: 0.8110 - YP_acc: 0.3308 - val_loss: 2.4731 - val_YT_loss: 0.6253 - val_YP_loss: 1.8479 - val_YT_acc: 0.8074 - val_YP_acc: 0.3521
# Epoch 71/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5338 - YT_loss: 0.6277 - YP_loss: 1.9061 - YT_acc: 0.8109 - YP_acc: 0.3313 - val_loss: 2.4704 - val_YT_loss: 0.6261 - val_YP_loss: 1.8443 - val_YT_acc: 0.8084 - val_YP_acc: 0.3541
# Epoch 72/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5273 - YT_loss: 0.6243 - YP_loss: 1.9030 - YT_acc: 0.8115 - YP_acc: 0.3313 - val_loss: 2.4670 - val_YT_loss: 0.6240 - val_YP_loss: 1.8430 - val_YT_acc: 0.8077 - val_YP_acc: 0.3537
# Epoch 73/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5239 - YT_loss: 0.6240 - YP_loss: 1.8999 - YT_acc: 0.8113 - YP_acc: 0.3329 - val_loss: 2.4660 - val_YT_loss: 0.6252 - val_YP_loss: 1.8408 - val_YT_acc: 0.8054 - val_YP_acc: 0.3555
# Epoch 74/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5274 - YT_loss: 0.6272 - YP_loss: 1.9002 - YT_acc: 0.8109 - YP_acc: 0.3326 - val_loss: 2.4691 - val_YT_loss: 0.6265 - val_YP_loss: 1.8426 - val_YT_acc: 0.8077 - val_YP_acc: 0.3533
# Epoch 75/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5244 - YT_loss: 0.6258 - YP_loss: 1.8986 - YT_acc: 0.8115 - YP_acc: 0.3333 - val_loss: 2.4629 - val_YT_loss: 0.6245 - val_YP_loss: 1.8385 - val_YT_acc: 0.8075 - val_YP_acc: 0.3547
# Epoch 76/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5189 - YT_loss: 0.6232 - YP_loss: 1.8957 - YT_acc: 0.8118 - YP_acc: 0.3348 - val_loss: 2.4595 - val_YT_loss: 0.6223 - val_YP_loss: 1.8372 - val_YT_acc: 0.8083 - val_YP_acc: 0.3568
# Epoch 77/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5159 - YT_loss: 0.6215 - YP_loss: 1.8944 - YT_acc: 0.8117 - YP_acc: 0.3351 - val_loss: 2.4597 - val_YT_loss: 0.6233 - val_YP_loss: 1.8364 - val_YT_acc: 0.8085 - val_YP_acc: 0.3558
# Epoch 78/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5133 - YT_loss: 0.6209 - YP_loss: 1.8924 - YT_acc: 0.8119 - YP_acc: 0.3355 - val_loss: 2.4564 - val_YT_loss: 0.6207 - val_YP_loss: 1.8357 - val_YT_acc: 0.8074 - val_YP_acc: 0.3562
# Epoch 79/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.5113 - YT_loss: 0.6195 - YP_loss: 1.8917 - YT_acc: 0.8120 - YP_acc: 0.3356 - val_loss: 2.4582 - val_YT_loss: 0.6216 - val_YP_loss: 1.8365 - val_YT_acc: 0.8085 - val_YP_acc: 0.3553
# Epoch 80/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5112 - YT_loss: 0.6206 - YP_loss: 1.8906 - YT_acc: 0.8122 - YP_acc: 0.3360 - val_loss: 2.4539 - val_YT_loss: 0.6200 - val_YP_loss: 1.8339 - val_YT_acc: 0.8082 - val_YP_acc: 0.3569
# Epoch 81/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5106 - YT_loss: 0.6195 - YP_loss: 1.8911 - YT_acc: 0.8127 - YP_acc: 0.3365 - val_loss: 2.4555 - val_YT_loss: 0.6211 - val_YP_loss: 1.8344 - val_YT_acc: 0.8082 - val_YP_acc: 0.3561
# Epoch 82/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.5085 - YT_loss: 0.6197 - YP_loss: 1.8888 - YT_acc: 0.8126 - YP_acc: 0.3367 - val_loss: 2.4494 - val_YT_loss: 0.6187 - val_YP_loss: 1.8307 - val_YT_acc: 0.8078 - val_YP_acc: 0.3575
# Epoch 83/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5053 - YT_loss: 0.6181 - YP_loss: 1.8871 - YT_acc: 0.8126 - YP_acc: 0.3373 - val_loss: 2.4474 - val_YT_loss: 0.6177 - val_YP_loss: 1.8298 - val_YT_acc: 0.8080 - val_YP_acc: 0.3582
# Epoch 84/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5016 - YT_loss: 0.6174 - YP_loss: 1.8842 - YT_acc: 0.8126 - YP_acc: 0.3393 - val_loss: 2.4469 - val_YT_loss: 0.6167 - val_YP_loss: 1.8302 - val_YT_acc: 0.8079 - val_YP_acc: 0.3581
# Epoch 85/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5015 - YT_loss: 0.6166 - YP_loss: 1.8849 - YT_acc: 0.8131 - YP_acc: 0.3378 - val_loss: 2.4462 - val_YT_loss: 0.6171 - val_YP_loss: 1.8291 - val_YT_acc: 0.8076 - val_YP_acc: 0.3593
# Epoch 86/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4982 - YT_loss: 0.6163 - YP_loss: 1.8819 - YT_acc: 0.8132 - YP_acc: 0.3392 - val_loss: 2.4448 - val_YT_loss: 0.6167 - val_YP_loss: 1.8282 - val_YT_acc: 0.8078 - val_YP_acc: 0.3588
# Epoch 87/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4976 - YT_loss: 0.6163 - YP_loss: 1.8813 - YT_acc: 0.8132 - YP_acc: 0.3393 - val_loss: 2.4437 - val_YT_loss: 0.6150 - val_YP_loss: 1.8287 - val_YT_acc: 0.8077 - val_YP_acc: 0.3602
# Epoch 88/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4953 - YT_loss: 0.6149 - YP_loss: 1.8804 - YT_acc: 0.8132 - YP_acc: 0.3401 - val_loss: 2.4427 - val_YT_loss: 0.6170 - val_YP_loss: 1.8258 - val_YT_acc: 0.8089 - val_YP_acc: 0.3601
# Epoch 89/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4928 - YT_loss: 0.6134 - YP_loss: 1.8794 - YT_acc: 0.8133 - YP_acc: 0.3402 - val_loss: 2.4402 - val_YT_loss: 0.6148 - val_YP_loss: 1.8255 - val_YT_acc: 0.8079 - val_YP_acc: 0.3605
# Epoch 90/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4918 - YT_loss: 0.6140 - YP_loss: 1.8778 - YT_acc: 0.8135 - YP_acc: 0.3409 - val_loss: 2.4409 - val_YT_loss: 0.6159 - val_YP_loss: 1.8250 - val_YT_acc: 0.8083 - val_YP_acc: 0.3603
# Epoch 91/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4953 - YT_loss: 0.6152 - YP_loss: 1.8801 - YT_acc: 0.8136 - YP_acc: 0.3409 - val_loss: 2.4402 - val_YT_loss: 0.6139 - val_YP_loss: 1.8263 - val_YT_acc: 0.8083 - val_YP_acc: 0.3593
# Epoch 92/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4918 - YT_loss: 0.6142 - YP_loss: 1.8776 - YT_acc: 0.8132 - YP_acc: 0.3417 - val_loss: 2.4384 - val_YT_loss: 0.6151 - val_YP_loss: 1.8233 - val_YT_acc: 0.8085 - val_YP_acc: 0.3609
# Epoch 93/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4874 - YT_loss: 0.6123 - YP_loss: 1.8751 - YT_acc: 0.8136 - YP_acc: 0.3417 - val_loss: 2.4357 - val_YT_loss: 0.6131 - val_YP_loss: 1.8226 - val_YT_acc: 0.8085 - val_YP_acc: 0.3615
# Epoch 94/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4838 - YT_loss: 0.6108 - YP_loss: 1.8730 - YT_acc: 0.8138 - YP_acc: 0.3428 - val_loss: 2.4332 - val_YT_loss: 0.6123 - val_YP_loss: 1.8209 - val_YT_acc: 0.8086 - val_YP_acc: 0.3619
# Epoch 95/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4869 - YT_loss: 0.6138 - YP_loss: 1.8730 - YT_acc: 0.8136 - YP_acc: 0.3432 - val_loss: 2.4382 - val_YT_loss: 0.6152 - val_YP_loss: 1.8229 - val_YT_acc: 0.8084 - val_YP_acc: 0.3618
# Epoch 96/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4861 - YT_loss: 0.6137 - YP_loss: 1.8724 - YT_acc: 0.8136 - YP_acc: 0.3430 - val_loss: 2.4358 - val_YT_loss: 0.6151 - val_YP_loss: 1.8207 - val_YT_acc: 0.8091 - val_YP_acc: 0.3623
# Epoch 97/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4839 - YT_loss: 0.6133 - YP_loss: 1.8705 - YT_acc: 0.8142 - YP_acc: 0.3436 - val_loss: 2.4367 - val_YT_loss: 0.6145 - val_YP_loss: 1.8222 - val_YT_acc: 0.8072 - val_YP_acc: 0.3618
# Epoch 98/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4836 - YT_loss: 0.6129 - YP_loss: 1.8706 - YT_acc: 0.8140 - YP_acc: 0.3439 - val_loss: 2.4365 - val_YT_loss: 0.6135 - val_YP_loss: 1.8230 - val_YT_acc: 0.8070 - val_YP_acc: 0.3628
# Epoch 99/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4813 - YT_loss: 0.6116 - YP_loss: 1.8697 - YT_acc: 0.8144 - YP_acc: 0.3438 - val_loss: 2.4343 - val_YT_loss: 0.6169 - val_YP_loss: 1.8174 - val_YT_acc: 0.8088 - val_YP_acc: 0.3628
# Epoch 100/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4790 - YT_loss: 0.6101 - YP_loss: 1.8689 - YT_acc: 0.8143 - YP_acc: 0.3446 - val_loss: 2.4297 - val_YT_loss: 0.6107 - val_YP_loss: 1.8190 - val_YT_acc: 0.8087 - val_YP_acc: 0.3629
# Epoch 101/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4746 - YT_loss: 0.6079 - YP_loss: 1.8667 - YT_acc: 0.8141 - YP_acc: 0.3442 - val_loss: 2.4287 - val_YT_loss: 0.6125 - val_YP_loss: 1.8162 - val_YT_acc: 0.8090 - val_YP_acc: 0.3634
# Epoch 102/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4748 - YT_loss: 0.6091 - YP_loss: 1.8657 - YT_acc: 0.8145 - YP_acc: 0.3453 - val_loss: 2.4289 - val_YT_loss: 0.6118 - val_YP_loss: 1.8171 - val_YT_acc: 0.8092 - val_YP_acc: 0.3629
# Epoch 103/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4713 - YT_loss: 0.6077 - YP_loss: 1.8637 - YT_acc: 0.8148 - YP_acc: 0.3457 - val_loss: 2.4252 - val_YT_loss: 0.6099 - val_YP_loss: 1.8153 - val_YT_acc: 0.8087 - val_YP_acc: 0.3646
# Epoch 104/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4702 - YT_loss: 0.6070 - YP_loss: 1.8632 - YT_acc: 0.8146 - YP_acc: 0.3459 - val_loss: 2.4218 - val_YT_loss: 0.6079 - val_YP_loss: 1.8138 - val_YT_acc: 0.8081 - val_YP_acc: 0.3642
# Epoch 105/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4688 - YT_loss: 0.6065 - YP_loss: 1.8623 - YT_acc: 0.8149 - YP_acc: 0.3461 - val_loss: 2.4210 - val_YT_loss: 0.6097 - val_YP_loss: 1.8113 - val_YT_acc: 0.8081 - val_YP_acc: 0.3656
# Epoch 106/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4737 - YT_loss: 0.6101 - YP_loss: 1.8637 - YT_acc: 0.8144 - YP_acc: 0.3464 - val_loss: 2.4439 - val_YT_loss: 0.6167 - val_YP_loss: 1.8272 - val_YT_acc: 0.8097 - val_YP_acc: 0.3578
# Epoch 107/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4805 - YT_loss: 0.6096 - YP_loss: 1.8709 - YT_acc: 0.8149 - YP_acc: 0.3436 - val_loss: 2.4301 - val_YT_loss: 0.6121 - val_YP_loss: 1.8180 - val_YT_acc: 0.8090 - val_YP_acc: 0.3641
# Epoch 108/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4730 - YT_loss: 0.6087 - YP_loss: 1.8643 - YT_acc: 0.8145 - YP_acc: 0.3455 - val_loss: 2.4255 - val_YT_loss: 0.6099 - val_YP_loss: 1.8155 - val_YT_acc: 0.8084 - val_YP_acc: 0.3614
# Epoch 109/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4696 - YT_loss: 0.6076 - YP_loss: 1.8621 - YT_acc: 0.8151 - YP_acc: 0.3465 - val_loss: 2.4235 - val_YT_loss: 0.6105 - val_YP_loss: 1.8130 - val_YT_acc: 0.8085 - val_YP_acc: 0.3641
# Epoch 110/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4658 - YT_loss: 0.6060 - YP_loss: 1.8598 - YT_acc: 0.8152 - YP_acc: 0.3474 - val_loss: 2.4212 - val_YT_loss: 0.6090 - val_YP_loss: 1.8121 - val_YT_acc: 0.8089 - val_YP_acc: 0.3640
# Epoch 111/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4636 - YT_loss: 0.6049 - YP_loss: 1.8587 - YT_acc: 0.8152 - YP_acc: 0.3475 - val_loss: 2.4155 - val_YT_loss: 0.6073 - val_YP_loss: 1.8082 - val_YT_acc: 0.8093 - val_YP_acc: 0.3665
# Epoch 112/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4602 - YT_loss: 0.6037 - YP_loss: 1.8565 - YT_acc: 0.8154 - YP_acc: 0.3485 - val_loss: 2.4157 - val_YT_loss: 0.6067 - val_YP_loss: 1.8090 - val_YT_acc: 0.8088 - val_YP_acc: 0.3658
# Epoch 113/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4577 - YT_loss: 0.6025 - YP_loss: 1.8552 - YT_acc: 0.8157 - YP_acc: 0.3493 - val_loss: 2.4131 - val_YT_loss: 0.6054 - val_YP_loss: 1.8077 - val_YT_acc: 0.8090 - val_YP_acc: 0.3666
# Epoch 114/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4575 - YT_loss: 0.6030 - YP_loss: 1.8545 - YT_acc: 0.8152 - YP_acc: 0.3496 - val_loss: 2.4148 - val_YT_loss: 0.6085 - val_YP_loss: 1.8063 - val_YT_acc: 0.8099 - val_YP_acc: 0.3678
# Epoch 115/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4566 - YT_loss: 0.6031 - YP_loss: 1.8535 - YT_acc: 0.8153 - YP_acc: 0.3496 - val_loss: 2.4137 - val_YT_loss: 0.6062 - val_YP_loss: 1.8075 - val_YT_acc: 0.8094 - val_YP_acc: 0.3660
# Epoch 116/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4560 - YT_loss: 0.6027 - YP_loss: 1.8532 - YT_acc: 0.8152 - YP_acc: 0.3496 - val_loss: 2.4133 - val_YT_loss: 0.6062 - val_YP_loss: 1.8071 - val_YT_acc: 0.8098 - val_YP_acc: 0.3674
# Epoch 117/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4545 - YT_loss: 0.6018 - YP_loss: 1.8527 - YT_acc: 0.8156 - YP_acc: 0.3509 - val_loss: 2.4112 - val_YT_loss: 0.6048 - val_YP_loss: 1.8064 - val_YT_acc: 0.8092 - val_YP_acc: 0.3663
# Epoch 118/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4552 - YT_loss: 0.6022 - YP_loss: 1.8530 - YT_acc: 0.8158 - YP_acc: 0.3506 - val_loss: 2.4132 - val_YT_loss: 0.6070 - val_YP_loss: 1.8062 - val_YT_acc: 0.8096 - val_YP_acc: 0.3669
# Epoch 119/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4658 - YT_loss: 0.6072 - YP_loss: 1.8586 - YT_acc: 0.8156 - YP_acc: 0.3484 - val_loss: 2.4260 - val_YT_loss: 0.6132 - val_YP_loss: 1.8128 - val_YT_acc: 0.8102 - val_YP_acc: 0.3652
# Epoch 120/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4663 - YT_loss: 0.6098 - YP_loss: 1.8565 - YT_acc: 0.8155 - YP_acc: 0.3487 - val_loss: 2.4221 - val_YT_loss: 0.6116 - val_YP_loss: 1.8105 - val_YT_acc: 0.8104 - val_YP_acc: 0.3670
# Epoch 121/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4604 - YT_loss: 0.6048 - YP_loss: 1.8557 - YT_acc: 0.8159 - YP_acc: 0.3494 - val_loss: 2.4154 - val_YT_loss: 0.6075 - val_YP_loss: 1.8079 - val_YT_acc: 0.8093 - val_YP_acc: 0.3657
# Epoch 122/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4541 - YT_loss: 0.6027 - YP_loss: 1.8515 - YT_acc: 0.8157 - YP_acc: 0.3509 - val_loss: 2.4092 - val_YT_loss: 0.6041 - val_YP_loss: 1.8051 - val_YT_acc: 0.8095 - val_YP_acc: 0.3682
# Epoch 123/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4505 - YT_loss: 0.6000 - YP_loss: 1.8505 - YT_acc: 0.8163 - YP_acc: 0.3503 - val_loss: 2.4063 - val_YT_loss: 0.6037 - val_YP_loss: 1.8026 - val_YT_acc: 0.8102 - val_YP_acc: 0.3686
# Epoch 124/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4482 - YT_loss: 0.5991 - YP_loss: 1.8491 - YT_acc: 0.8165 - YP_acc: 0.3510 - val_loss: 2.4054 - val_YT_loss: 0.6032 - val_YP_loss: 1.8022 - val_YT_acc: 0.8100 - val_YP_acc: 0.3681
# Epoch 125/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4457 - YT_loss: 0.5987 - YP_loss: 1.8470 - YT_acc: 0.8165 - YP_acc: 0.3519 - val_loss: 2.4045 - val_YT_loss: 0.6031 - val_YP_loss: 1.8014 - val_YT_acc: 0.8102 - val_YP_acc: 0.3684
# Epoch 126/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4456 - YT_loss: 0.6000 - YP_loss: 1.8456 - YT_acc: 0.8162 - YP_acc: 0.3523 - val_loss: 2.4026 - val_YT_loss: 0.6030 - val_YP_loss: 1.7996 - val_YT_acc: 0.8107 - val_YP_acc: 0.3695
# Epoch 127/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4445 - YT_loss: 0.5993 - YP_loss: 1.8451 - YT_acc: 0.8167 - YP_acc: 0.3534 - val_loss: 2.4043 - val_YT_loss: 0.6044 - val_YP_loss: 1.8000 - val_YT_acc: 0.8110 - val_YP_acc: 0.3690
# Epoch 128/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4437 - YT_loss: 0.5985 - YP_loss: 1.8452 - YT_acc: 0.8165 - YP_acc: 0.3528 - val_loss: 2.4002 - val_YT_loss: 0.6015 - val_YP_loss: 1.7987 - val_YT_acc: 0.8107 - val_YP_acc: 0.3697
# Epoch 129/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4413 - YT_loss: 0.5969 - YP_loss: 1.8444 - YT_acc: 0.8165 - YP_acc: 0.3534 - val_loss: 2.3991 - val_YT_loss: 0.6010 - val_YP_loss: 1.7981 - val_YT_acc: 0.8104 - val_YP_acc: 0.3695
# Epoch 130/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4402 - YT_loss: 0.5967 - YP_loss: 1.8435 - YT_acc: 0.8166 - YP_acc: 0.3540 - val_loss: 2.4011 - val_YT_loss: 0.6016 - val_YP_loss: 1.7995 - val_YT_acc: 0.8110 - val_YP_acc: 0.3682
# Epoch 131/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4438 - YT_loss: 0.5992 - YP_loss: 1.8446 - YT_acc: 0.8166 - YP_acc: 0.3531 - val_loss: 2.4040 - val_YT_loss: 0.6032 - val_YP_loss: 1.8008 - val_YT_acc: 0.8105 - val_YP_acc: 0.3694
# Epoch 132/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4439 - YT_loss: 0.5988 - YP_loss: 1.8452 - YT_acc: 0.8163 - YP_acc: 0.3531 - val_loss: 2.4096 - val_YT_loss: 0.6034 - val_YP_loss: 1.8062 - val_YT_acc: 0.8111 - val_YP_acc: 0.3651
# Epoch 133/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4434 - YT_loss: 0.5977 - YP_loss: 1.8457 - YT_acc: 0.8167 - YP_acc: 0.3526 - val_loss: 2.3998 - val_YT_loss: 0.6007 - val_YP_loss: 1.7992 - val_YT_acc: 0.8103 - val_YP_acc: 0.3695
# Epoch 134/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4399 - YT_loss: 0.5972 - YP_loss: 1.8427 - YT_acc: 0.8167 - YP_acc: 0.3543 - val_loss: 2.3970 - val_YT_loss: 0.5998 - val_YP_loss: 1.7972 - val_YT_acc: 0.8105 - val_YP_acc: 0.3704
# Epoch 135/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4372 - YT_loss: 0.5968 - YP_loss: 1.8404 - YT_acc: 0.8170 - YP_acc: 0.3545 - val_loss: 2.3956 - val_YT_loss: 0.5999 - val_YP_loss: 1.7956 - val_YT_acc: 0.8104 - val_YP_acc: 0.3705
# Epoch 136/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4374 - YT_loss: 0.5966 - YP_loss: 1.8408 - YT_acc: 0.8171 - YP_acc: 0.3546 - val_loss: 2.3982 - val_YT_loss: 0.6019 - val_YP_loss: 1.7963 - val_YT_acc: 0.8114 - val_YP_acc: 0.3702
# Epoch 137/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4347 - YT_loss: 0.5961 - YP_loss: 1.8386 - YT_acc: 0.8172 - YP_acc: 0.3556 - val_loss: 2.3974 - val_YT_loss: 0.6011 - val_YP_loss: 1.7964 - val_YT_acc: 0.8114 - val_YP_acc: 0.3687
# Epoch 138/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4330 - YT_loss: 0.5946 - YP_loss: 1.8384 - YT_acc: 0.8171 - YP_acc: 0.3558 - val_loss: 2.3948 - val_YT_loss: 0.6002 - val_YP_loss: 1.7945 - val_YT_acc: 0.8104 - val_YP_acc: 0.3714
# Epoch 139/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4383 - YT_loss: 0.5982 - YP_loss: 1.8400 - YT_acc: 0.8168 - YP_acc: 0.3550 - val_loss: 2.3973 - val_YT_loss: 0.6021 - val_YP_loss: 1.7952 - val_YT_acc: 0.8117 - val_YP_acc: 0.3709
# Epoch 140/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4330 - YT_loss: 0.5955 - YP_loss: 1.8375 - YT_acc: 0.8173 - YP_acc: 0.3553 - val_loss: 2.3923 - val_YT_loss: 0.5983 - val_YP_loss: 1.7940 - val_YT_acc: 0.8110 - val_YP_acc: 0.3704
# Epoch 141/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4314 - YT_loss: 0.5938 - YP_loss: 1.8375 - YT_acc: 0.8172 - YP_acc: 0.3556 - val_loss: 2.3941 - val_YT_loss: 0.5981 - val_YP_loss: 1.7960 - val_YT_acc: 0.8114 - val_YP_acc: 0.3705
# Epoch 142/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4338 - YT_loss: 0.5958 - YP_loss: 1.8381 - YT_acc: 0.8174 - YP_acc: 0.3556 - val_loss: 2.3914 - val_YT_loss: 0.5972 - val_YP_loss: 1.7942 - val_YT_acc: 0.8119 - val_YP_acc: 0.3721
# Epoch 143/250
# 3503/3503 [==============================] - 17s 5ms/step - loss: 2.4315 - YT_loss: 0.5943 - YP_loss: 1.8372 - YT_acc: 0.8177 - YP_acc: 0.3561 - val_loss: 2.3931 - val_YT_loss: 0.5992 - val_YP_loss: 1.7939 - val_YT_acc: 0.8119 - val_YP_acc: 0.3709
# Epoch 144/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4306 - YT_loss: 0.5932 - YP_loss: 1.8374 - YT_acc: 0.8177 - YP_acc: 0.3559 - val_loss: 2.3885 - val_YT_loss: 0.5973 - val_YP_loss: 1.7912 - val_YT_acc: 0.8118 - val_YP_acc: 0.3728
# Epoch 145/250
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4273 - YT_loss: 0.5921 - YP_loss: 1.8352 - YT_acc: 0.8177 - YP_acc: 0.3563 - val_loss: 2.3904 - val_YT_loss: 0.5983 - val_YP_loss: 1.7920 - val_YT_acc: 0.8119 - val_YP_acc: 0.3718
# Epoch 146/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4281 - YT_loss: 0.5925 - YP_loss: 1.8356 - YT_acc: 0.8179 - YP_acc: 0.3570 - val_loss: 2.3883 - val_YT_loss: 0.5961 - val_YP_loss: 1.7921 - val_YT_acc: 0.8121 - val_YP_acc: 0.3712
# Epoch 147/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4270 - YT_loss: 0.5923 - YP_loss: 1.8347 - YT_acc: 0.8180 - YP_acc: 0.3563 - val_loss: 2.3916 - val_YT_loss: 0.6008 - val_YP_loss: 1.7907 - val_YT_acc: 0.8122 - val_YP_acc: 0.3720
# Epoch 148/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4261 - YT_loss: 0.5927 - YP_loss: 1.8334 - YT_acc: 0.8181 - YP_acc: 0.3574 - val_loss: 2.3842 - val_YT_loss: 0.5949 - val_YP_loss: 1.7893 - val_YT_acc: 0.8122 - val_YP_acc: 0.3719
# Epoch 149/250
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4225 - YT_loss: 0.5902 - YP_loss: 1.8323 - YT_acc: 0.8184 - YP_acc: 0.3579 - val_loss: 2.3859 - val_YT_loss: 0.5961 - val_YP_loss: 1.7898 - val_YT_acc: 0.8121 - val_YP_acc: 0.3715
# Epoch 150/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4198 - YT_loss: 0.5897 - YP_loss: 1.8302 - YT_acc: 0.8187 - YP_acc: 0.3584 - val_loss: 2.3825 - val_YT_loss: 0.5948 - val_YP_loss: 1.7877 - val_YT_acc: 0.8124 - val_YP_acc: 0.3722
# Epoch 151/250
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4211 - YT_loss: 0.5891 - YP_loss: 1.8320 - YT_acc: 0.8186 - YP_acc: 0.3576 - val_loss: 2.3821 - val_YT_loss: 0.5926 - val_YP_loss: 1.7895 - val_YT_acc: 0.8122 - val_YP_acc: 0.3735
# Epoch 152/250
# 3503/3503 [==============================] - 17s 5ms/step - loss: 2.4187 - YT_loss: 0.5885 - YP_loss: 1.8302 - YT_acc: 0.8185 - YP_acc: 0.3582 - val_loss: 2.3812 - val_YT_loss: 0.5950 - val_YP_loss: 1.7862 - val_YT_acc: 0.8125 - val_YP_acc: 0.3749
# Epoch 153/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4182 - YT_loss: 0.5882 - YP_loss: 1.8300 - YT_acc: 0.8185 - YP_acc: 0.3582 - val_loss: 2.3795 - val_YT_loss: 0.5934 - val_YP_loss: 1.7862 - val_YT_acc: 0.8129 - val_YP_acc: 0.3731
# Epoch 154/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4192 - YT_loss: 0.5894 - YP_loss: 1.8299 - YT_acc: 0.8190 - YP_acc: 0.3586 - val_loss: 2.3812 - val_YT_loss: 0.5939 - val_YP_loss: 1.7873 - val_YT_acc: 0.8129 - val_YP_acc: 0.3738
# Epoch 155/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4205 - YT_loss: 0.5889 - YP_loss: 1.8315 - YT_acc: 0.8186 - YP_acc: 0.3581 - val_loss: 2.3793 - val_YT_loss: 0.5919 - val_YP_loss: 1.7874 - val_YT_acc: 0.8127 - val_YP_acc: 0.3724
# Epoch 156/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4164 - YT_loss: 0.5868 - YP_loss: 1.8296 - YT_acc: 0.8189 - YP_acc: 0.3581 - val_loss: 2.3756 - val_YT_loss: 0.5911 - val_YP_loss: 1.7845 - val_YT_acc: 0.8123 - val_YP_acc: 0.3741
# Epoch 157/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4133 - YT_loss: 0.5865 - YP_loss: 1.8268 - YT_acc: 0.8187 - YP_acc: 0.3597 - val_loss: 2.3761 - val_YT_loss: 0.5908 - val_YP_loss: 1.7853 - val_YT_acc: 0.8127 - val_YP_acc: 0.3740
# Epoch 158/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.4131 - YT_loss: 0.5860 - YP_loss: 1.8271 - YT_acc: 0.8190 - YP_acc: 0.3587 - val_loss: 2.3764 - val_YT_loss: 0.5901 - val_YP_loss: 1.7863 - val_YT_acc: 0.8130 - val_YP_acc: 0.3736
# Epoch 159/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.4115 - YT_loss: 0.5857 - YP_loss: 1.8258 - YT_acc: 0.8195 - YP_acc: 0.3595 - val_loss: 2.3741 - val_YT_loss: 0.5901 - val_YP_loss: 1.7840 - val_YT_acc: 0.8132 - val_YP_acc: 0.3739
# Epoch 160/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4124 - YT_loss: 0.5863 - YP_loss: 1.8262 - YT_acc: 0.8192 - YP_acc: 0.3597 - val_loss: 2.3743 - val_YT_loss: 0.5907 - val_YP_loss: 1.7837 - val_YT_acc: 0.8130 - val_YP_acc: 0.3742
# Epoch 161/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4118 - YT_loss: 0.5859 - YP_loss: 1.8259 - YT_acc: 0.8195 - YP_acc: 0.3598 - val_loss: 2.3749 - val_YT_loss: 0.5911 - val_YP_loss: 1.7838 - val_YT_acc: 0.8135 - val_YP_acc: 0.3753
# Epoch 162/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4081 - YT_loss: 0.5839 - YP_loss: 1.8242 - YT_acc: 0.8195 - YP_acc: 0.3607 - val_loss: 2.3690 - val_YT_loss: 0.5879 - val_YP_loss: 1.7811 - val_YT_acc: 0.8135 - val_YP_acc: 0.3754
# Epoch 163/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.4068 - YT_loss: 0.5832 - YP_loss: 1.8236 - YT_acc: 0.8196 - YP_acc: 0.3600 - val_loss: 2.3687 - val_YT_loss: 0.5875 - val_YP_loss: 1.7812 - val_YT_acc: 0.8134 - val_YP_acc: 0.3749
# Epoch 164/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.4068 - YT_loss: 0.5824 - YP_loss: 1.8244 - YT_acc: 0.8199 - YP_acc: 0.3601 - val_loss: 2.3670 - val_YT_loss: 0.5858 - val_YP_loss: 1.7812 - val_YT_acc: 0.8137 - val_YP_acc: 0.3753
# Epoch 165/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.4059 - YT_loss: 0.5820 - YP_loss: 1.8239 - YT_acc: 0.8201 - YP_acc: 0.3606 - val_loss: 2.3723 - val_YT_loss: 0.5868 - val_YP_loss: 1.7855 - val_YT_acc: 0.8136 - val_YP_acc: 0.3728
# Epoch 166/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4056 - YT_loss: 0.5816 - YP_loss: 1.8240 - YT_acc: 0.8204 - YP_acc: 0.3607 - val_loss: 2.3693 - val_YT_loss: 0.5862 - val_YP_loss: 1.7832 - val_YT_acc: 0.8137 - val_YP_acc: 0.3733
# Epoch 167/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4054 - YT_loss: 0.5802 - YP_loss: 1.8252 - YT_acc: 0.8209 - YP_acc: 0.3601 - val_loss: 2.3658 - val_YT_loss: 0.5837 - val_YP_loss: 1.7821 - val_YT_acc: 0.8141 - val_YP_acc: 0.3749
# Epoch 168/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4022 - YT_loss: 0.5788 - YP_loss: 1.8234 - YT_acc: 0.8207 - YP_acc: 0.3608 - val_loss: 2.3619 - val_YT_loss: 0.5831 - val_YP_loss: 1.7789 - val_YT_acc: 0.8137 - val_YP_acc: 0.3761
# Epoch 169/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3995 - YT_loss: 0.5783 - YP_loss: 1.8211 - YT_acc: 0.8208 - YP_acc: 0.3614 - val_loss: 2.3606 - val_YT_loss: 0.5817 - val_YP_loss: 1.7789 - val_YT_acc: 0.8138 - val_YP_acc: 0.3751
# Epoch 170/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3963 - YT_loss: 0.5766 - YP_loss: 1.8197 - YT_acc: 0.8211 - YP_acc: 0.3617 - val_loss: 2.3605 - val_YT_loss: 0.5823 - val_YP_loss: 1.7782 - val_YT_acc: 0.8143 - val_YP_acc: 0.3768
# Epoch 171/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3937 - YT_loss: 0.5755 - YP_loss: 1.8182 - YT_acc: 0.8214 - YP_acc: 0.3627 - val_loss: 2.3582 - val_YT_loss: 0.5804 - val_YP_loss: 1.7779 - val_YT_acc: 0.8142 - val_YP_acc: 0.3757
# Epoch 172/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3952 - YT_loss: 0.5751 - YP_loss: 1.8201 - YT_acc: 0.8212 - YP_acc: 0.3618 - val_loss: 2.3587 - val_YT_loss: 0.5812 - val_YP_loss: 1.7775 - val_YT_acc: 0.8145 - val_YP_acc: 0.3781
# Epoch 173/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3921 - YT_loss: 0.5740 - YP_loss: 1.8181 - YT_acc: 0.8214 - YP_acc: 0.3620 - val_loss: 2.3532 - val_YT_loss: 0.5760 - val_YP_loss: 1.7772 - val_YT_acc: 0.8150 - val_YP_acc: 0.3761
# Epoch 174/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3906 - YT_loss: 0.5721 - YP_loss: 1.8185 - YT_acc: 0.8217 - YP_acc: 0.3633 - val_loss: 2.3542 - val_YT_loss: 0.5760 - val_YP_loss: 1.7783 - val_YT_acc: 0.8147 - val_YP_acc: 0.3767
# Epoch 175/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3917 - YT_loss: 0.5731 - YP_loss: 1.8186 - YT_acc: 0.8217 - YP_acc: 0.3624 - val_loss: 2.3546 - val_YT_loss: 0.5772 - val_YP_loss: 1.7774 - val_YT_acc: 0.8145 - val_YP_acc: 0.3758
# Epoch 176/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3889 - YT_loss: 0.5714 - YP_loss: 1.8176 - YT_acc: 0.8219 - YP_acc: 0.3633 - val_loss: 2.3535 - val_YT_loss: 0.5760 - val_YP_loss: 1.7774 - val_YT_acc: 0.8149 - val_YP_acc: 0.3770
# Epoch 177/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3868 - YT_loss: 0.5711 - YP_loss: 1.8157 - YT_acc: 0.8219 - YP_acc: 0.3637 - val_loss: 2.3512 - val_YT_loss: 0.5747 - val_YP_loss: 1.7765 - val_YT_acc: 0.8145 - val_YP_acc: 0.3766
# Epoch 178/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3851 - YT_loss: 0.5688 - YP_loss: 1.8164 - YT_acc: 0.8222 - YP_acc: 0.3639 - val_loss: 2.3480 - val_YT_loss: 0.5737 - val_YP_loss: 1.7743 - val_YT_acc: 0.8146 - val_YP_acc: 0.3775
# Epoch 179/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3848 - YT_loss: 0.5685 - YP_loss: 1.8163 - YT_acc: 0.8221 - YP_acc: 0.3627 - val_loss: 2.3502 - val_YT_loss: 0.5747 - val_YP_loss: 1.7755 - val_YT_acc: 0.8148 - val_YP_acc: 0.3769
# Epoch 180/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3829 - YT_loss: 0.5686 - YP_loss: 1.8144 - YT_acc: 0.8227 - YP_acc: 0.3641 - val_loss: 2.3441 - val_YT_loss: 0.5723 - val_YP_loss: 1.7718 - val_YT_acc: 0.8148 - val_YP_acc: 0.3787
# Epoch 181/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3804 - YT_loss: 0.5672 - YP_loss: 1.8132 - YT_acc: 0.8228 - YP_acc: 0.3646 - val_loss: 2.3443 - val_YT_loss: 0.5732 - val_YP_loss: 1.7711 - val_YT_acc: 0.8150 - val_YP_acc: 0.3781
# Epoch 182/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3794 - YT_loss: 0.5659 - YP_loss: 1.8135 - YT_acc: 0.8230 - YP_acc: 0.3648 - val_loss: 2.3437 - val_YT_loss: 0.5696 - val_YP_loss: 1.7741 - val_YT_acc: 0.8150 - val_YP_acc: 0.3779
# Epoch 183/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3792 - YT_loss: 0.5651 - YP_loss: 1.8140 - YT_acc: 0.8232 - YP_acc: 0.3641 - val_loss: 2.3426 - val_YT_loss: 0.5705 - val_YP_loss: 1.7721 - val_YT_acc: 0.8151 - val_YP_acc: 0.3792
# Epoch 184/250
# ...
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3702 - YT_loss: 0.5612 - YP_loss: 1.8090 - YT_acc: 0.8237 - YP_acc: 0.3656 - val_loss: 2.3363 - val_YT_loss: 0.5671 - val_YP_loss: 1.7692 - val_YT_acc: 0.8153 - val_YP_acc: 0.3785
# Epoch 191/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3676 - YT_loss: 0.5603 - YP_loss: 1.8072 - YT_acc: 0.8238 - YP_acc: 0.3667 - val_loss: 2.3347 - val_YT_loss: 0.5675 - val_YP_loss: 1.7672 - val_YT_acc: 0.8164 - val_YP_acc: 0.3795
# Epoch 192/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3682 - YT_loss: 0.5615 - YP_loss: 1.8067 - YT_acc: 0.8235 - YP_acc: 0.3673 - val_loss: 2.3338 - val_YT_loss: 0.5651 - val_YP_loss: 1.7687 - val_YT_acc: 0.8162 - val_YP_acc: 0.3796
# Epoch 193/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3665 - YT_loss: 0.5596 - YP_loss: 1.8069 - YT_acc: 0.8243 - YP_acc: 0.3669 - val_loss: 2.3301 - val_YT_loss: 0.5661 - val_YP_loss: 1.7640 - val_YT_acc: 0.8158 - val_YP_acc: 0.3812
# Epoch 194/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3653 - YT_loss: 0.5600 - YP_loss: 1.8053 - YT_acc: 0.8238 - YP_acc: 0.3678 - val_loss: 2.3286 - val_YT_loss: 0.5643 - val_YP_loss: 1.7643 - val_YT_acc: 0.8159 - val_YP_acc: 0.3810
# Epoch 195/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3631 - YT_loss: 0.5588 - YP_loss: 1.8043 - YT_acc: 0.8240 - YP_acc: 0.3681 - val_loss: 2.3320 - val_YT_loss: 0.5672 - val_YP_loss: 1.7649 - val_YT_acc: 0.8157 - val_YP_acc: 0.3807
# Epoch 196/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3695 - YT_loss: 0.5621 - YP_loss: 1.8074 - YT_acc: 0.8240 - YP_acc: 0.3673 - val_loss: 2.3369 - val_YT_loss: 0.5681 - val_YP_loss: 1.7687 - val_YT_acc: 0.8167 - val_YP_acc: 0.3795
# Epoch 197/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3669 - YT_loss: 0.5612 - YP_loss: 1.8056 - YT_acc: 0.8237 - YP_acc: 0.3680 - val_loss: 2.3318 - val_YT_loss: 0.5652 - val_YP_loss: 1.7666 - val_YT_acc: 0.8159 - val_YP_acc: 0.3818
# Epoch 198/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3640 - YT_loss: 0.5584 - YP_loss: 1.8055 - YT_acc: 0.8239 - YP_acc: 0.3675 - val_loss: 2.3270 - val_YT_loss: 0.5634 - val_YP_loss: 1.7636 - val_YT_acc: 0.8159 - val_YP_acc: 0.3822
# Epoch 199/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3610 - YT_loss: 0.5579 - YP_loss: 1.8031 - YT_acc: 0.8241 - YP_acc: 0.3683 - val_loss: 2.3260 - val_YT_loss: 0.5614 - val_YP_loss: 1.7646 - val_YT_acc: 0.8163 - val_YP_acc: 0.3816
# Epoch 200/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.3592 - YT_loss: 0.5561 - YP_loss: 1.8031 - YT_acc: 0.8243 - YP_acc: 0.3681 - val_loss: 2.3257 - val_YT_loss: 0.5608 - val_YP_loss: 1.7649 - val_YT_acc: 0.8163 - val_YP_acc: 0.3822
# Epoch 201/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3583 - YT_loss: 0.5566 - YP_loss: 1.8017 - YT_acc: 0.8243 - YP_acc: 0.3678 - val_loss: 2.3256 - val_YT_loss: 0.5620 - val_YP_loss: 1.7636 - val_YT_acc: 0.8165 - val_YP_acc: 0.3819
# Epoch 202/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3562 - YT_loss: 0.5552 - YP_loss: 1.8010 - YT_acc: 0.8248 - YP_acc: 0.3693 - val_loss: 2.3204 - val_YT_loss: 0.5604 - val_YP_loss: 1.7600 - val_YT_acc: 0.8162 - val_YP_acc: 0.3824
# Epoch 203/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3544 - YT_loss: 0.5552 - YP_loss: 1.7992 - YT_acc: 0.8246 - YP_acc: 0.3698 - val_loss: 2.3249 - val_YT_loss: 0.5635 - val_YP_loss: 1.7614 - val_YT_acc: 0.8164 - val_YP_acc: 0.3835
# Epoch 204/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3565 - YT_loss: 0.5559 - YP_loss: 1.8006 - YT_acc: 0.8249 - YP_acc: 0.3694 - val_loss: 2.3224 - val_YT_loss: 0.5618 - val_YP_loss: 1.7607 - val_YT_acc: 0.8161 - val_YP_acc: 0.3850
# Epoch 205/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3533 - YT_loss: 0.5546 - YP_loss: 1.7987 - YT_acc: 0.8242 - YP_acc: 0.3695 - val_loss: 2.3184 - val_YT_loss: 0.5594 - val_YP_loss: 1.7590 - val_YT_acc: 0.8170 - val_YP_acc: 0.3841
# Epoch 206/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3510 - YT_loss: 0.5535 - YP_loss: 1.7975 - YT_acc: 0.8250 - YP_acc: 0.3709 - val_loss: 2.3167 - val_YT_loss: 0.5584 - val_YP_loss: 1.7583 - val_YT_acc: 0.8165 - val_YP_acc: 0.3838
# Epoch 207/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3513 - YT_loss: 0.5549 - YP_loss: 1.7964 - YT_acc: 0.8247 - YP_acc: 0.3710 - val_loss: 2.3295 - val_YT_loss: 0.5669 - val_YP_loss: 1.7626 - val_YT_acc: 0.8156 - val_YP_acc: 0.3816
# Epoch 208/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3576 - YT_loss: 0.5574 - YP_loss: 1.8001 - YT_acc: 0.8247 - YP_acc: 0.3698 - val_loss: 2.3234 - val_YT_loss: 0.5640 - val_YP_loss: 1.7593 - val_YT_acc: 0.8165 - val_YP_acc: 0.3840
# Epoch 209/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3528 - YT_loss: 0.5547 - YP_loss: 1.7981 - YT_acc: 0.8248 - YP_acc: 0.3704 - val_loss: 2.3183 - val_YT_loss: 0.5606 - val_YP_loss: 1.7577 - val_YT_acc: 0.8164 - val_YP_acc: 0.3842
# Epoch 210/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3506 - YT_loss: 0.5538 - YP_loss: 1.7967 - YT_acc: 0.8248 - YP_acc: 0.3704 - val_loss: 2.3196 - val_YT_loss: 0.5611 - val_YP_loss: 1.7585 - val_YT_acc: 0.8170 - val_YP_acc: 0.3847
# Epoch 211/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3478 - YT_loss: 0.5525 - YP_loss: 1.7953 - YT_acc: 0.8254 - YP_acc: 0.3710 - val_loss: 2.3143 - val_YT_loss: 0.5584 - val_YP_loss: 1.7560 - val_YT_acc: 0.8172 - val_YP_acc: 0.3855
# Epoch 212/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3458 - YT_loss: 0.5514 - YP_loss: 1.7944 - YT_acc: 0.8253 - YP_acc: 0.3717 - val_loss: 2.3141 - val_YT_loss: 0.5585 - val_YP_loss: 1.7555 - val_YT_acc: 0.8169 - val_YP_acc: 0.3844
# Epoch 213/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3458 - YT_loss: 0.5524 - YP_loss: 1.7934 - YT_acc: 0.8249 - YP_acc: 0.3723 - val_loss: 2.3206 - val_YT_loss: 0.5655 - val_YP_loss: 1.7551 - val_YT_acc: 0.8162 - val_YP_acc: 0.3852
# Epoch 214/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3499 - YT_loss: 0.5540 - YP_loss: 1.7959 - YT_acc: 0.8253 - YP_acc: 0.3708 - val_loss: 2.3176 - val_YT_loss: 0.5584 - val_YP_loss: 1.7593 - val_YT_acc: 0.8166 - val_YP_acc: 0.3842
# Epoch 215/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3445 - YT_loss: 0.5508 - YP_loss: 1.7938 - YT_acc: 0.8254 - YP_acc: 0.3713 - val_loss: 2.3117 - val_YT_loss: 0.5571 - val_YP_loss: 1.7546 - val_YT_acc: 0.8171 - val_YP_acc: 0.3861
# Epoch 216/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3457 - YT_loss: 0.5530 - YP_loss: 1.7927 - YT_acc: 0.8250 - YP_acc: 0.3724 - val_loss: 2.3137 - val_YT_loss: 0.5596 - val_YP_loss: 1.7541 - val_YT_acc: 0.8170 - val_YP_acc: 0.3867
# Epoch 217/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3410 - YT_loss: 0.5510 - YP_loss: 1.7900 - YT_acc: 0.8250 - YP_acc: 0.3736 - val_loss: 2.3090 - val_YT_loss: 0.5566 - val_YP_loss: 1.7524 - val_YT_acc: 0.8170 - val_YP_acc: 0.3854
# Epoch 218/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3392 - YT_loss: 0.5497 - YP_loss: 1.7895 - YT_acc: 0.8253 - YP_acc: 0.3727 - val_loss: 2.3079 - val_YT_loss: 0.5554 - val_YP_loss: 1.7525 - val_YT_acc: 0.8168 - val_YP_acc: 0.3862
# Epoch 219/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3403 - YT_loss: 0.5499 - YP_loss: 1.7903 - YT_acc: 0.8256 - YP_acc: 0.3726 - val_loss: 2.3118 - val_YT_loss: 0.5585 - val_YP_loss: 1.7534 - val_YT_acc: 0.8168 - val_YP_acc: 0.3859
# Epoch 220/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3401 - YT_loss: 0.5502 - YP_loss: 1.7900 - YT_acc: 0.8254 - YP_acc: 0.3728 - val_loss: 2.3123 - val_YT_loss: 0.5567 - val_YP_loss: 1.7557 - val_YT_acc: 0.8170 - val_YP_acc: 0.3846
# Epoch 221/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3397 - YT_loss: 0.5495 - YP_loss: 1.7902 - YT_acc: 0.8257 - YP_acc: 0.3729 - val_loss: 2.3106 - val_YT_loss: 0.5564 - val_YP_loss: 1.7541 - val_YT_acc: 0.8169 - val_YP_acc: 0.3864
# Epoch 222/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3413 - YT_loss: 0.5495 - YP_loss: 1.7918 - YT_acc: 0.8253 - YP_acc: 0.3723 - val_loss: 2.3098 - val_YT_loss: 0.5563 - val_YP_loss: 1.7535 - val_YT_acc: 0.8170 - val_YP_acc: 0.3854
# Epoch 223/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.3377 - YT_loss: 0.5495 - YP_loss: 1.7883 - YT_acc: 0.8257 - YP_acc: 0.3737 - val_loss: 2.3061 - val_YT_loss: 0.5552 - val_YP_loss: 1.7509 - val_YT_acc: 0.8175 - val_YP_acc: 0.3866
# Epoch 224/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3373 - YT_loss: 0.5498 - YP_loss: 1.7875 - YT_acc: 0.8254 - YP_acc: 0.3737 - val_loss: 2.3085 - val_YT_loss: 0.5573 - val_YP_loss: 1.7511 - val_YT_acc: 0.8175 - val_YP_acc: 0.3865
# Epoch 225/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3368 - YT_loss: 0.5497 - YP_loss: 1.7871 - YT_acc: 0.8257 - YP_acc: 0.3743 - val_loss: 2.3092 - val_YT_loss: 0.5575 - val_YP_loss: 1.7518 - val_YT_acc: 0.8180 - val_YP_acc: 0.3871
# Epoch 226/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3369 - YT_loss: 0.5493 - YP_loss: 1.7876 - YT_acc: 0.8260 - YP_acc: 0.3736 - val_loss: 2.3035 - val_YT_loss: 0.5545 - val_YP_loss: 1.7490 - val_YT_acc: 0.8175 - val_YP_acc: 0.3877
# Epoch 227/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3335 - YT_loss: 0.5483 - YP_loss: 1.7852 - YT_acc: 0.8260 - YP_acc: 0.3748 - val_loss: 2.3044 - val_YT_loss: 0.5565 - val_YP_loss: 1.7478 - val_YT_acc: 0.8167 - val_YP_acc: 0.3882
# Epoch 228/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3338 - YT_loss: 0.5471 - YP_loss: 1.7868 - YT_acc: 0.8260 - YP_acc: 0.3745 - val_loss: 2.3070 - val_YT_loss: 0.5578 - val_YP_loss: 1.7492 - val_YT_acc: 0.8167 - val_YP_acc: 0.3875
# Epoch 229/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3320 - YT_loss: 0.5479 - YP_loss: 1.7841 - YT_acc: 0.8261 - YP_acc: 0.3752 - val_loss: 2.3026 - val_YT_loss: 0.5559 - val_YP_loss: 1.7468 - val_YT_acc: 0.8172 - val_YP_acc: 0.3891
# Epoch 230/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3297 - YT_loss: 0.5472 - YP_loss: 1.7826 - YT_acc: 0.8256 - YP_acc: 0.3760 - val_loss: 2.3008 - val_YT_loss: 0.5541 - val_YP_loss: 1.7468 - val_YT_acc: 0.8172 - val_YP_acc: 0.3888
# Epoch 231/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3290 - YT_loss: 0.5457 - YP_loss: 1.7833 - YT_acc: 0.8261 - YP_acc: 0.3756 - val_loss: 2.3014 - val_YT_loss: 0.5551 - val_YP_loss: 1.7463 - val_YT_acc: 0.8170 - val_YP_acc: 0.3885
# Epoch 232/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3287 - YT_loss: 0.5460 - YP_loss: 1.7827 - YT_acc: 0.8262 - YP_acc: 0.3758 - val_loss: 2.3063 - val_YT_loss: 0.5604 - val_YP_loss: 1.7459 - val_YT_acc: 0.8168 - val_YP_acc: 0.3886
# Epoch 233/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3295 - YT_loss: 0.5476 - YP_loss: 1.7820 - YT_acc: 0.8261 - YP_acc: 0.3756 - val_loss: 2.3040 - val_YT_loss: 0.5568 - val_YP_loss: 1.7472 - val_YT_acc: 0.8173 - val_YP_acc: 0.3880
# Epoch 234/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3380 - YT_loss: 0.5491 - YP_loss: 1.7889 - YT_acc: 0.8256 - YP_acc: 0.3735 - val_loss: 2.3042 - val_YT_loss: 0.5550 - val_YP_loss: 1.7492 - val_YT_acc: 0.8178 - val_YP_acc: 0.3881
# Epoch 235/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3318 - YT_loss: 0.5470 - YP_loss: 1.7848 - YT_acc: 0.8256 - YP_acc: 0.3751 - val_loss: 2.3016 - val_YT_loss: 0.5545 - val_YP_loss: 1.7472 - val_YT_acc: 0.8182 - val_YP_acc: 0.3875
# Epoch 236/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3307 - YT_loss: 0.5472 - YP_loss: 1.7834 - YT_acc: 0.8260 - YP_acc: 0.3756 - val_loss: 2.3021 - val_YT_loss: 0.5559 - val_YP_loss: 1.7462 - val_YT_acc: 0.8170 - val_YP_acc: 0.3885
# Epoch 237/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3272 - YT_loss: 0.5453 - YP_loss: 1.7819 - YT_acc: 0.8260 - YP_acc: 0.3758 - val_loss: 2.2958 - val_YT_loss: 0.5522 - val_YP_loss: 1.7436 - val_YT_acc: 0.8178 - val_YP_acc: 0.3900
# Epoch 238/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3259 - YT_loss: 0.5451 - YP_loss: 1.7808 - YT_acc: 0.8261 - YP_acc: 0.3772 - val_loss: 2.2947 - val_YT_loss: 0.5527 - val_YP_loss: 1.7420 - val_YT_acc: 0.8173 - val_YP_acc: 0.3890
# Epoch 239/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3238 - YT_loss: 0.5452 - YP_loss: 1.7786 - YT_acc: 0.8260 - YP_acc: 0.3775 - val_loss: 2.2933 - val_YT_loss: 0.5529 - val_YP_loss: 1.7404 - val_YT_acc: 0.8179 - val_YP_acc: 0.3909
# Epoch 240/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3222 - YT_loss: 0.5450 - YP_loss: 1.7772 - YT_acc: 0.8261 - YP_acc: 0.3779 - val_loss: 2.2933 - val_YT_loss: 0.5521 - val_YP_loss: 1.7412 - val_YT_acc: 0.8173 - val_YP_acc: 0.3902
# Epoch 241/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3200 - YT_loss: 0.5437 - YP_loss: 1.7763 - YT_acc: 0.8265 - YP_acc: 0.3776 - val_loss: 2.2939 - val_YT_loss: 0.5505 - val_YP_loss: 1.7434 - val_YT_acc: 0.8176 - val_YP_acc: 0.3902
# Epoch 242/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3263 - YT_loss: 0.5474 - YP_loss: 1.7789 - YT_acc: 0.8260 - YP_acc: 0.3773 - val_loss: 2.3036 - val_YT_loss: 0.5580 - val_YP_loss: 1.7456 - val_YT_acc: 0.8175 - val_YP_acc: 0.3890
# Epoch 243/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3287 - YT_loss: 0.5494 - YP_loss: 1.7793 - YT_acc: 0.8259 - YP_acc: 0.3774 - val_loss: 2.3012 - val_YT_loss: 0.5580 - val_YP_loss: 1.7432 - val_YT_acc: 0.8170 - val_YP_acc: 0.3901
# Epoch 244/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3232 - YT_loss: 0.5467 - YP_loss: 1.7765 - YT_acc: 0.8262 - YP_acc: 0.3778 - val_loss: 2.2942 - val_YT_loss: 0.5533 - val_YP_loss: 1.7409 - val_YT_acc: 0.8175 - val_YP_acc: 0.3897
# Epoch 245/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3227 - YT_loss: 0.5445 - YP_loss: 1.7782 - YT_acc: 0.8264 - YP_acc: 0.3782 - val_loss: 2.2925 - val_YT_loss: 0.5523 - val_YP_loss: 1.7402 - val_YT_acc: 0.8178 - val_YP_acc: 0.3919
# Epoch 246/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3240 - YT_loss: 0.5458 - YP_loss: 1.7782 - YT_acc: 0.8260 - YP_acc: 0.3775 - val_loss: 2.3083 - val_YT_loss: 0.5644 - val_YP_loss: 1.7440 - val_YT_acc: 0.8172 - val_YP_acc: 0.3896
# Epoch 247/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3309 - YT_loss: 0.5507 - YP_loss: 1.7802 - YT_acc: 0.8262 - YP_acc: 0.3769 - val_loss: 2.2983 - val_YT_loss: 0.5564 - val_YP_loss: 1.7420 - val_YT_acc: 0.8174 - val_YP_acc: 0.3906
# Epoch 248/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3238 - YT_loss: 0.5469 - YP_loss: 1.7769 - YT_acc: 0.8260 - YP_acc: 0.3786 - val_loss: 2.2943 - val_YT_loss: 0.5537 - val_YP_loss: 1.7406 - val_YT_acc: 0.8175 - val_YP_acc: 0.3893
# Epoch 249/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3199 - YT_loss: 0.5443 - YP_loss: 1.7756 - YT_acc: 0.8269 - YP_acc: 0.3787 - val_loss: 2.2880 - val_YT_loss: 0.5518 - val_YP_loss: 1.7362 - val_YT_acc: 0.8174 - val_YP_acc: 0.3920
# Epoch 250/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3149 - YT_loss: 0.5425 - YP_loss: 1.7724 - YT_acc: 0.8264 - YP_acc: 0.3796 - val_loss: 2.2865 - val_YT_loss: 0.5499 - val_YP_loss: 1.7366 - val_YT_acc: 0.8174 - val_YP_acc: 0.3911
# Saved rnn model to disk

# %%
gru_file = Path("model_gru.json")
if not gru_file.is_file():
    history2 = GRUmodel.fit(x, y, batch_size=512, epochs=250, validation_split=0.2)
    with open('gru_history', 'wb') as file_pi:
        pickle.dump(history2.history, file_pi)
    model_json = GRUmodel.to_json()
    with open("model_gru.json", "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    GRUmodel.save_weights("model_gru.h5")
    print("Saved gru model to disk")
else:
    with open('gru_history', 'rb') as file_pi:
        h = pickle.load(file_pi)
    history2 = SavedHistory()
    history2.history = h
    
    # load json and create model
    json_file = open('model_gru.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    
    GRUmodel = model_from_json(loaded_model_json)
    # load weights into new model
    GRUmodel.load_weights("model_gru.h5")
    print("Loaded model from disk")
# Out:
# Train on 3503 samples, validate on 876 samples
# Epoch 1/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 6.1274 - YT_loss: 2.3222 - YP_loss: 3.8051 - YT_acc: 0.5810 - YP_acc: 0.0316 - val_loss: 5.1151 - val_YT_loss: 1.4079 - val_YP_loss: 3.7073 - val_YT_acc: 0.6805 - val_YP_acc: 0.0878
# Epoch 2/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 4.9035 - YT_loss: 1.2850 - YP_loss: 3.6185 - YT_acc: 0.7067 - YP_acc: 0.0736 - val_loss: 4.5460 - val_YT_loss: 1.1413 - val_YP_loss: 3.4048 - val_YT_acc: 0.6805 - val_YP_acc: 0.0895
# Epoch 3/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 4.4960 - YT_loss: 1.0903 - YP_loss: 3.4057 - YT_acc: 0.7102 - YP_acc: 0.0848 - val_loss: 4.3376 - val_YT_loss: 1.0643 - val_YP_loss: 3.2733 - val_YT_acc: 0.6837 - val_YP_acc: 0.0963
# Epoch 4/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 4.3254 - YT_loss: 1.0139 - YP_loss: 3.3115 - YT_acc: 0.7107 - YP_acc: 0.0806 - val_loss: 4.2053 - val_YT_loss: 1.0200 - val_YP_loss: 3.1853 - val_YT_acc: 0.6861 - val_YP_acc: 0.1002
# Epoch 5/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 4.2073 - YT_loss: 0.9685 - YP_loss: 3.2388 - YT_acc: 0.7312 - YP_acc: 0.0904 - val_loss: 4.1026 - val_YT_loss: 0.9710 - val_YP_loss: 3.1316 - val_YT_acc: 0.7247 - val_YP_acc: 0.0992
# Epoch 6/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 4.0821 - YT_loss: 0.9299 - YP_loss: 3.1522 - YT_acc: 0.7393 - YP_acc: 0.1034 - val_loss: 3.9355 - val_YT_loss: 0.9309 - val_YP_loss: 3.0046 - val_YT_acc: 0.7218 - val_YP_acc: 0.1374
# Epoch 7/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 3.8970 - YT_loss: 0.9006 - YP_loss: 2.9964 - YT_acc: 0.7448 - YP_acc: 0.1231 - val_loss: 3.6923 - val_YT_loss: 0.9026 - val_YP_loss: 2.7897 - val_YT_acc: 0.7363 - val_YP_acc: 0.1537
# Epoch 8/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 3.6832 - YT_loss: 0.8939 - YP_loss: 2.7894 - YT_acc: 0.7506 - YP_acc: 0.1368 - val_loss: 3.4914 - val_YT_loss: 0.8764 - val_YP_loss: 2.6150 - val_YT_acc: 0.7440 - val_YP_acc: 0.1624
# Epoch 9/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 3.5302 - YT_loss: 0.8683 - YP_loss: 2.6619 - YT_acc: 0.7537 - YP_acc: 0.1475 - val_loss: 3.3628 - val_YT_loss: 0.8579 - val_YP_loss: 2.5049 - val_YT_acc: 0.7463 - val_YP_acc: 0.1742
# Epoch 10/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 3.4139 - YT_loss: 0.8593 - YP_loss: 2.5546 - YT_acc: 0.7549 - YP_acc: 0.1580 - val_loss: 3.2484 - val_YT_loss: 0.8421 - val_YP_loss: 2.4063 - val_YT_acc: 0.7472 - val_YP_acc: 0.1818
# Epoch 11/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 3.3197 - YT_loss: 0.8399 - YP_loss: 2.4798 - YT_acc: 0.7575 - YP_acc: 0.1662 - val_loss: 3.1652 - val_YT_loss: 0.8172 - val_YP_loss: 2.3481 - val_YT_acc: 0.7485 - val_YP_acc: 0.1854
# Epoch 12/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 3.2453 - YT_loss: 0.8191 - YP_loss: 2.4262 - YT_acc: 0.7603 - YP_acc: 0.1726 - val_loss: 3.1022 - val_YT_loss: 0.8001 - val_YP_loss: 2.3021 - val_YT_acc: 0.7519 - val_YP_acc: 0.1984
# Epoch 13/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 3.1843 - YT_loss: 0.8057 - YP_loss: 2.3786 - YT_acc: 0.7614 - YP_acc: 0.1798 - val_loss: 3.0433 - val_YT_loss: 0.7866 - val_YP_loss: 2.2567 - val_YT_acc: 0.7542 - val_YP_acc: 0.2054
# Epoch 14/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 3.1296 - YT_loss: 0.7941 - YP_loss: 2.3355 - YT_acc: 0.7630 - YP_acc: 0.1866 - val_loss: 2.9923 - val_YT_loss: 0.7770 - val_YP_loss: 2.2153 - val_YT_acc: 0.7558 - val_YP_acc: 0.2147
# Epoch 15/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 3.0820 - YT_loss: 0.7856 - YP_loss: 2.2964 - YT_acc: 0.7647 - YP_acc: 0.1918 - val_loss: 2.9461 - val_YT_loss: 0.7674 - val_YP_loss: 2.1788 - val_YT_acc: 0.7580 - val_YP_acc: 0.2244
# Epoch 16/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 3.0357 - YT_loss: 0.7751 - YP_loss: 2.2606 - YT_acc: 0.7669 - YP_acc: 0.2002 - val_loss: 2.9044 - val_YT_loss: 0.7582 - val_YP_loss: 2.1462 - val_YT_acc: 0.7602 - val_YP_acc: 0.2322
# Epoch 17/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.9939 - YT_loss: 0.7657 - YP_loss: 2.2282 - YT_acc: 0.7698 - YP_acc: 0.2078 - val_loss: 2.8653 - val_YT_loss: 0.7486 - val_YP_loss: 2.1167 - val_YT_acc: 0.7635 - val_YP_acc: 0.2406
# Epoch 18/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.9585 - YT_loss: 0.7568 - YP_loss: 2.2017 - YT_acc: 0.7723 - YP_acc: 0.2138 - val_loss: 2.8303 - val_YT_loss: 0.7388 - val_YP_loss: 2.0915 - val_YT_acc: 0.7668 - val_YP_acc: 0.2481
# Epoch 19/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.9255 - YT_loss: 0.7472 - YP_loss: 2.1783 - YT_acc: 0.7744 - YP_acc: 0.2203 - val_loss: 2.7989 - val_YT_loss: 0.7295 - val_YP_loss: 2.0695 - val_YT_acc: 0.7691 - val_YP_acc: 0.2558
# Epoch 20/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.8939 - YT_loss: 0.7382 - YP_loss: 2.1557 - YT_acc: 0.7772 - YP_acc: 0.2276 - val_loss: 2.7705 - val_YT_loss: 0.7201 - val_YP_loss: 2.0504 - val_YT_acc: 0.7726 - val_YP_acc: 0.2646
# Epoch 21/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.8667 - YT_loss: 0.7288 - YP_loss: 2.1379 - YT_acc: 0.7796 - YP_acc: 0.2339 - val_loss: 2.7446 - val_YT_loss: 0.7113 - val_YP_loss: 2.0333 - val_YT_acc: 0.7774 - val_YP_acc: 0.2695
# Epoch 22/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.8408 - YT_loss: 0.7204 - YP_loss: 2.1204 - YT_acc: 0.7823 - YP_acc: 0.2404 - val_loss: 2.7208 - val_YT_loss: 0.7031 - val_YP_loss: 2.0177 - val_YT_acc: 0.7810 - val_YP_acc: 0.2763
# Epoch 23/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.8181 - YT_loss: 0.7138 - YP_loss: 2.1042 - YT_acc: 0.7852 - YP_acc: 0.2465 - val_loss: 2.6990 - val_YT_loss: 0.6950 - val_YP_loss: 2.0040 - val_YT_acc: 0.7844 - val_YP_acc: 0.2846
# Epoch 24/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.7940 - YT_loss: 0.7048 - YP_loss: 2.0892 - YT_acc: 0.7882 - YP_acc: 0.2526 - val_loss: 2.6790 - val_YT_loss: 0.6873 - val_YP_loss: 1.9917 - val_YT_acc: 0.7871 - val_YP_acc: 0.2895
# Epoch 25/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.7747 - YT_loss: 0.6980 - YP_loss: 2.0767 - YT_acc: 0.7910 - YP_acc: 0.2576 - val_loss: 2.6614 - val_YT_loss: 0.6810 - val_YP_loss: 1.9804 - val_YT_acc: 0.7894 - val_YP_acc: 0.2944
# Epoch 26/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.7561 - YT_loss: 0.6917 - YP_loss: 2.0644 - YT_acc: 0.7929 - YP_acc: 0.2632 - val_loss: 2.6472 - val_YT_loss: 0.6764 - val_YP_loss: 1.9708 - val_YT_acc: 0.7909 - val_YP_acc: 0.2980
# Epoch 27/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.7400 - YT_loss: 0.6869 - YP_loss: 2.0531 - YT_acc: 0.7941 - YP_acc: 0.2669 - val_loss: 2.6344 - val_YT_loss: 0.6723 - val_YP_loss: 1.9621 - val_YT_acc: 0.7925 - val_YP_acc: 0.3002
# Epoch 28/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.7255 - YT_loss: 0.6827 - YP_loss: 2.0429 - YT_acc: 0.7957 - YP_acc: 0.2723 - val_loss: 2.6222 - val_YT_loss: 0.6693 - val_YP_loss: 1.9529 - val_YT_acc: 0.7938 - val_YP_acc: 0.3042
# Epoch 29/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.7131 - YT_loss: 0.6793 - YP_loss: 2.0338 - YT_acc: 0.7966 - YP_acc: 0.2762 - val_loss: 2.6118 - val_YT_loss: 0.6660 - val_YP_loss: 1.9459 - val_YT_acc: 0.7946 - val_YP_acc: 0.3049
# Epoch 30/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.6998 - YT_loss: 0.6748 - YP_loss: 2.0251 - YT_acc: 0.7979 - YP_acc: 0.2803 - val_loss: 2.6018 - val_YT_loss: 0.6630 - val_YP_loss: 1.9388 - val_YT_acc: 0.7954 - val_YP_acc: 0.3094
# Epoch 31/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.6890 - YT_loss: 0.6719 - YP_loss: 2.0170 - YT_acc: 0.7987 - YP_acc: 0.2831 - val_loss: 2.5933 - val_YT_loss: 0.6604 - val_YP_loss: 1.9328 - val_YT_acc: 0.7971 - val_YP_acc: 0.3120
# Epoch 32/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.6773 - YT_loss: 0.6688 - YP_loss: 2.0084 - YT_acc: 0.7996 - YP_acc: 0.2872 - val_loss: 2.5839 - val_YT_loss: 0.6572 - val_YP_loss: 1.9267 - val_YT_acc: 0.7976 - val_YP_acc: 0.3142
# Epoch 33/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.6681 - YT_loss: 0.6653 - YP_loss: 2.0028 - YT_acc: 0.8001 - YP_acc: 0.2894 - val_loss: 2.5761 - val_YT_loss: 0.6548 - val_YP_loss: 1.9213 - val_YT_acc: 0.7990 - val_YP_acc: 0.3169
# Epoch 34/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.6578 - YT_loss: 0.6619 - YP_loss: 1.9959 - YT_acc: 0.8013 - YP_acc: 0.2925 - val_loss: 2.5685 - val_YT_loss: 0.6523 - val_YP_loss: 1.9161 - val_YT_acc: 0.7996 - val_YP_acc: 0.3188
# Epoch 35/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.6483 - YT_loss: 0.6587 - YP_loss: 1.9896 - YT_acc: 0.8025 - YP_acc: 0.2941 - val_loss: 2.5614 - val_YT_loss: 0.6500 - val_YP_loss: 1.9113 - val_YT_acc: 0.8004 - val_YP_acc: 0.3218
# Epoch 36/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.6391 - YT_loss: 0.6553 - YP_loss: 1.9838 - YT_acc: 0.8034 - YP_acc: 0.2974 - val_loss: 2.5541 - val_YT_loss: 0.6473 - val_YP_loss: 1.9068 - val_YT_acc: 0.8012 - val_YP_acc: 0.3239
# Epoch 37/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.6317 - YT_loss: 0.6528 - YP_loss: 1.9788 - YT_acc: 0.8041 - YP_acc: 0.2991 - val_loss: 2.5471 - val_YT_loss: 0.6451 - val_YP_loss: 1.9020 - val_YT_acc: 0.8017 - val_YP_acc: 0.3270
# Epoch 38/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.6224 - YT_loss: 0.6499 - YP_loss: 1.9726 - YT_acc: 0.8046 - YP_acc: 0.3024 - val_loss: 2.5408 - val_YT_loss: 0.6433 - val_YP_loss: 1.8975 - val_YT_acc: 0.8027 - val_YP_acc: 0.3293
# Epoch 39/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.6149 - YT_loss: 0.6474 - YP_loss: 1.9676 - YT_acc: 0.8052 - YP_acc: 0.3045 - val_loss: 2.5339 - val_YT_loss: 0.6410 - val_YP_loss: 1.8929 - val_YT_acc: 0.8031 - val_YP_acc: 0.3311
# Epoch 40/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.6078 - YT_loss: 0.6450 - YP_loss: 1.9628 - YT_acc: 0.8060 - YP_acc: 0.3055 - val_loss: 2.5284 - val_YT_loss: 0.6393 - val_YP_loss: 1.8891 - val_YT_acc: 0.8036 - val_YP_acc: 0.3323
# Epoch 41/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.6007 - YT_loss: 0.6431 - YP_loss: 1.9576 - YT_acc: 0.8066 - YP_acc: 0.3076 - val_loss: 2.5222 - val_YT_loss: 0.6374 - val_YP_loss: 1.8848 - val_YT_acc: 0.8037 - val_YP_acc: 0.3347
# Epoch 42/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.5931 - YT_loss: 0.6405 - YP_loss: 1.9526 - YT_acc: 0.8074 - YP_acc: 0.3098 - val_loss: 2.5161 - val_YT_loss: 0.6354 - val_YP_loss: 1.8807 - val_YT_acc: 0.8042 - val_YP_acc: 0.3361
# Epoch 43/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5855 - YT_loss: 0.6385 - YP_loss: 1.9470 - YT_acc: 0.8079 - YP_acc: 0.3118 - val_loss: 2.5111 - val_YT_loss: 0.6340 - val_YP_loss: 1.8772 - val_YT_acc: 0.8046 - val_YP_acc: 0.3374
# Epoch 44/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.5793 - YT_loss: 0.6361 - YP_loss: 1.9432 - YT_acc: 0.8085 - YP_acc: 0.3142 - val_loss: 2.5056 - val_YT_loss: 0.6322 - val_YP_loss: 1.8733 - val_YT_acc: 0.8051 - val_YP_acc: 0.3391
# Epoch 45/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.5721 - YT_loss: 0.6341 - YP_loss: 1.9380 - YT_acc: 0.8088 - YP_acc: 0.3148 - val_loss: 2.5006 - val_YT_loss: 0.6306 - val_YP_loss: 1.8700 - val_YT_acc: 0.8053 - val_YP_acc: 0.3398
# Epoch 46/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.5662 - YT_loss: 0.6327 - YP_loss: 1.9336 - YT_acc: 0.8091 - YP_acc: 0.3172 - val_loss: 2.4948 - val_YT_loss: 0.6291 - val_YP_loss: 1.8657 - val_YT_acc: 0.8055 - val_YP_acc: 0.3421
# Epoch 47/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5604 - YT_loss: 0.6316 - YP_loss: 1.9288 - YT_acc: 0.8094 - YP_acc: 0.3192 - val_loss: 2.4904 - val_YT_loss: 0.6281 - val_YP_loss: 1.8624 - val_YT_acc: 0.8061 - val_YP_acc: 0.3435
# Epoch 48/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.5541 - YT_loss: 0.6292 - YP_loss: 1.9249 - YT_acc: 0.8103 - YP_acc: 0.3207 - val_loss: 2.4858 - val_YT_loss: 0.6266 - val_YP_loss: 1.8592 - val_YT_acc: 0.8059 - val_YP_acc: 0.3447
# Epoch 49/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.5490 - YT_loss: 0.6282 - YP_loss: 1.9209 - YT_acc: 0.8103 - YP_acc: 0.3217 - val_loss: 2.4808 - val_YT_loss: 0.6253 - val_YP_loss: 1.8555 - val_YT_acc: 0.8062 - val_YP_acc: 0.3466
# Epoch 50/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5423 - YT_loss: 0.6261 - YP_loss: 1.9162 - YT_acc: 0.8109 - YP_acc: 0.3241 - val_loss: 2.4755 - val_YT_loss: 0.6238 - val_YP_loss: 1.8517 - val_YT_acc: 0.8067 - val_YP_acc: 0.3486
# Epoch 51/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5366 - YT_loss: 0.6246 - YP_loss: 1.9120 - YT_acc: 0.8111 - YP_acc: 0.3254 - val_loss: 2.4710 - val_YT_loss: 0.6228 - val_YP_loss: 1.8482 - val_YT_acc: 0.8067 - val_YP_acc: 0.3498
# Epoch 52/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.5303 - YT_loss: 0.6227 - YP_loss: 1.9076 - YT_acc: 0.8117 - YP_acc: 0.3270 - val_loss: 2.4663 - val_YT_loss: 0.6215 - val_YP_loss: 1.8448 - val_YT_acc: 0.8069 - val_YP_acc: 0.3523
# Epoch 53/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5240 - YT_loss: 0.6210 - YP_loss: 1.9030 - YT_acc: 0.8122 - YP_acc: 0.3287 - val_loss: 2.4609 - val_YT_loss: 0.6200 - val_YP_loss: 1.8409 - val_YT_acc: 0.8071 - val_YP_acc: 0.3529
# Epoch 54/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5186 - YT_loss: 0.6194 - YP_loss: 1.8992 - YT_acc: 0.8125 - YP_acc: 0.3309 - val_loss: 2.4557 - val_YT_loss: 0.6188 - val_YP_loss: 1.8369 - val_YT_acc: 0.8072 - val_YP_acc: 0.3555
# Epoch 55/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.5136 - YT_loss: 0.6182 - YP_loss: 1.8954 - YT_acc: 0.8126 - YP_acc: 0.3320 - val_loss: 2.4510 - val_YT_loss: 0.6174 - val_YP_loss: 1.8336 - val_YT_acc: 0.8075 - val_YP_acc: 0.3557
# Epoch 56/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5064 - YT_loss: 0.6167 - YP_loss: 1.8897 - YT_acc: 0.8131 - YP_acc: 0.3339 - val_loss: 2.4469 - val_YT_loss: 0.6164 - val_YP_loss: 1.8305 - val_YT_acc: 0.8076 - val_YP_acc: 0.3580
# Epoch 57/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.5026 - YT_loss: 0.6150 - YP_loss: 1.8876 - YT_acc: 0.8134 - YP_acc: 0.3353 - val_loss: 2.4418 - val_YT_loss: 0.6152 - val_YP_loss: 1.8266 - val_YT_acc: 0.8076 - val_YP_acc: 0.3593
# Epoch 58/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4964 - YT_loss: 0.6141 - YP_loss: 1.8822 - YT_acc: 0.8135 - YP_acc: 0.3370 - val_loss: 2.4367 - val_YT_loss: 0.6141 - val_YP_loss: 1.8226 - val_YT_acc: 0.8080 - val_YP_acc: 0.3613
# Epoch 59/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4918 - YT_loss: 0.6130 - YP_loss: 1.8788 - YT_acc: 0.8138 - YP_acc: 0.3388 - val_loss: 2.4329 - val_YT_loss: 0.6132 - val_YP_loss: 1.8197 - val_YT_acc: 0.8079 - val_YP_acc: 0.3623
# Epoch 60/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4864 - YT_loss: 0.6108 - YP_loss: 1.8756 - YT_acc: 0.8143 - YP_acc: 0.3393 - val_loss: 2.4276 - val_YT_loss: 0.6115 - val_YP_loss: 1.8160 - val_YT_acc: 0.8079 - val_YP_acc: 0.3643
# Epoch 61/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4806 - YT_loss: 0.6096 - YP_loss: 1.8710 - YT_acc: 0.8143 - YP_acc: 0.3417 - val_loss: 2.4235 - val_YT_loss: 0.6106 - val_YP_loss: 1.8128 - val_YT_acc: 0.8079 - val_YP_acc: 0.3654
# Epoch 62/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4762 - YT_loss: 0.6085 - YP_loss: 1.8677 - YT_acc: 0.8149 - YP_acc: 0.3419 - val_loss: 2.4187 - val_YT_loss: 0.6093 - val_YP_loss: 1.8094 - val_YT_acc: 0.8084 - val_YP_acc: 0.3661
# Epoch 63/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4728 - YT_loss: 0.6079 - YP_loss: 1.8649 - YT_acc: 0.8150 - YP_acc: 0.3429 - val_loss: 2.4152 - val_YT_loss: 0.6083 - val_YP_loss: 1.8069 - val_YT_acc: 0.8081 - val_YP_acc: 0.3662
# Epoch 64/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4665 - YT_loss: 0.6064 - YP_loss: 1.8601 - YT_acc: 0.8151 - YP_acc: 0.3455 - val_loss: 2.4111 - val_YT_loss: 0.6071 - val_YP_loss: 1.8040 - val_YT_acc: 0.8080 - val_YP_acc: 0.3683
# Epoch 65/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4614 - YT_loss: 0.6047 - YP_loss: 1.8567 - YT_acc: 0.8152 - YP_acc: 0.3468 - val_loss: 2.4065 - val_YT_loss: 0.6059 - val_YP_loss: 1.8006 - val_YT_acc: 0.8084 - val_YP_acc: 0.3698
# Epoch 66/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4588 - YT_loss: 0.6045 - YP_loss: 1.8543 - YT_acc: 0.8156 - YP_acc: 0.3477 - val_loss: 2.4026 - val_YT_loss: 0.6047 - val_YP_loss: 1.7980 - val_YT_acc: 0.8088 - val_YP_acc: 0.3702
# Epoch 67/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4536 - YT_loss: 0.6024 - YP_loss: 1.8512 - YT_acc: 0.8158 - YP_acc: 0.3493 - val_loss: 2.3989 - val_YT_loss: 0.6036 - val_YP_loss: 1.7953 - val_YT_acc: 0.8085 - val_YP_acc: 0.3709
# Epoch 68/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4501 - YT_loss: 0.6017 - YP_loss: 1.8484 - YT_acc: 0.8161 - YP_acc: 0.3496 - val_loss: 2.3951 - val_YT_loss: 0.6021 - val_YP_loss: 1.7931 - val_YT_acc: 0.8092 - val_YP_acc: 0.3720
# Epoch 69/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4445 - YT_loss: 0.6000 - YP_loss: 1.8445 - YT_acc: 0.8163 - YP_acc: 0.3513 - val_loss: 2.3913 - val_YT_loss: 0.6011 - val_YP_loss: 1.7903 - val_YT_acc: 0.8097 - val_YP_acc: 0.3734
# Epoch 70/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4416 - YT_loss: 0.5987 - YP_loss: 1.8430 - YT_acc: 0.8168 - YP_acc: 0.3527 - val_loss: 2.3880 - val_YT_loss: 0.5998 - val_YP_loss: 1.7883 - val_YT_acc: 0.8093 - val_YP_acc: 0.3736
# Epoch 71/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4373 - YT_loss: 0.5974 - YP_loss: 1.8399 - YT_acc: 0.8172 - YP_acc: 0.3526 - val_loss: 2.3844 - val_YT_loss: 0.5989 - val_YP_loss: 1.7855 - val_YT_acc: 0.8102 - val_YP_acc: 0.3745
# Epoch 72/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4331 - YT_loss: 0.5964 - YP_loss: 1.8367 - YT_acc: 0.8173 - YP_acc: 0.3549 - val_loss: 2.3813 - val_YT_loss: 0.5976 - val_YP_loss: 1.7838 - val_YT_acc: 0.8097 - val_YP_acc: 0.3756
# Epoch 73/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4292 - YT_loss: 0.5952 - YP_loss: 1.8340 - YT_acc: 0.8173 - YP_acc: 0.3553 - val_loss: 2.3771 - val_YT_loss: 0.5962 - val_YP_loss: 1.7810 - val_YT_acc: 0.8104 - val_YP_acc: 0.3767
# Epoch 74/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4251 - YT_loss: 0.5935 - YP_loss: 1.8316 - YT_acc: 0.8176 - YP_acc: 0.3566 - val_loss: 2.3746 - val_YT_loss: 0.5953 - val_YP_loss: 1.7793 - val_YT_acc: 0.8103 - val_YP_acc: 0.3776
# Epoch 75/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4221 - YT_loss: 0.5924 - YP_loss: 1.8297 - YT_acc: 0.8179 - YP_acc: 0.3568 - val_loss: 2.3712 - val_YT_loss: 0.5938 - val_YP_loss: 1.7774 - val_YT_acc: 0.8108 - val_YP_acc: 0.3779
# Epoch 76/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4182 - YT_loss: 0.5915 - YP_loss: 1.8267 - YT_acc: 0.8183 - YP_acc: 0.3578 - val_loss: 2.3683 - val_YT_loss: 0.5928 - val_YP_loss: 1.7755 - val_YT_acc: 0.8104 - val_YP_acc: 0.3788
# Epoch 77/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4138 - YT_loss: 0.5901 - YP_loss: 1.8238 - YT_acc: 0.8185 - YP_acc: 0.3592 - val_loss: 2.3634 - val_YT_loss: 0.5914 - val_YP_loss: 1.7720 - val_YT_acc: 0.8108 - val_YP_acc: 0.3804
# Epoch 78/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4100 - YT_loss: 0.5890 - YP_loss: 1.8210 - YT_acc: 0.8184 - YP_acc: 0.3598 - val_loss: 2.3609 - val_YT_loss: 0.5900 - val_YP_loss: 1.7709 - val_YT_acc: 0.8113 - val_YP_acc: 0.3790
# Epoch 79/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4067 - YT_loss: 0.5873 - YP_loss: 1.8193 - YT_acc: 0.8190 - YP_acc: 0.3616 - val_loss: 2.3568 - val_YT_loss: 0.5888 - val_YP_loss: 1.7681 - val_YT_acc: 0.8113 - val_YP_acc: 0.3812
# Epoch 80/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4034 - YT_loss: 0.5866 - YP_loss: 1.8168 - YT_acc: 0.8186 - YP_acc: 0.3622 - val_loss: 2.3544 - val_YT_loss: 0.5876 - val_YP_loss: 1.7668 - val_YT_acc: 0.8113 - val_YP_acc: 0.3818
# Epoch 81/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3995 - YT_loss: 0.5849 - YP_loss: 1.8146 - YT_acc: 0.8190 - YP_acc: 0.3624 - val_loss: 2.3509 - val_YT_loss: 0.5862 - val_YP_loss: 1.7646 - val_YT_acc: 0.8117 - val_YP_acc: 0.3827
# Epoch 82/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3959 - YT_loss: 0.5838 - YP_loss: 1.8121 - YT_acc: 0.8191 - YP_acc: 0.3636 - val_loss: 2.3489 - val_YT_loss: 0.5858 - val_YP_loss: 1.7631 - val_YT_acc: 0.8117 - val_YP_acc: 0.3832
# Epoch 83/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3924 - YT_loss: 0.5818 - YP_loss: 1.8105 - YT_acc: 0.8194 - YP_acc: 0.3644 - val_loss: 2.3454 - val_YT_loss: 0.5840 - val_YP_loss: 1.7614 - val_YT_acc: 0.8123 - val_YP_acc: 0.3828
# Epoch 84/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3896 - YT_loss: 0.5810 - YP_loss: 1.8086 - YT_acc: 0.8198 - YP_acc: 0.3649 - val_loss: 2.3416 - val_YT_loss: 0.5825 - val_YP_loss: 1.7591 - val_YT_acc: 0.8123 - val_YP_acc: 0.3846
# Epoch 85/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3854 - YT_loss: 0.5790 - YP_loss: 1.8064 - YT_acc: 0.8200 - YP_acc: 0.3659 - val_loss: 2.3390 - val_YT_loss: 0.5813 - val_YP_loss: 1.7576 - val_YT_acc: 0.8125 - val_YP_acc: 0.3837
# Epoch 86/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3826 - YT_loss: 0.5779 - YP_loss: 1.8047 - YT_acc: 0.8201 - YP_acc: 0.3667 - val_loss: 2.3354 - val_YT_loss: 0.5791 - val_YP_loss: 1.7563 - val_YT_acc: 0.8128 - val_YP_acc: 0.3842
# Epoch 87/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3783 - YT_loss: 0.5759 - YP_loss: 1.8024 - YT_acc: 0.8204 - YP_acc: 0.3672 - val_loss: 2.3314 - val_YT_loss: 0.5778 - val_YP_loss: 1.7536 - val_YT_acc: 0.8127 - val_YP_acc: 0.3854
# Epoch 88/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3745 - YT_loss: 0.5742 - YP_loss: 1.8002 - YT_acc: 0.8206 - YP_acc: 0.3683 - val_loss: 2.3294 - val_YT_loss: 0.5765 - val_YP_loss: 1.7528 - val_YT_acc: 0.8128 - val_YP_acc: 0.3858
# Epoch 89/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3704 - YT_loss: 0.5725 - YP_loss: 1.7979 - YT_acc: 0.8209 - YP_acc: 0.3690 - val_loss: 2.3254 - val_YT_loss: 0.5748 - val_YP_loss: 1.7506 - val_YT_acc: 0.8132 - val_YP_acc: 0.3861
# Epoch 90/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3669 - YT_loss: 0.5708 - YP_loss: 1.7962 - YT_acc: 0.8210 - YP_acc: 0.3700 - val_loss: 2.3214 - val_YT_loss: 0.5729 - val_YP_loss: 1.7485 - val_YT_acc: 0.8135 - val_YP_acc: 0.3867
# Epoch 91/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3639 - YT_loss: 0.5697 - YP_loss: 1.7942 - YT_acc: 0.8208 - YP_acc: 0.3705 - val_loss: 2.3186 - val_YT_loss: 0.5716 - val_YP_loss: 1.7470 - val_YT_acc: 0.8134 - val_YP_acc: 0.3871
# Epoch 92/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3601 - YT_loss: 0.5679 - YP_loss: 1.7923 - YT_acc: 0.8213 - YP_acc: 0.3714 - val_loss: 2.3145 - val_YT_loss: 0.5699 - val_YP_loss: 1.7446 - val_YT_acc: 0.8141 - val_YP_acc: 0.3883
# Epoch 93/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3559 - YT_loss: 0.5656 - YP_loss: 1.7904 - YT_acc: 0.8217 - YP_acc: 0.3722 - val_loss: 2.3110 - val_YT_loss: 0.5678 - val_YP_loss: 1.7431 - val_YT_acc: 0.8140 - val_YP_acc: 0.3883
# Epoch 94/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3512 - YT_loss: 0.5638 - YP_loss: 1.7874 - YT_acc: 0.8222 - YP_acc: 0.3734 - val_loss: 2.3074 - val_YT_loss: 0.5659 - val_YP_loss: 1.7414 - val_YT_acc: 0.8141 - val_YP_acc: 0.3883
# Epoch 95/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3486 - YT_loss: 0.5627 - YP_loss: 1.7860 - YT_acc: 0.8222 - YP_acc: 0.3739 - val_loss: 2.3047 - val_YT_loss: 0.5648 - val_YP_loss: 1.7399 - val_YT_acc: 0.8143 - val_YP_acc: 0.3890
# Epoch 96/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3445 - YT_loss: 0.5597 - YP_loss: 1.7848 - YT_acc: 0.8227 - YP_acc: 0.3747 - val_loss: 2.3006 - val_YT_loss: 0.5625 - val_YP_loss: 1.7381 - val_YT_acc: 0.8143 - val_YP_acc: 0.3899
# Epoch 97/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3402 - YT_loss: 0.5583 - YP_loss: 1.7819 - YT_acc: 0.8228 - YP_acc: 0.3750 - val_loss: 2.2961 - val_YT_loss: 0.5608 - val_YP_loss: 1.7353 - val_YT_acc: 0.8145 - val_YP_acc: 0.3908
# Epoch 98/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3370 - YT_loss: 0.5565 - YP_loss: 1.7806 - YT_acc: 0.8234 - YP_acc: 0.3757 - val_loss: 2.2935 - val_YT_loss: 0.5592 - val_YP_loss: 1.7343 - val_YT_acc: 0.8145 - val_YP_acc: 0.3912
# Epoch 99/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3330 - YT_loss: 0.5548 - YP_loss: 1.7782 - YT_acc: 0.8234 - YP_acc: 0.3767 - val_loss: 2.2899 - val_YT_loss: 0.5574 - val_YP_loss: 1.7325 - val_YT_acc: 0.8147 - val_YP_acc: 0.3920
# Epoch 100/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3283 - YT_loss: 0.5527 - YP_loss: 1.7756 - YT_acc: 0.8240 - YP_acc: 0.3776 - val_loss: 2.2873 - val_YT_loss: 0.5562 - val_YP_loss: 1.7311 - val_YT_acc: 0.8145 - val_YP_acc: 0.3915
# Epoch 101/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3247 - YT_loss: 0.5514 - YP_loss: 1.7733 - YT_acc: 0.8241 - YP_acc: 0.3785 - val_loss: 2.2832 - val_YT_loss: 0.5546 - val_YP_loss: 1.7286 - val_YT_acc: 0.8152 - val_YP_acc: 0.3929
# Epoch 102/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3218 - YT_loss: 0.5499 - YP_loss: 1.7719 - YT_acc: 0.8239 - YP_acc: 0.3794 - val_loss: 2.2800 - val_YT_loss: 0.5529 - val_YP_loss: 1.7270 - val_YT_acc: 0.8148 - val_YP_acc: 0.3930
# Epoch 103/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3186 - YT_loss: 0.5477 - YP_loss: 1.7709 - YT_acc: 0.8247 - YP_acc: 0.3794 - val_loss: 2.2769 - val_YT_loss: 0.5511 - val_YP_loss: 1.7258 - val_YT_acc: 0.8149 - val_YP_acc: 0.3935
# Epoch 104/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3139 - YT_loss: 0.5457 - YP_loss: 1.7682 - YT_acc: 0.8250 - YP_acc: 0.3805 - val_loss: 2.2739 - val_YT_loss: 0.5496 - val_YP_loss: 1.7243 - val_YT_acc: 0.8149 - val_YP_acc: 0.3941
# Epoch 105/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3109 - YT_loss: 0.5447 - YP_loss: 1.7661 - YT_acc: 0.8249 - YP_acc: 0.3814 - val_loss: 2.2698 - val_YT_loss: 0.5478 - val_YP_loss: 1.7220 - val_YT_acc: 0.8153 - val_YP_acc: 0.3949
# Epoch 106/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3070 - YT_loss: 0.5424 - YP_loss: 1.7646 - YT_acc: 0.8258 - YP_acc: 0.3812 - val_loss: 2.2674 - val_YT_loss: 0.5469 - val_YP_loss: 1.7205 - val_YT_acc: 0.8152 - val_YP_acc: 0.3956
# Epoch 107/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3029 - YT_loss: 0.5409 - YP_loss: 1.7620 - YT_acc: 0.8255 - YP_acc: 0.3828 - val_loss: 2.2658 - val_YT_loss: 0.5461 - val_YP_loss: 1.7197 - val_YT_acc: 0.8156 - val_YP_acc: 0.3963
# Epoch 108/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2997 - YT_loss: 0.5401 - YP_loss: 1.7597 - YT_acc: 0.8260 - YP_acc: 0.3836 - val_loss: 2.2617 - val_YT_loss: 0.5439 - val_YP_loss: 1.7178 - val_YT_acc: 0.8157 - val_YP_acc: 0.3971
# Epoch 109/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2973 - YT_loss: 0.5385 - YP_loss: 1.7588 - YT_acc: 0.8260 - YP_acc: 0.3840 - val_loss: 2.2594 - val_YT_loss: 0.5429 - val_YP_loss: 1.7165 - val_YT_acc: 0.8157 - val_YP_acc: 0.3964
# Epoch 110/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2942 - YT_loss: 0.5374 - YP_loss: 1.7568 - YT_acc: 0.8260 - YP_acc: 0.3848 - val_loss: 2.2574 - val_YT_loss: 0.5427 - val_YP_loss: 1.7148 - val_YT_acc: 0.8160 - val_YP_acc: 0.3972
# Epoch 111/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2916 - YT_loss: 0.5368 - YP_loss: 1.7548 - YT_acc: 0.8263 - YP_acc: 0.3858 - val_loss: 2.2546 - val_YT_loss: 0.5420 - val_YP_loss: 1.7127 - val_YT_acc: 0.8159 - val_YP_acc: 0.3981
# Epoch 112/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2886 - YT_loss: 0.5352 - YP_loss: 1.7534 - YT_acc: 0.8264 - YP_acc: 0.3856 - val_loss: 2.2518 - val_YT_loss: 0.5411 - val_YP_loss: 1.7107 - val_YT_acc: 0.8162 - val_YP_acc: 0.3987
# Epoch 113/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2840 - YT_loss: 0.5338 - YP_loss: 1.7502 - YT_acc: 0.8269 - YP_acc: 0.3872 - val_loss: 2.2488 - val_YT_loss: 0.5401 - val_YP_loss: 1.7087 - val_YT_acc: 0.8164 - val_YP_acc: 0.3994
# Epoch 114/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2816 - YT_loss: 0.5332 - YP_loss: 1.7484 - YT_acc: 0.8268 - YP_acc: 0.3870 - val_loss: 2.2474 - val_YT_loss: 0.5392 - val_YP_loss: 1.7082 - val_YT_acc: 0.8166 - val_YP_acc: 0.4001
# Epoch 115/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2792 - YT_loss: 0.5324 - YP_loss: 1.7468 - YT_acc: 0.8268 - YP_acc: 0.3889 - val_loss: 2.2447 - val_YT_loss: 0.5388 - val_YP_loss: 1.7059 - val_YT_acc: 0.8169 - val_YP_acc: 0.4004
# Epoch 116/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2780 - YT_loss: 0.5325 - YP_loss: 1.7455 - YT_acc: 0.8268 - YP_acc: 0.3887 - val_loss: 2.2421 - val_YT_loss: 0.5375 - val_YP_loss: 1.7046 - val_YT_acc: 0.8168 - val_YP_acc: 0.4007
# Epoch 117/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2730 - YT_loss: 0.5303 - YP_loss: 1.7427 - YT_acc: 0.8274 - YP_acc: 0.3897 - val_loss: 2.2401 - val_YT_loss: 0.5373 - val_YP_loss: 1.7028 - val_YT_acc: 0.8171 - val_YP_acc: 0.4015
# Epoch 118/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2706 - YT_loss: 0.5297 - YP_loss: 1.7408 - YT_acc: 0.8274 - YP_acc: 0.3905 - val_loss: 2.2378 - val_YT_loss: 0.5366 - val_YP_loss: 1.7012 - val_YT_acc: 0.8175 - val_YP_acc: 0.4016
# Epoch 119/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2673 - YT_loss: 0.5286 - YP_loss: 1.7387 - YT_acc: 0.8276 - YP_acc: 0.3906 - val_loss: 2.2355 - val_YT_loss: 0.5358 - val_YP_loss: 1.6998 - val_YT_acc: 0.8174 - val_YP_acc: 0.4031
# Epoch 120/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2643 - YT_loss: 0.5277 - YP_loss: 1.7366 - YT_acc: 0.8279 - YP_acc: 0.3922 - val_loss: 2.2331 - val_YT_loss: 0.5350 - val_YP_loss: 1.6981 - val_YT_acc: 0.8175 - val_YP_acc: 0.4031
# Epoch 121/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2628 - YT_loss: 0.5278 - YP_loss: 1.7350 - YT_acc: 0.8277 - YP_acc: 0.3926 - val_loss: 2.2321 - val_YT_loss: 0.5351 - val_YP_loss: 1.6970 - val_YT_acc: 0.8176 - val_YP_acc: 0.4039
# Epoch 122/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2596 - YT_loss: 0.5265 - YP_loss: 1.7331 - YT_acc: 0.8275 - YP_acc: 0.3931 - val_loss: 2.2294 - val_YT_loss: 0.5342 - val_YP_loss: 1.6951 - val_YT_acc: 0.8178 - val_YP_acc: 0.4046
# Epoch 123/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2569 - YT_loss: 0.5256 - YP_loss: 1.7313 - YT_acc: 0.8284 - YP_acc: 0.3941 - val_loss: 2.2268 - val_YT_loss: 0.5331 - val_YP_loss: 1.6937 - val_YT_acc: 0.8175 - val_YP_acc: 0.4051
# Epoch 124/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2527 - YT_loss: 0.5248 - YP_loss: 1.7279 - YT_acc: 0.8284 - YP_acc: 0.3950 - val_loss: 2.2260 - val_YT_loss: 0.5333 - val_YP_loss: 1.6927 - val_YT_acc: 0.8179 - val_YP_acc: 0.4047
# Epoch 125/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2515 - YT_loss: 0.5234 - YP_loss: 1.7280 - YT_acc: 0.8286 - YP_acc: 0.3958 - val_loss: 2.2249 - val_YT_loss: 0.5323 - val_YP_loss: 1.6925 - val_YT_acc: 0.8180 - val_YP_acc: 0.4054
# Epoch 126/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2487 - YT_loss: 0.5233 - YP_loss: 1.7254 - YT_acc: 0.8287 - YP_acc: 0.3956 - val_loss: 2.2216 - val_YT_loss: 0.5318 - val_YP_loss: 1.6898 - val_YT_acc: 0.8183 - val_YP_acc: 0.4061
# Epoch 127/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2457 - YT_loss: 0.5222 - YP_loss: 1.7235 - YT_acc: 0.8288 - YP_acc: 0.3970 - val_loss: 2.2186 - val_YT_loss: 0.5308 - val_YP_loss: 1.6878 - val_YT_acc: 0.8181 - val_YP_acc: 0.4068
# Epoch 128/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2444 - YT_loss: 0.5219 - YP_loss: 1.7225 - YT_acc: 0.8288 - YP_acc: 0.3970 - val_loss: 2.2185 - val_YT_loss: 0.5311 - val_YP_loss: 1.6875 - val_YT_acc: 0.8185 - val_YP_acc: 0.4070
# Epoch 129/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2419 - YT_loss: 0.5213 - YP_loss: 1.7206 - YT_acc: 0.8292 - YP_acc: 0.3981 - val_loss: 2.2153 - val_YT_loss: 0.5302 - val_YP_loss: 1.6850 - val_YT_acc: 0.8183 - val_YP_acc: 0.4084
# Epoch 130/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2391 - YT_loss: 0.5206 - YP_loss: 1.7184 - YT_acc: 0.8291 - YP_acc: 0.3989 - val_loss: 2.2141 - val_YT_loss: 0.5303 - val_YP_loss: 1.6838 - val_YT_acc: 0.8186 - val_YP_acc: 0.4088
# Epoch 131/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2370 - YT_loss: 0.5202 - YP_loss: 1.7168 - YT_acc: 0.8292 - YP_acc: 0.3986 - val_loss: 2.2117 - val_YT_loss: 0.5295 - val_YP_loss: 1.6823 - val_YT_acc: 0.8184 - val_YP_acc: 0.4098
# Epoch 132/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2341 - YT_loss: 0.5193 - YP_loss: 1.7148 - YT_acc: 0.8291 - YP_acc: 0.4008 - val_loss: 2.2109 - val_YT_loss: 0.5292 - val_YP_loss: 1.6817 - val_YT_acc: 0.8179 - val_YP_acc: 0.4099
# Epoch 133/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2322 - YT_loss: 0.5187 - YP_loss: 1.7135 - YT_acc: 0.8293 - YP_acc: 0.4005 - val_loss: 2.2094 - val_YT_loss: 0.5286 - val_YP_loss: 1.6807 - val_YT_acc: 0.8191 - val_YP_acc: 0.4099
# Epoch 134/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2295 - YT_loss: 0.5184 - YP_loss: 1.7111 - YT_acc: 0.8294 - YP_acc: 0.4016 - val_loss: 2.2075 - val_YT_loss: 0.5283 - val_YP_loss: 1.6792 - val_YT_acc: 0.8187 - val_YP_acc: 0.4110
# Epoch 135/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2271 - YT_loss: 0.5177 - YP_loss: 1.7094 - YT_acc: 0.8297 - YP_acc: 0.4024 - val_loss: 2.2049 - val_YT_loss: 0.5272 - val_YP_loss: 1.6776 - val_YT_acc: 0.8188 - val_YP_acc: 0.4115
# Epoch 136/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2237 - YT_loss: 0.5161 - YP_loss: 1.7076 - YT_acc: 0.8301 - YP_acc: 0.4028 - val_loss: 2.2036 - val_YT_loss: 0.5272 - val_YP_loss: 1.6764 - val_YT_acc: 0.8190 - val_YP_acc: 0.4121
# Epoch 137/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2219 - YT_loss: 0.5158 - YP_loss: 1.7061 - YT_acc: 0.8295 - YP_acc: 0.4035 - val_loss: 2.2012 - val_YT_loss: 0.5266 - val_YP_loss: 1.6746 - val_YT_acc: 0.8190 - val_YP_acc: 0.4126
# Epoch 138/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2195 - YT_loss: 0.5154 - YP_loss: 1.7042 - YT_acc: 0.8297 - YP_acc: 0.4046 - val_loss: 2.1988 - val_YT_loss: 0.5257 - val_YP_loss: 1.6730 - val_YT_acc: 0.8192 - val_YP_acc: 0.4134
# Epoch 139/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2163 - YT_loss: 0.5146 - YP_loss: 1.7016 - YT_acc: 0.8303 - YP_acc: 0.4051 - val_loss: 2.1976 - val_YT_loss: 0.5255 - val_YP_loss: 1.6721 - val_YT_acc: 0.8190 - val_YP_acc: 0.4128
# Epoch 140/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2143 - YT_loss: 0.5136 - YP_loss: 1.7007 - YT_acc: 0.8300 - YP_acc: 0.4059 - val_loss: 2.1966 - val_YT_loss: 0.5250 - val_YP_loss: 1.6716 - val_YT_acc: 0.8198 - val_YP_acc: 0.4139
# Epoch 141/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2123 - YT_loss: 0.5131 - YP_loss: 1.6992 - YT_acc: 0.8307 - YP_acc: 0.4064 - val_loss: 2.1941 - val_YT_loss: 0.5244 - val_YP_loss: 1.6697 - val_YT_acc: 0.8195 - val_YP_acc: 0.4144
# Epoch 142/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2096 - YT_loss: 0.5123 - YP_loss: 1.6973 - YT_acc: 0.8304 - YP_acc: 0.4062 - val_loss: 2.1930 - val_YT_loss: 0.5240 - val_YP_loss: 1.6690 - val_YT_acc: 0.8197 - val_YP_acc: 0.4148
# Epoch 143/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2075 - YT_loss: 0.5112 - YP_loss: 1.6963 - YT_acc: 0.8307 - YP_acc: 0.4068 - val_loss: 2.1908 - val_YT_loss: 0.5232 - val_YP_loss: 1.6676 - val_YT_acc: 0.8198 - val_YP_acc: 0.4149
# Epoch 144/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2055 - YT_loss: 0.5110 - YP_loss: 1.6945 - YT_acc: 0.8308 - YP_acc: 0.4077 - val_loss: 2.1894 - val_YT_loss: 0.5233 - val_YP_loss: 1.6661 - val_YT_acc: 0.8198 - val_YP_acc: 0.4154
# Epoch 145/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2027 - YT_loss: 0.5101 - YP_loss: 1.6926 - YT_acc: 0.8307 - YP_acc: 0.4088 - val_loss: 2.1885 - val_YT_loss: 0.5221 - val_YP_loss: 1.6664 - val_YT_acc: 0.8199 - val_YP_acc: 0.4159
# Epoch 146/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2018 - YT_loss: 0.5097 - YP_loss: 1.6921 - YT_acc: 0.8309 - YP_acc: 0.4093 - val_loss: 2.1858 - val_YT_loss: 0.5218 - val_YP_loss: 1.6640 - val_YT_acc: 0.8197 - val_YP_acc: 0.4171
# Epoch 147/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1985 - YT_loss: 0.5091 - YP_loss: 1.6894 - YT_acc: 0.8308 - YP_acc: 0.4094 - val_loss: 2.1841 - val_YT_loss: 0.5214 - val_YP_loss: 1.6627 - val_YT_acc: 0.8204 - val_YP_acc: 0.4168
# Epoch 148/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1956 - YT_loss: 0.5081 - YP_loss: 1.6875 - YT_acc: 0.8309 - YP_acc: 0.4101 - val_loss: 2.1818 - val_YT_loss: 0.5208 - val_YP_loss: 1.6610 - val_YT_acc: 0.8207 - val_YP_acc: 0.4171
# Epoch 149/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1935 - YT_loss: 0.5073 - YP_loss: 1.6863 - YT_acc: 0.8313 - YP_acc: 0.4111 - val_loss: 2.1806 - val_YT_loss: 0.5207 - val_YP_loss: 1.6600 - val_YT_acc: 0.8207 - val_YP_acc: 0.4188
# Epoch 150/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1918 - YT_loss: 0.5065 - YP_loss: 1.6853 - YT_acc: 0.8311 - YP_acc: 0.4115 - val_loss: 2.1788 - val_YT_loss: 0.5195 - val_YP_loss: 1.6594 - val_YT_acc: 0.8208 - val_YP_acc: 0.4188
# Epoch 151/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1889 - YT_loss: 0.5060 - YP_loss: 1.6829 - YT_acc: 0.8313 - YP_acc: 0.4125 - val_loss: 2.1763 - val_YT_loss: 0.5184 - val_YP_loss: 1.6579 - val_YT_acc: 0.8208 - val_YP_acc: 0.4192
# Epoch 152/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1852 - YT_loss: 0.5049 - YP_loss: 1.6802 - YT_acc: 0.8313 - YP_acc: 0.4136 - val_loss: 2.1747 - val_YT_loss: 0.5183 - val_YP_loss: 1.6564 - val_YT_acc: 0.8205 - val_YP_acc: 0.4201
# Epoch 153/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1827 - YT_loss: 0.5034 - YP_loss: 1.6793 - YT_acc: 0.8318 - YP_acc: 0.4131 - val_loss: 2.1731 - val_YT_loss: 0.5174 - val_YP_loss: 1.6557 - val_YT_acc: 0.8204 - val_YP_acc: 0.4210
# Epoch 154/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1818 - YT_loss: 0.5038 - YP_loss: 1.6780 - YT_acc: 0.8313 - YP_acc: 0.4150 - val_loss: 2.1702 - val_YT_loss: 0.5163 - val_YP_loss: 1.6539 - val_YT_acc: 0.8209 - val_YP_acc: 0.4212
# Epoch 155/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1788 - YT_loss: 0.5021 - YP_loss: 1.6767 - YT_acc: 0.8322 - YP_acc: 0.4146 - val_loss: 2.1696 - val_YT_loss: 0.5164 - val_YP_loss: 1.6532 - val_YT_acc: 0.8207 - val_YP_acc: 0.4218
# Epoch 156/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1764 - YT_loss: 0.5014 - YP_loss: 1.6750 - YT_acc: 0.8318 - YP_acc: 0.4155 - val_loss: 2.1672 - val_YT_loss: 0.5151 - val_YP_loss: 1.6521 - val_YT_acc: 0.8208 - val_YP_acc: 0.4222
# Epoch 157/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1750 - YT_loss: 0.5013 - YP_loss: 1.6737 - YT_acc: 0.8320 - YP_acc: 0.4171 - val_loss: 2.1657 - val_YT_loss: 0.5147 - val_YP_loss: 1.6511 - val_YT_acc: 0.8206 - val_YP_acc: 0.4222
# Epoch 158/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1727 - YT_loss: 0.5005 - YP_loss: 1.6722 - YT_acc: 0.8319 - YP_acc: 0.4163 - val_loss: 2.1636 - val_YT_loss: 0.5140 - val_YP_loss: 1.6495 - val_YT_acc: 0.8211 - val_YP_acc: 0.4226
# Epoch 159/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1696 - YT_loss: 0.4994 - YP_loss: 1.6702 - YT_acc: 0.8324 - YP_acc: 0.4165 - val_loss: 2.1621 - val_YT_loss: 0.5133 - val_YP_loss: 1.6488 - val_YT_acc: 0.8207 - val_YP_acc: 0.4240
# Epoch 160/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1674 - YT_loss: 0.4986 - YP_loss: 1.6688 - YT_acc: 0.8320 - YP_acc: 0.4181 - val_loss: 2.1614 - val_YT_loss: 0.5132 - val_YP_loss: 1.6482 - val_YT_acc: 0.8209 - val_YP_acc: 0.4242
# Epoch 161/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1648 - YT_loss: 0.4979 - YP_loss: 1.6669 - YT_acc: 0.8322 - YP_acc: 0.4188 - val_loss: 2.1587 - val_YT_loss: 0.5126 - val_YP_loss: 1.6461 - val_YT_acc: 0.8209 - val_YP_acc: 0.4248
# Epoch 162/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1628 - YT_loss: 0.4975 - YP_loss: 1.6653 - YT_acc: 0.8322 - YP_acc: 0.4192 - val_loss: 2.1575 - val_YT_loss: 0.5121 - val_YP_loss: 1.6454 - val_YT_acc: 0.8210 - val_YP_acc: 0.4246
# Epoch 163/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1604 - YT_loss: 0.4964 - YP_loss: 1.6639 - YT_acc: 0.8324 - YP_acc: 0.4196 - val_loss: 2.1555 - val_YT_loss: 0.5117 - val_YP_loss: 1.6437 - val_YT_acc: 0.8213 - val_YP_acc: 0.4251
# Epoch 164/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1582 - YT_loss: 0.4962 - YP_loss: 1.6620 - YT_acc: 0.8326 - YP_acc: 0.4203 - val_loss: 2.1547 - val_YT_loss: 0.5111 - val_YP_loss: 1.6436 - val_YT_acc: 0.8210 - val_YP_acc: 0.4259
# Epoch 165/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1551 - YT_loss: 0.4959 - YP_loss: 1.6592 - YT_acc: 0.8324 - YP_acc: 0.4216 - val_loss: 2.1526 - val_YT_loss: 0.5105 - val_YP_loss: 1.6421 - val_YT_acc: 0.8213 - val_YP_acc: 0.4273
# Epoch 166/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1542 - YT_loss: 0.4952 - YP_loss: 1.6590 - YT_acc: 0.8327 - YP_acc: 0.4223 - val_loss: 2.1513 - val_YT_loss: 0.5107 - val_YP_loss: 1.6406 - val_YT_acc: 0.8214 - val_YP_acc: 0.4275
# Epoch 167/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1511 - YT_loss: 0.4944 - YP_loss: 1.6568 - YT_acc: 0.8329 - YP_acc: 0.4226 - val_loss: 2.1501 - val_YT_loss: 0.5105 - val_YP_loss: 1.6396 - val_YT_acc: 0.8212 - val_YP_acc: 0.4277
# Epoch 168/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1492 - YT_loss: 0.4938 - YP_loss: 1.6554 - YT_acc: 0.8327 - YP_acc: 0.4233 - val_loss: 2.1503 - val_YT_loss: 0.5104 - val_YP_loss: 1.6399 - val_YT_acc: 0.8216 - val_YP_acc: 0.4279
# Epoch 169/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1481 - YT_loss: 0.4938 - YP_loss: 1.6543 - YT_acc: 0.8330 - YP_acc: 0.4233 - val_loss: 2.1481 - val_YT_loss: 0.5094 - val_YP_loss: 1.6388 - val_YT_acc: 0.8214 - val_YP_acc: 0.4275
# Epoch 170/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1443 - YT_loss: 0.4922 - YP_loss: 1.6521 - YT_acc: 0.8332 - YP_acc: 0.4247 - val_loss: 2.1454 - val_YT_loss: 0.5088 - val_YP_loss: 1.6365 - val_YT_acc: 0.8218 - val_YP_acc: 0.4286
# Epoch 171/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1431 - YT_loss: 0.4922 - YP_loss: 1.6508 - YT_acc: 0.8333 - YP_acc: 0.4252 - val_loss: 2.1435 - val_YT_loss: 0.5087 - val_YP_loss: 1.6348 - val_YT_acc: 0.8219 - val_YP_acc: 0.4293
# Epoch 172/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1399 - YT_loss: 0.4916 - YP_loss: 1.6483 - YT_acc: 0.8335 - YP_acc: 0.4249 - val_loss: 2.1417 - val_YT_loss: 0.5079 - val_YP_loss: 1.6338 - val_YT_acc: 0.8213 - val_YP_acc: 0.4300
# Epoch 173/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1389 - YT_loss: 0.4916 - YP_loss: 1.6473 - YT_acc: 0.8331 - YP_acc: 0.4264 - val_loss: 2.1417 - val_YT_loss: 0.5080 - val_YP_loss: 1.6336 - val_YT_acc: 0.8217 - val_YP_acc: 0.4304
# Epoch 174/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1366 - YT_loss: 0.4908 - YP_loss: 1.6457 - YT_acc: 0.8334 - YP_acc: 0.4270 - val_loss: 2.1389 - val_YT_loss: 0.5071 - val_YP_loss: 1.6318 - val_YT_acc: 0.8219 - val_YP_acc: 0.4308
# Epoch 175/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1343 - YT_loss: 0.4904 - YP_loss: 1.6439 - YT_acc: 0.8340 - YP_acc: 0.4279 - val_loss: 2.1377 - val_YT_loss: 0.5070 - val_YP_loss: 1.6307 - val_YT_acc: 0.8220 - val_YP_acc: 0.4310
# Epoch 176/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1315 - YT_loss: 0.4898 - YP_loss: 1.6417 - YT_acc: 0.8335 - YP_acc: 0.4285 - val_loss: 2.1385 - val_YT_loss: 0.5075 - val_YP_loss: 1.6310 - val_YT_acc: 0.8215 - val_YP_acc: 0.4309
# Epoch 177/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1309 - YT_loss: 0.4899 - YP_loss: 1.6410 - YT_acc: 0.8334 - YP_acc: 0.4284 - val_loss: 2.1367 - val_YT_loss: 0.5067 - val_YP_loss: 1.6300 - val_YT_acc: 0.8223 - val_YP_acc: 0.4310
# Epoch 178/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1289 - YT_loss: 0.4890 - YP_loss: 1.6400 - YT_acc: 0.8337 - YP_acc: 0.4296 - val_loss: 2.1348 - val_YT_loss: 0.5067 - val_YP_loss: 1.6280 - val_YT_acc: 0.8222 - val_YP_acc: 0.4319
# Epoch 179/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1263 - YT_loss: 0.4886 - YP_loss: 1.6377 - YT_acc: 0.8337 - YP_acc: 0.4296 - val_loss: 2.1335 - val_YT_loss: 0.5061 - val_YP_loss: 1.6274 - val_YT_acc: 0.8223 - val_YP_acc: 0.4325
# Epoch 180/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1238 - YT_loss: 0.4881 - YP_loss: 1.6357 - YT_acc: 0.8336 - YP_acc: 0.4303 - val_loss: 2.1330 - val_YT_loss: 0.5065 - val_YP_loss: 1.6264 - val_YT_acc: 0.8216 - val_YP_acc: 0.4335
# Epoch 181/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1226 - YT_loss: 0.4875 - YP_loss: 1.6351 - YT_acc: 0.8343 - YP_acc: 0.4310 - val_loss: 2.1304 - val_YT_loss: 0.5054 - val_YP_loss: 1.6250 - val_YT_acc: 0.8219 - val_YP_acc: 0.4323
# Epoch 182/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1205 - YT_loss: 0.4870 - YP_loss: 1.6335 - YT_acc: 0.8344 - YP_acc: 0.4317 - val_loss: 2.1292 - val_YT_loss: 0.5053 - val_YP_loss: 1.6239 - val_YT_acc: 0.8221 - val_YP_acc: 0.4339
# Epoch 183/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1191 - YT_loss: 0.4867 - YP_loss: 1.6324 - YT_acc: 0.8342 - YP_acc: 0.4327 - val_loss: 2.1295 - val_YT_loss: 0.5060 - val_YP_loss: 1.6235 - val_YT_acc: 0.8222 - val_YP_acc: 0.4335
# Epoch 184/250
# ...
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.1055 - YT_loss: 0.4840 - YP_loss: 1.6215 - YT_acc: 0.8343 - YP_acc: 0.4363 - val_loss: 2.1223 - val_YT_loss: 0.5040 - val_YP_loss: 1.6183 - val_YT_acc: 0.8227 - val_YP_acc: 0.4360
# Epoch 191/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1041 - YT_loss: 0.4836 - YP_loss: 1.6205 - YT_acc: 0.8348 - YP_acc: 0.4368 - val_loss: 2.1223 - val_YT_loss: 0.5039 - val_YP_loss: 1.6184 - val_YT_acc: 0.8219 - val_YP_acc: 0.4368
# Epoch 192/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.1022 - YT_loss: 0.4839 - YP_loss: 1.6183 - YT_acc: 0.8347 - YP_acc: 0.4377 - val_loss: 2.1199 - val_YT_loss: 0.5036 - val_YP_loss: 1.6163 - val_YT_acc: 0.8228 - val_YP_acc: 0.4361
# Epoch 193/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0999 - YT_loss: 0.4830 - YP_loss: 1.6170 - YT_acc: 0.8348 - YP_acc: 0.4377 - val_loss: 2.1183 - val_YT_loss: 0.5029 - val_YP_loss: 1.6154 - val_YT_acc: 0.8224 - val_YP_acc: 0.4368
# Epoch 194/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0967 - YT_loss: 0.4826 - YP_loss: 1.6141 - YT_acc: 0.8350 - YP_acc: 0.4384 - val_loss: 2.1162 - val_YT_loss: 0.5028 - val_YP_loss: 1.6133 - val_YT_acc: 0.8227 - val_YP_acc: 0.4381
# Epoch 195/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0957 - YT_loss: 0.4824 - YP_loss: 1.6133 - YT_acc: 0.8348 - YP_acc: 0.4394 - val_loss: 2.1154 - val_YT_loss: 0.5029 - val_YP_loss: 1.6125 - val_YT_acc: 0.8229 - val_YP_acc: 0.4383
# Epoch 196/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0949 - YT_loss: 0.4816 - YP_loss: 1.6133 - YT_acc: 0.8348 - YP_acc: 0.4396 - val_loss: 2.1150 - val_YT_loss: 0.5028 - val_YP_loss: 1.6122 - val_YT_acc: 0.8223 - val_YP_acc: 0.4386
# Epoch 197/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0935 - YT_loss: 0.4817 - YP_loss: 1.6119 - YT_acc: 0.8351 - YP_acc: 0.4403 - val_loss: 2.1142 - val_YT_loss: 0.5021 - val_YP_loss: 1.6121 - val_YT_acc: 0.8228 - val_YP_acc: 0.4382
# Epoch 198/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0916 - YT_loss: 0.4810 - YP_loss: 1.6106 - YT_acc: 0.8351 - YP_acc: 0.4404 - val_loss: 2.1154 - val_YT_loss: 0.5037 - val_YP_loss: 1.6117 - val_YT_acc: 0.8226 - val_YP_acc: 0.4380
# Epoch 199/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0899 - YT_loss: 0.4809 - YP_loss: 1.6090 - YT_acc: 0.8349 - YP_acc: 0.4407 - val_loss: 2.1133 - val_YT_loss: 0.5022 - val_YP_loss: 1.6110 - val_YT_acc: 0.8227 - val_YP_acc: 0.4380
# Epoch 200/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0884 - YT_loss: 0.4810 - YP_loss: 1.6074 - YT_acc: 0.8354 - YP_acc: 0.4409 - val_loss: 2.1109 - val_YT_loss: 0.5017 - val_YP_loss: 1.6091 - val_YT_acc: 0.8230 - val_YP_acc: 0.4387
# Epoch 201/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0872 - YT_loss: 0.4809 - YP_loss: 1.6064 - YT_acc: 0.8352 - YP_acc: 0.4422 - val_loss: 2.1115 - val_YT_loss: 0.5026 - val_YP_loss: 1.6089 - val_YT_acc: 0.8228 - val_YP_acc: 0.4391
# Epoch 202/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0852 - YT_loss: 0.4800 - YP_loss: 1.6052 - YT_acc: 0.8354 - YP_acc: 0.4428 - val_loss: 2.1104 - val_YT_loss: 0.5022 - val_YP_loss: 1.6082 - val_YT_acc: 0.8226 - val_YP_acc: 0.4393
# Epoch 203/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0837 - YT_loss: 0.4802 - YP_loss: 1.6035 - YT_acc: 0.8353 - YP_acc: 0.4437 - val_loss: 2.1089 - val_YT_loss: 0.5015 - val_YP_loss: 1.6074 - val_YT_acc: 0.8224 - val_YP_acc: 0.4400
# Epoch 204/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0819 - YT_loss: 0.4797 - YP_loss: 1.6022 - YT_acc: 0.8355 - YP_acc: 0.4434 - val_loss: 2.1078 - val_YT_loss: 0.5015 - val_YP_loss: 1.6063 - val_YT_acc: 0.8227 - val_YP_acc: 0.4405
# Epoch 205/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0808 - YT_loss: 0.4794 - YP_loss: 1.6014 - YT_acc: 0.8355 - YP_acc: 0.4434 - val_loss: 2.1073 - val_YT_loss: 0.5011 - val_YP_loss: 1.6061 - val_YT_acc: 0.8226 - val_YP_acc: 0.4400
# Epoch 206/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0782 - YT_loss: 0.4797 - YP_loss: 1.5985 - YT_acc: 0.8352 - YP_acc: 0.4448 - val_loss: 2.1065 - val_YT_loss: 0.5014 - val_YP_loss: 1.6051 - val_YT_acc: 0.8232 - val_YP_acc: 0.4405
# Epoch 207/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0771 - YT_loss: 0.4791 - YP_loss: 1.5979 - YT_acc: 0.8353 - YP_acc: 0.4458 - val_loss: 2.1064 - val_YT_loss: 0.5009 - val_YP_loss: 1.6055 - val_YT_acc: 0.8225 - val_YP_acc: 0.4407
# Epoch 208/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0747 - YT_loss: 0.4781 - YP_loss: 1.5966 - YT_acc: 0.8354 - YP_acc: 0.4457 - val_loss: 2.1048 - val_YT_loss: 0.5009 - val_YP_loss: 1.6039 - val_YT_acc: 0.8229 - val_YP_acc: 0.4417
# Epoch 209/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0729 - YT_loss: 0.4772 - YP_loss: 1.5957 - YT_acc: 0.8358 - YP_acc: 0.4468 - val_loss: 2.1038 - val_YT_loss: 0.5007 - val_YP_loss: 1.6031 - val_YT_acc: 0.8227 - val_YP_acc: 0.4416
# Epoch 210/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0724 - YT_loss: 0.4777 - YP_loss: 1.5947 - YT_acc: 0.8356 - YP_acc: 0.4460 - val_loss: 2.1045 - val_YT_loss: 0.5010 - val_YP_loss: 1.6035 - val_YT_acc: 0.8228 - val_YP_acc: 0.4420
# Epoch 211/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.0698 - YT_loss: 0.4776 - YP_loss: 1.5922 - YT_acc: 0.8356 - YP_acc: 0.4471 - val_loss: 2.1025 - val_YT_loss: 0.5006 - val_YP_loss: 1.6019 - val_YT_acc: 0.8231 - val_YP_acc: 0.4421
# Epoch 212/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0694 - YT_loss: 0.4769 - YP_loss: 1.5925 - YT_acc: 0.8357 - YP_acc: 0.4480 - val_loss: 2.1022 - val_YT_loss: 0.5007 - val_YP_loss: 1.6015 - val_YT_acc: 0.8230 - val_YP_acc: 0.4429
# Epoch 213/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0676 - YT_loss: 0.4771 - YP_loss: 1.5905 - YT_acc: 0.8361 - YP_acc: 0.4483 - val_loss: 2.1020 - val_YT_loss: 0.5008 - val_YP_loss: 1.6012 - val_YT_acc: 0.8229 - val_YP_acc: 0.4420
# Epoch 214/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0662 - YT_loss: 0.4766 - YP_loss: 1.5896 - YT_acc: 0.8358 - YP_acc: 0.4487 - val_loss: 2.1023 - val_YT_loss: 0.5014 - val_YP_loss: 1.6009 - val_YT_acc: 0.8225 - val_YP_acc: 0.4429
# Epoch 215/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0647 - YT_loss: 0.4764 - YP_loss: 1.5883 - YT_acc: 0.8360 - YP_acc: 0.4487 - val_loss: 2.1001 - val_YT_loss: 0.5006 - val_YP_loss: 1.5995 - val_YT_acc: 0.8227 - val_YP_acc: 0.4432
# Epoch 216/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0624 - YT_loss: 0.4767 - YP_loss: 1.5857 - YT_acc: 0.8359 - YP_acc: 0.4499 - val_loss: 2.0998 - val_YT_loss: 0.5001 - val_YP_loss: 1.5997 - val_YT_acc: 0.8232 - val_YP_acc: 0.4437
# Epoch 217/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0592 - YT_loss: 0.4755 - YP_loss: 1.5837 - YT_acc: 0.8360 - YP_acc: 0.4511 - val_loss: 2.0983 - val_YT_loss: 0.5003 - val_YP_loss: 1.5980 - val_YT_acc: 0.8228 - val_YP_acc: 0.4439
# Epoch 218/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0596 - YT_loss: 0.4755 - YP_loss: 1.5841 - YT_acc: 0.8361 - YP_acc: 0.4501 - val_loss: 2.0984 - val_YT_loss: 0.5002 - val_YP_loss: 1.5982 - val_YT_acc: 0.8227 - val_YP_acc: 0.4439
# Epoch 219/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0575 - YT_loss: 0.4747 - YP_loss: 1.5828 - YT_acc: 0.8365 - YP_acc: 0.4515 - val_loss: 2.0967 - val_YT_loss: 0.4997 - val_YP_loss: 1.5970 - val_YT_acc: 0.8228 - val_YP_acc: 0.4444
# Epoch 220/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0559 - YT_loss: 0.4745 - YP_loss: 1.5814 - YT_acc: 0.8364 - YP_acc: 0.4513 - val_loss: 2.0977 - val_YT_loss: 0.5002 - val_YP_loss: 1.5974 - val_YT_acc: 0.8227 - val_YP_acc: 0.4442
# Epoch 221/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0545 - YT_loss: 0.4745 - YP_loss: 1.5800 - YT_acc: 0.8360 - YP_acc: 0.4517 - val_loss: 2.0990 - val_YT_loss: 0.5005 - val_YP_loss: 1.5985 - val_YT_acc: 0.8228 - val_YP_acc: 0.4439
# Epoch 222/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0533 - YT_loss: 0.4747 - YP_loss: 1.5786 - YT_acc: 0.8363 - YP_acc: 0.4525 - val_loss: 2.0975 - val_YT_loss: 0.5005 - val_YP_loss: 1.5970 - val_YT_acc: 0.8236 - val_YP_acc: 0.4443
# Epoch 223/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0514 - YT_loss: 0.4745 - YP_loss: 1.5769 - YT_acc: 0.8362 - YP_acc: 0.4529 - val_loss: 2.0951 - val_YT_loss: 0.4997 - val_YP_loss: 1.5954 - val_YT_acc: 0.8227 - val_YP_acc: 0.4453
# Epoch 224/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0495 - YT_loss: 0.4740 - YP_loss: 1.5755 - YT_acc: 0.8363 - YP_acc: 0.4543 - val_loss: 2.0943 - val_YT_loss: 0.4998 - val_YP_loss: 1.5945 - val_YT_acc: 0.8232 - val_YP_acc: 0.4451
# Epoch 225/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0503 - YT_loss: 0.4742 - YP_loss: 1.5761 - YT_acc: 0.8363 - YP_acc: 0.4536 - val_loss: 2.0958 - val_YT_loss: 0.4998 - val_YP_loss: 1.5960 - val_YT_acc: 0.8226 - val_YP_acc: 0.4447
# Epoch 226/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0476 - YT_loss: 0.4740 - YP_loss: 1.5736 - YT_acc: 0.8364 - YP_acc: 0.4547 - val_loss: 2.0942 - val_YT_loss: 0.4998 - val_YP_loss: 1.5943 - val_YT_acc: 0.8227 - val_YP_acc: 0.4454
# Epoch 227/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0463 - YT_loss: 0.4726 - YP_loss: 1.5736 - YT_acc: 0.8365 - YP_acc: 0.4554 - val_loss: 2.0931 - val_YT_loss: 0.4995 - val_YP_loss: 1.5936 - val_YT_acc: 0.8229 - val_YP_acc: 0.4449
# Epoch 228/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0449 - YT_loss: 0.4729 - YP_loss: 1.5720 - YT_acc: 0.8367 - YP_acc: 0.4558 - val_loss: 2.0933 - val_YT_loss: 0.4997 - val_YP_loss: 1.5935 - val_YT_acc: 0.8231 - val_YP_acc: 0.4458
# Epoch 229/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0440 - YT_loss: 0.4731 - YP_loss: 1.5709 - YT_acc: 0.8369 - YP_acc: 0.4555 - val_loss: 2.0922 - val_YT_loss: 0.4994 - val_YP_loss: 1.5928 - val_YT_acc: 0.8230 - val_YP_acc: 0.4457
# Epoch 230/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0427 - YT_loss: 0.4730 - YP_loss: 1.5696 - YT_acc: 0.8364 - YP_acc: 0.4566 - val_loss: 2.0917 - val_YT_loss: 0.5000 - val_YP_loss: 1.5917 - val_YT_acc: 0.8234 - val_YP_acc: 0.4460
# Epoch 231/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0401 - YT_loss: 0.4727 - YP_loss: 1.5674 - YT_acc: 0.8366 - YP_acc: 0.4566 - val_loss: 2.0913 - val_YT_loss: 0.4999 - val_YP_loss: 1.5915 - val_YT_acc: 0.8230 - val_YP_acc: 0.4465
# Epoch 232/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0399 - YT_loss: 0.4726 - YP_loss: 1.5673 - YT_acc: 0.8367 - YP_acc: 0.4572 - val_loss: 2.0912 - val_YT_loss: 0.5001 - val_YP_loss: 1.5911 - val_YT_acc: 0.8231 - val_YP_acc: 0.4469
# Epoch 233/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0375 - YT_loss: 0.4718 - YP_loss: 1.5657 - YT_acc: 0.8367 - YP_acc: 0.4568 - val_loss: 2.0908 - val_YT_loss: 0.4994 - val_YP_loss: 1.5914 - val_YT_acc: 0.8228 - val_YP_acc: 0.4474
# Epoch 234/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0378 - YT_loss: 0.4720 - YP_loss: 1.5658 - YT_acc: 0.8368 - YP_acc: 0.4582 - val_loss: 2.0913 - val_YT_loss: 0.4992 - val_YP_loss: 1.5921 - val_YT_acc: 0.8229 - val_YP_acc: 0.4472
# Epoch 235/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0370 - YT_loss: 0.4721 - YP_loss: 1.5649 - YT_acc: 0.8367 - YP_acc: 0.4575 - val_loss: 2.0890 - val_YT_loss: 0.4992 - val_YP_loss: 1.5898 - val_YT_acc: 0.8231 - val_YP_acc: 0.4484
# Epoch 236/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0348 - YT_loss: 0.4711 - YP_loss: 1.5637 - YT_acc: 0.8368 - YP_acc: 0.4582 - val_loss: 2.0885 - val_YT_loss: 0.4995 - val_YP_loss: 1.5889 - val_YT_acc: 0.8233 - val_YP_acc: 0.4483
# Epoch 237/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0326 - YT_loss: 0.4711 - YP_loss: 1.5615 - YT_acc: 0.8368 - YP_acc: 0.4590 - val_loss: 2.0874 - val_YT_loss: 0.4988 - val_YP_loss: 1.5886 - val_YT_acc: 0.8235 - val_YP_acc: 0.4476
# Epoch 238/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0324 - YT_loss: 0.4710 - YP_loss: 1.5614 - YT_acc: 0.8371 - YP_acc: 0.4591 - val_loss: 2.0869 - val_YT_loss: 0.4985 - val_YP_loss: 1.5883 - val_YT_acc: 0.8231 - val_YP_acc: 0.4484
# Epoch 239/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0301 - YT_loss: 0.4708 - YP_loss: 1.5593 - YT_acc: 0.8371 - YP_acc: 0.4597 - val_loss: 2.0868 - val_YT_loss: 0.4987 - val_YP_loss: 1.5881 - val_YT_acc: 0.8231 - val_YP_acc: 0.4481
# Epoch 240/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0278 - YT_loss: 0.4699 - YP_loss: 1.5579 - YT_acc: 0.8371 - YP_acc: 0.4598 - val_loss: 2.0879 - val_YT_loss: 0.4991 - val_YP_loss: 1.5888 - val_YT_acc: 0.8230 - val_YP_acc: 0.4476
# Epoch 241/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0282 - YT_loss: 0.4705 - YP_loss: 1.5577 - YT_acc: 0.8373 - YP_acc: 0.4606 - val_loss: 2.0857 - val_YT_loss: 0.4982 - val_YP_loss: 1.5875 - val_YT_acc: 0.8231 - val_YP_acc: 0.4482
# Epoch 242/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0273 - YT_loss: 0.4702 - YP_loss: 1.5572 - YT_acc: 0.8374 - YP_acc: 0.4609 - val_loss: 2.0870 - val_YT_loss: 0.4989 - val_YP_loss: 1.5880 - val_YT_acc: 0.8235 - val_YP_acc: 0.4481
# Epoch 243/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0257 - YT_loss: 0.4702 - YP_loss: 1.5555 - YT_acc: 0.8371 - YP_acc: 0.4618 - val_loss: 2.0861 - val_YT_loss: 0.4993 - val_YP_loss: 1.5868 - val_YT_acc: 0.8227 - val_YP_acc: 0.4486
# Epoch 244/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0243 - YT_loss: 0.4695 - YP_loss: 1.5548 - YT_acc: 0.8372 - YP_acc: 0.4616 - val_loss: 2.0849 - val_YT_loss: 0.4988 - val_YP_loss: 1.5861 - val_YT_acc: 0.8231 - val_YP_acc: 0.4491
# Epoch 245/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0223 - YT_loss: 0.4690 - YP_loss: 1.5533 - YT_acc: 0.8375 - YP_acc: 0.4625 - val_loss: 2.0851 - val_YT_loss: 0.4990 - val_YP_loss: 1.5860 - val_YT_acc: 0.8231 - val_YP_acc: 0.4490
# Epoch 246/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0201 - YT_loss: 0.4691 - YP_loss: 1.5510 - YT_acc: 0.8374 - YP_acc: 0.4630 - val_loss: 2.0849 - val_YT_loss: 0.4989 - val_YP_loss: 1.5860 - val_YT_acc: 0.8235 - val_YP_acc: 0.4494
# Epoch 247/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0200 - YT_loss: 0.4693 - YP_loss: 1.5508 - YT_acc: 0.8375 - YP_acc: 0.4626 - val_loss: 2.0849 - val_YT_loss: 0.4989 - val_YP_loss: 1.5860 - val_YT_acc: 0.8231 - val_YP_acc: 0.4498
# Epoch 248/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0193 - YT_loss: 0.4690 - YP_loss: 1.5504 - YT_acc: 0.8374 - YP_acc: 0.4638 - val_loss: 2.0842 - val_YT_loss: 0.4989 - val_YP_loss: 1.5853 - val_YT_acc: 0.8228 - val_YP_acc: 0.4500
# Epoch 249/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.0183 - YT_loss: 0.4691 - YP_loss: 1.5491 - YT_acc: 0.8371 - YP_acc: 0.4635 - val_loss: 2.0841 - val_YT_loss: 0.4992 - val_YP_loss: 1.5849 - val_YT_acc: 0.8231 - val_YP_acc: 0.4499
# Epoch 250/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.0166 - YT_loss: 0.4688 - YP_loss: 1.5478 - YT_acc: 0.8374 - YP_acc: 0.4636 - val_loss: 2.0824 - val_YT_loss: 0.4987 - val_YP_loss: 1.5837 - val_YT_acc: 0.8235 - val_YP_acc: 0.4502
# Saved gru model to disk

# %% [markdown]
# **Question**: What are the best prediction accuracies you obtained? With which model?
#
# **Answer**: We obtained 43%/82% using the GRU model.
#
# **Question**: In a few sentences, comment on the plot comparing learning curves for the two activation function.
#
# **Answer**:

# %%
plotLearningCurves(history)

# %%
plotLearningCurves(history2)

# %% [markdown]
# ## Exercise 6: Visualizing the model
# ### Description
#
# 1. Using the model.predict and plotMelody functions, show the outputs of your best model when fed with 4 randomly selected melodies. Report the prediction accuracies as well.
# 2. For the same melodies, plot the hidden state evolution accross time steps. Construct a 2 dimensional matrix with the first dimension being time and the second the concatenation of all hidden unit activations and plot it using the provided `plotMelody` function. To get the hidden states of your network, you can modify the `buildModel` function so that you have another computation graph (another model with the same layers, but the output layer) returning you the hidden states. However, other approaches are equally valid.
# 3. For each hidden unit $i$ and accross the entire dataset, compute the average absolute change in activation $\Delta A_i$. Be careful not to take masked timesteps into account. Plot the histogram (50 bins) of this average for the RNN and GRU models on the same figure.

# %% [markdown]
# ### Solution

# %% [markdown]
# **Question**: How does the hidden state dynamics explain the performance of the RNN vs GRU models? Explain in term of temporal dependencies and base your explanation on figures obtained in 6.2 and 6.3.
#
# **Answer**:

# %% [markdown]
# ## Exercise 7: Generation of new melodies
# ### Description
#
# 1. Use your trained best model to generate new melodies. You can do that by starting with a random note, feeding it to your network and sample the output predictions in order to select the next note. Then add this note to your iteratively growing melodies. For your convenience, we provided the `sample` and `writeMIDI` functions. You can use the first in order to perform temperature sampling. The `writeMIDI` function allows you to write a MIDI file from the integer representation.
# 2. Try different sampling temperatures (e.g. 0.5, 1., 1.5) and observe the effect on your generated melodies.
# 3. Generate 32 melodies with both the RNN and GRU models
# 4. Listen to 4 randomly chosen melodies (2 from the GRU model and 2 from the RNN model). To play in a notebook, use a similar approach as the one shown below assuming you have the files `GRU_1.mid` and `RNN_1.mid` at the same level as this notebook. For your own curiosity, you can also directly listen to the MIDI files with your favorite MIDI player but make sure that we can listen to the 4 extracts directly from this notebook (without rerunning it). You might have to use the "Trust notebook" button (in the top right corner) to see the players. This currently only works in jupyter notebook (not jupyter lab). If you have trouble achieving that, upload the MIDI files with your submission.
# 5. (Optional) If you have a big enough computing power, try adding multiple and bigger layers. You could also try to improve your model with different add-ons, e.g. make your model learn when a melody ends, extend it to other datasets, ...
# 6. (Optional) If you are happy with your results submit a 1 hour long generated MIDI file to the [AI-generated music challenge](https://www.crowdai.org/challenges/ai-generated-music-challenge).

# %% [markdown]
# ### Solution

# %%
def generate_melody(random_note, length, model, temp=1.0):

    current_melody = random_note
    for i in range(length):
        prediction = model.predict(current_melody)
        T = np.zeros((1, dim_t))
        T[0][sample(prediction[0][0][i], temperature=temp)] = 1
        P = np.zeros((1, dim_p))
        P[0][sample(prediction[1][0][i], temperature=temp)] = 1
        
        current_melody['XT'][0][i+1] = T
        current_melody['XP'][0][i+1] = P
        
    current_melody['XT'] = np.argmax(current_melody['XT'][0][:1+np.max(list(np.where(np.sum(current_melody['XT'][0], axis=1) != 0)[0]))], axis=1)  
    current_melody['XP'] = np.argmax(current_melody['XP'][0][:1+np.max(list(np.where(np.sum(current_melody['XP'][0], axis=1) != 0)[0]))], axis=1)
    return current_melody

# %%
random_t = np.zeros((1, dim_t))
random_t[0][sample(np.array([1/dim_t]*dim_t))] = 1

random_p = np.zeros((1, dim_p))
random_p[0][sample(np.array([1/dim_p]*dim_p))] = 1
random_note = {'XT': pad_sequences(random_t.reshape((1, 1, dim_t)).T, maxlen=n_notes-1, padding='post', truncating='post').T,
               'XP': pad_sequences(random_p.reshape((1, 1, dim_p)).T, maxlen=n_notes-1, padding='post', truncating='post').T}

# %%
current_melody = generate_melody(random_note, 100, GRUmodel, .5)
plotMelody(current_melody['XP'], current_melody['XT'], dicts)

# %%
writeMIDI(current_melody['XP'], current_melody['XT'], dicts, 'GRU_1.mid')

# %%
print('GRU')
music21.midi.translate.midiFilePathToStream('GRU_1.mid').show('midi')
# Out:
# GRU
#                 <div id='midiPlayerDiv2118'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv2118');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
writeMIDI(current_melody['XP'], current_melody['XT'], dicts, 'test.mid')

# %%
print('RNN')
music21.midi.translate.midiFilePathToStream('test.mid').show('midi')
# Out:
# RNN
#                 <div id='midiPlayerDiv1063'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv1063');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# **Question**: What is the effect of the sampling temperature on the generated melodies?
#
# **Answer**:
#
# **Question**: Are the generated melodies from the RNN model different from the one generated by the GRU model? If yes, what are the main differences?
#
# **Answer**:

# %%
music21.midi.translate.midiFilePathToStream('chorpus/sessiontune160.mid').show('midi')
# Out:
#                 <div id='midiPlayerDiv5245232'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv5245232');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
