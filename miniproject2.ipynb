# %% [markdown]
# # Miniproject 2: Melody generation
#
# ## Introduction
#
# ### Description
#
# To develop a model employing ANN on real-world data requires going through several major steps, each of which with important design choices that directly impact the end results. In this project, we guide you through these choices starting from a large database of [Irish folk melodies](https://github.com/IraKorshunova/folk-rnn/tree/master/data) to your own model of symbolic music composition.
#
#
# ### Prerequisites
#
# - You should have a running installation of [tensorflow](https://www.tensorflow.org/install/) and [keras](https://keras.io/).
# - You should know the concepts "recurrent neural networks", "LSTM", "training and validation data", "overfitting" and "early stopping".
#
# ### What you will learn
#
# - You will be guided through a data processing procedure and understand the importance of design choices in ANN modeling
# - You will learn how to define recurrent neural networks in keras and fit them to data.
# - You will be guided through a prototyping procedure for the application of deep learning to a specific domain.
# - You will get in contact with concepts discussed later in the lecture, like "overfitting", "LSTM network", and "Generative model".
# - You will learn to be more patient :) Some fits may take your computer quite a bit of time; run them over night.
#
# ### Evaluation criteria
#
# The evaluation is (mostly) based on the figures you submit and your answer sentences.
# We will only do random tests of your code and not re-run the full notebook. Please ensure that your notebook is fully executed before handing it in.

# %% [markdown]
# ## Functions and imports
#
# For your convenience we import some libraries and provide some functions below. Some libraries (`midi` and `music21==5.1.0`) should be added. If you work with the docker image, pull it `docker pull zifeo/artificial-neural-networks:cpu` before to get the latest version where these libraries are added and stop/relaunch the container (as stated in the instructions https://github.com/zifeo/artificial-neural-networks). If you work locally, be sure to import them. If you do not find the midi library for python3, install it with `python setup.py install` inside the `python3-midi` folder after cloning https://github.com/louisabraham/python3-midi.git.
#
# Finally, fill in your sciper number(s) for the random seed and simply run the following cell.

# %%
sciper = {'student_1': 250726, 
          'student_2': 238122}
seed = sciper['student_1']+sciper['student_2']

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import os, sys

plt.rcParams['font.size'] = 28
plt.style.use('ggplot')
plt.rcParams["axes.grid"] = False
c = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams['figure.figsize'] = 8, 4

import keras
from keras.models import Model, load_model
from keras.layers import Input, Masking, TimeDistributed, Dense, Concatenate, Dropout, LSTM, GRU, SimpleRNN
from keras.optimizers import Adam
from keras.utils import np_utils
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import ModelCheckpoint

import midi
import music21

import copy
from collections import defaultdict
# Out:
# /home/maxime/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/maxime/anaconda3/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def plotMelody(P, T, dictionaries, PrP=None, PrT=None, H=None):
    """
    P: The pitch array (integer representation) or matrix (one-hot encoding)
    T: The duration array (integer representation) or matrix (one-hot encoding)
    dictionaries: The dictionaries relating integer to a pitch or duration
    PrP: (Optional) If provided with PrT, plot the transition probabilities
    PrT: (Optional) If provided with PrP, plot the transition probabilities
    H: (Optional) Add a plot with the hidden state dynamic sorted by frequency
    """
    P = np.asarray(P)
    T = np.asarray(T)
    if len(P.shape) == 1:#if array
        P = np_utils.to_categorical(P, len(dictionaries['P']))
    if len(T.shape) == 1:#if array
        T = np_utils.to_categorical(T, len(dictionaries['T']))
    
    xlim = [-1,np.where(P==1)[0][-1]+1]
    
    activeidxes = np.where(np.sum(P, axis=0)>1.)[0]
    plt.figure(figsize=(8,4))
    if PrP is not None:
        targets = np.where(P[:,activeidxes]==1)
        plt.imshow(PrP[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
        plt.scatter(targets[0]-1,targets[1], color='red',s=10, marker='.') 
    else:
        plt.imshow(P[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
    plt.ylim([-0.5,len(activeidxes)-0.5])
    plt.yticks(range(len(activeidxes)),[dictionaries["P"][i] for i in activeidxes])
    plt.tight_layout()
    plt.xlabel("$n$")
    plt.ylabel("$P[n]$")
    plt.xlim(xlim)
    plt.show()
    
    activeidxes = np.where(np.sum(T, axis=0)>1.)[0]
    plt.figure(figsize=(8,4))
    if PrT is not None:
        targets = np.where(T[:,activeidxes]==1)
        plt.imshow(PrT[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
        plt.scatter(targets[0]-1,targets[1], color='red',s=10, marker='.')
    else:
        plt.imshow(T[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
    plt.ylim([-0.5,len(activeidxes)-0.5])
    plt.yticks(range(len(activeidxes)),[dictionaries["T"][i] for i in activeidxes])
    plt.tight_layout()
    plt.xlabel("$n$")
    plt.ylabel("$T[n]$")
    plt.xlim(xlim)
    plt.show()
    
    
    if H is not None:
        diff = np.mean([[abs(j-i) for i,j in zip(H[:xlim[1]-1,k], H[1:xlim[1],k])] for k in range(H.shape[1])], axis=1)
        sortidx = np.argsort(-diff)
        H = H[:,sortidx]
        plt.figure(figsize=(8,4))
        plt.imshow(H.T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.seismic, vmin=-1, vmax=1)
        plt.xlim([-1,np.where(T==1)[0][-1]+1])
        plt.tight_layout()
        plt.xlabel("$n$")
        plt.ylabel("$H[n]$")
        plt.show()


def plotLearningCurves(History):
    
    log = History.history
    
    plt.figure(figsize=(8,4))
    plt.plot(log['YP_loss'], '--', c=c[0], label='Pitch train loss')
    plt.plot(log['val_YP_loss'], c=c[0], label='Pitch val loss')
    
    plt.plot(log['YT_loss'], '--', c=c[1], label='Dur train loss')
    plt.plot(log['val_YT_loss'], c=c[1], label='Dur val loss')
    plt.legend(loc='best')
    
    plt.figure(figsize=(8,4))
    plt.plot(log['YP_acc'], '--', c=c[0], label='Pitch train acc')
    plt.plot(log['val_YP_acc'], c=c[0], label='Pitch val acc')
    
    plt.plot(log['YT_acc'], '--', c=c[1], label='Dur train acc')
    plt.plot(log['val_YT_acc'], c=c[1], label='Dur val acc')
    plt.legend(loc='best')

def sample(preds, temperature=1.):
    """Helper function to sample an index from a probability array"""
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

def writeMIDI(xP, xT, dictionaries, label):

    # Instantiate a MIDI Pattern (contains a list of tracks)
    pattern = midi.Pattern(format = 0, resolution=480)
    # Instantiate a MIDI Track (contains a list of MIDI events)
    track = midi.Track()
    # Append the track to the pattern
    pattern.append(track)
    Events = []
    
    pseq = [dictionaries['P'][p] for p in xP]
    tseq = [dictionaries['T'][t] for t in xT]
    for t, p in zip(tseq, pseq):
        e = midi.NoteOnEvent(tick=0, velocity=90, pitch=p)
        track.append(e)
        e = midi.NoteOffEvent(tick=t, velocity=0, pitch=p)
        track.append(e)
        
    eot = midi.EndOfTrackEvent(tick=1)
    track.append(eot)
    # Save the pattern to disk
    midi.write_midifile(label, pattern)

# %% [markdown]
# ## Exercise 1 : Data processing
# ### Description
#
# For a real world application of ANNs, the original data should be translated into a representation understandable by an ANN. This step is often neglected but is of outmost importance. In order for you to better understand how ANN are applied to real world problems, the first step of this miniproject will guide you through a possible representation.
#
# Note that in general, your representation should be normalized in order to obtain homogeneous data from which a structure can be extracted by your ANN model. Importantly, all processing steps toward your representation should not (or minimally) distort your original data.
#
# To represent MIDI files, we provide you with a Python MIDI library. You should then
#
# 0. Download the MIDI tar file from [this link](https://github.com/IraKorshunova/folk-rnn/tree/master/data) and put it in a folder named "chorpus" at the same level of this notebook.
# 1. Parse the chorpus to extract the label of (a random subset of) the data (code is provided)
# 2. Read each MIDI file in the subset with the midi [library](https://github.com/louisabraham/python3-midi)
# 3. For each data sequence extract the sequence of MIDI notes defined by two dimensions ("P": the sequence of note pitches (integer between 0 and 127 representing a piano key), "T": the sequence of note durations.
# 4. Select two melodies and display them both as sequences of MIDI events and sequence of notes in two dimensions. Control that your representation is correct.
#
# For step 3, you should learn how MIDI files are constructed. Below, we give a minimal explanation and some code for this particular project. For a more complete explanation, look for MIDI in your favorite search engine. Given this dataset, you can observe that it is monophonic (one note at a time) and there's a small delay (1 tick) inbetween each note. You could decide to ignore this delay or correct (recommanded) for it.
#
# A MIDI files is composed of timed events of many kinds. For this project, we focus on the events related to notes being played or stopped. Those are MIDI events "Note Off" and "Note On". Each event is timed with respect with the previous one (dt). The duration of a note is therefore given by the cummulated dt inbetween the event associated to a note's onset and the event associated with the same note's offset.

# %% [markdown]
# ### Minimal code to read MIDI files

# %%
def display(midi_file="chorpus/sessiontune0.mid"):
    #index 0 for first track only
    events = midi.read_midifile(midi_file)[0] 
    tick = 0
    print(midi_file)
    print("#"*40)
    print("tick \t pitch \t message \t velocity")
    print("#"*40+'\n')
    for n, event in enumerate(events):
        tick += event.tick
        if event.name in ['Note On', 'Note Off']:
            if n<13 or n>len(events)-10:
                print("%i \t %i \t %s \t %i"%(tick, event.data[0], event.name, event.data[1]))
            if n in range(20,23):
                print(". \t . \t . \t \t .")
    print("#"*40+'\n')

display()

datapath = "chorpus/"
dataset = {}
np.random.seed(seed)

for filename in os.listdir(datapath):
    if filename.endswith("mid"):
        label = filename[:-4]
        #Down sample dataset
        if np.random.rand() < 0.1:
            dataset[label] = {"T":[], "P": []}
print("%i/%i melodies retained"%(len(list(dataset.keys())), len(os.listdir(datapath))))
# Out:
# chorpus/sessiontune0.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 67 	 Note On 	 105
# 240 	 67 	 Note Off 	 0
# 241 	 64 	 Note On 	 80
# 480 	 64 	 Note Off 	 0
# 481 	 64 	 Note On 	 80
# 720 	 64 	 Note Off 	 0
# 721 	 64 	 Note On 	 95
# 1200 	 64 	 Note Off 	 0
# 1201 	 62 	 Note On 	 80
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 33601 	 67 	 Note On 	 80
# 33840 	 67 	 Note Off 	 0
# 33841 	 69 	 Note On 	 95
# 34080 	 69 	 Note Off 	 0
# 34081 	 71 	 Note On 	 80
# 34320 	 71 	 Note Off 	 0
# 34321 	 72 	 Note On 	 80
# 34560 	 72 	 Note Off 	 0
# ########################################
#
# 4586/45853 melodies retained

# %% [markdown]
# ### Solution

# %%
def parseMIDI(midi_file):
    events = midi.read_midifile(midi_file)[0] #index 0 for first track only  
    T = []
    P = []
    for n, event in enumerate(events):
        if event.name == 'Note Off':
            pitch = event.data[0]
            time = event.tick
            if time > 0:
                P.append(pitch)
                T.append(time - 1)
            
    assert len(P) == len(T)
    return P, T

for label in list(dataset.keys()):
    Pseq, Tseq = parseMIDI(datapath+label+".mid")
    dataset[label]['T']= Tseq
    dataset[label]['P']= Pseq

for label in np.random.choice(list(dataset.keys()), 2):
    print(label)
    print("MIDI events")
    display(datapath+label+".mid")
    print("Note representation")
    print(dataset[label])
    print('/n')
# Out:
# sessiontune17751
# MIDI events
# chorpus/sessiontune17751.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 72 	 Note On 	 105
# 240 	 72 	 Note Off 	 0
# 241 	 69 	 Note On 	 80
# 480 	 69 	 Note Off 	 0
# 481 	 69 	 Note On 	 80
# 720 	 69 	 Note Off 	 0
# 721 	 72 	 Note On 	 80
# 960 	 72 	 Note Off 	 0
# 961 	 71 	 Note On 	 95
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 44881 	 71 	 Note On 	 80
# 45120 	 71 	 Note Off 	 0
# 45121 	 72 	 Note On 	 95
# 45600 	 72 	 Note Off 	 0
# 45601 	 72 	 Note On 	 80
# 45840 	 72 	 Note Off 	 0
# 45841 	 71 	 Note On 	 80
# 46080 	 71 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238], 'P': [72, 69, 69, 72, 71, 67, 69, 71, 72, 67, 64, 65, 64, 62, 67, 72, 67, 69, 72, 67, 64, 65, 64, 62, 64, 65, 67, 69, 71, 72, 69, 69, 72, 71, 67, 69, 71, 72, 67, 64, 65, 64, 62, 67, 60, 64, 64, 60, 64, 67, 64, 65, 67, 69, 71, 72, 72, 71, 72, 67, 72, 74, 76, 74, 76, 77, 79, 81, 79, 77, 76, 74, 72, 67, 72, 74, 76, 77, 76, 67, 74, 76, 76, 74, 72, 67, 69, 71, 72, 67, 72, 74, 76, 74, 76, 77, 79, 81, 79, 77, 76, 74, 72, 67, 69, 72, 67, 64, 65, 64, 62, 64, 65, 67, 69, 71, 72, 74, 76, 74, 72, 67, 69, 72, 67, 64, 65, 64, 62, 67, 72, 74, 76, 74, 72, 74, 76, 77, 79, 81, 79, 77, 76, 74, 72, 74, 76, 74, 72, 67, 69, 72, 67, 64, 65, 64, 62, 67, 60, 64, 64, 60, 64, 67, 64, 65, 67, 69, 71, 72, 72, 71]}
# /n
# sessiontune19457
# MIDI events
# chorpus/sessiontune19457.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 59 	 Note On 	 105
# 240 	 59 	 Note Off 	 0
# 241 	 62 	 Note On 	 80
# 480 	 62 	 Note Off 	 0
# 481 	 62 	 Note On 	 80
# 960 	 62 	 Note Off 	 0
# 961 	 64 	 Note On 	 95
# 1200 	 64 	 Note Off 	 0
# 1201 	 62 	 Note On 	 80
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 60241 	 62 	 Note On 	 80
# 60480 	 62 	 Note Off 	 0
# 60481 	 64 	 Note On 	 95
# 60720 	 64 	 Note Off 	 0
# 60721 	 67 	 Note On 	 80
# 60960 	 67 	 Note Off 	 0
# 60961 	 67 	 Note On 	 80
# 61440 	 67 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478], 'P': [59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 69, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 69, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 71, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 62, 67, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 71, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 62, 67, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67]}
# /n

# %% [markdown]
# ## Exercise 2: Tokenzation and translation to integer
# ### Description
#
# Now you should have a "dataset" dictionary where each entry corresponds to one melody example from a subset of the full dataset. In turn, every melody example is represented by a dictionary with two sequences: the "P" entry being the sequence of pitches and the "T" entry, the sequence of durations. Here, you will implement the first steps to translate this dataset in a language that can be read by your ANN models. To achieve that, we will later use the [one-hot encoding scheme](https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/), which will associate each input (and output) unit of your network to a unique pitch or duration. In your network, these units will then be sequentially activated in the same order as their corresponding pitch/duration in your dataset. And at each note, the model will be trained to approximate the probability distributions of the upcoming pitch and duration.
#
# 1. Gather in a list of all possible pitches and durations in your dataset. These two lists will be your "dictionaries" translating a pitch/duration to a unique integer between 0 and the number of entries (-1) in the pitch/duration dictionary.
# 2. Translate the pitch/duration sequence of each melody to the integer representation.
# 3. Select randomly two melodies and display them in the note representation and translated to integer. Check that the translation is correct.

# %% [markdown]
# ### Solution

# %%
def get_dicts(dataset):
    set_T = set()
    [set_T.update(dataset[label]['T']) for label in dataset.keys()]
    set_P = set()
    [set_P.update(dataset[label]['P']) for label in dataset.keys()]
    dict_T = {k: v for v, k in enumerate(list(set_T))}
    dict_P = {k: v for v, k in enumerate(list(set_P))}
    return {'T': dict_T, 'P': dict_P}, {'T': {v: k for k, v in dict_T.items()}, 'P': {v: k for k, v in dict_P.items()}}

# %%
def tokenize(dataset):
    dictionaries, inv = get_dicts(dataset)
    dataset_int = copy.deepcopy(dataset)
    for label in dataset_int.keys():
        dataset_int[label]['T'] = [dictionaries['T'][v] for v in dataset_int[label]['T']]
        dataset_int[label]['P'] = [dictionaries['P'][v] for v in dataset_int[label]['P']]
    return dataset_int, inv

# %%
dataset_int, _ = tokenize(dataset)

# %%
for label in np.random.choice(list(dataset.keys()), 2):
    print(label)
    print("MIDI events")
    display(datapath+label+".mid")
    print("Note representation")
    print(dataset_int[label])
    print('/n')
# Out:
# sessiontune22329
# MIDI events
# chorpus/sessiontune22329.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 79 	 Note On 	 105
# 240 	 79 	 Note Off 	 0
# 241 	 77 	 Note On 	 80
# 480 	 77 	 Note Off 	 0
# 481 	 74 	 Note On 	 105
# 720 	 74 	 Note Off 	 0
# 721 	 67 	 Note On 	 80
# 960 	 67 	 Note Off 	 0
# 961 	 67 	 Note On 	 80
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 61681 	 81 	 Note On 	 80
# 61920 	 81 	 Note Off 	 0
# 61921 	 79 	 Note On 	 95
# 62400 	 79 	 Note Off 	 0
# 62401 	 79 	 Note On 	 80
# 62640 	 79 	 Note Off 	 0
# 62641 	 77 	 Note On 	 80
# 62880 	 77 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61], 'P': [31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 17, 17, 17, 17, 12, 17, 21, 24, 26, 19, 19, 19, 19, 23, 26, 31, 33, 34, 33, 31, 29, 26, 31, 31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 19, 17, 19, 21, 23, 24, 29, 26, 31, 31, 28, 29, 28, 26, 24, 21, 17, 24, 21, 19, 31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 17, 17, 17, 17, 12, 17, 21, 24, 26, 19, 19, 19, 19, 23, 26, 31, 33, 34, 33, 31, 29, 26, 31, 31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 19, 17, 19, 21, 23, 24, 29, 26, 31, 31, 28, 29, 28, 26, 24, 21, 17, 24, 21, 19, 26, 28, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 31, 29, 33, 31, 26, 28, 28, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 33, 38, 40, 38, 36, 33, 35, 36, 33, 35, 38, 36, 33, 31, 26, 28, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 31, 29, 33, 31, 26, 28, 28, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 33, 38, 40, 38, 36, 33, 35, 36, 33, 35, 38, 36, 33, 31, 31, 29]}
# /n
# sessiontune36502
# MIDI events
# chorpus/sessiontune36502.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 63 	 Note On 	 105
# 240 	 63 	 Note Off 	 0
# 241 	 62 	 Note On 	 80
# 480 	 62 	 Note Off 	 0
# 481 	 63 	 Note On 	 80
# 720 	 63 	 Note Off 	 0
# 721 	 65 	 Note On 	 80
# 960 	 65 	 Note Off 	 0
# 961 	 66 	 Note On 	 95
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 18001 	 72 	 Note On 	 80
# 18240 	 72 	 Note Off 	 0
# 18241 	 73 	 Note On 	 95
# 18480 	 73 	 Note Off 	 0
# 18481 	 70 	 Note On 	 80
# 18720 	 70 	 Note Off 	 0
# 18721 	 68 	 Note On 	 80
# 18960 	 68 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 52, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 12, 12, 12, 61, 61, 52, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 12, 12, 12, 61, 61, 52, 61, 61, 52, 61, 61, 61, 61, 61], 'P': [15, 14, 15, 17, 18, 25, 20, 22, 25, 20, 17, 18, 15, 15, 15, 13, 18, 20, 22, 24, 25, 25, 20, 17, 13, 13, 13, 13, 8, 13, 17, 13, 17, 18, 20, 22, 24, 25, 24, 25, 22, 25, 20, 17, 15, 15, 13, 18, 20, 22, 24, 25, 25, 20, 17, 13, 13, 13, 13, 8, 13, 17, 13, 17, 18, 20, 22, 24, 25, 24, 25, 27, 27, 24, 25, 22, 20]}
# /n

# %% [markdown]
# ## Exercise 3: Data reprocessing
# ### Description
#
# Before moving to the implementation of your RNN generative model of note transition, you will perform data exploration and modification. This step will allow your model to get the most out of your original data as well as ensuring some features such as transposition invariance.
#
# To further improve your model, you might want to reconsider your original data. Many different approaches can be undertaken. Here you are asked to implement the a rare event suppression method and transposition invariance.
#
# **Rare event suppression** If a unit in your network is associated to a duration that happens very rarely in your data, a possible simplification consists in removing the melodies conaining these rare events from your dataset.
# 1. Plot and comment the histogram of durations in your entire dataset. Use the labels from the original duration values (rather than the integer representation).
# 2. Based on your observations, remove from your dataset melodies containing very rare durations. Adjust the rejection threshold such that at most 5% of the melodies are dicarded with this step.
# 3. Recompute the duration dictionary based on your filtered dataset and plot the new histogram of durations.
#
# **Transposition invariance** A melody is perceived similarly by the human ear if it's shifted up or down by a constant offset (see [transposition](https://en.wikipedia.org/wiki/Transposition_(music))). Here, you will force your model to be transposition invariant. For this you can choose to use one of two orthogonal methods. The first consists in transposing every melody into a common tonality (C Major/A minor). On the other hand, the second consists in transposing each melody in all possible keys. The second method will increase your dataset size by a factor bigger than 11! As the training time is directly related with the dataset size, to save computing time, we recomand that you implement the first option.
#
# ***Pitch normalization***
# 1. Use the provided function to create a new dataset where all melodies are transposed to C Major/A minor.
# 2. Plot the histograms of the pitches before and after transposition.
#
# Finally, you shoud recompute the tokenization step for your brand new filtered and normalized dataset.

# %% [markdown]
# ### Solution

# %%
def transposeDataset(dataset):
    transposed_dataset = {}

    for label in list(dataset.keys()):
        transposed_dataset[label] = {}
        score = music21.converter.parse(datapath+label+".mid")
        key = score.analyze('key')
        if key.mode == "major":
            i = music21.interval.Interval(key.tonic, music21.pitch.Pitch('C'))
        elif key.mode == "minor":
            i = music21.interval.Interval(key.tonic, music21.pitch.Pitch('A'))
        i = i.semitones
        transposed_dataset[label]['P'] = [p+i for p in dataset[label]['P']]
        transposed_dataset[label]['T'] = dataset[label]['T']
        
    return transposed_dataset

# %%
plt.hist([e for label in dataset.keys() for e in set(dataset[label]['T'])], bins=50);

# %%
tot_nb_melody = len(dataset.keys())

dataset_cleaned = copy.deepcopy(dataset)

d = defaultdict(list)

[d[e].append(label) for label in dataset.keys() for e in set(dataset[label]['T'])];

# %%
labels_to_remove = set()
duration_to_remove = 0
for time in sorted(d, key=lambda k: len(d[k]), reverse=False):
    if len(set(labels_to_remove).union(set(d[time]))) < 0.05 * tot_nb_melody:
        labels_to_remove = labels_to_remove.union(d[time])
        duration_to_remove += 1
    else:
        break

# %%
for label in labels_to_remove:
    del dataset_cleaned[label]

# %%
duration_to_remove/len(d.keys())
# Out:
# 0.7536231884057971

# %%
dataset_cleaned = transposeDataset(dataset_cleaned)

# %% [markdown]
# **Question**: How much did you reduce the space of possible durations with your rare event suppression procedure? What is the impact in term of training time?
#
# **Answer**: We reduced the number of possible durations by a factor of around 4. TODO: IMPACT ON TRAINING TIME
#
# **Question**: Explain why and how both transposition to a single tonality and to all possible tonalities can yield transposition invariance in your model.
#
# **Answer**:
#
# **Question**: In terms of number of dimensions, what would have been the impact of keeping the joint represenation of a note duration and pitch (vs separating the two features)?
#
# **Answer**:
#
# **Question**: How would the distribution of notes in the joint representation differ from the distributions in the pitch and duration only representations (as shown by your histograms above)?
#
# **Answer**:

# %% [markdown]
# ## Exercise 4: One-hot and zero-padding
# ### Description
#
# The last few steps to be able to feed (note by note) your music scores to a RNN model are
# 1. Transform the sequence of integers into a sequence of vectors in the one-hot encoding scheme.
# 2. Homegenize the length of each sequence
#
# **One-hot encode** You can implement your own integer to one-hot code. For this use the numpy library and the suitable datatype. Alternatively, Keras provides a [built in one-hot encoding scheme](https://keras.io/utils/#to_categorical). After this step, for each melody, you should have two similar length matrices with one representing the sequence of note pitches and the other the sequence of note durations.
# 1. Code the integer representation into matrices of one-hot vectors
#
# **Zero-padding** Most deep learning libraries, including Keras, require that you specify the shape of the input data. As such, you cannot have variable length inputs per-se. The trick to handle them is [zero-padding](https://keras.io/preprocessing/sequence/#pad_sequences). Provided with the [Masking Layer](https://keras.io/layers/core/#masking) Keras will then ignore time steps where all inputs are 0.
# 1. Extend the end of each melody matrices with vectors containing only zeros until all melodies have the same size. For simplicity, use the Keras pad_sequences function. There might be some rare very long melodies in your dataset, a possible choice is to set the 'maxlen' argument of pad_sequences to the mean+2std of the melody lengths. This ensure that 95% of your melodies would end before being truncated.
# 2. Check and display the dimension of the resulting tensors. Typically, the tensor representing the sequence of pitches should be of shape [number of melodies x number of notes x number of entries in the pitch dictionary] and the tensor representing the sequence of durations [number of melodies x number of notes x number of entries in the duration dictionary]
#
# To check if this step was done correctly use the provided plotMelody function. For two randomly selected melodies, call the plotMelody function before and after one-hot/zero-pad. You should obtain the same plots (or slightly truncated if you randomly selected one belonging to 5% longest).
#
# Finally, we strongly suggest that you save your preprocessed data now.

# %% [markdown]
# ### Solution

# %%
dataset_cleaned_int, dicts = tokenize(dataset_cleaned)

# %%
seq = [len(dataset_cleaned_int[label]['T']) for label in dataset_cleaned_int.keys()]
mean = np.mean(seq)
std = np.std(seq)

n_notes = int(mean + 2*std)

# %%
for label in dataset_cleaned_int.keys():
    dataset_cleaned_int[label]['T'] = np_utils.to_categorical(dataset_cleaned_int[label]['T'], len(dicts['T'].keys()))
    dataset_cleaned_int[label]['P'] = np_utils.to_categorical(dataset_cleaned_int[label]['P'], len(dicts['P'].keys()))

# %%
label = np.random.choice(list(dataset.keys()), 1)[0]

plotMelody(dataset_cleaned_int[label]['P'], dataset_cleaned_int[label]['T'], dicts)

# %%
for label_ in dataset_cleaned_int.keys():
    dataset_cleaned_int[label_]['T'] = pad_sequences(dataset_cleaned_int[label_]['T'].T, maxlen=n_notes, padding='post', truncating='post').T
    dataset_cleaned_int[label_]['P'] = pad_sequences(dataset_cleaned_int[label_]['P'].T, maxlen=n_notes, padding='post', truncating='post').T

# %%
plotMelody(dataset_cleaned_int[label]['P'], dataset_cleaned_int[label]['T'], dicts)

# %% [markdown]
# ## Exercise 5: Building and training a generative model of  note transition with the Keras functional API
# ### Description
#
# The Keras Sequential model is very efficient for fast prototyping, however suffers from a lack of design liberty. The Keras Functional API is only slightly more complex but allows for more control on the different parts of your model. You will be using the Functional API for the rest of this project. Please read carefully the [documentation](https://keras.io/getting-started/sequential-model-guide/).
#
# Here, you will be constructing your RNN model of note transition. To achieve that, your model should be trained to approximate the probability distribution of the upcoming note (observed as two output softmax layers - one for pitch and one for duration) given the current note (given as input) and the model internal representation of the history of notes (its hidden state). To achieve that, set the Keras RNN layer argument "return_sequences" to True when building your model. Doing this will give you an output for each note, rather than a single output at the end of the sequence. During training, the target at each time step is the next note pitch and duration.
#
# You are free to use your own architecture but make sure to use at least 128 hidden units, Masking, and dropout to prevent overfitting. Your model should have two output (softmax) layers, one related to the pitch predictions that you should name `YP`, and the other related to the duration predictions `YT`. You should monitor both the loss (categorical_crossentropy) and the accuracy. For your best model, you should reach 40%/75% accuracy on the pitch/duration predictions.
#
# 1. Train your first model composed of SimpleRNN cells for min 250 epochs and save the model/parameters that lead to the higher accuracy on the validating set. Use a validation split of 0.2. Try  If you correctly named the output layers (`YP` and `YT`) use the provided `plotLearningCurves(History)` function to plot the learning curves by giving the History object returned by the Keras fit function as argument.
# 2. Train a second model where you replaced the SimpleRNN units with GRUs (LSTM unit equivalent that requires less parameters). Make sure you use the same hyperparameters as before. Plot the learning curves.
# 3. On a single plot, adapt the `plotLearningCurves(History)` function to compare the validation learning curves of the simpleRNN and GRU models. In other words, plot the validation loss vs epoch for pitch/duration for the simpleRNN and GRU models. Do the same for accuracies.

# %% [markdown]
# ### Solution

# %%
def buildModel(dictionaries, batch_length, dropout=0.2, activation='GRU', Hsize=128):
    X = dict()
    H = dict()
    M = dict()
    Y = dict()
    
    X['T'] = Input(shape=(batch_length, len(dictionaries['T'])), name="XT")
    X['P'] = Input(shape=(batch_length, len(dictionaries['P'])), name="XP")
    
    M['T'] = Masking(mask_value=0., name="MT")(X['T'])
    M['P'] = Masking(mask_value=0., name="MP")(X['P'])
    
    H['1'] = Concatenate(name="MergeX")([M['T'], M['P']])
    if activation == 'GRU':
        #Your hidden layer(s) architecture with GRU
        GRU()
        print('Sorry, not implemented yet')
        return None
    elif activation == 'LSTM':
        #Your hidden layer(s) architecture with LSTM (For your own curiosity, not required for the project)
        print('Sorry, not implemented yet')
        return None
    elif activation == 'RNN':
        #Your hidden layer(s) architecture with SimpleRNN
        H['2'] = SimpleRNN(128, return_sequences=True, recurrent_dropout=0.2)(H['1'])
        H['2'] = Dropout(0.2)(H['2'])

    Y['T'] = TimeDistributed(Dense(len(dictionaries['T']), activation='softmax'), name='YT')(H['2'])
    Y['P'] = TimeDistributed(Dense(len(dictionaries['P']), activation='softmax'), name='YP')(H['2'])
    
    model = Model(inputs = [X['T'], X['P']], outputs = [Y['T'], Y['P']])
    opt = Adam() 
    model.compile(
        loss='categorical_crossentropy', 
        optimizer=opt,
        metrics=['acc'])
    
    
    return model

RNNmodel = buildModel(dicts, 
                      batch_length=n_notes-1,
                      activation='RNN')
RNNmodel.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# XT (InputLayer)                 (None, 387, 17)      0
# __________________________________________________________________________________________________
# XP (InputLayer)                 (None, 387, 52)      0
# __________________________________________________________________________________________________
# MT (Masking)                    (None, 387, 17)      0           XT[0][0]
# __________________________________________________________________________________________________
# MP (Masking)                    (None, 387, 52)      0           XP[0][0]
# __________________________________________________________________________________________________
# MergeX (Concatenate)            (None, 387, 69)      0           MT[0][0]
#                                                                  MP[0][0]
# __________________________________________________________________________________________________
# simple_rnn_6 (SimpleRNN)        (None, 387, 128)     25344       MergeX[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 387, 128)     0           simple_rnn_6[0][0]
# __________________________________________________________________________________________________
# YT (TimeDistributed)            (None, 387, 17)      2193        dropout_1[0][0]
# __________________________________________________________________________________________________
# YP (TimeDistributed)            (None, 387, 52)      6708        dropout_1[0][0]
# ==================================================================================================
# Total params: 34,245
# Trainable params: 34,245
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
data = {'XT': [], 'XP': []}
for label in dataset_cleaned_int.keys():
    data['XT'].append(dataset_cleaned_int[label]['T'])
    data['XP'].append(dataset_cleaned_int[label]['P'])
data['XT'] = np.array(data['XT'])
data['XP'] = np.array(data['XP'])

# %%
y = {'YT': [], 'YP': []}
y['YT'] = data['XT'][:,1:,:]
y['YP'] = data['XP'][:,1:,:]

x = {'YT': [], 'YP': []}
x['XT'] = data['XT'][:,:-1,:]
x['XP'] = data['XP'][:,:-1,:]

# %%
history = RNNmodel.fit(x, y, batch_size=250, epochs=150, validation_split=0.2)
# Out:
# Train on 3503 samples, validate on 876 samples
# Epoch 1/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 5.2738 - YT_loss: 1.5668 - YP_loss: 3.7070 - YT_acc: 0.6311 - YP_acc: 0.0505 - val_loss: 4.2655 - val_YT_loss: 1.1795 - val_YP_loss: 3.0860 - val_YT_acc: 0.6802 - val_YP_acc: 0.1110
# Epoch 2/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 4.0818 - YT_loss: 1.0860 - YP_loss: 2.9958 - YT_acc: 0.7108 - YP_acc: 0.1081 - val_loss: 3.8419 - val_YT_loss: 1.0249 - val_YP_loss: 2.8170 - val_YT_acc: 0.7121 - val_YP_acc: 0.1453
# Epoch 3/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 3.8335 - YT_loss: 0.9666 - YP_loss: 2.8669 - YT_acc: 0.7309 - YP_acc: 0.1234 - val_loss: 3.7058 - val_YT_loss: 0.9469 - val_YP_loss: 2.7589 - val_YT_acc: 0.7208 - val_YP_acc: 0.1537
# Epoch 4/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 3.6977 - YT_loss: 0.9192 - YP_loss: 2.7785 - YT_acc: 0.7396 - YP_acc: 0.1452 - val_loss: 3.5578 - val_YT_loss: 0.9157 - val_YP_loss: 2.6421 - val_YT_acc: 0.7224 - val_YP_acc: 0.1812
# Epoch 5/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 3.5218 - YT_loss: 0.9042 - YP_loss: 2.6176 - YT_acc: 0.7417 - YP_acc: 0.1710 - val_loss: 3.3708 - val_YT_loss: 0.8860 - val_YP_loss: 2.4847 - val_YT_acc: 0.7477 - val_YP_acc: 0.2055
# Epoch 6/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 3.3709 - YT_loss: 0.8742 - YP_loss: 2.4967 - YT_acc: 0.7578 - YP_acc: 0.1912 - val_loss: 3.2391 - val_YT_loss: 0.8618 - val_YP_loss: 2.3773 - val_YT_acc: 0.7457 - val_YP_acc: 0.2368
# Epoch 7/150
# 3503/3503 [==============================] - 12s 4ms/step - loss: 3.2491 - YT_loss: 0.8413 - YP_loss: 2.4078 - YT_acc: 0.7618 - YP_acc: 0.2061 - val_loss: 3.1440 - val_YT_loss: 0.8264 - val_YP_loss: 2.3176 - val_YT_acc: 0.7541 - val_YP_acc: 0.2428
# Epoch 8/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 3.1702 - YT_loss: 0.8197 - YP_loss: 2.3504 - YT_acc: 0.7651 - YP_acc: 0.2152 - val_loss: 3.0840 - val_YT_loss: 0.8091 - val_YP_loss: 2.2749 - val_YT_acc: 0.7601 - val_YP_acc: 0.2517
# Epoch 9/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 3.1050 - YT_loss: 0.8036 - YP_loss: 2.3013 - YT_acc: 0.7675 - YP_acc: 0.2284 - val_loss: 3.0284 - val_YT_loss: 0.7970 - val_YP_loss: 2.2313 - val_YT_acc: 0.7592 - val_YP_acc: 0.2625
# Epoch 10/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 3.0512 - YT_loss: 0.7930 - YP_loss: 2.2582 - YT_acc: 0.7695 - YP_acc: 0.2388 - val_loss: 2.9866 - val_YT_loss: 0.7937 - val_YP_loss: 2.1929 - val_YT_acc: 0.7648 - val_YP_acc: 0.2672
# Epoch 11/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 3.0187 - YT_loss: 0.7889 - YP_loss: 2.2299 - YT_acc: 0.7711 - YP_acc: 0.2463 - val_loss: 2.9612 - val_YT_loss: 0.7869 - val_YP_loss: 2.1744 - val_YT_acc: 0.7634 - val_YP_acc: 0.2760
# Epoch 12/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.9765 - YT_loss: 0.7761 - YP_loss: 2.2005 - YT_acc: 0.7724 - YP_acc: 0.2543 - val_loss: 2.9028 - val_YT_loss: 0.7709 - val_YP_loss: 2.1319 - val_YT_acc: 0.7672 - val_YP_acc: 0.2812
# Epoch 13/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.9304 - YT_loss: 0.7643 - YP_loss: 2.1660 - YT_acc: 0.7738 - YP_acc: 0.2631 - val_loss: 2.8658 - val_YT_loss: 0.7589 - val_YP_loss: 2.1070 - val_YT_acc: 0.7681 - val_YP_acc: 0.2860
# Epoch 14/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.8941 - YT_loss: 0.7533 - YP_loss: 2.1408 - YT_acc: 0.7757 - YP_acc: 0.2688 - val_loss: 2.8574 - val_YT_loss: 0.7685 - val_YP_loss: 2.0889 - val_YT_acc: 0.7670 - val_YP_acc: 0.2894
# Epoch 15/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.8743 - YT_loss: 0.7505 - YP_loss: 2.1238 - YT_acc: 0.7763 - YP_acc: 0.2724 - val_loss: 2.8103 - val_YT_loss: 0.7450 - val_YP_loss: 2.0654 - val_YT_acc: 0.7710 - val_YP_acc: 0.2928
# Epoch 16/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.8401 - YT_loss: 0.7411 - YP_loss: 2.0990 - YT_acc: 0.7775 - YP_acc: 0.2789 - val_loss: 2.7910 - val_YT_loss: 0.7394 - val_YP_loss: 2.0516 - val_YT_acc: 0.7744 - val_YP_acc: 0.2975
# Epoch 17/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.8179 - YT_loss: 0.7363 - YP_loss: 2.0816 - YT_acc: 0.7789 - YP_acc: 0.2842 - val_loss: 2.7661 - val_YT_loss: 0.7344 - val_YP_loss: 2.0316 - val_YT_acc: 0.7742 - val_YP_acc: 0.3027
# Epoch 18/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.7968 - YT_loss: 0.7306 - YP_loss: 2.0662 - YT_acc: 0.7796 - YP_acc: 0.2876 - val_loss: 2.7576 - val_YT_loss: 0.7365 - val_YP_loss: 2.0211 - val_YT_acc: 0.7733 - val_YP_acc: 0.3049
# Epoch 19/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.7792 - YT_loss: 0.7273 - YP_loss: 2.0519 - YT_acc: 0.7811 - YP_acc: 0.2928 - val_loss: 2.7350 - val_YT_loss: 0.7300 - val_YP_loss: 2.0051 - val_YT_acc: 0.7745 - val_YP_acc: 0.3088
# Epoch 20/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.7586 - YT_loss: 0.7224 - YP_loss: 2.0362 - YT_acc: 0.7821 - YP_acc: 0.2977 - val_loss: 2.7149 - val_YT_loss: 0.7221 - val_YP_loss: 1.9927 - val_YT_acc: 0.7766 - val_YP_acc: 0.3096
# Epoch 21/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.7380 - YT_loss: 0.7135 - YP_loss: 2.0245 - YT_acc: 0.7834 - YP_acc: 0.2981 - val_loss: 2.6939 - val_YT_loss: 0.7165 - val_YP_loss: 1.9773 - val_YT_acc: 0.7782 - val_YP_acc: 0.3170
# Epoch 22/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.7239 - YT_loss: 0.7123 - YP_loss: 2.0116 - YT_acc: 0.7844 - YP_acc: 0.3035 - val_loss: 2.6879 - val_YT_loss: 0.7199 - val_YP_loss: 1.9679 - val_YT_acc: 0.7799 - val_YP_acc: 0.3212
# Epoch 23/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.7147 - YT_loss: 0.7082 - YP_loss: 2.0065 - YT_acc: 0.7853 - YP_acc: 0.3045 - val_loss: 2.6787 - val_YT_loss: 0.7192 - val_YP_loss: 1.9595 - val_YT_acc: 0.7819 - val_YP_acc: 0.3252
# Epoch 24/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.7020 - YT_loss: 0.7048 - YP_loss: 1.9972 - YT_acc: 0.7871 - YP_acc: 0.3082 - val_loss: 2.6650 - val_YT_loss: 0.7067 - val_YP_loss: 1.9583 - val_YT_acc: 0.7824 - val_YP_acc: 0.3229
# Epoch 25/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.6855 - YT_loss: 0.6996 - YP_loss: 1.9859 - YT_acc: 0.7883 - YP_acc: 0.3106 - val_loss: 2.6693 - val_YT_loss: 0.7088 - val_YP_loss: 1.9605 - val_YT_acc: 0.7805 - val_YP_acc: 0.3218
# Epoch 26/150
# 3503/3503 [==============================] - 12s 4ms/step - loss: 2.6801 - YT_loss: 0.6983 - YP_loss: 1.9818 - YT_acc: 0.7884 - YP_acc: 0.3123 - val_loss: 2.6365 - val_YT_loss: 0.7021 - val_YP_loss: 1.9344 - val_YT_acc: 0.7825 - val_YP_acc: 0.3328
# Epoch 27/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.6612 - YT_loss: 0.6928 - YP_loss: 1.9684 - YT_acc: 0.7900 - YP_acc: 0.3162 - val_loss: 2.6285 - val_YT_loss: 0.7023 - val_YP_loss: 1.9262 - val_YT_acc: 0.7859 - val_YP_acc: 0.3338
# Epoch 28/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.6505 - YT_loss: 0.6905 - YP_loss: 1.9600 - YT_acc: 0.7910 - YP_acc: 0.3185 - val_loss: 2.6226 - val_YT_loss: 0.6976 - val_YP_loss: 1.9249 - val_YT_acc: 0.7886 - val_YP_acc: 0.3344
# Epoch 29/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.6428 - YT_loss: 0.6869 - YP_loss: 1.9559 - YT_acc: 0.7926 - YP_acc: 0.3198 - val_loss: 2.6207 - val_YT_loss: 0.7017 - val_YP_loss: 1.9191 - val_YT_acc: 0.7886 - val_YP_acc: 0.3357
# Epoch 30/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.6381 - YT_loss: 0.6856 - YP_loss: 1.9525 - YT_acc: 0.7942 - YP_acc: 0.3218 - val_loss: 2.6200 - val_YT_loss: 0.7008 - val_YP_loss: 1.9192 - val_YT_acc: 0.7868 - val_YP_acc: 0.3352
# Epoch 31/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.6346 - YT_loss: 0.6849 - YP_loss: 1.9497 - YT_acc: 0.7948 - YP_acc: 0.3231 - val_loss: 2.6145 - val_YT_loss: 0.6949 - val_YP_loss: 1.9196 - val_YT_acc: 0.7916 - val_YP_acc: 0.3396
# Epoch 32/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.6271 - YT_loss: 0.6828 - YP_loss: 1.9444 - YT_acc: 0.7959 - YP_acc: 0.3239 - val_loss: 2.5920 - val_YT_loss: 0.6853 - val_YP_loss: 1.9067 - val_YT_acc: 0.7917 - val_YP_acc: 0.3413
# Epoch 33/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.6115 - YT_loss: 0.6765 - YP_loss: 1.9350 - YT_acc: 0.7968 - YP_acc: 0.3258 - val_loss: 2.5862 - val_YT_loss: 0.6887 - val_YP_loss: 1.8975 - val_YT_acc: 0.7899 - val_YP_acc: 0.3403
# Epoch 34/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.6039 - YT_loss: 0.6753 - YP_loss: 1.9286 - YT_acc: 0.7977 - YP_acc: 0.3271 - val_loss: 2.5764 - val_YT_loss: 0.6809 - val_YP_loss: 1.8955 - val_YT_acc: 0.7925 - val_YP_acc: 0.3421
# Epoch 35/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5985 - YT_loss: 0.6722 - YP_loss: 1.9262 - YT_acc: 0.7979 - YP_acc: 0.3283 - val_loss: 2.5657 - val_YT_loss: 0.6772 - val_YP_loss: 1.8884 - val_YT_acc: 0.7939 - val_YP_acc: 0.3455
# Epoch 36/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5887 - YT_loss: 0.6684 - YP_loss: 1.9203 - YT_acc: 0.7987 - YP_acc: 0.3306 - val_loss: 2.6236 - val_YT_loss: 0.7170 - val_YP_loss: 1.9067 - val_YT_acc: 0.7880 - val_YP_acc: 0.3387
# Epoch 37/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.6117 - YT_loss: 0.6883 - YP_loss: 1.9234 - YT_acc: 0.7968 - YP_acc: 0.3288 - val_loss: 2.5766 - val_YT_loss: 0.6845 - val_YP_loss: 1.8921 - val_YT_acc: 0.7957 - val_YP_acc: 0.3468
# Epoch 38/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.5906 - YT_loss: 0.6731 - YP_loss: 1.9175 - YT_acc: 0.8011 - YP_acc: 0.3309 - val_loss: 2.5762 - val_YT_loss: 0.6792 - val_YP_loss: 1.8971 - val_YT_acc: 0.7960 - val_YP_acc: 0.3420
# Epoch 39/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.5805 - YT_loss: 0.6656 - YP_loss: 1.9149 - YT_acc: 0.8011 - YP_acc: 0.3317 - val_loss: 2.5530 - val_YT_loss: 0.6720 - val_YP_loss: 1.8810 - val_YT_acc: 0.7955 - val_YP_acc: 0.3478
# Epoch 40/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.5734 - YT_loss: 0.6627 - YP_loss: 1.9107 - YT_acc: 0.8018 - YP_acc: 0.3317 - val_loss: 2.5444 - val_YT_loss: 0.6688 - val_YP_loss: 1.8756 - val_YT_acc: 0.7967 - val_YP_acc: 0.3498
# Epoch 41/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.5653 - YT_loss: 0.6610 - YP_loss: 1.9043 - YT_acc: 0.8019 - YP_acc: 0.3344 - val_loss: 2.5385 - val_YT_loss: 0.6681 - val_YP_loss: 1.8705 - val_YT_acc: 0.7978 - val_YP_acc: 0.3509
# Epoch 42/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.5570 - YT_loss: 0.6569 - YP_loss: 1.9001 - YT_acc: 0.8031 - YP_acc: 0.3355 - val_loss: 2.5474 - val_YT_loss: 0.6685 - val_YP_loss: 1.8789 - val_YT_acc: 0.7974 - val_YP_acc: 0.3482
# Epoch 43/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.5606 - YT_loss: 0.6584 - YP_loss: 1.9022 - YT_acc: 0.8031 - YP_acc: 0.3361 - val_loss: 2.5400 - val_YT_loss: 0.6655 - val_YP_loss: 1.8745 - val_YT_acc: 0.7978 - val_YP_acc: 0.3502
# Epoch 44/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5583 - YT_loss: 0.6571 - YP_loss: 1.9012 - YT_acc: 0.8031 - YP_acc: 0.3359 - val_loss: 2.5570 - val_YT_loss: 0.6883 - val_YP_loss: 1.8686 - val_YT_acc: 0.7962 - val_YP_acc: 0.3512
# Epoch 45/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.5614 - YT_loss: 0.6652 - YP_loss: 1.8962 - YT_acc: 0.8030 - YP_acc: 0.3377 - val_loss: 2.5264 - val_YT_loss: 0.6653 - val_YP_loss: 1.8611 - val_YT_acc: 0.7985 - val_YP_acc: 0.3548
# Epoch 46/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.5455 - YT_loss: 0.6544 - YP_loss: 1.8911 - YT_acc: 0.8046 - YP_acc: 0.3389 - val_loss: 2.5416 - val_YT_loss: 0.6655 - val_YP_loss: 1.8761 - val_YT_acc: 0.7972 - val_YP_acc: 0.3502
# Epoch 47/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5462 - YT_loss: 0.6524 - YP_loss: 1.8938 - YT_acc: 0.8053 - YP_acc: 0.3385 - val_loss: 2.5213 - val_YT_loss: 0.6603 - val_YP_loss: 1.8610 - val_YT_acc: 0.7998 - val_YP_acc: 0.3529
# Epoch 48/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.5403 - YT_loss: 0.6526 - YP_loss: 1.8877 - YT_acc: 0.8057 - YP_acc: 0.3404 - val_loss: 2.5513 - val_YT_loss: 0.6683 - val_YP_loss: 1.8830 - val_YT_acc: 0.8011 - val_YP_acc: 0.3493
# Epoch 49/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5438 - YT_loss: 0.6511 - YP_loss: 1.8927 - YT_acc: 0.8059 - YP_acc: 0.3385 - val_loss: 2.5210 - val_YT_loss: 0.6593 - val_YP_loss: 1.8617 - val_YT_acc: 0.7999 - val_YP_acc: 0.3523
# Epoch 50/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.5352 - YT_loss: 0.6500 - YP_loss: 1.8852 - YT_acc: 0.8066 - YP_acc: 0.3404 - val_loss: 2.5225 - val_YT_loss: 0.6647 - val_YP_loss: 1.8578 - val_YT_acc: 0.8009 - val_YP_acc: 0.3539
# Epoch 51/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.5339 - YT_loss: 0.6499 - YP_loss: 1.8840 - YT_acc: 0.8070 - YP_acc: 0.3416 - val_loss: 2.5139 - val_YT_loss: 0.6583 - val_YP_loss: 1.8556 - val_YT_acc: 0.8012 - val_YP_acc: 0.3564
# Epoch 52/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.5243 - YT_loss: 0.6447 - YP_loss: 1.8796 - YT_acc: 0.8072 - YP_acc: 0.3431 - val_loss: 2.5137 - val_YT_loss: 0.6569 - val_YP_loss: 1.8568 - val_YT_acc: 0.8006 - val_YP_acc: 0.3572
# Epoch 53/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.5246 - YT_loss: 0.6448 - YP_loss: 1.8799 - YT_acc: 0.8075 - YP_acc: 0.3430 - val_loss: 2.5128 - val_YT_loss: 0.6608 - val_YP_loss: 1.8520 - val_YT_acc: 0.8028 - val_YP_acc: 0.3570
# Epoch 54/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.5298 - YT_loss: 0.6499 - YP_loss: 1.8800 - YT_acc: 0.8070 - YP_acc: 0.3429 - val_loss: 2.5188 - val_YT_loss: 0.6589 - val_YP_loss: 1.8599 - val_YT_acc: 0.8004 - val_YP_acc: 0.3533
# Epoch 55/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.5295 - YT_loss: 0.6461 - YP_loss: 1.8835 - YT_acc: 0.8078 - YP_acc: 0.3421 - val_loss: 2.5172 - val_YT_loss: 0.6622 - val_YP_loss: 1.8550 - val_YT_acc: 0.8012 - val_YP_acc: 0.3565
# Epoch 56/150
# 3503/3503 [==============================] - 12s 4ms/step - loss: 2.5185 - YT_loss: 0.6436 - YP_loss: 1.8749 - YT_acc: 0.8082 - YP_acc: 0.3439 - val_loss: 2.5029 - val_YT_loss: 0.6546 - val_YP_loss: 1.8483 - val_YT_acc: 0.8021 - val_YP_acc: 0.3575
# Epoch 57/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.5164 - YT_loss: 0.6425 - YP_loss: 1.8739 - YT_acc: 0.8085 - YP_acc: 0.3439 - val_loss: 2.5007 - val_YT_loss: 0.6534 - val_YP_loss: 1.8473 - val_YT_acc: 0.8026 - val_YP_acc: 0.3564
# Epoch 58/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.5131 - YT_loss: 0.6413 - YP_loss: 1.8718 - YT_acc: 0.8082 - YP_acc: 0.3446 - val_loss: 2.5004 - val_YT_loss: 0.6569 - val_YP_loss: 1.8435 - val_YT_acc: 0.8021 - val_YP_acc: 0.3599
# Epoch 59/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.5116 - YT_loss: 0.6427 - YP_loss: 1.8689 - YT_acc: 0.8086 - YP_acc: 0.3459 - val_loss: 2.5073 - val_YT_loss: 0.6546 - val_YP_loss: 1.8527 - val_YT_acc: 0.8017 - val_YP_acc: 0.3537
# Epoch 60/150
# 3503/3503 [==============================] - 12s 3ms/step - loss: 2.5118 - YT_loss: 0.6404 - YP_loss: 1.8714 - YT_acc: 0.8083 - YP_acc: 0.3451 - val_loss: 2.4925 - val_YT_loss: 0.6495 - val_YP_loss: 1.8430 - val_YT_acc: 0.8019 - val_YP_acc: 0.3599
# Epoch 61/150
# 3503/3503 [==============================] - 11s 3ms/step - loss: 2.5053 - YT_loss: 0.6395 - YP_loss: 1.8658 - YT_acc: 0.8078 - YP_acc: 0.3465 - val_loss: 2.5109 - val_YT_loss: 0.6668 - val_YP_loss: 1.8441 - val_YT_acc: 0.8002 - val_YP_acc: 0.3586
# Epoch 62/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.5104 - YT_loss: 0.6443 - YP_loss: 1.8661 - YT_acc: 0.8086 - YP_acc: 0.3463 - val_loss: 2.4902 - val_YT_loss: 0.6509 - val_YP_loss: 1.8393 - val_YT_acc: 0.8029 - val_YP_acc: 0.3612
# Epoch 63/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.5011 - YT_loss: 0.6372 - YP_loss: 1.8639 - YT_acc: 0.8094 - YP_acc: 0.3479 - val_loss: 2.4978 - val_YT_loss: 0.6579 - val_YP_loss: 1.8399 - val_YT_acc: 0.8017 - val_YP_acc: 0.3605
# Epoch 64/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.5038 - YT_loss: 0.6404 - YP_loss: 1.8634 - YT_acc: 0.8088 - YP_acc: 0.3472 - val_loss: 2.4926 - val_YT_loss: 0.6527 - val_YP_loss: 1.8399 - val_YT_acc: 0.8020 - val_YP_acc: 0.3591
# Epoch 65/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.5006 - YT_loss: 0.6394 - YP_loss: 1.8612 - YT_acc: 0.8090 - YP_acc: 0.3482 - val_loss: 2.4958 - val_YT_loss: 0.6508 - val_YP_loss: 1.8450 - val_YT_acc: 0.8029 - val_YP_acc: 0.3569
# Epoch 66/150
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4986 - YT_loss: 0.6380 - YP_loss: 1.8607 - YT_acc: 0.8081 - YP_acc: 0.3485 - val_loss: 2.5046 - val_YT_loss: 0.6595 - val_YP_loss: 1.8450 - val_YT_acc: 0.8009 - val_YP_acc: 0.3560
# Epoch 67/150
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.5024 - YT_loss: 0.6414 - YP_loss: 1.8610 - YT_acc: 0.8082 - YP_acc: 0.3471 - val_loss: 2.4925 - val_YT_loss: 0.6485 - val_YP_loss: 1.8440 - val_YT_acc: 0.8038 - val_YP_acc: 0.3569
# Epoch 68/150
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4957 - YT_loss: 0.6348 - YP_loss: 1.8609 - YT_acc: 0.8102 - YP_acc: 0.3476 - val_loss: 2.4976 - val_YT_loss: 0.6520 - val_YP_loss: 1.8456 - val_YT_acc: 0.8018 - val_YP_acc: 0.3553
# Epoch 69/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4939 - YT_loss: 0.6359 - YP_loss: 1.8580 - YT_acc: 0.8093 - YP_acc: 0.3486 - val_loss: 2.4907 - val_YT_loss: 0.6478 - val_YP_loss: 1.8429 - val_YT_acc: 0.8023 - val_YP_acc: 0.3579
# Epoch 70/150
# 3503/3503 [==============================] - 17s 5ms/step - loss: 2.4901 - YT_loss: 0.6336 - YP_loss: 1.8565 - YT_acc: 0.8097 - YP_acc: 0.3481 - val_loss: 2.4808 - val_YT_loss: 0.6499 - val_YP_loss: 1.8308 - val_YT_acc: 0.8037 - val_YP_acc: 0.3607
# Epoch 71/150
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4885 - YT_loss: 0.6335 - YP_loss: 1.8550 - YT_acc: 0.8098 - YP_acc: 0.3481 - val_loss: 2.4809 - val_YT_loss: 0.6448 - val_YP_loss: 1.8361 - val_YT_acc: 0.8028 - val_YP_acc: 0.3583
# Epoch 72/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4838 - YT_loss: 0.6317 - YP_loss: 1.8521 - YT_acc: 0.8102 - YP_acc: 0.3488 - val_loss: 2.4795 - val_YT_loss: 0.6478 - val_YP_loss: 1.8317 - val_YT_acc: 0.8043 - val_YP_acc: 0.3614
# Epoch 73/150
# 3503/3503 [==============================] - 16s 4ms/step - loss: 2.4848 - YT_loss: 0.6321 - YP_loss: 1.8527 - YT_acc: 0.8106 - YP_acc: 0.3498 - val_loss: 2.4872 - val_YT_loss: 0.6529 - val_YP_loss: 1.8343 - val_YT_acc: 0.8046 - val_YP_acc: 0.3614
# Epoch 74/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4920 - YT_loss: 0.6364 - YP_loss: 1.8555 - YT_acc: 0.8101 - YP_acc: 0.3492 - val_loss: 2.5059 - val_YT_loss: 0.6526 - val_YP_loss: 1.8533 - val_YT_acc: 0.8025 - val_YP_acc: 0.3554
# Epoch 75/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4997 - YT_loss: 0.6362 - YP_loss: 1.8636 - YT_acc: 0.8094 - YP_acc: 0.3470 - val_loss: 2.4877 - val_YT_loss: 0.6496 - val_YP_loss: 1.8381 - val_YT_acc: 0.8023 - val_YP_acc: 0.3607
# Epoch 76/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4912 - YT_loss: 0.6363 - YP_loss: 1.8549 - YT_acc: 0.8095 - YP_acc: 0.3495 - val_loss: 2.4852 - val_YT_loss: 0.6508 - val_YP_loss: 1.8344 - val_YT_acc: 0.8038 - val_YP_acc: 0.3604
# Epoch 77/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4834 - YT_loss: 0.6319 - YP_loss: 1.8515 - YT_acc: 0.8096 - YP_acc: 0.3511 - val_loss: 2.4758 - val_YT_loss: 0.6480 - val_YP_loss: 1.8278 - val_YT_acc: 0.8035 - val_YP_acc: 0.3623
# Epoch 78/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4815 - YT_loss: 0.6332 - YP_loss: 1.8483 - YT_acc: 0.8096 - YP_acc: 0.3512 - val_loss: 2.4717 - val_YT_loss: 0.6440 - val_YP_loss: 1.8276 - val_YT_acc: 0.8046 - val_YP_acc: 0.3654
# Epoch 79/150
# 3503/3503 [==============================] - 16s 5ms/step - loss: 2.4741 - YT_loss: 0.6285 - YP_loss: 1.8456 - YT_acc: 0.8101 - YP_acc: 0.3525 - val_loss: 2.4712 - val_YT_loss: 0.6433 - val_YP_loss: 1.8279 - val_YT_acc: 0.8009 - val_YP_acc: 0.3644
# Epoch 80/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4759 - YT_loss: 0.6281 - YP_loss: 1.8478 - YT_acc: 0.8097 - YP_acc: 0.3525 - val_loss: 2.4649 - val_YT_loss: 0.6408 - val_YP_loss: 1.8240 - val_YT_acc: 0.8034 - val_YP_acc: 0.3651
# Epoch 81/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4745 - YT_loss: 0.6298 - YP_loss: 1.8447 - YT_acc: 0.8098 - YP_acc: 0.3521 - val_loss: 2.4713 - val_YT_loss: 0.6436 - val_YP_loss: 1.8277 - val_YT_acc: 0.8025 - val_YP_acc: 0.3627
# Epoch 82/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4704 - YT_loss: 0.6271 - YP_loss: 1.8434 - YT_acc: 0.8106 - YP_acc: 0.3534 - val_loss: 2.4642 - val_YT_loss: 0.6441 - val_YP_loss: 1.8201 - val_YT_acc: 0.8012 - val_YP_acc: 0.3645
# Epoch 83/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4703 - YT_loss: 0.6282 - YP_loss: 1.8422 - YT_acc: 0.8103 - YP_acc: 0.3524 - val_loss: 2.4661 - val_YT_loss: 0.6442 - val_YP_loss: 1.8219 - val_YT_acc: 0.8050 - val_YP_acc: 0.3655
# Epoch 84/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4673 - YT_loss: 0.6262 - YP_loss: 1.8411 - YT_acc: 0.8105 - YP_acc: 0.3545 - val_loss: 2.4798 - val_YT_loss: 0.6409 - val_YP_loss: 1.8390 - val_YT_acc: 0.8037 - val_YP_acc: 0.3578
# Epoch 85/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4740 - YT_loss: 0.6261 - YP_loss: 1.8479 - YT_acc: 0.8104 - YP_acc: 0.3513 - val_loss: 2.4744 - val_YT_loss: 0.6455 - val_YP_loss: 1.8289 - val_YT_acc: 0.8040 - val_YP_acc: 0.3651
# Epoch 86/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4698 - YT_loss: 0.6278 - YP_loss: 1.8420 - YT_acc: 0.8109 - YP_acc: 0.3538 - val_loss: 2.4668 - val_YT_loss: 0.6498 - val_YP_loss: 1.8170 - val_YT_acc: 0.8014 - val_YP_acc: 0.3663
# Epoch 87/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4681 - YT_loss: 0.6274 - YP_loss: 1.8407 - YT_acc: 0.8102 - YP_acc: 0.3534 - val_loss: 2.4689 - val_YT_loss: 0.6394 - val_YP_loss: 1.8295 - val_YT_acc: 0.8028 - val_YP_acc: 0.3597
# Epoch 88/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4671 - YT_loss: 0.6253 - YP_loss: 1.8418 - YT_acc: 0.8107 - YP_acc: 0.3537 - val_loss: 2.4856 - val_YT_loss: 0.6417 - val_YP_loss: 1.8439 - val_YT_acc: 0.8028 - val_YP_acc: 0.3578
# Epoch 89/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4701 - YT_loss: 0.6247 - YP_loss: 1.8454 - YT_acc: 0.8105 - YP_acc: 0.3532 - val_loss: 2.4750 - val_YT_loss: 0.6455 - val_YP_loss: 1.8295 - val_YT_acc: 0.8027 - val_YP_acc: 0.3595
# Epoch 90/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4744 - YT_loss: 0.6298 - YP_loss: 1.8447 - YT_acc: 0.8111 - YP_acc: 0.3519 - val_loss: 2.4702 - val_YT_loss: 0.6455 - val_YP_loss: 1.8247 - val_YT_acc: 0.8028 - val_YP_acc: 0.3640
# Epoch 91/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4655 - YT_loss: 0.6257 - YP_loss: 1.8398 - YT_acc: 0.8113 - YP_acc: 0.3554 - val_loss: 2.4591 - val_YT_loss: 0.6413 - val_YP_loss: 1.8178 - val_YT_acc: 0.8034 - val_YP_acc: 0.3679
# Epoch 92/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4626 - YT_loss: 0.6254 - YP_loss: 1.8372 - YT_acc: 0.8113 - YP_acc: 0.3557 - val_loss: 2.4524 - val_YT_loss: 0.6397 - val_YP_loss: 1.8126 - val_YT_acc: 0.8046 - val_YP_acc: 0.3674
# Epoch 93/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4597 - YT_loss: 0.6225 - YP_loss: 1.8373 - YT_acc: 0.8114 - YP_acc: 0.3545 - val_loss: 2.4718 - val_YT_loss: 0.6436 - val_YP_loss: 1.8281 - val_YT_acc: 0.8032 - val_YP_acc: 0.3622
# Epoch 94/150
# 3503/3503 [==============================] - 17s 5ms/step - loss: 2.4661 - YT_loss: 0.6266 - YP_loss: 1.8395 - YT_acc: 0.8110 - YP_acc: 0.3543 - val_loss: 2.4718 - val_YT_loss: 0.6560 - val_YP_loss: 1.8158 - val_YT_acc: 0.7970 - val_YP_acc: 0.3668
# Epoch 95/150
# 3503/3503 [==============================] - 17s 5ms/step - loss: 2.4667 - YT_loss: 0.6294 - YP_loss: 1.8372 - YT_acc: 0.8110 - YP_acc: 0.3556 - val_loss: 2.4592 - val_YT_loss: 0.6425 - val_YP_loss: 1.8167 - val_YT_acc: 0.8030 - val_YP_acc: 0.3659
# Epoch 96/150
# 3503/3503 [==============================] - 15s 4ms/step - loss: 2.4592 - YT_loss: 0.6239 - YP_loss: 1.8353 - YT_acc: 0.8120 - YP_acc: 0.3555 - val_loss: 2.4547 - val_YT_loss: 0.6375 - val_YP_loss: 1.8171 - val_YT_acc: 0.8016 - val_YP_acc: 0.3669
# Epoch 97/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4535 - YT_loss: 0.6209 - YP_loss: 1.8326 - YT_acc: 0.8117 - YP_acc: 0.3568 - val_loss: 2.4505 - val_YT_loss: 0.6364 - val_YP_loss: 1.8141 - val_YT_acc: 0.8045 - val_YP_acc: 0.3687
# Epoch 98/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4520 - YT_loss: 0.6193 - YP_loss: 1.8328 - YT_acc: 0.8119 - YP_acc: 0.3564 - val_loss: 2.4655 - val_YT_loss: 0.6407 - val_YP_loss: 1.8247 - val_YT_acc: 0.8042 - val_YP_acc: 0.3625
# Epoch 99/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4581 - YT_loss: 0.6208 - YP_loss: 1.8373 - YT_acc: 0.8115 - YP_acc: 0.3551 - val_loss: 2.4490 - val_YT_loss: 0.6328 - val_YP_loss: 1.8161 - val_YT_acc: 0.8033 - val_YP_acc: 0.3665
# Epoch 100/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4500 - YT_loss: 0.6184 - YP_loss: 1.8316 - YT_acc: 0.8117 - YP_acc: 0.3566 - val_loss: 2.4693 - val_YT_loss: 0.6450 - val_YP_loss: 1.8243 - val_YT_acc: 0.8030 - val_YP_acc: 0.3614
# Epoch 101/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4580 - YT_loss: 0.6219 - YP_loss: 1.8361 - YT_acc: 0.8116 - YP_acc: 0.3558 - val_loss: 2.4530 - val_YT_loss: 0.6382 - val_YP_loss: 1.8149 - val_YT_acc: 0.8021 - val_YP_acc: 0.3665
# Epoch 102/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4547 - YT_loss: 0.6210 - YP_loss: 1.8336 - YT_acc: 0.8112 - YP_acc: 0.3564 - val_loss: 2.4544 - val_YT_loss: 0.6393 - val_YP_loss: 1.8150 - val_YT_acc: 0.8016 - val_YP_acc: 0.3658
# Epoch 103/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4542 - YT_loss: 0.6239 - YP_loss: 1.8303 - YT_acc: 0.8105 - YP_acc: 0.3573 - val_loss: 2.4604 - val_YT_loss: 0.6448 - val_YP_loss: 1.8156 - val_YT_acc: 0.8025 - val_YP_acc: 0.3648
# Epoch 104/150
# 3503/3503 [==============================] - 14s 4ms/step - loss: 2.4576 - YT_loss: 0.6239 - YP_loss: 1.8337 - YT_acc: 0.8109 - YP_acc: 0.3566 - val_loss: 2.4688 - val_YT_loss: 0.6404 - val_YP_loss: 1.8284 - val_YT_acc: 0.8026 - val_YP_acc: 0.3622
# Epoch 105/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4572 - YT_loss: 0.6215 - YP_loss: 1.8357 - YT_acc: 0.8119 - YP_acc: 0.3554 - val_loss: 2.4576 - val_YT_loss: 0.6387 - val_YP_loss: 1.8189 - val_YT_acc: 0.8038 - val_YP_acc: 0.3649
# Epoch 106/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4552 - YT_loss: 0.6220 - YP_loss: 1.8332 - YT_acc: 0.8113 - YP_acc: 0.3567 - val_loss: 2.4618 - val_YT_loss: 0.6423 - val_YP_loss: 1.8195 - val_YT_acc: 0.8030 - val_YP_acc: 0.3644
# Epoch 107/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4555 - YT_loss: 0.6230 - YP_loss: 1.8324 - YT_acc: 0.8113 - YP_acc: 0.3571 - val_loss: 2.4487 - val_YT_loss: 0.6346 - val_YP_loss: 1.8141 - val_YT_acc: 0.8046 - val_YP_acc: 0.3685
# Epoch 108/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4466 - YT_loss: 0.6171 - YP_loss: 1.8294 - YT_acc: 0.8121 - YP_acc: 0.3583 - val_loss: 2.4878 - val_YT_loss: 0.6380 - val_YP_loss: 1.8498 - val_YT_acc: 0.8030 - val_YP_acc: 0.3545
# Epoch 109/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4652 - YT_loss: 0.6222 - YP_loss: 1.8430 - YT_acc: 0.8116 - YP_acc: 0.3549 - val_loss: 2.4774 - val_YT_loss: 0.6506 - val_YP_loss: 1.8268 - val_YT_acc: 0.8039 - val_YP_acc: 0.3609
# Epoch 110/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4628 - YT_loss: 0.6272 - YP_loss: 1.8356 - YT_acc: 0.8115 - YP_acc: 0.3546 - val_loss: 2.4503 - val_YT_loss: 0.6400 - val_YP_loss: 1.8103 - val_YT_acc: 0.8049 - val_YP_acc: 0.3681
# Epoch 111/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4501 - YT_loss: 0.6208 - YP_loss: 1.8292 - YT_acc: 0.8126 - YP_acc: 0.3576 - val_loss: 2.4890 - val_YT_loss: 0.6407 - val_YP_loss: 1.8483 - val_YT_acc: 0.8041 - val_YP_acc: 0.3542
# Epoch 112/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4718 - YT_loss: 0.6259 - YP_loss: 1.8459 - YT_acc: 0.8113 - YP_acc: 0.3518 - val_loss: 2.4615 - val_YT_loss: 0.6393 - val_YP_loss: 1.8222 - val_YT_acc: 0.8043 - val_YP_acc: 0.3611
# Epoch 113/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4654 - YT_loss: 0.6261 - YP_loss: 1.8393 - YT_acc: 0.8128 - YP_acc: 0.3537 - val_loss: 2.4521 - val_YT_loss: 0.6363 - val_YP_loss: 1.8158 - val_YT_acc: 0.8058 - val_YP_acc: 0.3652
# Epoch 114/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4494 - YT_loss: 0.6194 - YP_loss: 1.8300 - YT_acc: 0.8126 - YP_acc: 0.3570 - val_loss: 2.4444 - val_YT_loss: 0.6351 - val_YP_loss: 1.8093 - val_YT_acc: 0.8054 - val_YP_acc: 0.3675
# Epoch 115/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4447 - YT_loss: 0.6179 - YP_loss: 1.8268 - YT_acc: 0.8126 - YP_acc: 0.3579 - val_loss: 2.4487 - val_YT_loss: 0.6315 - val_YP_loss: 1.8173 - val_YT_acc: 0.8043 - val_YP_acc: 0.3631
# Epoch 116/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4445 - YT_loss: 0.6172 - YP_loss: 1.8273 - YT_acc: 0.8126 - YP_acc: 0.3572 - val_loss: 2.4394 - val_YT_loss: 0.6295 - val_YP_loss: 1.8099 - val_YT_acc: 0.8042 - val_YP_acc: 0.3664
# Epoch 117/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4413 - YT_loss: 0.6149 - YP_loss: 1.8264 - YT_acc: 0.8125 - YP_acc: 0.3593 - val_loss: 2.4652 - val_YT_loss: 0.6449 - val_YP_loss: 1.8203 - val_YT_acc: 0.8040 - val_YP_acc: 0.3662
# Epoch 118/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4561 - YT_loss: 0.6262 - YP_loss: 1.8298 - YT_acc: 0.8123 - YP_acc: 0.3564 - val_loss: 2.4491 - val_YT_loss: 0.6351 - val_YP_loss: 1.8140 - val_YT_acc: 0.8043 - val_YP_acc: 0.3674
# Epoch 119/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4445 - YT_loss: 0.6187 - YP_loss: 1.8258 - YT_acc: 0.8126 - YP_acc: 0.3588 - val_loss: 2.5403 - val_YT_loss: 0.7240 - val_YP_loss: 1.8164 - val_YT_acc: 0.7782 - val_YP_acc: 0.3645
# Epoch 120/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4823 - YT_loss: 0.6419 - YP_loss: 1.8404 - YT_acc: 0.8096 - YP_acc: 0.3552 - val_loss: 2.4726 - val_YT_loss: 0.6539 - val_YP_loss: 1.8187 - val_YT_acc: 0.8044 - val_YP_acc: 0.3665
# Epoch 121/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4653 - YT_loss: 0.6302 - YP_loss: 1.8351 - YT_acc: 0.8124 - YP_acc: 0.3567 - val_loss: 2.4525 - val_YT_loss: 0.6402 - val_YP_loss: 1.8123 - val_YT_acc: 0.8040 - val_YP_acc: 0.3685
# Epoch 122/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4532 - YT_loss: 0.6232 - YP_loss: 1.8299 - YT_acc: 0.8126 - YP_acc: 0.3586 - val_loss: 2.4433 - val_YT_loss: 0.6348 - val_YP_loss: 1.8085 - val_YT_acc: 0.8054 - val_YP_acc: 0.3704
# Epoch 123/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4447 - YT_loss: 0.6196 - YP_loss: 1.8251 - YT_acc: 0.8129 - YP_acc: 0.3599 - val_loss: 2.4375 - val_YT_loss: 0.6321 - val_YP_loss: 1.8054 - val_YT_acc: 0.8055 - val_YP_acc: 0.3708
# Epoch 124/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4394 - YT_loss: 0.6156 - YP_loss: 1.8238 - YT_acc: 0.8131 - YP_acc: 0.3599 - val_loss: 2.4545 - val_YT_loss: 0.6342 - val_YP_loss: 1.8203 - val_YT_acc: 0.8048 - val_YP_acc: 0.3645
# Epoch 125/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4469 - YT_loss: 0.6188 - YP_loss: 1.8281 - YT_acc: 0.8127 - YP_acc: 0.3587 - val_loss: 2.4479 - val_YT_loss: 0.6366 - val_YP_loss: 1.8113 - val_YT_acc: 0.8059 - val_YP_acc: 0.3701
# Epoch 126/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4444 - YT_loss: 0.6196 - YP_loss: 1.8248 - YT_acc: 0.8132 - YP_acc: 0.3600 - val_loss: 2.4340 - val_YT_loss: 0.6302 - val_YP_loss: 1.8038 - val_YT_acc: 0.8050 - val_YP_acc: 0.3700
# Epoch 127/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4364 - YT_loss: 0.6139 - YP_loss: 1.8226 - YT_acc: 0.8134 - YP_acc: 0.3610 - val_loss: 2.4525 - val_YT_loss: 0.6326 - val_YP_loss: 1.8199 - val_YT_acc: 0.8055 - val_YP_acc: 0.3640
# Epoch 128/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4449 - YT_loss: 0.6169 - YP_loss: 1.8279 - YT_acc: 0.8132 - YP_acc: 0.3586 - val_loss: 2.4395 - val_YT_loss: 0.6337 - val_YP_loss: 1.8058 - val_YT_acc: 0.8054 - val_YP_acc: 0.3692
# Epoch 129/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4428 - YT_loss: 0.6171 - YP_loss: 1.8256 - YT_acc: 0.8128 - YP_acc: 0.3592 - val_loss: 2.4504 - val_YT_loss: 0.6325 - val_YP_loss: 1.8179 - val_YT_acc: 0.8061 - val_YP_acc: 0.3673
# Epoch 130/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4414 - YT_loss: 0.6159 - YP_loss: 1.8256 - YT_acc: 0.8133 - YP_acc: 0.3605 - val_loss: 2.4361 - val_YT_loss: 0.6277 - val_YP_loss: 1.8084 - val_YT_acc: 0.8059 - val_YP_acc: 0.3692
# Epoch 131/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4369 - YT_loss: 0.6127 - YP_loss: 1.8242 - YT_acc: 0.8128 - YP_acc: 0.3593 - val_loss: 2.4375 - val_YT_loss: 0.6314 - val_YP_loss: 1.8060 - val_YT_acc: 0.8037 - val_YP_acc: 0.3700
# Epoch 132/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4349 - YT_loss: 0.6125 - YP_loss: 1.8224 - YT_acc: 0.8132 - YP_acc: 0.3588 - val_loss: 2.4435 - val_YT_loss: 0.6339 - val_YP_loss: 1.8096 - val_YT_acc: 0.8063 - val_YP_acc: 0.3690
# Epoch 133/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4340 - YT_loss: 0.6131 - YP_loss: 1.8208 - YT_acc: 0.8133 - YP_acc: 0.3606 - val_loss: 2.4342 - val_YT_loss: 0.6257 - val_YP_loss: 1.8085 - val_YT_acc: 0.8041 - val_YP_acc: 0.3703
# Epoch 134/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4327 - YT_loss: 0.6115 - YP_loss: 1.8212 - YT_acc: 0.8132 - YP_acc: 0.3600 - val_loss: 2.4284 - val_YT_loss: 0.6247 - val_YP_loss: 1.8037 - val_YT_acc: 0.8050 - val_YP_acc: 0.3710
# Epoch 135/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4303 - YT_loss: 0.6103 - YP_loss: 1.8201 - YT_acc: 0.8133 - YP_acc: 0.3602 - val_loss: 2.4586 - val_YT_loss: 0.6259 - val_YP_loss: 1.8327 - val_YT_acc: 0.8056 - val_YP_acc: 0.3593
# Epoch 136/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4393 - YT_loss: 0.6114 - YP_loss: 1.8279 - YT_acc: 0.8130 - YP_acc: 0.3582 - val_loss: 2.4688 - val_YT_loss: 0.6364 - val_YP_loss: 1.8324 - val_YT_acc: 0.8056 - val_YP_acc: 0.3609
# Epoch 137/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4467 - YT_loss: 0.6141 - YP_loss: 1.8326 - YT_acc: 0.8130 - YP_acc: 0.3564 - val_loss: 2.4400 - val_YT_loss: 0.6282 - val_YP_loss: 1.8118 - val_YT_acc: 0.8045 - val_YP_acc: 0.3664
# Epoch 138/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4390 - YT_loss: 0.6114 - YP_loss: 1.8276 - YT_acc: 0.8134 - YP_acc: 0.3568 - val_loss: 2.4351 - val_YT_loss: 0.6283 - val_YP_loss: 1.8069 - val_YT_acc: 0.8053 - val_YP_acc: 0.3684
# Epoch 139/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4369 - YT_loss: 0.6126 - YP_loss: 1.8243 - YT_acc: 0.8136 - YP_acc: 0.3585 - val_loss: 2.4349 - val_YT_loss: 0.6263 - val_YP_loss: 1.8086 - val_YT_acc: 0.8059 - val_YP_acc: 0.3670
# Epoch 140/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4290 - YT_loss: 0.6087 - YP_loss: 1.8203 - YT_acc: 0.8140 - YP_acc: 0.3588 - val_loss: 2.4556 - val_YT_loss: 0.6380 - val_YP_loss: 1.8177 - val_YT_acc: 0.8022 - val_YP_acc: 0.3632
# Epoch 141/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4380 - YT_loss: 0.6137 - YP_loss: 1.8243 - YT_acc: 0.8129 - YP_acc: 0.3579 - val_loss: 2.4302 - val_YT_loss: 0.6277 - val_YP_loss: 1.8026 - val_YT_acc: 0.8052 - val_YP_acc: 0.3704
# Epoch 142/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4323 - YT_loss: 0.6134 - YP_loss: 1.8189 - YT_acc: 0.8130 - YP_acc: 0.3603 - val_loss: 2.4389 - val_YT_loss: 0.6315 - val_YP_loss: 1.8074 - val_YT_acc: 0.8065 - val_YP_acc: 0.3677
# Epoch 143/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4332 - YT_loss: 0.6129 - YP_loss: 1.8202 - YT_acc: 0.8131 - YP_acc: 0.3605 - val_loss: 2.4272 - val_YT_loss: 0.6252 - val_YP_loss: 1.8020 - val_YT_acc: 0.8057 - val_YP_acc: 0.3716
# Epoch 144/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4315 - YT_loss: 0.6130 - YP_loss: 1.8185 - YT_acc: 0.8138 - YP_acc: 0.3609 - val_loss: 2.4552 - val_YT_loss: 0.6417 - val_YP_loss: 1.8136 - val_YT_acc: 0.8022 - val_YP_acc: 0.3672
# Epoch 145/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4385 - YT_loss: 0.6144 - YP_loss: 1.8241 - YT_acc: 0.8135 - YP_acc: 0.3608 - val_loss: 2.4348 - val_YT_loss: 0.6317 - val_YP_loss: 1.8031 - val_YT_acc: 0.8041 - val_YP_acc: 0.3715
# Epoch 146/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4281 - YT_loss: 0.6101 - YP_loss: 1.8180 - YT_acc: 0.8145 - YP_acc: 0.3613 - val_loss: 2.4266 - val_YT_loss: 0.6248 - val_YP_loss: 1.8018 - val_YT_acc: 0.8053 - val_YP_acc: 0.3704
# Epoch 147/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4236 - YT_loss: 0.6062 - YP_loss: 1.8173 - YT_acc: 0.8140 - YP_acc: 0.3612 - val_loss: 2.4280 - val_YT_loss: 0.6245 - val_YP_loss: 1.8035 - val_YT_acc: 0.8064 - val_YP_acc: 0.3701
# Epoch 148/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4213 - YT_loss: 0.6050 - YP_loss: 1.8163 - YT_acc: 0.8136 - YP_acc: 0.3614 - val_loss: 2.4361 - val_YT_loss: 0.6253 - val_YP_loss: 1.8108 - val_YT_acc: 0.8062 - val_YP_acc: 0.3680
# Epoch 149/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4284 - YT_loss: 0.6062 - YP_loss: 1.8222 - YT_acc: 0.8136 - YP_acc: 0.3601 - val_loss: 2.4376 - val_YT_loss: 0.6224 - val_YP_loss: 1.8152 - val_YT_acc: 0.8047 - val_YP_acc: 0.3635
# Epoch 150/150
# 3503/3503 [==============================] - 13s 4ms/step - loss: 2.4306 - YT_loss: 0.6077 - YP_loss: 1.8230 - YT_acc: 0.8136 - YP_acc: 0.3589 - val_loss: 2.4279 - val_YT_loss: 0.6248 - val_YP_loss: 1.8031 - val_YT_acc: 0.8054 - val_YP_acc: 0.3717

# %% [markdown]
# **Question**: What are the best prediction accuracies you obtained? With which model?
#
# **Answer**:
#
# **Question**: In a few sentences, comment on the plot comparing learning curves for the two activation function.
#
# **Answer**:

# %%
plotLearningCurves(history)

# %% [markdown]
# ## Exercise 6: Visualizing the model
# ### Description
#
# 1. Using the model.predict and plotMelody functions, show the outputs of your best model when fed with 4 randomly selected melodies. Report the prediction accuracies as well.
# 2. For the same melodies, plot the hidden state evolution accross time steps. Construct a 2 dimensional matrix with the first dimension being time and the second the concatenation of all hidden unit activations and plot it using the provided `plotMelody` function. To get the hidden states of your network, you can modify the `buildModel` function so that you have another computation graph (another model with the same layers, but the output layer) returning you the hidden states. However, other approaches are equally valid.
# 3. For each hidden unit $i$ and accross the entire dataset, compute the average absolute change in activation $\Delta A_i$. Be careful not to take masked timesteps into account. Plot the histogram (50 bins) of this average for the RNN and GRU models on the same figure.

# %% [markdown]
# ### Solution

# %%
def generate_melody(random_note, length, temp=1.0):

    current_melody = random_note
    for i in range(length):
        prediction = RNNmodel.predict(current_melody)
        T = np.zeros((1, 17))
        T[0][sample(prediction[0][0][i], temperature=temp)] = 1
        P = np.zeros((1, 52))
        P[0][sample(prediction[1][0][i], temperature=temp)] = 1
        current_melody = {'XT': pad_sequences(np.append(current_melody['XT'][0][:i+1], T.reshape((1,17)).astype(int), axis=0).T,
                                              maxlen=n_notes-1, padding='post', truncating='post').T.reshape((1, 387, 17)),
                          'XP': pad_sequences(np.append(current_melody['XP'][0][:i+1], P.reshape((1,52)).astype(int), axis=0).T,
                                              maxlen=n_notes-1, padding='post', truncating='post').T.reshape((1, 387, 52))}

    current_melody['XT'] = np.argmax(current_melody['XT'][0][:1+np.max(list(np.where(np.sum(current_melody['XT'][0], axis=1) != 0)[0]))], axis=1)  
    current_melody['XP'] = np.argmax(current_melody['XP'][0][:1+np.max(list(np.where(np.sum(current_melody['XP'][0], axis=1) != 0)[0]))], axis=1)
    return current_melody

# %%
random_note = {'XT': pad_sequences(data['XT'][5][0].reshape((1, 1, 17)).T, maxlen=n_notes-1, padding='post', truncating='post').T,
               'XP': pad_sequences(data['XP'][5][0].reshape((1, 1, 52)).T, maxlen=n_notes-1, padding='post', truncating='post').T}

# %%
current_melody = generate_melody(random_note, 300, .5)
plotMelody(current_melody['XP'], current_melody['XT'], dicts)

# %% [markdown]
# **Question**: How does the hidden state dynamics explain the performance of the RNN vs GRU models? Explain in term of temporal dependencies and base your explanation on figures obtained in 6.2 and 6.3.
#
# **Answer**:

# %% [markdown]
# ## Exercise 7: Generation of new melodies
# ### Description
#
# 1. Use your trained best model to generate new melodies. You can do that by starting with a random note, feeding it to your network and sample the output predictions in order to select the next note. Then add this note to your iteratively growing melodies. For your convenience, we provided the `sample` and `writeMIDI` functions. You can use the first in order to perform temperature sampling. The `writeMIDI` function allows you to write a MIDI file from the integer representation.
# 2. Try different sampling temperatures (e.g. 0.5, 1., 1.5) and observe the effect on your generated melodies.
# 3. Generate 32 melodies with both the RNN and GRU models
# 4. Listen to 4 randomly chosen melodies (2 from the GRU model and 2 from the RNN model). To play in a notebook, use a similar approach as the one shown below assuming you have the files `GRU_1.mid` and `RNN_1.mid` at the same level as this notebook. For your own curiosity, you can also directly listen to the MIDI files with your favorite MIDI player but make sure that we can listen to the 4 extracts directly from this notebook (without rerunning it). You might have to use the "Trust notebook" button (in the top right corner) to see the players. This currently only works in jupyter notebook (not jupyter lab). If you have trouble achieving that, upload the MIDI files with your submission.
# 5. (Optional) If you have a big enough computing power, try adding multiple and bigger layers. You could also try to improve your model with different add-ons, e.g. make your model learn when a melody ends, extend it to other datasets, ...
# 6. (Optional) If you are happy with your results submit a 1 hour long generated MIDI file to the [AI-generated music challenge](https://www.crowdai.org/challenges/ai-generated-music-challenge).

# %% [markdown]
# ### Solution

# %%
print('GRU')
music21.midi.translate.midiFilePathToStream('GRU_1.mid').show('midi')
# Out:
# GRU
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-258-1995432c657f> in <module>()
#       1 print('GRU')
# ----> 2 music21.midi.translate.midiFilePathToStream('GRU_1.mid').show('midi')
#
# /home/maxime/anaconda3/lib/python3.6/site-packages/music21/midi/translate.py in midiFilePathToStream(filePath, inputM21, **keywords)
#    1968     from music21 import midi as midiModule
#    1969     mf = midiModule.MidiFile()
# -> 1970     mf.open(filePath)
#    1971     mf.read()
#    1972     mf.close()
#
# /home/maxime/anaconda3/lib/python3.6/site-packages/music21/midi/__init__.py in open(self, filename, attrib)
#    1182         if attrib not in ['rb', 'wb']:
#    1183             raise MidiException('cannot read or write unless in binary mode, not:', attrib)
# -> 1184         self.file = open(str(filename), attrib)
#    1185
#    1186     def openFileLike(self, fileLike):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GRU_1.mid'

# %%
writeMIDI(current_melody['XP'], current_melody['XT'], dicts, 'test.mid')

# %%
print('RNN')
music21.midi.translate.midiFilePathToStream('test.mid').show('midi')
# Out:
# RNN
#                 <div id='midiPlayerDiv4429573'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv4429573');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# **Question**: What is the effect of the sampling temperature on the generated melodies?
#
# **Answer**:
#
# **Question**: Are the generated melodies from the RNN model different from the one generated by the GRU model? If yes, what are the main differences?
#
# **Answer**:
