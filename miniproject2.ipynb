# %% [markdown]
# # Miniproject 2: Melody generation
#
# ## Introduction
#
# ### Description
#
# To develop a model employing ANN on real-world data requires going through several major steps, each of which with important design choices that directly impact the end results. In this project, we guide you through these choices starting from a large database of [Irish folk melodies](https://github.com/IraKorshunova/folk-rnn/tree/master/data) to your own model of symbolic music composition.
#
#
# ### Prerequisites
#
# - You should have a running installation of [tensorflow](https://www.tensorflow.org/install/) and [keras](https://keras.io/).
# - You should know the concepts "recurrent neural networks", "LSTM", "training and validation data", "overfitting" and "early stopping".
#
# ### What you will learn
#
# - You will be guided through a data processing procedure and understand the importance of design choices in ANN modeling
# - You will learn how to define recurrent neural networks in keras and fit them to data.
# - You will be guided through a prototyping procedure for the application of deep learning to a specific domain.
# - You will get in contact with concepts discussed later in the lecture, like "overfitting", "LSTM network", and "Generative model".
# - You will learn to be more patient :) Some fits may take your computer quite a bit of time; run them over night.
#
# ### Evaluation criteria
#
# The evaluation is (mostly) based on the figures you submit and your answer sentences.
# We will only do random tests of your code and not re-run the full notebook. Please ensure that your notebook is fully executed before handing it in.

# %% [markdown]
# ## Functions and imports
#
# For your convenience we import some libraries and provide some functions below. Some libraries (`midi` and `music21==5.1.0`) should be added. If you work with the docker image, pull it `docker pull zifeo/artificial-neural-networks:cpu` before to get the latest version where these libraries are added and stop/relaunch the container (as stated in the instructions https://github.com/zifeo/artificial-neural-networks). If you work locally, be sure to import them. If you do not find the midi library for python3, install it with `python setup.py install` inside the `python3-midi` folder after cloning https://github.com/louisabraham/python3-midi.git.
#
# Finally, fill in your sciper number(s) for the random seed and simply run the following cell.

# %%
sciper = {'student_1': 250726, 
          'student_2': 238122}
seed = sciper['student_1'] + sciper['student_2']

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import os, sys

plt.rcParams['font.size'] = 28
plt.style.use('ggplot')
plt.rcParams["axes.grid"] = False
c = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams['figure.figsize'] = 8, 4

import keras
from keras.models import Model, load_model
from keras.layers import Input, Masking, TimeDistributed, Dense, Concatenate, Dropout, LSTM, GRU, SimpleRNN
from keras.optimizers import Adam
from keras.utils import np_utils
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import ModelCheckpoint

import midi
import music21

import copy
from collections import defaultdict

from keras.models import model_from_json
from pathlib import Path
import pickle
# Out:
# /home/maxime/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/maxime/anaconda3/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def plotMelody(P, T, dictionaries, PrP=None, PrT=None, H=None):
    """
    P: The pitch array (integer representation) or matrix (one-hot encoding)
    T: The duration array (integer representation) or matrix (one-hot encoding)
    dictionaries: The dictionaries relating integer to a pitch or duration
    PrP: (Optional) If provided with PrT, plot the transition probabilities
    PrT: (Optional) If provided with PrP, plot the transition probabilities
    H: (Optional) Add a plot with the hidden state dynamic sorted by frequency
    """
    P = np.asarray(P)
    T = np.asarray(T)
    if len(P.shape) == 1:#if array
        P = np_utils.to_categorical(P, len(dictionaries['P']))
    if len(T.shape) == 1:#if array
        T = np_utils.to_categorical(T, len(dictionaries['T']))
    
    xlim = [-1,np.where(P==1)[0][-1]+1]
    
    activeidxes = np.where(np.sum(P, axis=0)>1.)[0]
    plt.figure(figsize=(8,4))
    if PrP is not None:
        targets = np.where(P[:,activeidxes]==1)
        plt.imshow(PrP[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
        plt.scatter(targets[0]-1,targets[1], color='red',s=10, marker='.') 
    else:
        plt.imshow(P[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
    plt.ylim([-0.5,len(activeidxes)-0.5])
    plt.yticks(range(len(activeidxes)),[dictionaries["P"][i] for i in activeidxes])
    plt.tight_layout()
    plt.xlabel("$n$")
    plt.ylabel("$P[n]$")
    plt.xlim(xlim)
    plt.show()
    
    activeidxes = np.where(np.sum(T, axis=0)>1.)[0]
    plt.figure(figsize=(8,4))
    if PrT is not None:
        targets = np.where(T[:,activeidxes]==1)
        plt.imshow(PrT[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
        plt.scatter(targets[0]-1,targets[1], color='red',s=10, marker='.')
    else:
        plt.imshow(T[:,activeidxes].T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.gray_r, vmin=0, vmax=1)
    plt.ylim([-0.5,len(activeidxes)-0.5])
    plt.yticks(range(len(activeidxes)),[dictionaries["T"][i] for i in activeidxes])
    plt.tight_layout()
    plt.xlabel("$n$")
    plt.ylabel("$T[n]$")
    plt.xlim(xlim)
    plt.show()
    
    
    if H is not None:
        diff = np.mean([[abs(j-i) for i,j in zip(H[:xlim[1]-1,k], H[1:xlim[1],k])] for k in range(H.shape[1])], axis=1)
        sortidx = np.argsort(-diff)
        H = H[:,sortidx]
        plt.figure(figsize=(8,4))
        plt.imshow(H.T, origin='lower', aspect='auto', interpolation='nearest', cmap=plt.cm.seismic, vmin=-1, vmax=1)
        plt.xlim([-1,np.where(T==1)[0][-1]+1])
        plt.tight_layout()
        plt.xlabel("$n$")
        plt.ylabel("$H[n]$")
        plt.show()


def plotLearningCurves(History):
    
    log = History.history
    
    plt.figure(figsize=(8,4))
    plt.plot(log['YP_loss'], '--', c=c[0], label='Pitch train loss')
    plt.plot(log['val_YP_loss'], c=c[0], label='Pitch val loss')
    
    plt.plot(log['YT_loss'], '--', c=c[1], label='Dur train loss')
    plt.plot(log['val_YT_loss'], c=c[1], label='Dur val loss')
    plt.legend(loc='best')
    
    plt.figure(figsize=(8,4))
    plt.plot(log['YP_acc'], '--', c=c[0], label='Pitch train acc')
    plt.plot(log['val_YP_acc'], c=c[0], label='Pitch val acc')
    
    plt.plot(log['YT_acc'], '--', c=c[1], label='Dur train acc')
    plt.plot(log['val_YT_acc'], c=c[1], label='Dur val acc')
    plt.legend(loc='best')

def sample(preds, temperature=1.):
    """Helper function to sample an index from a probability array"""
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

def writeMIDI(xP, xT, dictionaries, label):

    # Instantiate a MIDI Pattern (contains a list of tracks)
    pattern = midi.Pattern(format = 0, resolution=480)
    # Instantiate a MIDI Track (contains a list of MIDI events)
    track = midi.Track()
    # Append the track to the pattern
    pattern.append(track)
    Events = []
    
    pseq = [dictionaries['P'][p] for p in xP]
    tseq = [dictionaries['T'][t] for t in xT]
    for t, p in zip(tseq, pseq):
        e = midi.NoteOnEvent(tick=0, velocity=90, pitch=p)
        track.append(e)
        e = midi.NoteOffEvent(tick=t, velocity=0, pitch=p)
        track.append(e)
        
    eot = midi.EndOfTrackEvent(tick=1)
    track.append(eot)
    # Save the pattern to disk
    midi.write_midifile(label, pattern)

# %% [markdown]
# ## Exercise 1 : Data processing
# ### Description
#
# For a real world application of ANNs, the original data should be translated into a representation understandable by an ANN. This step is often neglected but is of outmost importance. In order for you to better understand how ANN are applied to real world problems, the first step of this miniproject will guide you through a possible representation.
#
# Note that in general, your representation should be normalized in order to obtain homogeneous data from which a structure can be extracted by your ANN model. Importantly, all processing steps toward your representation should not (or minimally) distort your original data.
#
# To represent MIDI files, we provide you with a Python MIDI library. You should then
#
# 0. Download the MIDI tar file from [this link](https://github.com/IraKorshunova/folk-rnn/tree/master/data) and put it in a folder named "chorpus" at the same level of this notebook.
# 1. Parse the chorpus to extract the label of (a random subset of) the data (code is provided)
# 2. Read each MIDI file in the subset with the midi [library](https://github.com/louisabraham/python3-midi)
# 3. For each data sequence extract the sequence of MIDI notes defined by two dimensions ("P": the sequence of note pitches (integer between 0 and 127 representing a piano key), "T": the sequence of note durations.
# 4. Select two melodies and display them both as sequences of MIDI events and sequence of notes in two dimensions. Control that your representation is correct.
#
# For step 3, you should learn how MIDI files are constructed. Below, we give a minimal explanation and some code for this particular project. For a more complete explanation, look for MIDI in your favorite search engine. Given this dataset, you can observe that it is monophonic (one note at a time) and there's a small delay (1 tick) inbetween each note. You could decide to ignore this delay or correct (recommanded) for it.
#
# A MIDI files is composed of timed events of many kinds. For this project, we focus on the events related to notes being played or stopped. Those are MIDI events "Note Off" and "Note On". Each event is timed with respect with the previous one (dt). The duration of a note is therefore given by the cummulated dt inbetween the event associated to a note's onset and the event associated with the same note's offset.

# %% [markdown]
# ### Minimal code to read MIDI files

# %%
def display(midi_file="chorpus/sessiontune0.mid"):
    #index 0 for first track only
    events = midi.read_midifile(midi_file)[0] 
    tick = 0
    print(midi_file)
    print("#"*40)
    print("tick \t pitch \t message \t velocity")
    print("#"*40+'\n')
    for n, event in enumerate(events):
        tick += event.tick
        if event.name in ['Note On', 'Note Off']:
            if n<13 or n>len(events)-10:
                print("%i \t %i \t %s \t %i"%(tick, event.data[0], event.name, event.data[1]))
            if n in range(20,23):
                print(". \t . \t . \t \t .")
    print("#"*40+'\n')

display()

datapath = "chorpus/"
dataset = {}
np.random.seed(seed)


song_label_file = Path("selected_songs.label")
if not song_label_file.is_file():
    for filename in os.listdir(datapath):
        if filename.endswith("mid"):
            label = filename[:-4]
            #Down sample dataset
            if np.random.rand() < 0.1:
                dataset[label] = {"T":[], "P": []}
    with open('selected_songs.label', 'wb') as file_pi:
        pickle.dump(list(dataset.keys()), file_pi)
else:
    with open('selected_songs.label', 'rb') as file_pi:
        labels = pickle.load(file_pi)
    for label in labels:
        dataset[label] = {"T":[], "P": []}
print("%i/%i melodies retained"%(len(list(dataset.keys())), len(os.listdir(datapath))))
# Out:
# chorpus/sessiontune0.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 67 	 Note On 	 105
# 240 	 67 	 Note Off 	 0
# 241 	 64 	 Note On 	 80
# 480 	 64 	 Note Off 	 0
# 481 	 64 	 Note On 	 80
# 720 	 64 	 Note Off 	 0
# 721 	 64 	 Note On 	 95
# 1200 	 64 	 Note Off 	 0
# 1201 	 62 	 Note On 	 80
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 33601 	 67 	 Note On 	 80
# 33840 	 67 	 Note Off 	 0
# 33841 	 69 	 Note On 	 95
# 34080 	 69 	 Note Off 	 0
# 34081 	 71 	 Note On 	 80
# 34320 	 71 	 Note Off 	 0
# 34321 	 72 	 Note On 	 80
# 34560 	 72 	 Note Off 	 0
# ########################################
#
# 4586/45853 melodies retained

# %%
song_label_file = Path("selected_songs.label")
if not song_label_file.is_file():
    with open('selected_songs.label', 'wb') as file_pi:
        pickle.dump(list(dataset.keys()), file_pi)

# %% [markdown]
# Since we are working on different OS (MacOS, Windows and Ubuntu), we need to store once the randomly chosen labels with one of the OS (Ubuntu in our case) so that we are able to use the same labels when running the code on the other OS or other versions of Python or Numpy.

# %% [markdown]
# ### Solution

# %%
def parseMIDI(midi_file):
    events = midi.read_midifile(midi_file)[0] #index 0 for first track only  
    T = []
    P = []
    for n, event in enumerate(events):
        if event.name == 'Note Off':
            pitch = event.data[0]
            time = event.tick
            if time > 0:
                P.append(pitch)
                T.append(time - 1)
            
    assert len(P) == len(T)
    return P, T

for label in list(dataset.keys()):
    Pseq, Tseq = parseMIDI(datapath+label+".mid")
    dataset[label]['T']= Tseq
    dataset[label]['P']= Pseq

for label in np.random.choice(list(dataset.keys()), 2):
    print(label)
    print("MIDI events")
    display(datapath+label+".mid")
    print("Note representation")
    print(dataset[label])
    print('/n')
# Out:
# sessiontune17751
# MIDI events
# chorpus/sessiontune17751.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 72 	 Note On 	 105
# 240 	 72 	 Note Off 	 0
# 241 	 69 	 Note On 	 80
# 480 	 69 	 Note Off 	 0
# 481 	 69 	 Note On 	 80
# 720 	 69 	 Note Off 	 0
# 721 	 72 	 Note On 	 80
# 960 	 72 	 Note Off 	 0
# 961 	 71 	 Note On 	 95
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 44881 	 71 	 Note On 	 80
# 45120 	 71 	 Note Off 	 0
# 45121 	 72 	 Note On 	 95
# 45600 	 72 	 Note Off 	 0
# 45601 	 72 	 Note On 	 80
# 45840 	 72 	 Note Off 	 0
# 45841 	 71 	 Note On 	 80
# 46080 	 71 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 718, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238], 'P': [72, 69, 69, 72, 71, 67, 69, 71, 72, 67, 64, 65, 64, 62, 67, 72, 67, 69, 72, 67, 64, 65, 64, 62, 64, 65, 67, 69, 71, 72, 69, 69, 72, 71, 67, 69, 71, 72, 67, 64, 65, 64, 62, 67, 60, 64, 64, 60, 64, 67, 64, 65, 67, 69, 71, 72, 72, 71, 72, 67, 72, 74, 76, 74, 76, 77, 79, 81, 79, 77, 76, 74, 72, 67, 72, 74, 76, 77, 76, 67, 74, 76, 76, 74, 72, 67, 69, 71, 72, 67, 72, 74, 76, 74, 76, 77, 79, 81, 79, 77, 76, 74, 72, 67, 69, 72, 67, 64, 65, 64, 62, 64, 65, 67, 69, 71, 72, 74, 76, 74, 72, 67, 69, 72, 67, 64, 65, 64, 62, 67, 72, 74, 76, 74, 72, 74, 76, 77, 79, 81, 79, 77, 76, 74, 72, 74, 76, 74, 72, 67, 69, 72, 67, 64, 65, 64, 62, 67, 60, 64, 64, 60, 64, 67, 64, 65, 67, 69, 71, 72, 72, 71]}
# /n
# sessiontune19457
# MIDI events
# chorpus/sessiontune19457.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 59 	 Note On 	 105
# 240 	 59 	 Note Off 	 0
# 241 	 62 	 Note On 	 80
# 480 	 62 	 Note Off 	 0
# 481 	 62 	 Note On 	 80
# 960 	 62 	 Note Off 	 0
# 961 	 64 	 Note On 	 95
# 1200 	 64 	 Note Off 	 0
# 1201 	 62 	 Note On 	 80
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 60241 	 62 	 Note On 	 80
# 60480 	 62 	 Note Off 	 0
# 60481 	 64 	 Note On 	 95
# 60720 	 64 	 Note Off 	 0
# 60721 	 67 	 Note On 	 80
# 60960 	 67 	 Note Off 	 0
# 60961 	 67 	 Note On 	 80
# 61440 	 67 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 238, 238, 478, 238, 238, 478, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 238, 478], 'P': [59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 69, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 62, 60, 59, 62, 62, 64, 62, 59, 62, 71, 67, 69, 67, 64, 67, 69, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 71, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 62, 67, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 71, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 67, 69, 71, 74, 74, 72, 76, 76, 74, 71, 67, 71, 69, 62, 67, 71, 72, 64, 69, 72, 71, 62, 67, 71, 69, 67, 64, 62, 64, 67, 67]}
# /n

# %% [markdown]
# ## Exercise 2: Tokenzation and translation to integer
# ### Description
#
# Now you should have a "dataset" dictionary where each entry corresponds to one melody example from a subset of the full dataset. In turn, every melody example is represented by a dictionary with two sequences: the "P" entry being the sequence of pitches and the "T" entry, the sequence of durations. Here, you will implement the first steps to translate this dataset in a language that can be read by your ANN models. To achieve that, we will later use the [one-hot encoding scheme](https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/), which will associate each input (and output) unit of your network to a unique pitch or duration. In your network, these units will then be sequentially activated in the same order as their corresponding pitch/duration in your dataset. And at each note, the model will be trained to approximate the probability distributions of the upcoming pitch and duration.
#
# 1. Gather in a list of all possible pitches and durations in your dataset. These two lists will be your "dictionaries" translating a pitch/duration to a unique integer between 0 and the number of entries (-1) in the pitch/duration dictionary.
# 2. Translate the pitch/duration sequence of each melody to the integer representation.
# 3. Select randomly two melodies and display them in the note representation and translated to integer. Check that the translation is correct.

# %% [markdown]
# ### Solution

# %% [markdown]
# ### 1. and 2.

# %%
def get_dicts(dataset):
    set_T = set()
    [set_T.update(dataset[label]['T']) for label in dataset.keys()]
    set_P = set()
    [set_P.update(dataset[label]['P']) for label in dataset.keys()]
    dict_T = {k: v for v, k in enumerate(list(set_T))}
    dict_P = {k: v for v, k in enumerate(list(set_P))}
    return {'T': dict_T, 'P': dict_P}, {'T': {v: k for k, v in dict_T.items()}, 'P': {v: k for k, v in dict_P.items()}}

# %%
def tokenize(dataset):
    dictionaries, inv = get_dicts(dataset)
    dataset_int = copy.deepcopy(dataset)
    for label in dataset_int.keys():
        dataset_int[label]['T'] = [dictionaries['T'][v] for v in dataset_int[label]['T']]
        dataset_int[label]['P'] = [dictionaries['P'][v] for v in dataset_int[label]['P']]
    return dataset_int, inv

# %%
dataset_int, dicts = tokenize(dataset)

# %% [markdown]
# ### 3.

# %%
for label in np.random.choice(list(dataset.keys()), 2):
    print(label)
    print("MIDI events")
    display(datapath+label+".mid")
    print("Note representation")
    print(dataset_int[label])
    print('/n')
# Out:
# sessiontune22329
# MIDI events
# chorpus/sessiontune22329.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 79 	 Note On 	 105
# 240 	 79 	 Note Off 	 0
# 241 	 77 	 Note On 	 80
# 480 	 77 	 Note Off 	 0
# 481 	 74 	 Note On 	 105
# 720 	 74 	 Note Off 	 0
# 721 	 67 	 Note On 	 80
# 960 	 67 	 Note Off 	 0
# 961 	 67 	 Note On 	 80
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 61681 	 81 	 Note On 	 80
# 61920 	 81 	 Note Off 	 0
# 61921 	 79 	 Note On 	 95
# 62400 	 79 	 Note Off 	 0
# 62401 	 79 	 Note On 	 80
# 62640 	 79 	 Note Off 	 0
# 62641 	 77 	 Note On 	 80
# 62880 	 77 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 12, 12, 12, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 52, 61, 61], 'P': [31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 17, 17, 17, 17, 12, 17, 21, 24, 26, 19, 19, 19, 19, 23, 26, 31, 33, 34, 33, 31, 29, 26, 31, 31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 19, 17, 19, 21, 23, 24, 29, 26, 31, 31, 28, 29, 28, 26, 24, 21, 17, 24, 21, 19, 31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 17, 17, 17, 17, 12, 17, 21, 24, 26, 19, 19, 19, 19, 23, 26, 31, 33, 34, 33, 31, 29, 26, 31, 31, 29, 26, 19, 19, 19, 19, 23, 26, 24, 23, 21, 19, 17, 19, 21, 23, 24, 29, 26, 31, 31, 28, 29, 28, 26, 24, 21, 17, 24, 21, 19, 26, 28, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 31, 29, 33, 31, 26, 28, 28, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 33, 38, 40, 38, 36, 33, 35, 36, 33, 35, 38, 36, 33, 31, 26, 28, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 31, 29, 33, 31, 26, 28, 28, 29, 31, 26, 31, 35, 38, 35, 31, 35, 33, 29, 36, 29, 38, 29, 36, 33, 38, 40, 38, 36, 33, 35, 36, 33, 35, 38, 36, 33, 31, 31, 29]}
# /n
# sessiontune36502
# MIDI events
# chorpus/sessiontune36502.mid
# ########################################
# tick 	 pitch 	 message 	 velocity
# ########################################
#
# 1 	 63 	 Note On 	 105
# 240 	 63 	 Note Off 	 0
# 241 	 62 	 Note On 	 80
# 480 	 62 	 Note Off 	 0
# 481 	 63 	 Note On 	 80
# 720 	 63 	 Note Off 	 0
# 721 	 65 	 Note On 	 80
# 960 	 65 	 Note Off 	 0
# 961 	 66 	 Note On 	 95
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# . 	 . 	 . 	 	 .
# 18001 	 72 	 Note On 	 80
# 18240 	 72 	 Note Off 	 0
# 18241 	 73 	 Note On 	 95
# 18480 	 73 	 Note Off 	 0
# 18481 	 70 	 Note On 	 80
# 18720 	 70 	 Note Off 	 0
# 18721 	 68 	 Note On 	 80
# 18960 	 68 	 Note Off 	 0
# ########################################
#
# Note representation
# {'T': [61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 52, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 12, 12, 12, 61, 61, 52, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 61, 61, 52, 61, 61, 61, 61, 12, 12, 12, 61, 61, 61, 61, 12, 12, 12, 61, 61, 52, 61, 61, 52, 61, 61, 61, 61, 61], 'P': [15, 14, 15, 17, 18, 25, 20, 22, 25, 20, 17, 18, 15, 15, 15, 13, 18, 20, 22, 24, 25, 25, 20, 17, 13, 13, 13, 13, 8, 13, 17, 13, 17, 18, 20, 22, 24, 25, 24, 25, 22, 25, 20, 17, 15, 15, 13, 18, 20, 22, 24, 25, 25, 20, 17, 13, 13, 13, 13, 8, 13, 17, 13, 17, 18, 20, 22, 24, 25, 24, 25, 27, 27, 24, 25, 22, 20]}
# /n

# %% [markdown]
# ## Exercise 3: Data reprocessing
# ### Description
#
# Before moving to the implementation of your RNN generative model of note transition, you will perform data exploration and modification. This step will allow your model to get the most out of your original data as well as ensuring some features such as transposition invariance.
#
# To further improve your model, you might want to reconsider your original data. Many different approaches can be undertaken. Here you are asked to implement the a rare event suppression method and transposition invariance.
#
# **Rare event suppression** If a unit in your network is associated to a duration that happens very rarely in your data, a possible simplification consists in removing the melodies conaining these rare events from your dataset.
# 1. Plot and comment the histogram of durations in your entire dataset. Use the labels from the original duration values (rather than the integer representation).
# 2. Based on your observations, remove from your dataset melodies containing very rare durations. Adjust the rejection threshold such that at most 5% of the melodies are dicarded with this step.
# 3. Recompute the duration dictionary based on your filtered dataset and plot the new histogram of durations.
#
# **Transposition invariance** A melody is perceived similarly by the human ear if it's shifted up or down by a constant offset (see [transposition](https://en.wikipedia.org/wiki/Transposition_(music))). Here, you will force your model to be transposition invariant. For this you can choose to use one of two orthogonal methods. The first consists in transposing every melody into a common tonality (C Major/A minor). On the other hand, the second consists in transposing each melody in all possible keys. The second method will increase your dataset size by a factor bigger than 11! As the training time is directly related with the dataset size, to save computing time, we recomand that you implement the first option.
#
# ***Pitch normalization***
# 1. Use the provided function to create a new dataset where all melodies are transposed to C Major/A minor.
# 2. Plot the histograms of the pitches before and after transposition.
#
# Finally, you shoud recompute the tokenization step for your brand new filtered and normalized dataset.

# %% [markdown]
# ### Solution

# %%
def transposeDataset(dataset):
    transposed_dataset = {}

    for label in list(dataset.keys()):
        transposed_dataset[label] = {}
        score = music21.converter.parse(datapath+label+".mid")
        key = score.analyze('key')
        if key.mode == "major":
            i = music21.interval.Interval(key.tonic, music21.pitch.Pitch('C'))
        elif key.mode == "minor":
            i = music21.interval.Interval(key.tonic, music21.pitch.Pitch('A'))
        i = i.semitones
        transposed_dataset[label]['P'] = [p+i for p in dataset[label]['P']]
        transposed_dataset[label]['T'] = dataset[label]['T']
        
    return transposed_dataset

# %% [markdown]
# ### Rare event suppression

# %% [markdown]
# ### 1.

# %%
plt.hist([e for label in dataset.keys() for e in set(dataset[label]['T'])], bins=50);

# %% [markdown]
# ### TODO : comment histogram

# %% [markdown]
# ### 2.

# %%
tot_nb_melody = len(dataset.keys())

dataset_cleaned = copy.deepcopy(dataset)

d = defaultdict(list)

[d[e].append(label) for label in dataset.keys() for e in set(dataset[label]['T'])];

# %%
labels_to_remove = set()
duration_to_remove = 0
for time in sorted(d, key=lambda k: len(d[k]), reverse=False):
    if len(set(labels_to_remove).union(set(d[time]))) < 0.05 * tot_nb_melody:
        labels_to_remove = labels_to_remove.union(d[time])
        duration_to_remove += 1
    else:
        break

# %%
for label in labels_to_remove:
    del dataset_cleaned[label]

# %%
'Fraction of durations removed : '+str(duration_to_remove/len(d.keys()))
# Out:
# 'Fraction of durations removed : 0.7536231884057971'

# %%
'Fraction of melodies removed : '+str(1 - len(dataset_cleaned.keys())/len(dataset.keys()))
# Out:
# 'Fraction of melodies removed : 0.045137374618403836'

# %% [markdown]
# ### 3.

# %%
plt.hist([e for label in dataset_cleaned.keys() for e in set(dataset_cleaned[label]['T'])], bins=50);

# %% [markdown]
# ### Pitch normalization

# %% [markdown]
# ### 1.

# %%
dataset_cleaned_t = transposeDataset(dataset_cleaned)

# %%
plt.hist([e for label in dataset_cleaned.keys() for e in set(dataset_cleaned[label]['P'])], bins=100)
plt.title('Before pitch transposition');

# %%
plt.hist([e for label in dataset_cleaned_t.keys() for e in set(dataset_cleaned_t[label]['P'])], bins=100)
plt.title('After pitch transposition');

# %% [markdown]
# ### 2.

# %%
dataset_cleaned_int, dicts = tokenize(dataset_cleaned_t)

# %% [markdown]
# **Question**: How much did you reduce the space of possible durations with your rare event suppression procedure? What is the impact in term of training time?
#
# **Answer**: We reduced the number of possible durations by almost 75%. TODO: IMPACT ON TRAINING TIME
#
# **Question**: Explain why and how both transposition to a single tonality and to all possible tonalities can yield transposition invariance in your model.
#
# **Answer**:
#
# **Question**: In terms of number of dimensions, what would have been the impact of keeping the joint represenation of a note duration and pitch (vs separating the two features)?
#
# **Answer**: After preprocessing, we would have had a bit less than 600 dimensions vs around 70 when we separate.
#
# **Question**: How would the distribution of notes in the joint representation differ from the distributions in the pitch and duration only representations (as shown by your histograms above)?
#
# **Answer**:

# %% [markdown]
# ## Exercise 4: One-hot and zero-padding
# ### Description
#
# The last few steps to be able to feed (note by note) your music scores to a RNN model are
# 1. Transform the sequence of integers into a sequence of vectors in the one-hot encoding scheme.
# 2. Homegenize the length of each sequence
#
# **One-hot encode** You can implement your own integer to one-hot code. For this use the numpy library and the suitable datatype. Alternatively, Keras provides a [built in one-hot encoding scheme](https://keras.io/utils/#to_categorical). After this step, for each melody, you should have two similar length matrices with one representing the sequence of note pitches and the other the sequence of note durations.
# 1. Code the integer representation into matrices of one-hot vectors
#
# **Zero-padding** Most deep learning libraries, including Keras, require that you specify the shape of the input data. As such, you cannot have variable length inputs per-se. The trick to handle them is [zero-padding](https://keras.io/preprocessing/sequence/#pad_sequences). Provided with the [Masking Layer](https://keras.io/layers/core/#masking) Keras will then ignore time steps where all inputs are 0.
# 1. Extend the end of each melody matrices with vectors containing only zeros until all melodies have the same size. For simplicity, use the Keras pad_sequences function. There might be some rare very long melodies in your dataset, a possible choice is to set the 'maxlen' argument of pad_sequences to the mean+2std of the melody lengths. This ensure that 95% of your melodies would end before being truncated.
# 2. Check and display the dimension of the resulting tensors. Typically, the tensor representing the sequence of pitches should be of shape [number of melodies x number of notes x number of entries in the pitch dictionary] and the tensor representing the sequence of durations [number of melodies x number of notes x number of entries in the duration dictionary]
#
# To check if this step was done correctly use the provided plotMelody function. For two randomly selected melodies, call the plotMelody function before and after one-hot/zero-pad. You should obtain the same plots (or slightly truncated if you randomly selected one belonging to 5% longest).
#
# Finally, we strongly suggest that you save your preprocessed data now.

# %% [markdown]
# ### Solution

# %% [markdown]
# ### One-hot encode and Zero-padding

# %% [markdown]
# ### 1.

# %%
seq = [len(dataset_cleaned_int[label]['T']) for label in dataset_cleaned_int.keys()]
mean = np.mean(seq)
std = np.std(seq)

n_notes = int(mean + 2*std)

# %%
for label in dataset_cleaned_int.keys():
    dataset_cleaned_int[label]['T'] = np_utils.to_categorical(dataset_cleaned_int[label]['T'], len(dicts['T'].keys()))
    dataset_cleaned_int[label]['P'] = np_utils.to_categorical(dataset_cleaned_int[label]['P'], len(dicts['P'].keys()))

# %%
label = np.random.choice(list(dataset.keys()), 1)[0]

plotMelody(dataset_cleaned_int[label]['P'], dataset_cleaned_int[label]['T'], dicts)

# %%
for label_ in dataset_cleaned_int.keys():
    dataset_cleaned_int[label_]['T'] = pad_sequences(dataset_cleaned_int[label_]['T'].T, maxlen=n_notes, padding='post', truncating='post').T
    dataset_cleaned_int[label_]['P'] = pad_sequences(dataset_cleaned_int[label_]['P'].T, maxlen=n_notes, padding='post', truncating='post').T

# %% [markdown]
# ### 2.

# %%
data = {'XT': [], 'XP': []}
for label in dataset_cleaned_int.keys():
    data['XT'].append(dataset_cleaned_int[label]['T'])
    data['XP'].append(dataset_cleaned_int[label]['P'])
data['XT'] = np.array(data['XT'])
data['XP'] = np.array(data['XP'])

# %%
'The tensor representing the sequence of pitches is of dimension of : '+str(data['XT'].shape)
# Out:
# 'The tensor representing the sequence of pitches is of dimension of : (4379, 388, 17)'

# %%
'The tensor representing the sequence of durations is of dimension of : '+str(data['XP'].shape)
# Out:
# 'The tensor representing the sequence of durations is of dimension of : (4379, 388, 52)'

# %%
plotMelody(dataset_cleaned_int[label]['P'], dataset_cleaned_int[label]['T'], dicts)

# %%
dim_p = len(dicts['P'].keys())
dim_t = len(dicts['T'].keys())

# %% [markdown]
# ## Exercise 5: Building and training a generative model of  note transition with the Keras functional API
# ### Description
#
# The Keras Sequential model is very efficient for fast prototyping, however suffers from a lack of design liberty. The Keras Functional API is only slightly more complex but allows for more control on the different parts of your model. You will be using the Functional API for the rest of this project. Please read carefully the [documentation](https://keras.io/getting-started/sequential-model-guide/).
#
# Here, you will be constructing your RNN model of note transition. To achieve that, your model should be trained to approximate the probability distribution of the upcoming note (observed as two output softmax layers - one for pitch and one for duration) given the current note (given as input) and the model internal representation of the history of notes (its hidden state). To achieve that, set the Keras RNN layer argument "return_sequences" to True when building your model. Doing this will give you an output for each note, rather than a single output at the end of the sequence. During training, the target at each time step is the next note pitch and duration.
#
# You are free to use your own architecture but make sure to use at least 128 hidden units, Masking, and dropout to prevent overfitting. Your model should have two output (softmax) layers, one related to the pitch predictions that you should name `YP`, and the other related to the duration predictions `YT`. You should monitor both the loss (categorical_crossentropy) and the accuracy. For your best model, you should reach 40%/75% accuracy on the pitch/duration predictions.
#
# 1. Train your first model composed of SimpleRNN cells for min 250 epochs and save the model/parameters that lead to the higher accuracy on the validating set. Use a validation split of 0.2. Try  If you correctly named the output layers (`YP` and `YT`) use the provided `plotLearningCurves(History)` function to plot the learning curves by giving the History object returned by the Keras fit function as argument.
# 2. Train a second model where you replaced the SimpleRNN units with GRUs (LSTM unit equivalent that requires less parameters). Make sure you use the same hyperparameters as before. Plot the learning curves.
# 3. On a single plot, adapt the `plotLearningCurves(History)` function to compare the validation learning curves of the simpleRNN and GRU models. In other words, plot the validation loss vs epoch for pitch/duration for the simpleRNN and GRU models. Do the same for accuracies.

# %% [markdown]
# ### Solution

# %%
def buildModel(dictionaries, batch_length, dropout=0.2, activation='GRU', Hsize=128):
    X = dict()
    H = dict()
    M = dict()
    Y = dict()
    
    X['T'] = Input(shape=(batch_length, len(dictionaries['T'])), name="XT")
    X['P'] = Input(shape=(batch_length, len(dictionaries['P'])), name="XP")
    
    M['T'] = Masking(mask_value=0., name="MT")(X['T'])
    M['P'] = Masking(mask_value=0., name="MP")(X['P'])
    
    H['1'] = Concatenate(name="MergeX")([M['T'], M['P']])
    if activation == 'GRU':
        H['2'] = GRU(128, return_sequences=True)(H['1'])
        H['2'] = Dropout(0.3)(H['2'])
        H['2'] = GRU(128, return_sequences=True)(H['2'])
        H['2'] = Dense(128)(H['2'])
        H['2'] = Dropout(0.3)(H['2'])
    elif activation == 'LSTM':
        #Your hidden layer(s) architecture with LSTM (For your own curiosity, not required for the project)
        print('Sorry, not implemented yet')
        return None
    elif activation == 'RNN':
        H['2'] = SimpleRNN(128, return_sequences=True)(H['1'])
        H['2'] = Dropout(0.3)(H['2'])
        H['2'] = SimpleRNN(128, return_sequences=True)(H['2'])
        H['2'] = Dense(128)(H['2'])
        H['2'] = Dropout(0.3)(H['2'])

    Y['T'] = TimeDistributed(Dense(len(dictionaries['T']), activation='softmax'), name='YT')(H['2'])
    Y['P'] = TimeDistributed(Dense(len(dictionaries['P']), activation='softmax'), name='YP')(H['2'])
    
    model = Model(inputs = [X['T'], X['P']], outputs = [Y['T'], Y['P']])
    opt = Adam() 
    model.compile(
        loss='categorical_crossentropy', 
        optimizer=opt,
        metrics=['acc'])
    
    
    return model

print('RNN model')
RNNmodel = buildModel(dicts, 
                      batch_length=n_notes-1,
                      activation='RNN')
RNNmodel.summary()

print('GRU model')
GRUmodel = buildModel(dicts, 
                      batch_length=n_notes-1,
                      activation='GRU')
GRUmodel.summary()
# Out:
# RNN model
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# XT (InputLayer)                 (None, 387, 17)      0
# __________________________________________________________________________________________________
# XP (InputLayer)                 (None, 387, 52)      0
# __________________________________________________________________________________________________
# MT (Masking)                    (None, 387, 17)      0           XT[0][0]
# __________________________________________________________________________________________________
# MP (Masking)                    (None, 387, 52)      0           XP[0][0]
# __________________________________________________________________________________________________
# MergeX (Concatenate)            (None, 387, 69)      0           MT[0][0]
#                                                                  MP[0][0]
# __________________________________________________________________________________________________
# simple_rnn_1 (SimpleRNN)        (None, 387, 128)     25344       MergeX[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 387, 128)     0           simple_rnn_1[0][0]
# __________________________________________________________________________________________________
# simple_rnn_2 (SimpleRNN)        (None, 387, 128)     32896       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 387, 128)     16512       simple_rnn_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 387, 128)     0           dense_1[0][0]
# __________________________________________________________________________________________________
# YT (TimeDistributed)            (None, 387, 17)      2193        dropout_2[0][0]
# __________________________________________________________________________________________________
# YP (TimeDistributed)            (None, 387, 52)      6708        dropout_2[0][0]
# ==================================================================================================
# Total params: 83,653
# Trainable params: 83,653
# Non-trainable params: 0
# __________________________________________________________________________________________________
# GRU model
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# XT (InputLayer)                 (None, 387, 17)      0
# __________________________________________________________________________________________________
# XP (InputLayer)                 (None, 387, 52)      0
# __________________________________________________________________________________________________
# MT (Masking)                    (None, 387, 17)      0           XT[0][0]
# __________________________________________________________________________________________________
# MP (Masking)                    (None, 387, 52)      0           XP[0][0]
# __________________________________________________________________________________________________
# MergeX (Concatenate)            (None, 387, 69)      0           MT[0][0]
#                                                                  MP[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 387, 128)     76032       MergeX[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 387, 128)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 387, 128)     98688       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 387, 128)     16512       gru_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 387, 128)     0           dense_4[0][0]
# __________________________________________________________________________________________________
# YT (TimeDistributed)            (None, 387, 17)      2193        dropout_4[0][0]
# __________________________________________________________________________________________________
# YP (TimeDistributed)            (None, 387, 52)      6708        dropout_4[0][0]
# ==================================================================================================
# Total params: 200,133
# Trainable params: 200,133
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
y = {'YT': [], 'YP': []}
y['YT'] = data['XT'][:,1:,:]
y['YP'] = data['XP'][:,1:,:]

x = {'YT': [], 'YP': []}
x['XT'] = data['XT'][:,:-1,:]
x['XP'] = data['XP'][:,:-1,:]

# %%
class SavedHistory(object):
    pass

# %%
rnn_file = Path("model_rnn.json")
if not rnn_file.is_file():
    history = RNNmodel.fit(x, y, batch_size=512, epochs=250, validation_split=0.2)
    with open('rnn_history', 'wb') as file_pi:
        pickle.dump(history.history, file_pi)
    model_json = RNNmodel.to_json()
    with open("model_rnn.json", "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    RNNmodel.save_weights("model_rnn.h5")
    print("Saved rnn model to disk")
else:
    with open('rnn_history', 'rb') as file_pi:
        h = pickle.load(file_pi)
    history = SavedHistory()
    history.history = h
    
    # load json and create model
    json_file = open('model_rnn.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    
    RNNmodel = model_from_json(loaded_model_json)
    # load weights into new model
    RNNmodel.load_weights("model_rnn.h5")
    print("Loaded model from disk")
# Out:
# Train on 3503 samples, validate on 876 samples
# Epoch 1/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 5.6322 - YT_loss: 1.6470 - YP_loss: 3.9852 - YT_acc: 0.5954 - YP_acc: 0.0318 - val_loss: 4.4185 - val_YT_loss: 1.0879 - val_YP_loss: 3.3306 - val_YT_acc: 0.7270 - val_YP_acc: 0.1033
# Epoch 2/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 4.3832 - YT_loss: 1.1327 - YP_loss: 3.2505 - YT_acc: 0.7148 - YP_acc: 0.0926 - val_loss: 3.8720 - val_YT_loss: 0.9553 - val_YP_loss: 2.9167 - val_YT_acc: 0.7260 - val_YP_acc: 0.1211
# Epoch 3/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 4.0450 - YT_loss: 0.9934 - YP_loss: 3.0515 - YT_acc: 0.7345 - YP_acc: 0.1010 - val_loss: 3.6728 - val_YT_loss: 0.8971 - val_YP_loss: 2.7757 - val_YT_acc: 0.7450 - val_YP_acc: 0.1444
# Epoch 4/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.8409 - YT_loss: 0.9339 - YP_loss: 2.9070 - YT_acc: 0.7435 - YP_acc: 0.1199 - val_loss: 3.5418 - val_YT_loss: 0.8672 - val_YP_loss: 2.6746 - val_YT_acc: 0.7557 - val_YP_acc: 0.1663
# Epoch 5/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.6760 - YT_loss: 0.8987 - YP_loss: 2.7774 - YT_acc: 0.7500 - YP_acc: 0.1436 - val_loss: 3.3960 - val_YT_loss: 0.8422 - val_YP_loss: 2.5537 - val_YT_acc: 0.7529 - val_YP_acc: 0.1834
# Epoch 6/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.5349 - YT_loss: 0.8831 - YP_loss: 2.6518 - YT_acc: 0.7551 - YP_acc: 0.1625 - val_loss: 3.2847 - val_YT_loss: 0.8498 - val_YP_loss: 2.4349 - val_YT_acc: 0.7516 - val_YP_acc: 0.1944
# Epoch 7/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 3.4166 - YT_loss: 0.8648 - YP_loss: 2.5518 - YT_acc: 0.7591 - YP_acc: 0.1728 - val_loss: 3.1795 - val_YT_loss: 0.8149 - val_YP_loss: 2.3646 - val_YT_acc: 0.7562 - val_YP_acc: 0.2091
# Epoch 8/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.3230 - YT_loss: 0.8441 - YP_loss: 2.4789 - YT_acc: 0.7611 - YP_acc: 0.1824 - val_loss: 3.1028 - val_YT_loss: 0.8021 - val_YP_loss: 2.3007 - val_YT_acc: 0.7601 - val_YP_acc: 0.2236
# Epoch 9/250
# 3503/3503 [==============================] - 23s 7ms/step - loss: 3.2441 - YT_loss: 0.8261 - YP_loss: 2.4181 - YT_acc: 0.7634 - YP_acc: 0.1922 - val_loss: 3.0419 - val_YT_loss: 0.7861 - val_YP_loss: 2.2558 - val_YT_acc: 0.7635 - val_YP_acc: 0.2342
# Epoch 10/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.1774 - YT_loss: 0.8110 - YP_loss: 2.3664 - YT_acc: 0.7660 - YP_acc: 0.2015 - val_loss: 2.9843 - val_YT_loss: 0.7736 - val_YP_loss: 2.2107 - val_YT_acc: 0.7655 - val_YP_acc: 0.2420
# Epoch 11/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.1190 - YT_loss: 0.7941 - YP_loss: 2.3249 - YT_acc: 0.7686 - YP_acc: 0.2089 - val_loss: 2.9345 - val_YT_loss: 0.7583 - val_YP_loss: 2.1762 - val_YT_acc: 0.7675 - val_YP_acc: 0.2504
# Epoch 12/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 3.0688 - YT_loss: 0.7808 - YP_loss: 2.2881 - YT_acc: 0.7704 - YP_acc: 0.2172 - val_loss: 2.8881 - val_YT_loss: 0.7464 - val_YP_loss: 2.1416 - val_YT_acc: 0.7690 - val_YP_acc: 0.2620
# Epoch 13/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 3.0213 - YT_loss: 0.7687 - YP_loss: 2.2527 - YT_acc: 0.7721 - YP_acc: 0.2253 - val_loss: 2.8480 - val_YT_loss: 0.7369 - val_YP_loss: 2.1111 - val_YT_acc: 0.7711 - val_YP_acc: 0.2707
# Epoch 14/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.9808 - YT_loss: 0.7602 - YP_loss: 2.2206 - YT_acc: 0.7743 - YP_acc: 0.2346 - val_loss: 2.8135 - val_YT_loss: 0.7304 - val_YP_loss: 2.0831 - val_YT_acc: 0.7736 - val_YP_acc: 0.2791
# Epoch 15/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.9470 - YT_loss: 0.7529 - YP_loss: 2.1941 - YT_acc: 0.7764 - YP_acc: 0.2418 - val_loss: 2.7820 - val_YT_loss: 0.7229 - val_YP_loss: 2.0591 - val_YT_acc: 0.7746 - val_YP_acc: 0.2855
# Epoch 16/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.9141 - YT_loss: 0.7444 - YP_loss: 2.1697 - YT_acc: 0.7781 - YP_acc: 0.2481 - val_loss: 2.7544 - val_YT_loss: 0.7169 - val_YP_loss: 2.0374 - val_YT_acc: 0.7781 - val_YP_acc: 0.2931
# Epoch 17/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.8860 - YT_loss: 0.7369 - YP_loss: 2.1491 - YT_acc: 0.7805 - YP_acc: 0.2545 - val_loss: 2.7291 - val_YT_loss: 0.7094 - val_YP_loss: 2.0197 - val_YT_acc: 0.7796 - val_YP_acc: 0.2982
# Epoch 18/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.8585 - YT_loss: 0.7302 - YP_loss: 2.1283 - YT_acc: 0.7821 - YP_acc: 0.2608 - val_loss: 2.7076 - val_YT_loss: 0.7039 - val_YP_loss: 2.0037 - val_YT_acc: 0.7812 - val_YP_acc: 0.3036
# Epoch 19/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.8343 - YT_loss: 0.7241 - YP_loss: 2.1102 - YT_acc: 0.7837 - YP_acc: 0.2667 - val_loss: 2.6880 - val_YT_loss: 0.6992 - val_YP_loss: 1.9888 - val_YT_acc: 0.7833 - val_YP_acc: 0.3076
# Epoch 20/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.8140 - YT_loss: 0.7184 - YP_loss: 2.0957 - YT_acc: 0.7854 - YP_acc: 0.2716 - val_loss: 2.6710 - val_YT_loss: 0.6956 - val_YP_loss: 1.9755 - val_YT_acc: 0.7858 - val_YP_acc: 0.3126
# Epoch 21/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.7937 - YT_loss: 0.7134 - YP_loss: 2.0803 - YT_acc: 0.7870 - YP_acc: 0.2761 - val_loss: 2.6547 - val_YT_loss: 0.6909 - val_YP_loss: 1.9639 - val_YT_acc: 0.7867 - val_YP_acc: 0.3147
# Epoch 22/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.7750 - YT_loss: 0.7082 - YP_loss: 2.0668 - YT_acc: 0.7889 - YP_acc: 0.2814 - val_loss: 2.6381 - val_YT_loss: 0.6859 - val_YP_loss: 1.9522 - val_YT_acc: 0.7883 - val_YP_acc: 0.3204
# Epoch 23/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.7571 - YT_loss: 0.7037 - YP_loss: 2.0535 - YT_acc: 0.7898 - YP_acc: 0.2850 - val_loss: 2.6253 - val_YT_loss: 0.6821 - val_YP_loss: 1.9432 - val_YT_acc: 0.7897 - val_YP_acc: 0.3239
# Epoch 24/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.7405 - YT_loss: 0.6985 - YP_loss: 2.0420 - YT_acc: 0.7917 - YP_acc: 0.2897 - val_loss: 2.6145 - val_YT_loss: 0.6800 - val_YP_loss: 1.9346 - val_YT_acc: 0.7912 - val_YP_acc: 0.3251
# Epoch 25/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.7257 - YT_loss: 0.6944 - YP_loss: 2.0313 - YT_acc: 0.7922 - YP_acc: 0.2929 - val_loss: 2.6004 - val_YT_loss: 0.6754 - val_YP_loss: 1.9250 - val_YT_acc: 0.7930 - val_YP_acc: 0.3290
# Epoch 26/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.7123 - YT_loss: 0.6912 - YP_loss: 2.0211 - YT_acc: 0.7933 - YP_acc: 0.2960 - val_loss: 2.5907 - val_YT_loss: 0.6732 - val_YP_loss: 1.9175 - val_YT_acc: 0.7948 - val_YP_acc: 0.3308
# Epoch 27/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.6999 - YT_loss: 0.6878 - YP_loss: 2.0122 - YT_acc: 0.7949 - YP_acc: 0.2998 - val_loss: 2.5817 - val_YT_loss: 0.6708 - val_YP_loss: 1.9109 - val_YT_acc: 0.7954 - val_YP_acc: 0.3342
# Epoch 28/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.6871 - YT_loss: 0.6846 - YP_loss: 2.0025 - YT_acc: 0.7958 - YP_acc: 0.3031 - val_loss: 2.5724 - val_YT_loss: 0.6677 - val_YP_loss: 1.9048 - val_YT_acc: 0.7964 - val_YP_acc: 0.3349
# Epoch 29/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.6766 - YT_loss: 0.6811 - YP_loss: 1.9955 - YT_acc: 0.7967 - YP_acc: 0.3060 - val_loss: 2.5650 - val_YT_loss: 0.6666 - val_YP_loss: 1.8984 - val_YT_acc: 0.7971 - val_YP_acc: 0.3379
# Epoch 30/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.6685 - YT_loss: 0.6799 - YP_loss: 1.9886 - YT_acc: 0.7971 - YP_acc: 0.3079 - val_loss: 2.5569 - val_YT_loss: 0.6643 - val_YP_loss: 1.8926 - val_YT_acc: 0.7982 - val_YP_acc: 0.3388
# Epoch 31/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.6584 - YT_loss: 0.6760 - YP_loss: 1.9824 - YT_acc: 0.7982 - YP_acc: 0.3098 - val_loss: 2.5537 - val_YT_loss: 0.6629 - val_YP_loss: 1.8908 - val_YT_acc: 0.7980 - val_YP_acc: 0.3411
# Epoch 32/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.6488 - YT_loss: 0.6733 - YP_loss: 1.9756 - YT_acc: 0.7990 - YP_acc: 0.3124 - val_loss: 2.5434 - val_YT_loss: 0.6597 - val_YP_loss: 1.8837 - val_YT_acc: 0.7984 - val_YP_acc: 0.3423
# Epoch 33/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.6398 - YT_loss: 0.6700 - YP_loss: 1.9698 - YT_acc: 0.7998 - YP_acc: 0.3140 - val_loss: 2.5378 - val_YT_loss: 0.6584 - val_YP_loss: 1.8795 - val_YT_acc: 0.7992 - val_YP_acc: 0.3429
# Epoch 34/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.6320 - YT_loss: 0.6685 - YP_loss: 1.9636 - YT_acc: 0.7999 - YP_acc: 0.3161 - val_loss: 2.5312 - val_YT_loss: 0.6556 - val_YP_loss: 1.8756 - val_YT_acc: 0.8002 - val_YP_acc: 0.3453
# Epoch 35/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.6222 - YT_loss: 0.6651 - YP_loss: 1.9571 - YT_acc: 0.8009 - YP_acc: 0.3183 - val_loss: 2.5251 - val_YT_loss: 0.6539 - val_YP_loss: 1.8712 - val_YT_acc: 0.8007 - val_YP_acc: 0.3477
# Epoch 36/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.6166 - YT_loss: 0.6636 - YP_loss: 1.9530 - YT_acc: 0.8017 - YP_acc: 0.3200 - val_loss: 2.5197 - val_YT_loss: 0.6527 - val_YP_loss: 1.8670 - val_YT_acc: 0.8009 - val_YP_acc: 0.3487
# Epoch 37/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.6087 - YT_loss: 0.6618 - YP_loss: 1.9469 - YT_acc: 0.8021 - YP_acc: 0.3218 - val_loss: 2.5178 - val_YT_loss: 0.6508 - val_YP_loss: 1.8670 - val_YT_acc: 0.8017 - val_YP_acc: 0.3475
# Epoch 38/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.6038 - YT_loss: 0.6591 - YP_loss: 1.9447 - YT_acc: 0.8029 - YP_acc: 0.3228 - val_loss: 2.5122 - val_YT_loss: 0.6509 - val_YP_loss: 1.8613 - val_YT_acc: 0.8021 - val_YP_acc: 0.3515
# Epoch 39/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5988 - YT_loss: 0.6585 - YP_loss: 1.9404 - YT_acc: 0.8028 - YP_acc: 0.3237 - val_loss: 2.5093 - val_YT_loss: 0.6479 - val_YP_loss: 1.8614 - val_YT_acc: 0.8022 - val_YP_acc: 0.3523
# Epoch 40/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5929 - YT_loss: 0.6569 - YP_loss: 1.9360 - YT_acc: 0.8035 - YP_acc: 0.3261 - val_loss: 2.5094 - val_YT_loss: 0.6503 - val_YP_loss: 1.8591 - val_YT_acc: 0.8029 - val_YP_acc: 0.3526
# Epoch 41/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5855 - YT_loss: 0.6543 - YP_loss: 1.9312 - YT_acc: 0.8044 - YP_acc: 0.3282 - val_loss: 2.4970 - val_YT_loss: 0.6443 - val_YP_loss: 1.8527 - val_YT_acc: 0.8026 - val_YP_acc: 0.3545
# Epoch 42/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5797 - YT_loss: 0.6525 - YP_loss: 1.9272 - YT_acc: 0.8041 - YP_acc: 0.3284 - val_loss: 2.4981 - val_YT_loss: 0.6456 - val_YP_loss: 1.8525 - val_YT_acc: 0.8034 - val_YP_acc: 0.3550
# Epoch 43/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5783 - YT_loss: 0.6513 - YP_loss: 1.9270 - YT_acc: 0.8049 - YP_acc: 0.3285 - val_loss: 2.4963 - val_YT_loss: 0.6459 - val_YP_loss: 1.8504 - val_YT_acc: 0.8036 - val_YP_acc: 0.3545
# Epoch 44/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5713 - YT_loss: 0.6502 - YP_loss: 1.9211 - YT_acc: 0.8053 - YP_acc: 0.3298 - val_loss: 2.4908 - val_YT_loss: 0.6423 - val_YP_loss: 1.8485 - val_YT_acc: 0.8041 - val_YP_acc: 0.3577
# Epoch 45/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5665 - YT_loss: 0.6474 - YP_loss: 1.9191 - YT_acc: 0.8055 - YP_acc: 0.3312 - val_loss: 2.4823 - val_YT_loss: 0.6407 - val_YP_loss: 1.8416 - val_YT_acc: 0.8038 - val_YP_acc: 0.3587
# Epoch 46/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5607 - YT_loss: 0.6466 - YP_loss: 1.9141 - YT_acc: 0.8060 - YP_acc: 0.3325 - val_loss: 2.4883 - val_YT_loss: 0.6398 - val_YP_loss: 1.8485 - val_YT_acc: 0.8047 - val_YP_acc: 0.3563
# Epoch 47/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5587 - YT_loss: 0.6446 - YP_loss: 1.9141 - YT_acc: 0.8065 - YP_acc: 0.3331 - val_loss: 2.4785 - val_YT_loss: 0.6386 - val_YP_loss: 1.8399 - val_YT_acc: 0.8051 - val_YP_acc: 0.3595
# Epoch 48/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5534 - YT_loss: 0.6436 - YP_loss: 1.9098 - YT_acc: 0.8067 - YP_acc: 0.3349 - val_loss: 2.4774 - val_YT_loss: 0.6376 - val_YP_loss: 1.8398 - val_YT_acc: 0.8039 - val_YP_acc: 0.3602
# Epoch 49/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5486 - YT_loss: 0.6416 - YP_loss: 1.9070 - YT_acc: 0.8069 - YP_acc: 0.3351 - val_loss: 2.4703 - val_YT_loss: 0.6360 - val_YP_loss: 1.8343 - val_YT_acc: 0.8055 - val_YP_acc: 0.3623
# Epoch 50/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5443 - YT_loss: 0.6412 - YP_loss: 1.9031 - YT_acc: 0.8070 - YP_acc: 0.3373 - val_loss: 2.4689 - val_YT_loss: 0.6349 - val_YP_loss: 1.8340 - val_YT_acc: 0.8050 - val_YP_acc: 0.3626
# Epoch 51/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5412 - YT_loss: 0.6393 - YP_loss: 1.9019 - YT_acc: 0.8074 - YP_acc: 0.3370 - val_loss: 2.4650 - val_YT_loss: 0.6336 - val_YP_loss: 1.8314 - val_YT_acc: 0.8059 - val_YP_acc: 0.3638
# Epoch 52/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5369 - YT_loss: 0.6384 - YP_loss: 1.8985 - YT_acc: 0.8080 - YP_acc: 0.3377 - val_loss: 2.4633 - val_YT_loss: 0.6320 - val_YP_loss: 1.8313 - val_YT_acc: 0.8056 - val_YP_acc: 0.3625
# Epoch 53/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5345 - YT_loss: 0.6368 - YP_loss: 1.8977 - YT_acc: 0.8077 - YP_acc: 0.3387 - val_loss: 2.4618 - val_YT_loss: 0.6319 - val_YP_loss: 1.8299 - val_YT_acc: 0.8046 - val_YP_acc: 0.3643
# Epoch 54/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5308 - YT_loss: 0.6359 - YP_loss: 1.8949 - YT_acc: 0.8083 - YP_acc: 0.3389 - val_loss: 2.4601 - val_YT_loss: 0.6316 - val_YP_loss: 1.8285 - val_YT_acc: 0.8044 - val_YP_acc: 0.3642
# Epoch 55/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5286 - YT_loss: 0.6355 - YP_loss: 1.8931 - YT_acc: 0.8085 - YP_acc: 0.3398 - val_loss: 2.4650 - val_YT_loss: 0.6402 - val_YP_loss: 1.8248 - val_YT_acc: 0.8061 - val_YP_acc: 0.3654
# Epoch 56/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5287 - YT_loss: 0.6372 - YP_loss: 1.8915 - YT_acc: 0.8087 - YP_acc: 0.3404 - val_loss: 2.4595 - val_YT_loss: 0.6346 - val_YP_loss: 1.8250 - val_YT_acc: 0.8064 - val_YP_acc: 0.3656
# Epoch 57/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5205 - YT_loss: 0.6327 - YP_loss: 1.8878 - YT_acc: 0.8086 - YP_acc: 0.3411 - val_loss: 2.4565 - val_YT_loss: 0.6302 - val_YP_loss: 1.8263 - val_YT_acc: 0.8062 - val_YP_acc: 0.3659
# Epoch 58/250
# 3503/3503 [==============================] - 22s 6ms/step - loss: 2.5178 - YT_loss: 0.6313 - YP_loss: 1.8865 - YT_acc: 0.8088 - YP_acc: 0.3428 - val_loss: 2.4492 - val_YT_loss: 0.6262 - val_YP_loss: 1.8231 - val_YT_acc: 0.8063 - val_YP_acc: 0.3659
# Epoch 59/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5196 - YT_loss: 0.6326 - YP_loss: 1.8871 - YT_acc: 0.8091 - YP_acc: 0.3418 - val_loss: 2.4498 - val_YT_loss: 0.6298 - val_YP_loss: 1.8200 - val_YT_acc: 0.8067 - val_YP_acc: 0.3687
# Epoch 60/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.5153 - YT_loss: 0.6325 - YP_loss: 1.8828 - YT_acc: 0.8094 - YP_acc: 0.3428 - val_loss: 2.4464 - val_YT_loss: 0.6272 - val_YP_loss: 1.8191 - val_YT_acc: 0.8065 - val_YP_acc: 0.3687
# Epoch 61/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.5108 - YT_loss: 0.6304 - YP_loss: 1.8805 - YT_acc: 0.8103 - YP_acc: 0.3447 - val_loss: 2.4437 - val_YT_loss: 0.6273 - val_YP_loss: 1.8164 - val_YT_acc: 0.8065 - val_YP_acc: 0.3684
# Epoch 62/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5064 - YT_loss: 0.6281 - YP_loss: 1.8783 - YT_acc: 0.8103 - YP_acc: 0.3456 - val_loss: 2.4404 - val_YT_loss: 0.6244 - val_YP_loss: 1.8160 - val_YT_acc: 0.8060 - val_YP_acc: 0.3692
# Epoch 63/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.5038 - YT_loss: 0.6267 - YP_loss: 1.8770 - YT_acc: 0.8101 - YP_acc: 0.3457 - val_loss: 2.4402 - val_YT_loss: 0.6246 - val_YP_loss: 1.8156 - val_YT_acc: 0.8061 - val_YP_acc: 0.3672
# Epoch 64/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.5013 - YT_loss: 0.6255 - YP_loss: 1.8758 - YT_acc: 0.8101 - YP_acc: 0.3457 - val_loss: 2.4365 - val_YT_loss: 0.6223 - val_YP_loss: 1.8142 - val_YT_acc: 0.8059 - val_YP_acc: 0.3682
# Epoch 65/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4980 - YT_loss: 0.6235 - YP_loss: 1.8745 - YT_acc: 0.8103 - YP_acc: 0.3461 - val_loss: 2.4379 - val_YT_loss: 0.6219 - val_YP_loss: 1.8160 - val_YT_acc: 0.8070 - val_YP_acc: 0.3679
# Epoch 66/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4984 - YT_loss: 0.6236 - YP_loss: 1.8748 - YT_acc: 0.8104 - YP_acc: 0.3472 - val_loss: 2.4355 - val_YT_loss: 0.6212 - val_YP_loss: 1.8143 - val_YT_acc: 0.8066 - val_YP_acc: 0.3676
# Epoch 67/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4926 - YT_loss: 0.6231 - YP_loss: 1.8695 - YT_acc: 0.8106 - YP_acc: 0.3482 - val_loss: 2.4319 - val_YT_loss: 0.6211 - val_YP_loss: 1.8108 - val_YT_acc: 0.8067 - val_YP_acc: 0.3696
# Epoch 68/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4921 - YT_loss: 0.6224 - YP_loss: 1.8697 - YT_acc: 0.8110 - YP_acc: 0.3482 - val_loss: 2.4308 - val_YT_loss: 0.6220 - val_YP_loss: 1.8088 - val_YT_acc: 0.8073 - val_YP_acc: 0.3718
# Epoch 69/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.4909 - YT_loss: 0.6223 - YP_loss: 1.8685 - YT_acc: 0.8109 - YP_acc: 0.3486 - val_loss: 2.4273 - val_YT_loss: 0.6191 - val_YP_loss: 1.8082 - val_YT_acc: 0.8068 - val_YP_acc: 0.3715
# Epoch 70/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4896 - YT_loss: 0.6216 - YP_loss: 1.8680 - YT_acc: 0.8114 - YP_acc: 0.3485 - val_loss: 2.4315 - val_YT_loss: 0.6211 - val_YP_loss: 1.8104 - val_YT_acc: 0.8068 - val_YP_acc: 0.3697
# Epoch 71/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4866 - YT_loss: 0.6207 - YP_loss: 1.8658 - YT_acc: 0.8115 - YP_acc: 0.3496 - val_loss: 2.4226 - val_YT_loss: 0.6172 - val_YP_loss: 1.8054 - val_YT_acc: 0.8068 - val_YP_acc: 0.3721
# Epoch 72/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4818 - YT_loss: 0.6192 - YP_loss: 1.8626 - YT_acc: 0.8112 - YP_acc: 0.3500 - val_loss: 2.4208 - val_YT_loss: 0.6169 - val_YP_loss: 1.8038 - val_YT_acc: 0.8073 - val_YP_acc: 0.3736
# Epoch 73/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4782 - YT_loss: 0.6178 - YP_loss: 1.8604 - YT_acc: 0.8117 - YP_acc: 0.3506 - val_loss: 2.4199 - val_YT_loss: 0.6170 - val_YP_loss: 1.8029 - val_YT_acc: 0.8075 - val_YP_acc: 0.3737
# Epoch 74/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4781 - YT_loss: 0.6174 - YP_loss: 1.8607 - YT_acc: 0.8118 - YP_acc: 0.3508 - val_loss: 2.4295 - val_YT_loss: 0.6192 - val_YP_loss: 1.8103 - val_YT_acc: 0.8072 - val_YP_acc: 0.3696
# Epoch 75/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4857 - YT_loss: 0.6226 - YP_loss: 1.8631 - YT_acc: 0.8118 - YP_acc: 0.3506 - val_loss: 2.4302 - val_YT_loss: 0.6248 - val_YP_loss: 1.8054 - val_YT_acc: 0.8074 - val_YP_acc: 0.3724
# Epoch 76/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4815 - YT_loss: 0.6228 - YP_loss: 1.8587 - YT_acc: 0.8120 - YP_acc: 0.3511 - val_loss: 2.4209 - val_YT_loss: 0.6190 - val_YP_loss: 1.8019 - val_YT_acc: 0.8075 - val_YP_acc: 0.3734
# Epoch 77/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.4750 - YT_loss: 0.6175 - YP_loss: 1.8574 - YT_acc: 0.8120 - YP_acc: 0.3522 - val_loss: 2.4156 - val_YT_loss: 0.6164 - val_YP_loss: 1.7993 - val_YT_acc: 0.8077 - val_YP_acc: 0.3756
# Epoch 78/250
# 3503/3503 [==============================] - 22s 6ms/step - loss: 2.4682 - YT_loss: 0.6142 - YP_loss: 1.8540 - YT_acc: 0.8129 - YP_acc: 0.3538 - val_loss: 2.4138 - val_YT_loss: 0.6156 - val_YP_loss: 1.7982 - val_YT_acc: 0.8081 - val_YP_acc: 0.3756
# Epoch 79/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4690 - YT_loss: 0.6152 - YP_loss: 1.8538 - YT_acc: 0.8125 - YP_acc: 0.3537 - val_loss: 2.4148 - val_YT_loss: 0.6146 - val_YP_loss: 1.8002 - val_YT_acc: 0.8079 - val_YP_acc: 0.3749
# Epoch 80/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4690 - YT_loss: 0.6149 - YP_loss: 1.8540 - YT_acc: 0.8125 - YP_acc: 0.3531 - val_loss: 2.4146 - val_YT_loss: 0.6147 - val_YP_loss: 1.7999 - val_YT_acc: 0.8071 - val_YP_acc: 0.3745
# Epoch 81/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4660 - YT_loss: 0.6144 - YP_loss: 1.8517 - YT_acc: 0.8127 - YP_acc: 0.3535 - val_loss: 2.4095 - val_YT_loss: 0.6131 - val_YP_loss: 1.7963 - val_YT_acc: 0.8067 - val_YP_acc: 0.3755
# Epoch 82/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4629 - YT_loss: 0.6129 - YP_loss: 1.8500 - YT_acc: 0.8127 - YP_acc: 0.3546 - val_loss: 2.4084 - val_YT_loss: 0.6140 - val_YP_loss: 1.7945 - val_YT_acc: 0.8083 - val_YP_acc: 0.3758
# Epoch 83/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4593 - YT_loss: 0.6114 - YP_loss: 1.8478 - YT_acc: 0.8131 - YP_acc: 0.3547 - val_loss: 2.4043 - val_YT_loss: 0.6117 - val_YP_loss: 1.7925 - val_YT_acc: 0.8073 - val_YP_acc: 0.3770
# Epoch 84/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4568 - YT_loss: 0.6107 - YP_loss: 1.8460 - YT_acc: 0.8130 - YP_acc: 0.3564 - val_loss: 2.4045 - val_YT_loss: 0.6120 - val_YP_loss: 1.7926 - val_YT_acc: 0.8083 - val_YP_acc: 0.3759
# Epoch 85/250
# 3503/3503 [==============================] - 22s 6ms/step - loss: 2.4577 - YT_loss: 0.6101 - YP_loss: 1.8475 - YT_acc: 0.8129 - YP_acc: 0.3559 - val_loss: 2.4064 - val_YT_loss: 0.6121 - val_YP_loss: 1.7944 - val_YT_acc: 0.8086 - val_YP_acc: 0.3753
# Epoch 86/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4576 - YT_loss: 0.6114 - YP_loss: 1.8462 - YT_acc: 0.8132 - YP_acc: 0.3556 - val_loss: 2.4022 - val_YT_loss: 0.6113 - val_YP_loss: 1.7909 - val_YT_acc: 0.8084 - val_YP_acc: 0.3782
# Epoch 87/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4532 - YT_loss: 0.6090 - YP_loss: 1.8441 - YT_acc: 0.8135 - YP_acc: 0.3564 - val_loss: 2.4027 - val_YT_loss: 0.6114 - val_YP_loss: 1.7913 - val_YT_acc: 0.8082 - val_YP_acc: 0.3779
# Epoch 88/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4530 - YT_loss: 0.6090 - YP_loss: 1.8440 - YT_acc: 0.8135 - YP_acc: 0.3563 - val_loss: 2.3999 - val_YT_loss: 0.6098 - val_YP_loss: 1.7901 - val_YT_acc: 0.8084 - val_YP_acc: 0.3780
# Epoch 89/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4495 - YT_loss: 0.6080 - YP_loss: 1.8414 - YT_acc: 0.8134 - YP_acc: 0.3578 - val_loss: 2.3964 - val_YT_loss: 0.6087 - val_YP_loss: 1.7877 - val_YT_acc: 0.8086 - val_YP_acc: 0.3778
# Epoch 90/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4488 - YT_loss: 0.6066 - YP_loss: 1.8422 - YT_acc: 0.8134 - YP_acc: 0.3572 - val_loss: 2.3985 - val_YT_loss: 0.6085 - val_YP_loss: 1.7900 - val_YT_acc: 0.8088 - val_YP_acc: 0.3771
# Epoch 91/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4497 - YT_loss: 0.6082 - YP_loss: 1.8416 - YT_acc: 0.8141 - YP_acc: 0.3579 - val_loss: 2.3971 - val_YT_loss: 0.6116 - val_YP_loss: 1.7856 - val_YT_acc: 0.8090 - val_YP_acc: 0.3793
# Epoch 92/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.4478 - YT_loss: 0.6080 - YP_loss: 1.8398 - YT_acc: 0.8138 - YP_acc: 0.3581 - val_loss: 2.3951 - val_YT_loss: 0.6072 - val_YP_loss: 1.7878 - val_YT_acc: 0.8087 - val_YP_acc: 0.3776
# Epoch 93/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4452 - YT_loss: 0.6065 - YP_loss: 1.8387 - YT_acc: 0.8137 - YP_acc: 0.3576 - val_loss: 2.3971 - val_YT_loss: 0.6093 - val_YP_loss: 1.7878 - val_YT_acc: 0.8089 - val_YP_acc: 0.3776
# Epoch 94/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4428 - YT_loss: 0.6059 - YP_loss: 1.8369 - YT_acc: 0.8141 - YP_acc: 0.3594 - val_loss: 2.3972 - val_YT_loss: 0.6080 - val_YP_loss: 1.7892 - val_YT_acc: 0.8092 - val_YP_acc: 0.3788
# Epoch 95/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4399 - YT_loss: 0.6052 - YP_loss: 1.8347 - YT_acc: 0.8146 - YP_acc: 0.3593 - val_loss: 2.3918 - val_YT_loss: 0.6067 - val_YP_loss: 1.7852 - val_YT_acc: 0.8092 - val_YP_acc: 0.3782
# Epoch 96/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4392 - YT_loss: 0.6044 - YP_loss: 1.8348 - YT_acc: 0.8146 - YP_acc: 0.3598 - val_loss: 2.3901 - val_YT_loss: 0.6065 - val_YP_loss: 1.7836 - val_YT_acc: 0.8088 - val_YP_acc: 0.3800
# Epoch 97/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4390 - YT_loss: 0.6052 - YP_loss: 1.8338 - YT_acc: 0.8142 - YP_acc: 0.3602 - val_loss: 2.3888 - val_YT_loss: 0.6062 - val_YP_loss: 1.7826 - val_YT_acc: 0.8088 - val_YP_acc: 0.3792
# Epoch 98/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4390 - YT_loss: 0.6052 - YP_loss: 1.8338 - YT_acc: 0.8152 - YP_acc: 0.3604 - val_loss: 2.3893 - val_YT_loss: 0.6080 - val_YP_loss: 1.7813 - val_YT_acc: 0.8092 - val_YP_acc: 0.3808
# Epoch 99/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4368 - YT_loss: 0.6053 - YP_loss: 1.8315 - YT_acc: 0.8146 - YP_acc: 0.3613 - val_loss: 2.3880 - val_YT_loss: 0.6050 - val_YP_loss: 1.7829 - val_YT_acc: 0.8092 - val_YP_acc: 0.3804
# Epoch 100/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4357 - YT_loss: 0.6038 - YP_loss: 1.8319 - YT_acc: 0.8144 - YP_acc: 0.3612 - val_loss: 2.3884 - val_YT_loss: 0.6060 - val_YP_loss: 1.7824 - val_YT_acc: 0.8093 - val_YP_acc: 0.3810
# Epoch 101/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4345 - YT_loss: 0.6038 - YP_loss: 1.8308 - YT_acc: 0.8147 - YP_acc: 0.3607 - val_loss: 2.3863 - val_YT_loss: 0.6048 - val_YP_loss: 1.7816 - val_YT_acc: 0.8089 - val_YP_acc: 0.3811
# Epoch 102/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4349 - YT_loss: 0.6048 - YP_loss: 1.8301 - YT_acc: 0.8150 - YP_acc: 0.3614 - val_loss: 2.3863 - val_YT_loss: 0.6074 - val_YP_loss: 1.7789 - val_YT_acc: 0.8092 - val_YP_acc: 0.3815
# Epoch 103/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4299 - YT_loss: 0.6024 - YP_loss: 1.8275 - YT_acc: 0.8152 - YP_acc: 0.3618 - val_loss: 2.3816 - val_YT_loss: 0.6040 - val_YP_loss: 1.7776 - val_YT_acc: 0.8095 - val_YP_acc: 0.3815
# Epoch 104/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.4267 - YT_loss: 0.6001 - YP_loss: 1.8266 - YT_acc: 0.8155 - YP_acc: 0.3619 - val_loss: 2.3819 - val_YT_loss: 0.6017 - val_YP_loss: 1.7802 - val_YT_acc: 0.8095 - val_YP_acc: 0.3803
# Epoch 105/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4280 - YT_loss: 0.6007 - YP_loss: 1.8274 - YT_acc: 0.8150 - YP_acc: 0.3620 - val_loss: 2.3805 - val_YT_loss: 0.6034 - val_YP_loss: 1.7770 - val_YT_acc: 0.8097 - val_YP_acc: 0.3827
# Epoch 106/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4236 - YT_loss: 0.5994 - YP_loss: 1.8242 - YT_acc: 0.8154 - YP_acc: 0.3630 - val_loss: 2.3772 - val_YT_loss: 0.6027 - val_YP_loss: 1.7745 - val_YT_acc: 0.8096 - val_YP_acc: 0.3834
# Epoch 107/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4234 - YT_loss: 0.5992 - YP_loss: 1.8242 - YT_acc: 0.8153 - YP_acc: 0.3632 - val_loss: 2.3775 - val_YT_loss: 0.6028 - val_YP_loss: 1.7748 - val_YT_acc: 0.8098 - val_YP_acc: 0.3816
# Epoch 108/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4303 - YT_loss: 0.6022 - YP_loss: 1.8281 - YT_acc: 0.8154 - YP_acc: 0.3621 - val_loss: 2.4003 - val_YT_loss: 0.6161 - val_YP_loss: 1.7842 - val_YT_acc: 0.8079 - val_YP_acc: 0.3783
# Epoch 109/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4321 - YT_loss: 0.6048 - YP_loss: 1.8272 - YT_acc: 0.8153 - YP_acc: 0.3621 - val_loss: 2.3850 - val_YT_loss: 0.6073 - val_YP_loss: 1.7777 - val_YT_acc: 0.8093 - val_YP_acc: 0.3806
# Epoch 110/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4267 - YT_loss: 0.6021 - YP_loss: 1.8246 - YT_acc: 0.8154 - YP_acc: 0.3624 - val_loss: 2.3787 - val_YT_loss: 0.6045 - val_YP_loss: 1.7742 - val_YT_acc: 0.8097 - val_YP_acc: 0.3820
# Epoch 111/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4218 - YT_loss: 0.6006 - YP_loss: 1.8212 - YT_acc: 0.8154 - YP_acc: 0.3638 - val_loss: 2.3723 - val_YT_loss: 0.6013 - val_YP_loss: 1.7710 - val_YT_acc: 0.8099 - val_YP_acc: 0.3842
# Epoch 112/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.4182 - YT_loss: 0.5971 - YP_loss: 1.8211 - YT_acc: 0.8161 - YP_acc: 0.3638 - val_loss: 2.3737 - val_YT_loss: 0.6006 - val_YP_loss: 1.7731 - val_YT_acc: 0.8105 - val_YP_acc: 0.3839
# Epoch 113/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4159 - YT_loss: 0.5972 - YP_loss: 1.8187 - YT_acc: 0.8160 - YP_acc: 0.3654 - val_loss: 2.3701 - val_YT_loss: 0.5992 - val_YP_loss: 1.7709 - val_YT_acc: 0.8102 - val_YP_acc: 0.3837
# Epoch 114/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4147 - YT_loss: 0.5977 - YP_loss: 1.8170 - YT_acc: 0.8161 - YP_acc: 0.3660 - val_loss: 2.3683 - val_YT_loss: 0.6002 - val_YP_loss: 1.7680 - val_YT_acc: 0.8104 - val_YP_acc: 0.3860
# Epoch 115/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4115 - YT_loss: 0.5956 - YP_loss: 1.8159 - YT_acc: 0.8163 - YP_acc: 0.3659 - val_loss: 2.3807 - val_YT_loss: 0.6032 - val_YP_loss: 1.7775 - val_YT_acc: 0.8106 - val_YP_acc: 0.3819
# Epoch 116/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4178 - YT_loss: 0.5988 - YP_loss: 1.8190 - YT_acc: 0.8164 - YP_acc: 0.3642 - val_loss: 2.3761 - val_YT_loss: 0.6041 - val_YP_loss: 1.7720 - val_YT_acc: 0.8108 - val_YP_acc: 0.3833
# Epoch 117/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4185 - YT_loss: 0.5984 - YP_loss: 1.8200 - YT_acc: 0.8162 - YP_acc: 0.3646 - val_loss: 2.3712 - val_YT_loss: 0.6001 - val_YP_loss: 1.7711 - val_YT_acc: 0.8108 - val_YP_acc: 0.3835
# Epoch 118/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.4120 - YT_loss: 0.5958 - YP_loss: 1.8162 - YT_acc: 0.8166 - YP_acc: 0.3650 - val_loss: 2.3674 - val_YT_loss: 0.5989 - val_YP_loss: 1.7685 - val_YT_acc: 0.8107 - val_YP_acc: 0.3850
# Epoch 119/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4079 - YT_loss: 0.5944 - YP_loss: 1.8135 - YT_acc: 0.8166 - YP_acc: 0.3666 - val_loss: 2.3632 - val_YT_loss: 0.5970 - val_YP_loss: 1.7662 - val_YT_acc: 0.8106 - val_YP_acc: 0.3863
# Epoch 120/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4049 - YT_loss: 0.5934 - YP_loss: 1.8115 - YT_acc: 0.8167 - YP_acc: 0.3680 - val_loss: 2.3625 - val_YT_loss: 0.5981 - val_YP_loss: 1.7644 - val_YT_acc: 0.8111 - val_YP_acc: 0.3868
# Epoch 121/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4059 - YT_loss: 0.5938 - YP_loss: 1.8121 - YT_acc: 0.8168 - YP_acc: 0.3670 - val_loss: 2.3652 - val_YT_loss: 0.6001 - val_YP_loss: 1.7651 - val_YT_acc: 0.8106 - val_YP_acc: 0.3858
# Epoch 122/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4075 - YT_loss: 0.5957 - YP_loss: 1.8117 - YT_acc: 0.8169 - YP_acc: 0.3672 - val_loss: 2.3639 - val_YT_loss: 0.5994 - val_YP_loss: 1.7645 - val_YT_acc: 0.8106 - val_YP_acc: 0.3857
# Epoch 123/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4053 - YT_loss: 0.5954 - YP_loss: 1.8098 - YT_acc: 0.8170 - YP_acc: 0.3689 - val_loss: 2.3681 - val_YT_loss: 0.6000 - val_YP_loss: 1.7681 - val_YT_acc: 0.8111 - val_YP_acc: 0.3858
# Epoch 124/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4044 - YT_loss: 0.5933 - YP_loss: 1.8111 - YT_acc: 0.8170 - YP_acc: 0.3679 - val_loss: 2.3609 - val_YT_loss: 0.5982 - val_YP_loss: 1.7627 - val_YT_acc: 0.8113 - val_YP_acc: 0.3880
# Epoch 125/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.4020 - YT_loss: 0.5933 - YP_loss: 1.8086 - YT_acc: 0.8170 - YP_acc: 0.3675 - val_loss: 2.3579 - val_YT_loss: 0.5954 - val_YP_loss: 1.7625 - val_YT_acc: 0.8110 - val_YP_acc: 0.3872
# Epoch 126/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4021 - YT_loss: 0.5926 - YP_loss: 1.8095 - YT_acc: 0.8173 - YP_acc: 0.3685 - val_loss: 2.3582 - val_YT_loss: 0.5954 - val_YP_loss: 1.7628 - val_YT_acc: 0.8113 - val_YP_acc: 0.3878
# Epoch 127/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.4009 - YT_loss: 0.5918 - YP_loss: 1.8091 - YT_acc: 0.8176 - YP_acc: 0.3687 - val_loss: 2.3581 - val_YT_loss: 0.5958 - val_YP_loss: 1.7623 - val_YT_acc: 0.8112 - val_YP_acc: 0.3862
# Epoch 128/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3978 - YT_loss: 0.5919 - YP_loss: 1.8059 - YT_acc: 0.8175 - YP_acc: 0.3690 - val_loss: 2.3542 - val_YT_loss: 0.5948 - val_YP_loss: 1.7594 - val_YT_acc: 0.8113 - val_YP_acc: 0.3885
# Epoch 129/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3944 - YT_loss: 0.5897 - YP_loss: 1.8047 - YT_acc: 0.8178 - YP_acc: 0.3691 - val_loss: 2.3551 - val_YT_loss: 0.5953 - val_YP_loss: 1.7598 - val_YT_acc: 0.8117 - val_YP_acc: 0.3878
# Epoch 130/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3940 - YT_loss: 0.5899 - YP_loss: 1.8041 - YT_acc: 0.8174 - YP_acc: 0.3699 - val_loss: 2.3519 - val_YT_loss: 0.5933 - val_YP_loss: 1.7587 - val_YT_acc: 0.8118 - val_YP_acc: 0.3884
# Epoch 131/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.3938 - YT_loss: 0.5893 - YP_loss: 1.8045 - YT_acc: 0.8181 - YP_acc: 0.3693 - val_loss: 2.3526 - val_YT_loss: 0.5932 - val_YP_loss: 1.7594 - val_YT_acc: 0.8117 - val_YP_acc: 0.3884
# Epoch 132/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3914 - YT_loss: 0.5877 - YP_loss: 1.8037 - YT_acc: 0.8182 - YP_acc: 0.3701 - val_loss: 2.3511 - val_YT_loss: 0.5931 - val_YP_loss: 1.7580 - val_YT_acc: 0.8116 - val_YP_acc: 0.3891
# Epoch 133/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3917 - YT_loss: 0.5885 - YP_loss: 1.8032 - YT_acc: 0.8179 - YP_acc: 0.3707 - val_loss: 2.3476 - val_YT_loss: 0.5912 - val_YP_loss: 1.7563 - val_YT_acc: 0.8117 - val_YP_acc: 0.3886
# Epoch 134/250
# 3503/3503 [==============================] - 22s 6ms/step - loss: 2.3890 - YT_loss: 0.5888 - YP_loss: 1.8002 - YT_acc: 0.8181 - YP_acc: 0.3710 - val_loss: 2.3472 - val_YT_loss: 0.5924 - val_YP_loss: 1.7548 - val_YT_acc: 0.8124 - val_YP_acc: 0.3900
# Epoch 135/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.3877 - YT_loss: 0.5881 - YP_loss: 1.7996 - YT_acc: 0.8180 - YP_acc: 0.3711 - val_loss: 2.3477 - val_YT_loss: 0.5938 - val_YP_loss: 1.7539 - val_YT_acc: 0.8119 - val_YP_acc: 0.3917
# Epoch 136/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3857 - YT_loss: 0.5868 - YP_loss: 1.7990 - YT_acc: 0.8185 - YP_acc: 0.3716 - val_loss: 2.3445 - val_YT_loss: 0.5898 - val_YP_loss: 1.7547 - val_YT_acc: 0.8124 - val_YP_acc: 0.3890
# Epoch 137/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3843 - YT_loss: 0.5868 - YP_loss: 1.7975 - YT_acc: 0.8185 - YP_acc: 0.3725 - val_loss: 2.3443 - val_YT_loss: 0.5892 - val_YP_loss: 1.7551 - val_YT_acc: 0.8122 - val_YP_acc: 0.3903
# Epoch 138/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3833 - YT_loss: 0.5849 - YP_loss: 1.7983 - YT_acc: 0.8187 - YP_acc: 0.3717 - val_loss: 2.3431 - val_YT_loss: 0.5896 - val_YP_loss: 1.7535 - val_YT_acc: 0.8123 - val_YP_acc: 0.3919
# Epoch 139/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3881 - YT_loss: 0.5868 - YP_loss: 1.8013 - YT_acc: 0.8187 - YP_acc: 0.3716 - val_loss: 2.3504 - val_YT_loss: 0.5891 - val_YP_loss: 1.7614 - val_YT_acc: 0.8126 - val_YP_acc: 0.3875
# Epoch 140/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3853 - YT_loss: 0.5856 - YP_loss: 1.7997 - YT_acc: 0.8189 - YP_acc: 0.3716 - val_loss: 2.3470 - val_YT_loss: 0.5913 - val_YP_loss: 1.7557 - val_YT_acc: 0.8123 - val_YP_acc: 0.3883
# Epoch 141/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3828 - YT_loss: 0.5857 - YP_loss: 1.7971 - YT_acc: 0.8187 - YP_acc: 0.3717 - val_loss: 2.3404 - val_YT_loss: 0.5881 - val_YP_loss: 1.7523 - val_YT_acc: 0.8125 - val_YP_acc: 0.3902
# Epoch 142/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3774 - YT_loss: 0.5826 - YP_loss: 1.7948 - YT_acc: 0.8193 - YP_acc: 0.3733 - val_loss: 2.3354 - val_YT_loss: 0.5849 - val_YP_loss: 1.7506 - val_YT_acc: 0.8135 - val_YP_acc: 0.3907
# Epoch 143/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3752 - YT_loss: 0.5812 - YP_loss: 1.7940 - YT_acc: 0.8195 - YP_acc: 0.3739 - val_loss: 2.3363 - val_YT_loss: 0.5855 - val_YP_loss: 1.7508 - val_YT_acc: 0.8128 - val_YP_acc: 0.3911
# Epoch 144/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3738 - YT_loss: 0.5803 - YP_loss: 1.7935 - YT_acc: 0.8195 - YP_acc: 0.3734 - val_loss: 2.3383 - val_YT_loss: 0.5844 - val_YP_loss: 1.7539 - val_YT_acc: 0.8132 - val_YP_acc: 0.3907
# Epoch 145/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3722 - YT_loss: 0.5798 - YP_loss: 1.7924 - YT_acc: 0.8197 - YP_acc: 0.3740 - val_loss: 2.3340 - val_YT_loss: 0.5836 - val_YP_loss: 1.7505 - val_YT_acc: 0.8134 - val_YP_acc: 0.3920
# Epoch 146/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3713 - YT_loss: 0.5788 - YP_loss: 1.7925 - YT_acc: 0.8200 - YP_acc: 0.3738 - val_loss: 2.3367 - val_YT_loss: 0.5842 - val_YP_loss: 1.7525 - val_YT_acc: 0.8134 - val_YP_acc: 0.3904
# Epoch 147/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3801 - YT_loss: 0.5830 - YP_loss: 1.7970 - YT_acc: 0.8199 - YP_acc: 0.3732 - val_loss: 2.3402 - val_YT_loss: 0.5850 - val_YP_loss: 1.7552 - val_YT_acc: 0.8136 - val_YP_acc: 0.3892
# Epoch 148/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3770 - YT_loss: 0.5800 - YP_loss: 1.7970 - YT_acc: 0.8203 - YP_acc: 0.3723 - val_loss: 2.3363 - val_YT_loss: 0.5839 - val_YP_loss: 1.7524 - val_YT_acc: 0.8134 - val_YP_acc: 0.3909
# Epoch 149/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3715 - YT_loss: 0.5781 - YP_loss: 1.7934 - YT_acc: 0.8203 - YP_acc: 0.3733 - val_loss: 2.3292 - val_YT_loss: 0.5817 - val_YP_loss: 1.7475 - val_YT_acc: 0.8138 - val_YP_acc: 0.3912
# Epoch 150/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3662 - YT_loss: 0.5765 - YP_loss: 1.7897 - YT_acc: 0.8207 - YP_acc: 0.3753 - val_loss: 2.3241 - val_YT_loss: 0.5771 - val_YP_loss: 1.7470 - val_YT_acc: 0.8144 - val_YP_acc: 0.3917
# Epoch 151/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3623 - YT_loss: 0.5737 - YP_loss: 1.7886 - YT_acc: 0.8208 - YP_acc: 0.3755 - val_loss: 2.3250 - val_YT_loss: 0.5787 - val_YP_loss: 1.7462 - val_YT_acc: 0.8143 - val_YP_acc: 0.3910
# Epoch 152/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3621 - YT_loss: 0.5735 - YP_loss: 1.7886 - YT_acc: 0.8213 - YP_acc: 0.3757 - val_loss: 2.3231 - val_YT_loss: 0.5773 - val_YP_loss: 1.7457 - val_YT_acc: 0.8143 - val_YP_acc: 0.3924
# Epoch 153/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3584 - YT_loss: 0.5722 - YP_loss: 1.7861 - YT_acc: 0.8212 - YP_acc: 0.3766 - val_loss: 2.3229 - val_YT_loss: 0.5766 - val_YP_loss: 1.7463 - val_YT_acc: 0.8142 - val_YP_acc: 0.3918
# Epoch 154/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3586 - YT_loss: 0.5718 - YP_loss: 1.7868 - YT_acc: 0.8213 - YP_acc: 0.3767 - val_loss: 2.3240 - val_YT_loss: 0.5777 - val_YP_loss: 1.7463 - val_YT_acc: 0.8143 - val_YP_acc: 0.3922
# Epoch 155/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3584 - YT_loss: 0.5722 - YP_loss: 1.7862 - YT_acc: 0.8216 - YP_acc: 0.3763 - val_loss: 2.3170 - val_YT_loss: 0.5738 - val_YP_loss: 1.7432 - val_YT_acc: 0.8144 - val_YP_acc: 0.3937
# Epoch 156/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3563 - YT_loss: 0.5702 - YP_loss: 1.7861 - YT_acc: 0.8220 - YP_acc: 0.3766 - val_loss: 2.3159 - val_YT_loss: 0.5725 - val_YP_loss: 1.7434 - val_YT_acc: 0.8146 - val_YP_acc: 0.3936
# Epoch 157/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3530 - YT_loss: 0.5688 - YP_loss: 1.7842 - YT_acc: 0.8220 - YP_acc: 0.3775 - val_loss: 2.3141 - val_YT_loss: 0.5718 - val_YP_loss: 1.7422 - val_YT_acc: 0.8149 - val_YP_acc: 0.3949
# Epoch 158/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3517 - YT_loss: 0.5686 - YP_loss: 1.7830 - YT_acc: 0.8221 - YP_acc: 0.3774 - val_loss: 2.3117 - val_YT_loss: 0.5709 - val_YP_loss: 1.7408 - val_YT_acc: 0.8152 - val_YP_acc: 0.3939
# Epoch 159/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3516 - YT_loss: 0.5683 - YP_loss: 1.7833 - YT_acc: 0.8220 - YP_acc: 0.3777 - val_loss: 2.3131 - val_YT_loss: 0.5737 - val_YP_loss: 1.7394 - val_YT_acc: 0.8151 - val_YP_acc: 0.3945
# Epoch 160/250
# 3503/3503 [==============================] - 23s 7ms/step - loss: 2.3506 - YT_loss: 0.5685 - YP_loss: 1.7821 - YT_acc: 0.8223 - YP_acc: 0.3780 - val_loss: 2.3105 - val_YT_loss: 0.5711 - val_YP_loss: 1.7394 - val_YT_acc: 0.8149 - val_YP_acc: 0.3937
# Epoch 161/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3483 - YT_loss: 0.5672 - YP_loss: 1.7811 - YT_acc: 0.8221 - YP_acc: 0.3787 - val_loss: 2.3100 - val_YT_loss: 0.5694 - val_YP_loss: 1.7407 - val_YT_acc: 0.8152 - val_YP_acc: 0.3940
# Epoch 162/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3468 - YT_loss: 0.5659 - YP_loss: 1.7809 - YT_acc: 0.8225 - YP_acc: 0.3791 - val_loss: 2.3115 - val_YT_loss: 0.5705 - val_YP_loss: 1.7410 - val_YT_acc: 0.8155 - val_YP_acc: 0.3940
# Epoch 163/250
# 3503/3503 [==============================] - 22s 6ms/step - loss: 2.3490 - YT_loss: 0.5670 - YP_loss: 1.7820 - YT_acc: 0.8225 - YP_acc: 0.3773 - val_loss: 2.3110 - val_YT_loss: 0.5710 - val_YP_loss: 1.7400 - val_YT_acc: 0.8150 - val_YP_acc: 0.3953
# Epoch 164/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3449 - YT_loss: 0.5653 - YP_loss: 1.7797 - YT_acc: 0.8228 - YP_acc: 0.3786 - val_loss: 2.3043 - val_YT_loss: 0.5683 - val_YP_loss: 1.7360 - val_YT_acc: 0.8151 - val_YP_acc: 0.3958
# Epoch 165/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3422 - YT_loss: 0.5646 - YP_loss: 1.7777 - YT_acc: 0.8227 - YP_acc: 0.3796 - val_loss: 2.3060 - val_YT_loss: 0.5697 - val_YP_loss: 1.7363 - val_YT_acc: 0.8150 - val_YP_acc: 0.3961
# Epoch 166/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3400 - YT_loss: 0.5637 - YP_loss: 1.7764 - YT_acc: 0.8231 - YP_acc: 0.3796 - val_loss: 2.3009 - val_YT_loss: 0.5669 - val_YP_loss: 1.7340 - val_YT_acc: 0.8153 - val_YP_acc: 0.3971
# Epoch 167/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3411 - YT_loss: 0.5638 - YP_loss: 1.7773 - YT_acc: 0.8230 - YP_acc: 0.3795 - val_loss: 2.3032 - val_YT_loss: 0.5652 - val_YP_loss: 1.7380 - val_YT_acc: 0.8155 - val_YP_acc: 0.3959
# Epoch 168/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3395 - YT_loss: 0.5629 - YP_loss: 1.7766 - YT_acc: 0.8233 - YP_acc: 0.3804 - val_loss: 2.3053 - val_YT_loss: 0.5695 - val_YP_loss: 1.7358 - val_YT_acc: 0.8149 - val_YP_acc: 0.3954
# Epoch 169/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3388 - YT_loss: 0.5626 - YP_loss: 1.7761 - YT_acc: 0.8234 - YP_acc: 0.3801 - val_loss: 2.3033 - val_YT_loss: 0.5673 - val_YP_loss: 1.7360 - val_YT_acc: 0.8156 - val_YP_acc: 0.3948
# Epoch 170/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3365 - YT_loss: 0.5616 - YP_loss: 1.7748 - YT_acc: 0.8235 - YP_acc: 0.3804 - val_loss: 2.2984 - val_YT_loss: 0.5667 - val_YP_loss: 1.7317 - val_YT_acc: 0.8155 - val_YP_acc: 0.3977
# Epoch 171/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3349 - YT_loss: 0.5627 - YP_loss: 1.7721 - YT_acc: 0.8231 - YP_acc: 0.3818 - val_loss: 2.2954 - val_YT_loss: 0.5653 - val_YP_loss: 1.7301 - val_YT_acc: 0.8159 - val_YP_acc: 0.3968
# Epoch 172/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3378 - YT_loss: 0.5636 - YP_loss: 1.7742 - YT_acc: 0.8234 - YP_acc: 0.3808 - val_loss: 2.3066 - val_YT_loss: 0.5675 - val_YP_loss: 1.7392 - val_YT_acc: 0.8150 - val_YP_acc: 0.3934
# Epoch 173/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3369 - YT_loss: 0.5633 - YP_loss: 1.7736 - YT_acc: 0.8233 - YP_acc: 0.3817 - val_loss: 2.2974 - val_YT_loss: 0.5649 - val_YP_loss: 1.7325 - val_YT_acc: 0.8155 - val_YP_acc: 0.3962
# Epoch 174/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3327 - YT_loss: 0.5611 - YP_loss: 1.7716 - YT_acc: 0.8235 - YP_acc: 0.3812 - val_loss: 2.2998 - val_YT_loss: 0.5673 - val_YP_loss: 1.7325 - val_YT_acc: 0.8156 - val_YP_acc: 0.3959
# Epoch 175/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3314 - YT_loss: 0.5599 - YP_loss: 1.7714 - YT_acc: 0.8236 - YP_acc: 0.3819 - val_loss: 2.2943 - val_YT_loss: 0.5635 - val_YP_loss: 1.7308 - val_YT_acc: 0.8160 - val_YP_acc: 0.3969
# Epoch 176/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3285 - YT_loss: 0.5589 - YP_loss: 1.7696 - YT_acc: 0.8240 - YP_acc: 0.3820 - val_loss: 2.2901 - val_YT_loss: 0.5634 - val_YP_loss: 1.7267 - val_YT_acc: 0.8163 - val_YP_acc: 0.3993
# Epoch 177/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3274 - YT_loss: 0.5590 - YP_loss: 1.7683 - YT_acc: 0.8239 - YP_acc: 0.3832 - val_loss: 2.2941 - val_YT_loss: 0.5659 - val_YP_loss: 1.7282 - val_YT_acc: 0.8162 - val_YP_acc: 0.3997
# Epoch 178/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3292 - YT_loss: 0.5593 - YP_loss: 1.7699 - YT_acc: 0.8239 - YP_acc: 0.3825 - val_loss: 2.2900 - val_YT_loss: 0.5623 - val_YP_loss: 1.7277 - val_YT_acc: 0.8158 - val_YP_acc: 0.3985
# Epoch 179/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3240 - YT_loss: 0.5576 - YP_loss: 1.7664 - YT_acc: 0.8243 - YP_acc: 0.3838 - val_loss: 2.2873 - val_YT_loss: 0.5623 - val_YP_loss: 1.7249 - val_YT_acc: 0.8161 - val_YP_acc: 0.4000
# Epoch 180/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3263 - YT_loss: 0.5598 - YP_loss: 1.7665 - YT_acc: 0.8239 - YP_acc: 0.3830 - val_loss: 2.2899 - val_YT_loss: 0.5642 - val_YP_loss: 1.7257 - val_YT_acc: 0.8165 - val_YP_acc: 0.3996
# Epoch 181/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3255 - YT_loss: 0.5590 - YP_loss: 1.7664 - YT_acc: 0.8244 - YP_acc: 0.3839 - val_loss: 2.2877 - val_YT_loss: 0.5623 - val_YP_loss: 1.7254 - val_YT_acc: 0.8164 - val_YP_acc: 0.4001
# Epoch 182/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3211 - YT_loss: 0.5572 - YP_loss: 1.7639 - YT_acc: 0.8243 - YP_acc: 0.3846 - val_loss: 2.2856 - val_YT_loss: 0.5612 - val_YP_loss: 1.7245 - val_YT_acc: 0.8161 - val_YP_acc: 0.3993
# Epoch 183/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3203 - YT_loss: 0.5565 - YP_loss: 1.7638 - YT_acc: 0.8244 - YP_acc: 0.3842 - val_loss: 2.2863 - val_YT_loss: 0.5617 - val_YP_loss: 1.7246 - val_YT_acc: 0.8163 - val_YP_acc: 0.4009
# Epoch 184/250
# ...
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3141 - YT_loss: 0.5553 - YP_loss: 1.7588 - YT_acc: 0.8248 - YP_acc: 0.3869 - val_loss: 2.2800 - val_YT_loss: 0.5599 - val_YP_loss: 1.7202 - val_YT_acc: 0.8167 - val_YP_acc: 0.4017
# Epoch 191/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3223 - YT_loss: 0.5566 - YP_loss: 1.7657 - YT_acc: 0.8246 - YP_acc: 0.3841 - val_loss: 2.2870 - val_YT_loss: 0.5616 - val_YP_loss: 1.7255 - val_YT_acc: 0.8165 - val_YP_acc: 0.3977
# Epoch 192/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3203 - YT_loss: 0.5555 - YP_loss: 1.7649 - YT_acc: 0.8249 - YP_acc: 0.3842 - val_loss: 2.2824 - val_YT_loss: 0.5601 - val_YP_loss: 1.7223 - val_YT_acc: 0.8165 - val_YP_acc: 0.4004
# Epoch 193/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3155 - YT_loss: 0.5542 - YP_loss: 1.7613 - YT_acc: 0.8251 - YP_acc: 0.3852 - val_loss: 2.2786 - val_YT_loss: 0.5600 - val_YP_loss: 1.7186 - val_YT_acc: 0.8163 - val_YP_acc: 0.4025
# Epoch 194/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3095 - YT_loss: 0.5529 - YP_loss: 1.7567 - YT_acc: 0.8253 - YP_acc: 0.3873 - val_loss: 2.2760 - val_YT_loss: 0.5570 - val_YP_loss: 1.7190 - val_YT_acc: 0.8168 - val_YP_acc: 0.4006
# Epoch 195/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3092 - YT_loss: 0.5528 - YP_loss: 1.7565 - YT_acc: 0.8252 - YP_acc: 0.3875 - val_loss: 2.2793 - val_YT_loss: 0.5590 - val_YP_loss: 1.7203 - val_YT_acc: 0.8161 - val_YP_acc: 0.4001
# Epoch 196/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3091 - YT_loss: 0.5514 - YP_loss: 1.7577 - YT_acc: 0.8255 - YP_acc: 0.3868 - val_loss: 2.2769 - val_YT_loss: 0.5584 - val_YP_loss: 1.7184 - val_YT_acc: 0.8170 - val_YP_acc: 0.4012
# Epoch 197/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3088 - YT_loss: 0.5535 - YP_loss: 1.7552 - YT_acc: 0.8256 - YP_acc: 0.3881 - val_loss: 2.2787 - val_YT_loss: 0.5642 - val_YP_loss: 1.7145 - val_YT_acc: 0.8152 - val_YP_acc: 0.4025
# Epoch 198/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3079 - YT_loss: 0.5531 - YP_loss: 1.7548 - YT_acc: 0.8250 - YP_acc: 0.3882 - val_loss: 2.2723 - val_YT_loss: 0.5580 - val_YP_loss: 1.7142 - val_YT_acc: 0.8170 - val_YP_acc: 0.4034
# Epoch 199/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3026 - YT_loss: 0.5499 - YP_loss: 1.7527 - YT_acc: 0.8257 - YP_acc: 0.3885 - val_loss: 2.2680 - val_YT_loss: 0.5556 - val_YP_loss: 1.7123 - val_YT_acc: 0.8171 - val_YP_acc: 0.4042
# Epoch 200/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2996 - YT_loss: 0.5492 - YP_loss: 1.7504 - YT_acc: 0.8252 - YP_acc: 0.3893 - val_loss: 2.2902 - val_YT_loss: 0.5756 - val_YP_loss: 1.7146 - val_YT_acc: 0.8165 - val_YP_acc: 0.4033
# Epoch 201/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.3369 - YT_loss: 0.5691 - YP_loss: 1.7679 - YT_acc: 0.8243 - YP_acc: 0.3839 - val_loss: 2.3192 - val_YT_loss: 0.5822 - val_YP_loss: 1.7370 - val_YT_acc: 0.8139 - val_YP_acc: 0.3934
# Epoch 202/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3439 - YT_loss: 0.5705 - YP_loss: 1.7734 - YT_acc: 0.8242 - YP_acc: 0.3810 - val_loss: 2.3044 - val_YT_loss: 0.5704 - val_YP_loss: 1.7340 - val_YT_acc: 0.8160 - val_YP_acc: 0.3972
# Epoch 203/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3281 - YT_loss: 0.5620 - YP_loss: 1.7660 - YT_acc: 0.8249 - YP_acc: 0.3842 - val_loss: 2.2894 - val_YT_loss: 0.5672 - val_YP_loss: 1.7221 - val_YT_acc: 0.8167 - val_YP_acc: 0.3997
# Epoch 204/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3161 - YT_loss: 0.5581 - YP_loss: 1.7580 - YT_acc: 0.8251 - YP_acc: 0.3866 - val_loss: 2.2792 - val_YT_loss: 0.5618 - val_YP_loss: 1.7174 - val_YT_acc: 0.8174 - val_YP_acc: 0.4019
# Epoch 205/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.3103 - YT_loss: 0.5550 - YP_loss: 1.7553 - YT_acc: 0.8257 - YP_acc: 0.3877 - val_loss: 2.2756 - val_YT_loss: 0.5594 - val_YP_loss: 1.7162 - val_YT_acc: 0.8166 - val_YP_acc: 0.4019
# Epoch 206/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3061 - YT_loss: 0.5522 - YP_loss: 1.7539 - YT_acc: 0.8257 - YP_acc: 0.3887 - val_loss: 2.2717 - val_YT_loss: 0.5580 - val_YP_loss: 1.7137 - val_YT_acc: 0.8175 - val_YP_acc: 0.4030
# Epoch 207/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.3038 - YT_loss: 0.5530 - YP_loss: 1.7509 - YT_acc: 0.8254 - YP_acc: 0.3887 - val_loss: 2.2713 - val_YT_loss: 0.5568 - val_YP_loss: 1.7145 - val_YT_acc: 0.8172 - val_YP_acc: 0.4024
# Epoch 208/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.3012 - YT_loss: 0.5504 - YP_loss: 1.7508 - YT_acc: 0.8256 - YP_acc: 0.3893 - val_loss: 2.2705 - val_YT_loss: 0.5582 - val_YP_loss: 1.7123 - val_YT_acc: 0.8169 - val_YP_acc: 0.4033
# Epoch 209/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2995 - YT_loss: 0.5502 - YP_loss: 1.7493 - YT_acc: 0.8261 - YP_acc: 0.3888 - val_loss: 2.2679 - val_YT_loss: 0.5589 - val_YP_loss: 1.7089 - val_YT_acc: 0.8172 - val_YP_acc: 0.4051
# Epoch 210/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.2964 - YT_loss: 0.5497 - YP_loss: 1.7467 - YT_acc: 0.8261 - YP_acc: 0.3905 - val_loss: 2.2693 - val_YT_loss: 0.5563 - val_YP_loss: 1.7130 - val_YT_acc: 0.8175 - val_YP_acc: 0.4036
# Epoch 211/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2978 - YT_loss: 0.5495 - YP_loss: 1.7483 - YT_acc: 0.8257 - YP_acc: 0.3901 - val_loss: 2.2656 - val_YT_loss: 0.5553 - val_YP_loss: 1.7103 - val_YT_acc: 0.8176 - val_YP_acc: 0.4033
# Epoch 212/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2963 - YT_loss: 0.5488 - YP_loss: 1.7475 - YT_acc: 0.8263 - YP_acc: 0.3901 - val_loss: 2.2625 - val_YT_loss: 0.5539 - val_YP_loss: 1.7086 - val_YT_acc: 0.8178 - val_YP_acc: 0.4047
# Epoch 213/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2924 - YT_loss: 0.5478 - YP_loss: 1.7446 - YT_acc: 0.8261 - YP_acc: 0.3913 - val_loss: 2.2610 - val_YT_loss: 0.5555 - val_YP_loss: 1.7055 - val_YT_acc: 0.8170 - val_YP_acc: 0.4063
# Epoch 214/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2936 - YT_loss: 0.5483 - YP_loss: 1.7454 - YT_acc: 0.8257 - YP_acc: 0.3917 - val_loss: 2.2606 - val_YT_loss: 0.5550 - val_YP_loss: 1.7056 - val_YT_acc: 0.8178 - val_YP_acc: 0.4055
# Epoch 215/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.2926 - YT_loss: 0.5488 - YP_loss: 1.7438 - YT_acc: 0.8264 - YP_acc: 0.3915 - val_loss: 2.2593 - val_YT_loss: 0.5549 - val_YP_loss: 1.7044 - val_YT_acc: 0.8174 - val_YP_acc: 0.4062
# Epoch 216/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2906 - YT_loss: 0.5479 - YP_loss: 1.7427 - YT_acc: 0.8265 - YP_acc: 0.3919 - val_loss: 2.2578 - val_YT_loss: 0.5532 - val_YP_loss: 1.7046 - val_YT_acc: 0.8179 - val_YP_acc: 0.4071
# Epoch 217/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2886 - YT_loss: 0.5464 - YP_loss: 1.7422 - YT_acc: 0.8260 - YP_acc: 0.3922 - val_loss: 2.2561 - val_YT_loss: 0.5531 - val_YP_loss: 1.7030 - val_YT_acc: 0.8174 - val_YP_acc: 0.4074
# Epoch 218/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2876 - YT_loss: 0.5461 - YP_loss: 1.7414 - YT_acc: 0.8263 - YP_acc: 0.3925 - val_loss: 2.2581 - val_YT_loss: 0.5534 - val_YP_loss: 1.7047 - val_YT_acc: 0.8174 - val_YP_acc: 0.4071
# Epoch 219/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2933 - YT_loss: 0.5508 - YP_loss: 1.7425 - YT_acc: 0.8260 - YP_acc: 0.3923 - val_loss: 2.2668 - val_YT_loss: 0.5617 - val_YP_loss: 1.7052 - val_YT_acc: 0.8175 - val_YP_acc: 0.4072
# Epoch 220/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2941 - YT_loss: 0.5523 - YP_loss: 1.7418 - YT_acc: 0.8261 - YP_acc: 0.3933 - val_loss: 2.2678 - val_YT_loss: 0.5588 - val_YP_loss: 1.7090 - val_YT_acc: 0.8170 - val_YP_acc: 0.4040
# Epoch 221/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2923 - YT_loss: 0.5493 - YP_loss: 1.7430 - YT_acc: 0.8259 - YP_acc: 0.3920 - val_loss: 2.2562 - val_YT_loss: 0.5549 - val_YP_loss: 1.7013 - val_YT_acc: 0.8169 - val_YP_acc: 0.4082
# Epoch 222/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2861 - YT_loss: 0.5468 - YP_loss: 1.7393 - YT_acc: 0.8259 - YP_acc: 0.3938 - val_loss: 2.2556 - val_YT_loss: 0.5543 - val_YP_loss: 1.7013 - val_YT_acc: 0.8179 - val_YP_acc: 0.4079
# Epoch 223/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.2843 - YT_loss: 0.5450 - YP_loss: 1.7393 - YT_acc: 0.8271 - YP_acc: 0.3931 - val_loss: 2.2530 - val_YT_loss: 0.5508 - val_YP_loss: 1.7022 - val_YT_acc: 0.8185 - val_YP_acc: 0.4071
# Epoch 224/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2823 - YT_loss: 0.5444 - YP_loss: 1.7378 - YT_acc: 0.8270 - YP_acc: 0.3937 - val_loss: 2.2499 - val_YT_loss: 0.5504 - val_YP_loss: 1.6995 - val_YT_acc: 0.8176 - val_YP_acc: 0.4083
# Epoch 225/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.2797 - YT_loss: 0.5424 - YP_loss: 1.7373 - YT_acc: 0.8269 - YP_acc: 0.3941 - val_loss: 2.2482 - val_YT_loss: 0.5494 - val_YP_loss: 1.6987 - val_YT_acc: 0.8179 - val_YP_acc: 0.4091
# Epoch 226/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2795 - YT_loss: 0.5428 - YP_loss: 1.7367 - YT_acc: 0.8266 - YP_acc: 0.3940 - val_loss: 2.2497 - val_YT_loss: 0.5501 - val_YP_loss: 1.6996 - val_YT_acc: 0.8179 - val_YP_acc: 0.4085
# Epoch 227/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.2772 - YT_loss: 0.5423 - YP_loss: 1.7348 - YT_acc: 0.8268 - YP_acc: 0.3948 - val_loss: 2.2461 - val_YT_loss: 0.5497 - val_YP_loss: 1.6964 - val_YT_acc: 0.8182 - val_YP_acc: 0.4085
# Epoch 228/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2765 - YT_loss: 0.5427 - YP_loss: 1.7338 - YT_acc: 0.8270 - YP_acc: 0.3961 - val_loss: 2.2512 - val_YT_loss: 0.5497 - val_YP_loss: 1.7016 - val_YT_acc: 0.8178 - val_YP_acc: 0.4078
# Epoch 229/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2804 - YT_loss: 0.5424 - YP_loss: 1.7380 - YT_acc: 0.8270 - YP_acc: 0.3947 - val_loss: 2.2625 - val_YT_loss: 0.5562 - val_YP_loss: 1.7063 - val_YT_acc: 0.8172 - val_YP_acc: 0.4030
# Epoch 230/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.2832 - YT_loss: 0.5446 - YP_loss: 1.7387 - YT_acc: 0.8270 - YP_acc: 0.3941 - val_loss: 2.2518 - val_YT_loss: 0.5531 - val_YP_loss: 1.6987 - val_YT_acc: 0.8177 - val_YP_acc: 0.4091
# Epoch 231/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.2793 - YT_loss: 0.5432 - YP_loss: 1.7361 - YT_acc: 0.8270 - YP_acc: 0.3950 - val_loss: 2.2456 - val_YT_loss: 0.5493 - val_YP_loss: 1.6963 - val_YT_acc: 0.8182 - val_YP_acc: 0.4096
# Epoch 232/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2782 - YT_loss: 0.5431 - YP_loss: 1.7351 - YT_acc: 0.8269 - YP_acc: 0.3955 - val_loss: 2.2462 - val_YT_loss: 0.5493 - val_YP_loss: 1.6969 - val_YT_acc: 0.8181 - val_YP_acc: 0.4089
# Epoch 233/250
# 3503/3503 [==============================] - 22s 6ms/step - loss: 2.2743 - YT_loss: 0.5413 - YP_loss: 1.7331 - YT_acc: 0.8273 - YP_acc: 0.3963 - val_loss: 2.2429 - val_YT_loss: 0.5490 - val_YP_loss: 1.6939 - val_YT_acc: 0.8182 - val_YP_acc: 0.4113
# Epoch 234/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2729 - YT_loss: 0.5412 - YP_loss: 1.7317 - YT_acc: 0.8270 - YP_acc: 0.3965 - val_loss: 2.2424 - val_YT_loss: 0.5497 - val_YP_loss: 1.6927 - val_YT_acc: 0.8181 - val_YP_acc: 0.4115
# Epoch 235/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2706 - YT_loss: 0.5400 - YP_loss: 1.7306 - YT_acc: 0.8270 - YP_acc: 0.3969 - val_loss: 2.2451 - val_YT_loss: 0.5482 - val_YP_loss: 1.6969 - val_YT_acc: 0.8181 - val_YP_acc: 0.4091
# Epoch 236/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2733 - YT_loss: 0.5410 - YP_loss: 1.7323 - YT_acc: 0.8276 - YP_acc: 0.3964 - val_loss: 2.2440 - val_YT_loss: 0.5503 - val_YP_loss: 1.6938 - val_YT_acc: 0.8182 - val_YP_acc: 0.4080
# Epoch 237/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2720 - YT_loss: 0.5434 - YP_loss: 1.7287 - YT_acc: 0.8269 - YP_acc: 0.3972 - val_loss: 2.2432 - val_YT_loss: 0.5515 - val_YP_loss: 1.6917 - val_YT_acc: 0.8182 - val_YP_acc: 0.4107
# Epoch 238/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2717 - YT_loss: 0.5423 - YP_loss: 1.7293 - YT_acc: 0.8273 - YP_acc: 0.3979 - val_loss: 2.2459 - val_YT_loss: 0.5514 - val_YP_loss: 1.6945 - val_YT_acc: 0.8177 - val_YP_acc: 0.4095
# Epoch 239/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2722 - YT_loss: 0.5420 - YP_loss: 1.7302 - YT_acc: 0.8275 - YP_acc: 0.3973 - val_loss: 2.2412 - val_YT_loss: 0.5493 - val_YP_loss: 1.6919 - val_YT_acc: 0.8180 - val_YP_acc: 0.4092
# Epoch 240/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2683 - YT_loss: 0.5404 - YP_loss: 1.7278 - YT_acc: 0.8273 - YP_acc: 0.3973 - val_loss: 2.2370 - val_YT_loss: 0.5474 - val_YP_loss: 1.6896 - val_YT_acc: 0.8182 - val_YP_acc: 0.4115
# Epoch 241/250
# 3503/3503 [==============================] - 19s 6ms/step - loss: 2.2687 - YT_loss: 0.5403 - YP_loss: 1.7284 - YT_acc: 0.8269 - YP_acc: 0.3979 - val_loss: 2.2420 - val_YT_loss: 0.5499 - val_YP_loss: 1.6921 - val_YT_acc: 0.8185 - val_YP_acc: 0.4106
# Epoch 242/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2721 - YT_loss: 0.5425 - YP_loss: 1.7297 - YT_acc: 0.8273 - YP_acc: 0.3973 - val_loss: 2.2632 - val_YT_loss: 0.5662 - val_YP_loss: 1.6970 - val_YT_acc: 0.8173 - val_YP_acc: 0.4094
# Epoch 243/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2861 - YT_loss: 0.5520 - YP_loss: 1.7341 - YT_acc: 0.8262 - YP_acc: 0.3954 - val_loss: 2.2521 - val_YT_loss: 0.5578 - val_YP_loss: 1.6943 - val_YT_acc: 0.8178 - val_YP_acc: 0.4094
# Epoch 244/250
# 3503/3503 [==============================] - 18s 5ms/step - loss: 2.2766 - YT_loss: 0.5459 - YP_loss: 1.7307 - YT_acc: 0.8272 - YP_acc: 0.3976 - val_loss: 2.2455 - val_YT_loss: 0.5526 - val_YP_loss: 1.6929 - val_YT_acc: 0.8180 - val_YP_acc: 0.4098
# Epoch 245/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2701 - YT_loss: 0.5421 - YP_loss: 1.7280 - YT_acc: 0.8272 - YP_acc: 0.3983 - val_loss: 2.2416 - val_YT_loss: 0.5501 - val_YP_loss: 1.6915 - val_YT_acc: 0.8185 - val_YP_acc: 0.4109
# Epoch 246/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2668 - YT_loss: 0.5404 - YP_loss: 1.7264 - YT_acc: 0.8275 - YP_acc: 0.3974 - val_loss: 2.2358 - val_YT_loss: 0.5465 - val_YP_loss: 1.6893 - val_YT_acc: 0.8185 - val_YP_acc: 0.4117
# Epoch 247/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2640 - YT_loss: 0.5389 - YP_loss: 1.7251 - YT_acc: 0.8273 - YP_acc: 0.3987 - val_loss: 2.2388 - val_YT_loss: 0.5485 - val_YP_loss: 1.6903 - val_YT_acc: 0.8183 - val_YP_acc: 0.4122
# Epoch 248/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2638 - YT_loss: 0.5387 - YP_loss: 1.7252 - YT_acc: 0.8278 - YP_acc: 0.3985 - val_loss: 2.2402 - val_YT_loss: 0.5472 - val_YP_loss: 1.6929 - val_YT_acc: 0.8182 - val_YP_acc: 0.4106
# Epoch 249/250
# 3503/3503 [==============================] - 20s 6ms/step - loss: 2.2644 - YT_loss: 0.5388 - YP_loss: 1.7256 - YT_acc: 0.8273 - YP_acc: 0.3987 - val_loss: 2.2378 - val_YT_loss: 0.5482 - val_YP_loss: 1.6897 - val_YT_acc: 0.8187 - val_YP_acc: 0.4117
# Epoch 250/250
# 3503/3503 [==============================] - 19s 5ms/step - loss: 2.2615 - YT_loss: 0.5385 - YP_loss: 1.7230 - YT_acc: 0.8278 - YP_acc: 0.3996 - val_loss: 2.2346 - val_YT_loss: 0.5468 - val_YP_loss: 1.6878 - val_YT_acc: 0.8185 - val_YP_acc: 0.4120
# Saved rnn model to disk

# %%
gru_file = Path("model_gru.json")
if not gru_file.is_file():
    history2 = GRUmodel.fit(x, y, batch_size=512, epochs=250, validation_split=0.2)
    with open('gru_history', 'wb') as file_pi:
        pickle.dump(history2.history, file_pi)
    model_json = GRUmodel.to_json()
    with open("model_gru.json", "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    GRUmodel.save_weights("model_gru.h5")
    print("Saved gru model to disk")
else:
    with open('gru_history', 'rb') as file_pi:
        h = pickle.load(file_pi)
    history2 = SavedHistory()
    history2.history = h
    
    # load json and create model
    json_file = open('model_gru.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    
    GRUmodel = model_from_json(loaded_model_json)
    # load weights into new model
    GRUmodel.load_weights("model_gru.h5")
    print("Loaded model from disk")
# Out:
# Train on 3503 samples, validate on 876 samples
# Epoch 1/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 6.2606 - YT_loss: 2.3520 - YP_loss: 3.9087 - YT_acc: 0.5796 - YP_acc: 0.0200 - val_loss: 5.2883 - val_YT_loss: 1.4835 - val_YP_loss: 3.8048 - val_YT_acc: 0.6805 - val_YP_acc: 0.0021
# Epoch 2/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 4.9599 - YT_loss: 1.3254 - YP_loss: 3.6345 - YT_acc: 0.7068 - YP_acc: 0.0523 - val_loss: 4.4567 - val_YT_loss: 1.1903 - val_YP_loss: 3.2664 - val_YT_acc: 0.6805 - val_YP_acc: 0.1427
# Epoch 3/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 4.2884 - YT_loss: 1.0877 - YP_loss: 3.2006 - YT_acc: 0.7087 - YP_acc: 0.1145 - val_loss: 3.9811 - val_YT_loss: 1.0347 - val_YP_loss: 2.9464 - val_YT_acc: 0.6806 - val_YP_acc: 0.1332
# Epoch 4/250
# 3503/3503 [==============================] - 31s 9ms/step - loss: 3.9849 - YT_loss: 1.0172 - YP_loss: 2.9677 - YT_acc: 0.7085 - YP_acc: 0.1188 - val_loss: 3.7634 - val_YT_loss: 0.9936 - val_YP_loss: 2.7699 - val_YT_acc: 0.6819 - val_YP_acc: 0.1690
# Epoch 5/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 3.8200 - YT_loss: 0.9806 - YP_loss: 2.8395 - YT_acc: 0.7201 - YP_acc: 0.1343 - val_loss: 3.6198 - val_YT_loss: 0.9620 - val_YP_loss: 2.6578 - val_YT_acc: 0.7024 - val_YP_acc: 0.1726
# Epoch 6/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 3.6346 - YT_loss: 0.9439 - YP_loss: 2.6907 - YT_acc: 0.7279 - YP_acc: 0.1539 - val_loss: 3.4531 - val_YT_loss: 0.9281 - val_YP_loss: 2.5250 - val_YT_acc: 0.7287 - val_YP_acc: 0.1649
# Epoch 7/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 3.5006 - YT_loss: 0.9143 - YP_loss: 2.5862 - YT_acc: 0.7436 - YP_acc: 0.1620 - val_loss: 3.3364 - val_YT_loss: 0.8893 - val_YP_loss: 2.4471 - val_YT_acc: 0.7403 - val_YP_acc: 0.1863
# Epoch 8/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 3.3886 - YT_loss: 0.8780 - YP_loss: 2.5105 - YT_acc: 0.7518 - YP_acc: 0.1695 - val_loss: 3.2483 - val_YT_loss: 0.8627 - val_YP_loss: 2.3857 - val_YT_acc: 0.7434 - val_YP_acc: 0.1996
# Epoch 9/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 3.3009 - YT_loss: 0.8553 - YP_loss: 2.4455 - YT_acc: 0.7550 - YP_acc: 0.1787 - val_loss: 3.1585 - val_YT_loss: 0.8373 - val_YP_loss: 2.3212 - val_YT_acc: 0.7461 - val_YP_acc: 0.2034
# Epoch 10/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 3.2267 - YT_loss: 0.8410 - YP_loss: 2.3857 - YT_acc: 0.7550 - YP_acc: 0.1870 - val_loss: 3.0859 - val_YT_loss: 0.8224 - val_YP_loss: 2.2635 - val_YT_acc: 0.7487 - val_YP_acc: 0.2086
# Epoch 11/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 3.1638 - YT_loss: 0.8274 - YP_loss: 2.3364 - YT_acc: 0.7584 - YP_acc: 0.1934 - val_loss: 3.0295 - val_YT_loss: 0.8090 - val_YP_loss: 2.2205 - val_YT_acc: 0.7528 - val_YP_acc: 0.2184
# Epoch 12/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 3.1066 - YT_loss: 0.8141 - YP_loss: 2.2925 - YT_acc: 0.7608 - YP_acc: 0.2011 - val_loss: 2.9765 - val_YT_loss: 0.7962 - val_YP_loss: 2.1803 - val_YT_acc: 0.7544 - val_YP_acc: 0.2304
# Epoch 13/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 3.0568 - YT_loss: 0.8027 - YP_loss: 2.2541 - YT_acc: 0.7617 - YP_acc: 0.2089 - val_loss: 2.9271 - val_YT_loss: 0.7852 - val_YP_loss: 2.1419 - val_YT_acc: 0.7560 - val_YP_acc: 0.2388
# Epoch 14/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 3.0116 - YT_loss: 0.7941 - YP_loss: 2.2174 - YT_acc: 0.7635 - YP_acc: 0.2177 - val_loss: 2.8846 - val_YT_loss: 0.7754 - val_YP_loss: 2.1092 - val_YT_acc: 0.7576 - val_YP_acc: 0.2494
# Epoch 15/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.9706 - YT_loss: 0.7839 - YP_loss: 2.1867 - YT_acc: 0.7658 - YP_acc: 0.2266 - val_loss: 2.8451 - val_YT_loss: 0.7656 - val_YP_loss: 2.0795 - val_YT_acc: 0.7594 - val_YP_acc: 0.2620
# Epoch 16/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 2.9341 - YT_loss: 0.7741 - YP_loss: 2.1600 - YT_acc: 0.7682 - YP_acc: 0.2354 - val_loss: 2.8082 - val_YT_loss: 0.7555 - val_YP_loss: 2.0527 - val_YT_acc: 0.7622 - val_YP_acc: 0.2764
# Epoch 17/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.8985 - YT_loss: 0.7649 - YP_loss: 2.1336 - YT_acc: 0.7705 - YP_acc: 0.2457 - val_loss: 2.7758 - val_YT_loss: 0.7462 - val_YP_loss: 2.0296 - val_YT_acc: 0.7647 - val_YP_acc: 0.2895
# Epoch 18/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.8684 - YT_loss: 0.7555 - YP_loss: 2.1129 - YT_acc: 0.7732 - YP_acc: 0.2546 - val_loss: 2.7469 - val_YT_loss: 0.7365 - val_YP_loss: 2.0104 - val_YT_acc: 0.7671 - val_YP_acc: 0.2984
# Epoch 19/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.8383 - YT_loss: 0.7446 - YP_loss: 2.0937 - YT_acc: 0.7760 - YP_acc: 0.2636 - val_loss: 2.7215 - val_YT_loss: 0.7277 - val_YP_loss: 1.9938 - val_YT_acc: 0.7701 - val_YP_acc: 0.3062
# Epoch 20/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.8140 - YT_loss: 0.7362 - YP_loss: 2.0778 - YT_acc: 0.7785 - YP_acc: 0.2698 - val_loss: 2.6985 - val_YT_loss: 0.7182 - val_YP_loss: 1.9803 - val_YT_acc: 0.7732 - val_YP_acc: 0.3097
# Epoch 21/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.7900 - YT_loss: 0.7269 - YP_loss: 2.0632 - YT_acc: 0.7808 - YP_acc: 0.2769 - val_loss: 2.6786 - val_YT_loss: 0.7091 - val_YP_loss: 1.9695 - val_YT_acc: 0.7764 - val_YP_acc: 0.3132
# Epoch 22/250
# 3503/3503 [==============================] - 26s 8ms/step - loss: 2.7688 - YT_loss: 0.7176 - YP_loss: 2.0512 - YT_acc: 0.7836 - YP_acc: 0.2817 - val_loss: 2.6600 - val_YT_loss: 0.7003 - val_YP_loss: 1.9597 - val_YT_acc: 0.7806 - val_YP_acc: 0.3153
# Epoch 23/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 2.7506 - YT_loss: 0.7107 - YP_loss: 2.0399 - YT_acc: 0.7858 - YP_acc: 0.2859 - val_loss: 2.6434 - val_YT_loss: 0.6915 - val_YP_loss: 1.9519 - val_YT_acc: 0.7848 - val_YP_acc: 0.3176
# Epoch 24/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.7306 - YT_loss: 0.7004 - YP_loss: 2.0302 - YT_acc: 0.7898 - YP_acc: 0.2890 - val_loss: 2.6282 - val_YT_loss: 0.6836 - val_YP_loss: 1.9447 - val_YT_acc: 0.7882 - val_YP_acc: 0.3207
# Epoch 25/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.7155 - YT_loss: 0.6943 - YP_loss: 2.0212 - YT_acc: 0.7914 - YP_acc: 0.2935 - val_loss: 2.6149 - val_YT_loss: 0.6777 - val_YP_loss: 1.9371 - val_YT_acc: 0.7908 - val_YP_acc: 0.3240
# Epoch 26/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.7005 - YT_loss: 0.6883 - YP_loss: 2.0121 - YT_acc: 0.7936 - YP_acc: 0.2968 - val_loss: 2.6040 - val_YT_loss: 0.6732 - val_YP_loss: 1.9308 - val_YT_acc: 0.7923 - val_YP_acc: 0.3271
# Epoch 27/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.6885 - YT_loss: 0.6839 - YP_loss: 2.0046 - YT_acc: 0.7947 - YP_acc: 0.2998 - val_loss: 2.5939 - val_YT_loss: 0.6694 - val_YP_loss: 1.9244 - val_YT_acc: 0.7945 - val_YP_acc: 0.3308
# Epoch 28/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.6744 - YT_loss: 0.6786 - YP_loss: 1.9959 - YT_acc: 0.7968 - YP_acc: 0.3038 - val_loss: 2.5845 - val_YT_loss: 0.6660 - val_YP_loss: 1.9185 - val_YT_acc: 0.7968 - val_YP_acc: 0.3335
# Epoch 29/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.6627 - YT_loss: 0.6747 - YP_loss: 1.9881 - YT_acc: 0.7981 - YP_acc: 0.3070 - val_loss: 2.5744 - val_YT_loss: 0.6619 - val_YP_loss: 1.9126 - val_YT_acc: 0.7977 - val_YP_acc: 0.3361
# Epoch 30/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.6526 - YT_loss: 0.6701 - YP_loss: 1.9825 - YT_acc: 0.7993 - YP_acc: 0.3086 - val_loss: 2.5651 - val_YT_loss: 0.6578 - val_YP_loss: 1.9073 - val_YT_acc: 0.7988 - val_YP_acc: 0.3380
# Epoch 31/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.6411 - YT_loss: 0.6661 - YP_loss: 1.9750 - YT_acc: 0.8008 - YP_acc: 0.3110 - val_loss: 2.5564 - val_YT_loss: 0.6551 - val_YP_loss: 1.9013 - val_YT_acc: 0.8005 - val_YP_acc: 0.3397
# Epoch 32/250
# 3503/3503 [==============================] - 30s 8ms/step - loss: 2.6305 - YT_loss: 0.6622 - YP_loss: 1.9683 - YT_acc: 0.8022 - YP_acc: 0.3127 - val_loss: 2.5483 - val_YT_loss: 0.6518 - val_YP_loss: 1.8965 - val_YT_acc: 0.8012 - val_YP_acc: 0.3416
# Epoch 33/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.6205 - YT_loss: 0.6596 - YP_loss: 1.9610 - YT_acc: 0.8030 - YP_acc: 0.3150 - val_loss: 2.5403 - val_YT_loss: 0.6497 - val_YP_loss: 1.8906 - val_YT_acc: 0.8025 - val_YP_acc: 0.3424
# Epoch 34/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.6110 - YT_loss: 0.6563 - YP_loss: 1.9548 - YT_acc: 0.8044 - YP_acc: 0.3177 - val_loss: 2.5317 - val_YT_loss: 0.6468 - val_YP_loss: 1.8849 - val_YT_acc: 0.8035 - val_YP_acc: 0.3443
# Epoch 35/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.6010 - YT_loss: 0.6531 - YP_loss: 1.9479 - YT_acc: 0.8051 - YP_acc: 0.3196 - val_loss: 2.5231 - val_YT_loss: 0.6437 - val_YP_loss: 1.8794 - val_YT_acc: 0.8039 - val_YP_acc: 0.3462
# Epoch 36/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.5926 - YT_loss: 0.6506 - YP_loss: 1.9420 - YT_acc: 0.8059 - YP_acc: 0.3218 - val_loss: 2.5157 - val_YT_loss: 0.6421 - val_YP_loss: 1.8735 - val_YT_acc: 0.8044 - val_YP_acc: 0.3484
# Epoch 37/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.5815 - YT_loss: 0.6465 - YP_loss: 1.9350 - YT_acc: 0.8070 - YP_acc: 0.3244 - val_loss: 2.5080 - val_YT_loss: 0.6397 - val_YP_loss: 1.8683 - val_YT_acc: 0.8049 - val_YP_acc: 0.3495
# Epoch 38/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.5746 - YT_loss: 0.6449 - YP_loss: 1.9297 - YT_acc: 0.8075 - YP_acc: 0.3270 - val_loss: 2.4998 - val_YT_loss: 0.6379 - val_YP_loss: 1.8619 - val_YT_acc: 0.8056 - val_YP_acc: 0.3526
# Epoch 39/250
# 3503/3503 [==============================] - 30s 8ms/step - loss: 2.5651 - YT_loss: 0.6435 - YP_loss: 1.9216 - YT_acc: 0.8084 - YP_acc: 0.3297 - val_loss: 2.4919 - val_YT_loss: 0.6361 - val_YP_loss: 1.8558 - val_YT_acc: 0.8056 - val_YP_acc: 0.3543
# Epoch 40/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.5559 - YT_loss: 0.6400 - YP_loss: 1.9159 - YT_acc: 0.8086 - YP_acc: 0.3318 - val_loss: 2.4839 - val_YT_loss: 0.6337 - val_YP_loss: 1.8502 - val_YT_acc: 0.8061 - val_YP_acc: 0.3566
# Epoch 41/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 2.5475 - YT_loss: 0.6378 - YP_loss: 1.9097 - YT_acc: 0.8095 - YP_acc: 0.3346 - val_loss: 2.4766 - val_YT_loss: 0.6318 - val_YP_loss: 1.8448 - val_YT_acc: 0.8063 - val_YP_acc: 0.3584
# Epoch 42/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.5391 - YT_loss: 0.6362 - YP_loss: 1.9030 - YT_acc: 0.8097 - YP_acc: 0.3369 - val_loss: 2.4701 - val_YT_loss: 0.6300 - val_YP_loss: 1.8400 - val_YT_acc: 0.8066 - val_YP_acc: 0.3604
# Epoch 43/250
# 3503/3503 [==============================] - 26s 8ms/step - loss: 2.5308 - YT_loss: 0.6335 - YP_loss: 1.8972 - YT_acc: 0.8105 - YP_acc: 0.3385 - val_loss: 2.4625 - val_YT_loss: 0.6283 - val_YP_loss: 1.8342 - val_YT_acc: 0.8068 - val_YP_acc: 0.3624
# Epoch 44/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 2.5239 - YT_loss: 0.6318 - YP_loss: 1.8921 - YT_acc: 0.8106 - YP_acc: 0.3411 - val_loss: 2.4566 - val_YT_loss: 0.6270 - val_YP_loss: 1.8296 - val_YT_acc: 0.8072 - val_YP_acc: 0.3648
# Epoch 45/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.5169 - YT_loss: 0.6296 - YP_loss: 1.8873 - YT_acc: 0.8114 - YP_acc: 0.3428 - val_loss: 2.4492 - val_YT_loss: 0.6250 - val_YP_loss: 1.8242 - val_YT_acc: 0.8070 - val_YP_acc: 0.3671
# Epoch 46/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.5089 - YT_loss: 0.6273 - YP_loss: 1.8816 - YT_acc: 0.8116 - YP_acc: 0.3451 - val_loss: 2.4435 - val_YT_loss: 0.6233 - val_YP_loss: 1.8202 - val_YT_acc: 0.8074 - val_YP_acc: 0.3676
# Epoch 47/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.5021 - YT_loss: 0.6255 - YP_loss: 1.8767 - YT_acc: 0.8119 - YP_acc: 0.3462 - val_loss: 2.4382 - val_YT_loss: 0.6217 - val_YP_loss: 1.8165 - val_YT_acc: 0.8081 - val_YP_acc: 0.3692
# Epoch 48/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.4958 - YT_loss: 0.6235 - YP_loss: 1.8723 - YT_acc: 0.8124 - YP_acc: 0.3479 - val_loss: 2.4328 - val_YT_loss: 0.6202 - val_YP_loss: 1.8126 - val_YT_acc: 0.8079 - val_YP_acc: 0.3704
# Epoch 49/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.4891 - YT_loss: 0.6212 - YP_loss: 1.8679 - YT_acc: 0.8125 - YP_acc: 0.3496 - val_loss: 2.4279 - val_YT_loss: 0.6184 - val_YP_loss: 1.8094 - val_YT_acc: 0.8084 - val_YP_acc: 0.3713
# Epoch 50/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.4833 - YT_loss: 0.6190 - YP_loss: 1.8642 - YT_acc: 0.8131 - YP_acc: 0.3511 - val_loss: 2.4223 - val_YT_loss: 0.6168 - val_YP_loss: 1.8055 - val_YT_acc: 0.8084 - val_YP_acc: 0.3723
# Epoch 51/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.4779 - YT_loss: 0.6177 - YP_loss: 1.8602 - YT_acc: 0.8132 - YP_acc: 0.3521 - val_loss: 2.4175 - val_YT_loss: 0.6157 - val_YP_loss: 1.8018 - val_YT_acc: 0.8087 - val_YP_acc: 0.3745
# Epoch 52/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.4727 - YT_loss: 0.6164 - YP_loss: 1.8563 - YT_acc: 0.8136 - YP_acc: 0.3544 - val_loss: 2.4130 - val_YT_loss: 0.6140 - val_YP_loss: 1.7990 - val_YT_acc: 0.8087 - val_YP_acc: 0.3740
# Epoch 53/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 2.4665 - YT_loss: 0.6147 - YP_loss: 1.8518 - YT_acc: 0.8136 - YP_acc: 0.3555 - val_loss: 2.4076 - val_YT_loss: 0.6124 - val_YP_loss: 1.7953 - val_YT_acc: 0.8089 - val_YP_acc: 0.3763
# Epoch 54/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.4616 - YT_loss: 0.6126 - YP_loss: 1.8490 - YT_acc: 0.8143 - YP_acc: 0.3563 - val_loss: 2.4033 - val_YT_loss: 0.6111 - val_YP_loss: 1.7921 - val_YT_acc: 0.8098 - val_YP_acc: 0.3767
# Epoch 55/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 2.4566 - YT_loss: 0.6111 - YP_loss: 1.8455 - YT_acc: 0.8146 - YP_acc: 0.3582 - val_loss: 2.3989 - val_YT_loss: 0.6093 - val_YP_loss: 1.7895 - val_YT_acc: 0.8093 - val_YP_acc: 0.3788
# Epoch 56/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.4508 - YT_loss: 0.6084 - YP_loss: 1.8425 - YT_acc: 0.8148 - YP_acc: 0.3591 - val_loss: 2.3944 - val_YT_loss: 0.6081 - val_YP_loss: 1.7863 - val_YT_acc: 0.8096 - val_YP_acc: 0.3795
# Epoch 57/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.4471 - YT_loss: 0.6084 - YP_loss: 1.8388 - YT_acc: 0.8151 - YP_acc: 0.3596 - val_loss: 2.3901 - val_YT_loss: 0.6067 - val_YP_loss: 1.7834 - val_YT_acc: 0.8098 - val_YP_acc: 0.3806
# Epoch 58/250
# 3503/3503 [==============================] - 30s 8ms/step - loss: 2.4425 - YT_loss: 0.6066 - YP_loss: 1.8359 - YT_acc: 0.8155 - YP_acc: 0.3610 - val_loss: 2.3857 - val_YT_loss: 0.6052 - val_YP_loss: 1.7805 - val_YT_acc: 0.8099 - val_YP_acc: 0.3816
# Epoch 59/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.4367 - YT_loss: 0.6049 - YP_loss: 1.8318 - YT_acc: 0.8153 - YP_acc: 0.3622 - val_loss: 2.3813 - val_YT_loss: 0.6038 - val_YP_loss: 1.7775 - val_YT_acc: 0.8097 - val_YP_acc: 0.3823
# Epoch 60/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.4320 - YT_loss: 0.6028 - YP_loss: 1.8292 - YT_acc: 0.8158 - YP_acc: 0.3631 - val_loss: 2.3764 - val_YT_loss: 0.6022 - val_YP_loss: 1.7743 - val_YT_acc: 0.8099 - val_YP_acc: 0.3833
# Epoch 61/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.4274 - YT_loss: 0.6021 - YP_loss: 1.8253 - YT_acc: 0.8159 - YP_acc: 0.3641 - val_loss: 2.3726 - val_YT_loss: 0.6006 - val_YP_loss: 1.7720 - val_YT_acc: 0.8100 - val_YP_acc: 0.3842
# Epoch 62/250
# 3503/3503 [==============================] - 23s 7ms/step - loss: 2.4228 - YT_loss: 0.5993 - YP_loss: 1.8235 - YT_acc: 0.8168 - YP_acc: 0.3655 - val_loss: 2.3686 - val_YT_loss: 0.5988 - val_YP_loss: 1.7697 - val_YT_acc: 0.8104 - val_YP_acc: 0.3844
# Epoch 63/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.4173 - YT_loss: 0.5975 - YP_loss: 1.8198 - YT_acc: 0.8171 - YP_acc: 0.3666 - val_loss: 2.3632 - val_YT_loss: 0.5969 - val_YP_loss: 1.7663 - val_YT_acc: 0.8106 - val_YP_acc: 0.3866
# Epoch 64/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.4134 - YT_loss: 0.5960 - YP_loss: 1.8174 - YT_acc: 0.8170 - YP_acc: 0.3674 - val_loss: 2.3597 - val_YT_loss: 0.5949 - val_YP_loss: 1.7648 - val_YT_acc: 0.8108 - val_YP_acc: 0.3855
# Epoch 65/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.4078 - YT_loss: 0.5937 - YP_loss: 1.8142 - YT_acc: 0.8171 - YP_acc: 0.3686 - val_loss: 2.3542 - val_YT_loss: 0.5933 - val_YP_loss: 1.7609 - val_YT_acc: 0.8114 - val_YP_acc: 0.3879
# Epoch 66/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.4025 - YT_loss: 0.5916 - YP_loss: 1.8109 - YT_acc: 0.8175 - YP_acc: 0.3697 - val_loss: 2.3496 - val_YT_loss: 0.5912 - val_YP_loss: 1.7584 - val_YT_acc: 0.8115 - val_YP_acc: 0.3893
# Epoch 67/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.3979 - YT_loss: 0.5895 - YP_loss: 1.8084 - YT_acc: 0.8177 - YP_acc: 0.3704 - val_loss: 2.3450 - val_YT_loss: 0.5891 - val_YP_loss: 1.7559 - val_YT_acc: 0.8115 - val_YP_acc: 0.3894
# Epoch 68/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.3937 - YT_loss: 0.5881 - YP_loss: 1.8056 - YT_acc: 0.8180 - YP_acc: 0.3723 - val_loss: 2.3415 - val_YT_loss: 0.5877 - val_YP_loss: 1.7538 - val_YT_acc: 0.8119 - val_YP_acc: 0.3902
# Epoch 69/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.3886 - YT_loss: 0.5853 - YP_loss: 1.8033 - YT_acc: 0.8186 - YP_acc: 0.3729 - val_loss: 2.3364 - val_YT_loss: 0.5854 - val_YP_loss: 1.7510 - val_YT_acc: 0.8119 - val_YP_acc: 0.3908
# Epoch 70/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.3835 - YT_loss: 0.5837 - YP_loss: 1.7999 - YT_acc: 0.8185 - YP_acc: 0.3736 - val_loss: 2.3311 - val_YT_loss: 0.5830 - val_YP_loss: 1.7481 - val_YT_acc: 0.8123 - val_YP_acc: 0.3926
# Epoch 71/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.3786 - YT_loss: 0.5815 - YP_loss: 1.7971 - YT_acc: 0.8190 - YP_acc: 0.3747 - val_loss: 2.3265 - val_YT_loss: 0.5810 - val_YP_loss: 1.7455 - val_YT_acc: 0.8128 - val_YP_acc: 0.3930
# Epoch 72/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.3736 - YT_loss: 0.5795 - YP_loss: 1.7941 - YT_acc: 0.8194 - YP_acc: 0.3764 - val_loss: 2.3235 - val_YT_loss: 0.5800 - val_YP_loss: 1.7435 - val_YT_acc: 0.8130 - val_YP_acc: 0.3937
# Epoch 73/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.3697 - YT_loss: 0.5780 - YP_loss: 1.7917 - YT_acc: 0.8199 - YP_acc: 0.3768 - val_loss: 2.3187 - val_YT_loss: 0.5775 - val_YP_loss: 1.7411 - val_YT_acc: 0.8128 - val_YP_acc: 0.3948
# Epoch 74/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 2.3647 - YT_loss: 0.5760 - YP_loss: 1.7886 - YT_acc: 0.8198 - YP_acc: 0.3779 - val_loss: 2.3143 - val_YT_loss: 0.5760 - val_YP_loss: 1.7383 - val_YT_acc: 0.8134 - val_YP_acc: 0.3956
# Epoch 75/250
# 3503/3503 [==============================] - 22s 6ms/step - loss: 2.3603 - YT_loss: 0.5743 - YP_loss: 1.7860 - YT_acc: 0.8203 - YP_acc: 0.3784 - val_loss: 2.3092 - val_YT_loss: 0.5738 - val_YP_loss: 1.7354 - val_YT_acc: 0.8133 - val_YP_acc: 0.3963
# Epoch 76/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.3560 - YT_loss: 0.5726 - YP_loss: 1.7834 - YT_acc: 0.8206 - YP_acc: 0.3801 - val_loss: 2.3065 - val_YT_loss: 0.5730 - val_YP_loss: 1.7335 - val_YT_acc: 0.8137 - val_YP_acc: 0.3973
# Epoch 77/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.3510 - YT_loss: 0.5711 - YP_loss: 1.7799 - YT_acc: 0.8209 - YP_acc: 0.3809 - val_loss: 2.3013 - val_YT_loss: 0.5709 - val_YP_loss: 1.7303 - val_YT_acc: 0.8138 - val_YP_acc: 0.3987
# Epoch 78/250
# 3503/3503 [==============================] - 26s 8ms/step - loss: 2.3458 - YT_loss: 0.5684 - YP_loss: 1.7774 - YT_acc: 0.8211 - YP_acc: 0.3821 - val_loss: 2.2980 - val_YT_loss: 0.5696 - val_YP_loss: 1.7284 - val_YT_acc: 0.8138 - val_YP_acc: 0.3991
# Epoch 79/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.3423 - YT_loss: 0.5672 - YP_loss: 1.7751 - YT_acc: 0.8213 - YP_acc: 0.3829 - val_loss: 2.2934 - val_YT_loss: 0.5684 - val_YP_loss: 1.7250 - val_YT_acc: 0.8143 - val_YP_acc: 0.4006
# Epoch 80/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.3373 - YT_loss: 0.5656 - YP_loss: 1.7717 - YT_acc: 0.8221 - YP_acc: 0.3834 - val_loss: 2.2892 - val_YT_loss: 0.5661 - val_YP_loss: 1.7231 - val_YT_acc: 0.8143 - val_YP_acc: 0.4005
# Epoch 81/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.3330 - YT_loss: 0.5640 - YP_loss: 1.7690 - YT_acc: 0.8218 - YP_acc: 0.3852 - val_loss: 2.2847 - val_YT_loss: 0.5647 - val_YP_loss: 1.7200 - val_YT_acc: 0.8143 - val_YP_acc: 0.4016
# Epoch 82/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.3280 - YT_loss: 0.5623 - YP_loss: 1.7657 - YT_acc: 0.8224 - YP_acc: 0.3863 - val_loss: 2.2817 - val_YT_loss: 0.5635 - val_YP_loss: 1.7182 - val_YT_acc: 0.8144 - val_YP_acc: 0.4028
# Epoch 83/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.3255 - YT_loss: 0.5613 - YP_loss: 1.7642 - YT_acc: 0.8223 - YP_acc: 0.3869 - val_loss: 2.2771 - val_YT_loss: 0.5615 - val_YP_loss: 1.7155 - val_YT_acc: 0.8144 - val_YP_acc: 0.4037
# Epoch 84/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 2.3203 - YT_loss: 0.5600 - YP_loss: 1.7603 - YT_acc: 0.8228 - YP_acc: 0.3872 - val_loss: 2.2732 - val_YT_loss: 0.5601 - val_YP_loss: 1.7131 - val_YT_acc: 0.8149 - val_YP_acc: 0.4040
# Epoch 85/250
# 3503/3503 [==============================] - 30s 8ms/step - loss: 2.3167 - YT_loss: 0.5577 - YP_loss: 1.7590 - YT_acc: 0.8230 - YP_acc: 0.3880 - val_loss: 2.2702 - val_YT_loss: 0.5594 - val_YP_loss: 1.7107 - val_YT_acc: 0.8154 - val_YP_acc: 0.4052
# Epoch 86/250
# 3503/3503 [==============================] - 26s 8ms/step - loss: 2.3129 - YT_loss: 0.5568 - YP_loss: 1.7562 - YT_acc: 0.8235 - YP_acc: 0.3887 - val_loss: 2.2662 - val_YT_loss: 0.5579 - val_YP_loss: 1.7084 - val_YT_acc: 0.8151 - val_YP_acc: 0.4061
# Epoch 87/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.3097 - YT_loss: 0.5557 - YP_loss: 1.7539 - YT_acc: 0.8235 - YP_acc: 0.3904 - val_loss: 2.2624 - val_YT_loss: 0.5556 - val_YP_loss: 1.7068 - val_YT_acc: 0.8154 - val_YP_acc: 0.4067
# Epoch 88/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.3046 - YT_loss: 0.5532 - YP_loss: 1.7514 - YT_acc: 0.8238 - YP_acc: 0.3909 - val_loss: 2.2594 - val_YT_loss: 0.5545 - val_YP_loss: 1.7049 - val_YT_acc: 0.8156 - val_YP_acc: 0.4070
# Epoch 89/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 2.3006 - YT_loss: 0.5516 - YP_loss: 1.7490 - YT_acc: 0.8242 - YP_acc: 0.3913 - val_loss: 2.2567 - val_YT_loss: 0.5540 - val_YP_loss: 1.7027 - val_YT_acc: 0.8162 - val_YP_acc: 0.4077
# Epoch 90/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.2977 - YT_loss: 0.5511 - YP_loss: 1.7466 - YT_acc: 0.8242 - YP_acc: 0.3928 - val_loss: 2.2547 - val_YT_loss: 0.5526 - val_YP_loss: 1.7021 - val_YT_acc: 0.8161 - val_YP_acc: 0.4079
# Epoch 91/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.2933 - YT_loss: 0.5489 - YP_loss: 1.7443 - YT_acc: 0.8248 - YP_acc: 0.3933 - val_loss: 2.2484 - val_YT_loss: 0.5509 - val_YP_loss: 1.6975 - val_YT_acc: 0.8162 - val_YP_acc: 0.4091
# Epoch 92/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.2895 - YT_loss: 0.5481 - YP_loss: 1.7414 - YT_acc: 0.8244 - YP_acc: 0.3942 - val_loss: 2.2467 - val_YT_loss: 0.5501 - val_YP_loss: 1.6966 - val_YT_acc: 0.8168 - val_YP_acc: 0.4099
# Epoch 93/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 2.2859 - YT_loss: 0.5462 - YP_loss: 1.7396 - YT_acc: 0.8254 - YP_acc: 0.3947 - val_loss: 2.2416 - val_YT_loss: 0.5485 - val_YP_loss: 1.6931 - val_YT_acc: 0.8171 - val_YP_acc: 0.4104
# Epoch 94/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.2819 - YT_loss: 0.5449 - YP_loss: 1.7370 - YT_acc: 0.8257 - YP_acc: 0.3955 - val_loss: 2.2388 - val_YT_loss: 0.5471 - val_YP_loss: 1.6917 - val_YT_acc: 0.8172 - val_YP_acc: 0.4117
# Epoch 95/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.2783 - YT_loss: 0.5438 - YP_loss: 1.7345 - YT_acc: 0.8257 - YP_acc: 0.3962 - val_loss: 2.2356 - val_YT_loss: 0.5465 - val_YP_loss: 1.6892 - val_YT_acc: 0.8177 - val_YP_acc: 0.4126
# Epoch 96/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.2757 - YT_loss: 0.5433 - YP_loss: 1.7324 - YT_acc: 0.8261 - YP_acc: 0.3968 - val_loss: 2.2334 - val_YT_loss: 0.5451 - val_YP_loss: 1.6883 - val_YT_acc: 0.8174 - val_YP_acc: 0.4123
# Epoch 97/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.2721 - YT_loss: 0.5419 - YP_loss: 1.7302 - YT_acc: 0.8264 - YP_acc: 0.3980 - val_loss: 2.2294 - val_YT_loss: 0.5444 - val_YP_loss: 1.6850 - val_YT_acc: 0.8180 - val_YP_acc: 0.4146
# Epoch 98/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.2683 - YT_loss: 0.5403 - YP_loss: 1.7280 - YT_acc: 0.8265 - YP_acc: 0.3980 - val_loss: 2.2266 - val_YT_loss: 0.5434 - val_YP_loss: 1.6833 - val_YT_acc: 0.8182 - val_YP_acc: 0.4150
# Epoch 99/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.2647 - YT_loss: 0.5393 - YP_loss: 1.7254 - YT_acc: 0.8267 - YP_acc: 0.3995 - val_loss: 2.2237 - val_YT_loss: 0.5428 - val_YP_loss: 1.6809 - val_YT_acc: 0.8177 - val_YP_acc: 0.4157
# Epoch 100/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.2609 - YT_loss: 0.5384 - YP_loss: 1.7225 - YT_acc: 0.8270 - YP_acc: 0.4011 - val_loss: 2.2216 - val_YT_loss: 0.5418 - val_YP_loss: 1.6798 - val_YT_acc: 0.8183 - val_YP_acc: 0.4157
# Epoch 101/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.2581 - YT_loss: 0.5378 - YP_loss: 1.7204 - YT_acc: 0.8272 - YP_acc: 0.4010 - val_loss: 2.2187 - val_YT_loss: 0.5405 - val_YP_loss: 1.6782 - val_YT_acc: 0.8185 - val_YP_acc: 0.4165
# Epoch 102/250
# 3503/3503 [==============================] - 23s 6ms/step - loss: 2.2543 - YT_loss: 0.5361 - YP_loss: 1.7182 - YT_acc: 0.8273 - YP_acc: 0.4021 - val_loss: 2.2164 - val_YT_loss: 0.5400 - val_YP_loss: 1.6764 - val_YT_acc: 0.8190 - val_YP_acc: 0.4170
# Epoch 103/250
# 3503/3503 [==============================] - 21s 6ms/step - loss: 2.2521 - YT_loss: 0.5352 - YP_loss: 1.7169 - YT_acc: 0.8280 - YP_acc: 0.4031 - val_loss: 2.2132 - val_YT_loss: 0.5393 - val_YP_loss: 1.6740 - val_YT_acc: 0.8188 - val_YP_acc: 0.4178
# Epoch 104/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.2483 - YT_loss: 0.5337 - YP_loss: 1.7146 - YT_acc: 0.8278 - YP_acc: 0.4035 - val_loss: 2.2113 - val_YT_loss: 0.5387 - val_YP_loss: 1.6726 - val_YT_acc: 0.8187 - val_YP_acc: 0.4181
# Epoch 105/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.2459 - YT_loss: 0.5331 - YP_loss: 1.7127 - YT_acc: 0.8278 - YP_acc: 0.4039 - val_loss: 2.2068 - val_YT_loss: 0.5372 - val_YP_loss: 1.6696 - val_YT_acc: 0.8191 - val_YP_acc: 0.4194
# Epoch 106/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.2411 - YT_loss: 0.5322 - YP_loss: 1.7089 - YT_acc: 0.8283 - YP_acc: 0.4053 - val_loss: 2.2038 - val_YT_loss: 0.5364 - val_YP_loss: 1.6674 - val_YT_acc: 0.8193 - val_YP_acc: 0.4205
# Epoch 107/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.2383 - YT_loss: 0.5307 - YP_loss: 1.7076 - YT_acc: 0.8285 - YP_acc: 0.4057 - val_loss: 2.2024 - val_YT_loss: 0.5363 - val_YP_loss: 1.6661 - val_YT_acc: 0.8195 - val_YP_acc: 0.4210
# Epoch 108/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.2348 - YT_loss: 0.5294 - YP_loss: 1.7053 - YT_acc: 0.8286 - YP_acc: 0.4061 - val_loss: 2.2004 - val_YT_loss: 0.5352 - val_YP_loss: 1.6651 - val_YT_acc: 0.8192 - val_YP_acc: 0.4212
# Epoch 109/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.2315 - YT_loss: 0.5292 - YP_loss: 1.7023 - YT_acc: 0.8287 - YP_acc: 0.4075 - val_loss: 2.1970 - val_YT_loss: 0.5348 - val_YP_loss: 1.6621 - val_YT_acc: 0.8197 - val_YP_acc: 0.4224
# Epoch 110/250
# 3503/3503 [==============================] - 31s 9ms/step - loss: 2.2296 - YT_loss: 0.5280 - YP_loss: 1.7016 - YT_acc: 0.8288 - YP_acc: 0.4081 - val_loss: 2.1944 - val_YT_loss: 0.5340 - val_YP_loss: 1.6605 - val_YT_acc: 0.8198 - val_YP_acc: 0.4226
# Epoch 111/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.2260 - YT_loss: 0.5276 - YP_loss: 1.6984 - YT_acc: 0.8292 - YP_acc: 0.4088 - val_loss: 2.1920 - val_YT_loss: 0.5329 - val_YP_loss: 1.6591 - val_YT_acc: 0.8200 - val_YP_acc: 0.4229
# Epoch 112/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.2230 - YT_loss: 0.5262 - YP_loss: 1.6968 - YT_acc: 0.8293 - YP_acc: 0.4092 - val_loss: 2.1884 - val_YT_loss: 0.5320 - val_YP_loss: 1.6564 - val_YT_acc: 0.8198 - val_YP_acc: 0.4237
# Epoch 113/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.2197 - YT_loss: 0.5249 - YP_loss: 1.6947 - YT_acc: 0.8292 - YP_acc: 0.4102 - val_loss: 2.1859 - val_YT_loss: 0.5311 - val_YP_loss: 1.6548 - val_YT_acc: 0.8198 - val_YP_acc: 0.4242
# Epoch 114/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.2179 - YT_loss: 0.5247 - YP_loss: 1.6932 - YT_acc: 0.8293 - YP_acc: 0.4114 - val_loss: 2.1840 - val_YT_loss: 0.5306 - val_YP_loss: 1.6535 - val_YT_acc: 0.8198 - val_YP_acc: 0.4247
# Epoch 115/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.2132 - YT_loss: 0.5234 - YP_loss: 1.6898 - YT_acc: 0.8297 - YP_acc: 0.4123 - val_loss: 2.1819 - val_YT_loss: 0.5298 - val_YP_loss: 1.6522 - val_YT_acc: 0.8205 - val_YP_acc: 0.4252
# Epoch 116/250
# 3503/3503 [==============================] - 31s 9ms/step - loss: 2.2103 - YT_loss: 0.5222 - YP_loss: 1.6880 - YT_acc: 0.8297 - YP_acc: 0.4123 - val_loss: 2.1785 - val_YT_loss: 0.5294 - val_YP_loss: 1.6491 - val_YT_acc: 0.8204 - val_YP_acc: 0.4268
# Epoch 117/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.2075 - YT_loss: 0.5209 - YP_loss: 1.6866 - YT_acc: 0.8301 - YP_acc: 0.4129 - val_loss: 2.1768 - val_YT_loss: 0.5287 - val_YP_loss: 1.6481 - val_YT_acc: 0.8207 - val_YP_acc: 0.4265
# Epoch 118/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.2054 - YT_loss: 0.5201 - YP_loss: 1.6853 - YT_acc: 0.8303 - YP_acc: 0.4143 - val_loss: 2.1738 - val_YT_loss: 0.5278 - val_YP_loss: 1.6461 - val_YT_acc: 0.8205 - val_YP_acc: 0.4270
# Epoch 119/250
# 3503/3503 [==============================] - 26s 8ms/step - loss: 2.2013 - YT_loss: 0.5188 - YP_loss: 1.6825 - YT_acc: 0.8302 - YP_acc: 0.4145 - val_loss: 2.1725 - val_YT_loss: 0.5271 - val_YP_loss: 1.6453 - val_YT_acc: 0.8206 - val_YP_acc: 0.4280
# Epoch 120/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.1981 - YT_loss: 0.5177 - YP_loss: 1.6804 - YT_acc: 0.8305 - YP_acc: 0.4156 - val_loss: 2.1704 - val_YT_loss: 0.5267 - val_YP_loss: 1.6436 - val_YT_acc: 0.8210 - val_YP_acc: 0.4284
# Epoch 121/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.1965 - YT_loss: 0.5176 - YP_loss: 1.6789 - YT_acc: 0.8306 - YP_acc: 0.4161 - val_loss: 2.1684 - val_YT_loss: 0.5260 - val_YP_loss: 1.6424 - val_YT_acc: 0.8209 - val_YP_acc: 0.4286
# Epoch 122/250
# 3503/3503 [==============================] - 30s 8ms/step - loss: 2.1927 - YT_loss: 0.5160 - YP_loss: 1.6766 - YT_acc: 0.8307 - YP_acc: 0.4169 - val_loss: 2.1664 - val_YT_loss: 0.5247 - val_YP_loss: 1.6417 - val_YT_acc: 0.8208 - val_YP_acc: 0.4291
# Epoch 123/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.1900 - YT_loss: 0.5149 - YP_loss: 1.6751 - YT_acc: 0.8311 - YP_acc: 0.4168 - val_loss: 2.1616 - val_YT_loss: 0.5235 - val_YP_loss: 1.6381 - val_YT_acc: 0.8211 - val_YP_acc: 0.4302
# Epoch 124/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.1864 - YT_loss: 0.5140 - YP_loss: 1.6724 - YT_acc: 0.8309 - YP_acc: 0.4185 - val_loss: 2.1606 - val_YT_loss: 0.5235 - val_YP_loss: 1.6371 - val_YT_acc: 0.8211 - val_YP_acc: 0.4304
# Epoch 125/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.1830 - YT_loss: 0.5130 - YP_loss: 1.6700 - YT_acc: 0.8310 - YP_acc: 0.4187 - val_loss: 2.1564 - val_YT_loss: 0.5223 - val_YP_loss: 1.6342 - val_YT_acc: 0.8214 - val_YP_acc: 0.4319
# Epoch 126/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 2.1806 - YT_loss: 0.5117 - YP_loss: 1.6689 - YT_acc: 0.8311 - YP_acc: 0.4195 - val_loss: 2.1553 - val_YT_loss: 0.5219 - val_YP_loss: 1.6334 - val_YT_acc: 0.8217 - val_YP_acc: 0.4321
# Epoch 127/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.1774 - YT_loss: 0.5107 - YP_loss: 1.6667 - YT_acc: 0.8309 - YP_acc: 0.4205 - val_loss: 2.1526 - val_YT_loss: 0.5207 - val_YP_loss: 1.6319 - val_YT_acc: 0.8214 - val_YP_acc: 0.4328
# Epoch 128/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.1738 - YT_loss: 0.5100 - YP_loss: 1.6638 - YT_acc: 0.8313 - YP_acc: 0.4210 - val_loss: 2.1485 - val_YT_loss: 0.5195 - val_YP_loss: 1.6290 - val_YT_acc: 0.8214 - val_YP_acc: 0.4334
# Epoch 129/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.1715 - YT_loss: 0.5089 - YP_loss: 1.6625 - YT_acc: 0.8315 - YP_acc: 0.4225 - val_loss: 2.1484 - val_YT_loss: 0.5192 - val_YP_loss: 1.6292 - val_YT_acc: 0.8216 - val_YP_acc: 0.4324
# Epoch 130/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.1681 - YT_loss: 0.5076 - YP_loss: 1.6605 - YT_acc: 0.8316 - YP_acc: 0.4231 - val_loss: 2.1462 - val_YT_loss: 0.5193 - val_YP_loss: 1.6269 - val_YT_acc: 0.8217 - val_YP_acc: 0.4342
# Epoch 131/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.1655 - YT_loss: 0.5073 - YP_loss: 1.6582 - YT_acc: 0.8316 - YP_acc: 0.4232 - val_loss: 2.1421 - val_YT_loss: 0.5175 - val_YP_loss: 1.6246 - val_YT_acc: 0.8222 - val_YP_acc: 0.4344
# Epoch 132/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.1619 - YT_loss: 0.5054 - YP_loss: 1.6565 - YT_acc: 0.8318 - YP_acc: 0.4237 - val_loss: 2.1406 - val_YT_loss: 0.5170 - val_YP_loss: 1.6236 - val_YT_acc: 0.8212 - val_YP_acc: 0.4355
# Epoch 133/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.1590 - YT_loss: 0.5052 - YP_loss: 1.6538 - YT_acc: 0.8315 - YP_acc: 0.4254 - val_loss: 2.1380 - val_YT_loss: 0.5159 - val_YP_loss: 1.6221 - val_YT_acc: 0.8215 - val_YP_acc: 0.4353
# Epoch 134/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.1569 - YT_loss: 0.5038 - YP_loss: 1.6530 - YT_acc: 0.8319 - YP_acc: 0.4256 - val_loss: 2.1349 - val_YT_loss: 0.5158 - val_YP_loss: 1.6191 - val_YT_acc: 0.8219 - val_YP_acc: 0.4367
# Epoch 135/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.1540 - YT_loss: 0.5036 - YP_loss: 1.6504 - YT_acc: 0.8321 - YP_acc: 0.4259 - val_loss: 2.1323 - val_YT_loss: 0.5147 - val_YP_loss: 1.6176 - val_YT_acc: 0.8218 - val_YP_acc: 0.4372
# Epoch 136/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.1504 - YT_loss: 0.5030 - YP_loss: 1.6474 - YT_acc: 0.8323 - YP_acc: 0.4274 - val_loss: 2.1314 - val_YT_loss: 0.5141 - val_YP_loss: 1.6174 - val_YT_acc: 0.8217 - val_YP_acc: 0.4366
# Epoch 137/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.1481 - YT_loss: 0.5015 - YP_loss: 1.6466 - YT_acc: 0.8324 - YP_acc: 0.4285 - val_loss: 2.1280 - val_YT_loss: 0.5137 - val_YP_loss: 1.6143 - val_YT_acc: 0.8218 - val_YP_acc: 0.4386
# Epoch 138/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.1451 - YT_loss: 0.5013 - YP_loss: 1.6438 - YT_acc: 0.8321 - YP_acc: 0.4289 - val_loss: 2.1261 - val_YT_loss: 0.5131 - val_YP_loss: 1.6130 - val_YT_acc: 0.8218 - val_YP_acc: 0.4387
# Epoch 139/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.1432 - YT_loss: 0.5011 - YP_loss: 1.6421 - YT_acc: 0.8321 - YP_acc: 0.4299 - val_loss: 2.1252 - val_YT_loss: 0.5136 - val_YP_loss: 1.6116 - val_YT_acc: 0.8220 - val_YP_acc: 0.4395
# Epoch 140/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.1393 - YT_loss: 0.4996 - YP_loss: 1.6396 - YT_acc: 0.8326 - YP_acc: 0.4304 - val_loss: 2.1232 - val_YT_loss: 0.5125 - val_YP_loss: 1.6107 - val_YT_acc: 0.8222 - val_YP_acc: 0.4392
# Epoch 141/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.1380 - YT_loss: 0.4990 - YP_loss: 1.6390 - YT_acc: 0.8325 - YP_acc: 0.4309 - val_loss: 2.1200 - val_YT_loss: 0.5111 - val_YP_loss: 1.6088 - val_YT_acc: 0.8221 - val_YP_acc: 0.4406
# Epoch 142/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.1355 - YT_loss: 0.4983 - YP_loss: 1.6372 - YT_acc: 0.8328 - YP_acc: 0.4314 - val_loss: 2.1202 - val_YT_loss: 0.5120 - val_YP_loss: 1.6082 - val_YT_acc: 0.8224 - val_YP_acc: 0.4411
# Epoch 143/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.1328 - YT_loss: 0.4979 - YP_loss: 1.6349 - YT_acc: 0.8328 - YP_acc: 0.4324 - val_loss: 2.1169 - val_YT_loss: 0.5105 - val_YP_loss: 1.6064 - val_YT_acc: 0.8223 - val_YP_acc: 0.4409
# Epoch 144/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.1310 - YT_loss: 0.4976 - YP_loss: 1.6334 - YT_acc: 0.8329 - YP_acc: 0.4333 - val_loss: 2.1172 - val_YT_loss: 0.5113 - val_YP_loss: 1.6059 - val_YT_acc: 0.8224 - val_YP_acc: 0.4418
# Epoch 145/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.1270 - YT_loss: 0.4963 - YP_loss: 1.6307 - YT_acc: 0.8329 - YP_acc: 0.4343 - val_loss: 2.1131 - val_YT_loss: 0.5096 - val_YP_loss: 1.6035 - val_YT_acc: 0.8222 - val_YP_acc: 0.4422
# Epoch 146/250
# 3503/3503 [==============================] - 30s 8ms/step - loss: 2.1260 - YT_loss: 0.4960 - YP_loss: 1.6300 - YT_acc: 0.8333 - YP_acc: 0.4346 - val_loss: 2.1106 - val_YT_loss: 0.5091 - val_YP_loss: 1.6015 - val_YT_acc: 0.8228 - val_YP_acc: 0.4430
# Epoch 147/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.1235 - YT_loss: 0.4954 - YP_loss: 1.6281 - YT_acc: 0.8327 - YP_acc: 0.4357 - val_loss: 2.1107 - val_YT_loss: 0.5097 - val_YP_loss: 1.6010 - val_YT_acc: 0.8227 - val_YP_acc: 0.4431
# Epoch 148/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.1197 - YT_loss: 0.4941 - YP_loss: 1.6256 - YT_acc: 0.8337 - YP_acc: 0.4356 - val_loss: 2.1076 - val_YT_loss: 0.5083 - val_YP_loss: 1.5994 - val_YT_acc: 0.8224 - val_YP_acc: 0.4439
# Epoch 149/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.1175 - YT_loss: 0.4943 - YP_loss: 1.6232 - YT_acc: 0.8333 - YP_acc: 0.4366 - val_loss: 2.1080 - val_YT_loss: 0.5084 - val_YP_loss: 1.5996 - val_YT_acc: 0.8225 - val_YP_acc: 0.4443
# Epoch 150/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.1155 - YT_loss: 0.4933 - YP_loss: 1.6222 - YT_acc: 0.8332 - YP_acc: 0.4379 - val_loss: 2.1049 - val_YT_loss: 0.5074 - val_YP_loss: 1.5976 - val_YT_acc: 0.8229 - val_YP_acc: 0.4450
# Epoch 151/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.1133 - YT_loss: 0.4930 - YP_loss: 1.6203 - YT_acc: 0.8334 - YP_acc: 0.4388 - val_loss: 2.1050 - val_YT_loss: 0.5081 - val_YP_loss: 1.5970 - val_YT_acc: 0.8225 - val_YP_acc: 0.4449
# Epoch 152/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.1120 - YT_loss: 0.4928 - YP_loss: 1.6192 - YT_acc: 0.8337 - YP_acc: 0.4386 - val_loss: 2.1003 - val_YT_loss: 0.5069 - val_YP_loss: 1.5934 - val_YT_acc: 0.8231 - val_YP_acc: 0.4461
# Epoch 153/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.1080 - YT_loss: 0.4922 - YP_loss: 1.6158 - YT_acc: 0.8336 - YP_acc: 0.4394 - val_loss: 2.0995 - val_YT_loss: 0.5066 - val_YP_loss: 1.5929 - val_YT_acc: 0.8229 - val_YP_acc: 0.4464
# Epoch 154/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.1059 - YT_loss: 0.4908 - YP_loss: 1.6151 - YT_acc: 0.8338 - YP_acc: 0.4398 - val_loss: 2.0987 - val_YT_loss: 0.5063 - val_YP_loss: 1.5924 - val_YT_acc: 0.8231 - val_YP_acc: 0.4467
# Epoch 155/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.1044 - YT_loss: 0.4907 - YP_loss: 1.6137 - YT_acc: 0.8338 - YP_acc: 0.4406 - val_loss: 2.0951 - val_YT_loss: 0.5059 - val_YP_loss: 1.5892 - val_YT_acc: 0.8232 - val_YP_acc: 0.4475
# Epoch 156/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.1029 - YT_loss: 0.4903 - YP_loss: 1.6126 - YT_acc: 0.8339 - YP_acc: 0.4402 - val_loss: 2.0962 - val_YT_loss: 0.5064 - val_YP_loss: 1.5898 - val_YT_acc: 0.8226 - val_YP_acc: 0.4473
# Epoch 157/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.0996 - YT_loss: 0.4900 - YP_loss: 1.6096 - YT_acc: 0.8338 - YP_acc: 0.4423 - val_loss: 2.0926 - val_YT_loss: 0.5051 - val_YP_loss: 1.5875 - val_YT_acc: 0.8233 - val_YP_acc: 0.4476
# Epoch 158/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0965 - YT_loss: 0.4896 - YP_loss: 1.6070 - YT_acc: 0.8334 - YP_acc: 0.4430 - val_loss: 2.0922 - val_YT_loss: 0.5053 - val_YP_loss: 1.5869 - val_YT_acc: 0.8227 - val_YP_acc: 0.4484
# Epoch 159/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 2.0948 - YT_loss: 0.4891 - YP_loss: 1.6057 - YT_acc: 0.8343 - YP_acc: 0.4432 - val_loss: 2.0897 - val_YT_loss: 0.5047 - val_YP_loss: 1.5850 - val_YT_acc: 0.8233 - val_YP_acc: 0.4493
# Epoch 160/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.0932 - YT_loss: 0.4887 - YP_loss: 1.6045 - YT_acc: 0.8342 - YP_acc: 0.4442 - val_loss: 2.0878 - val_YT_loss: 0.5041 - val_YP_loss: 1.5837 - val_YT_acc: 0.8234 - val_YP_acc: 0.4494
# Epoch 161/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0902 - YT_loss: 0.4879 - YP_loss: 1.6022 - YT_acc: 0.8344 - YP_acc: 0.4454 - val_loss: 2.0872 - val_YT_loss: 0.5044 - val_YP_loss: 1.5828 - val_YT_acc: 0.8236 - val_YP_acc: 0.4503
# Epoch 162/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.0884 - YT_loss: 0.4877 - YP_loss: 1.6007 - YT_acc: 0.8341 - YP_acc: 0.4456 - val_loss: 2.0854 - val_YT_loss: 0.5039 - val_YP_loss: 1.5815 - val_YT_acc: 0.8237 - val_YP_acc: 0.4505
# Epoch 163/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.0861 - YT_loss: 0.4875 - YP_loss: 1.5986 - YT_acc: 0.8340 - YP_acc: 0.4461 - val_loss: 2.0846 - val_YT_loss: 0.5039 - val_YP_loss: 1.5807 - val_YT_acc: 0.8236 - val_YP_acc: 0.4510
# Epoch 164/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.0848 - YT_loss: 0.4871 - YP_loss: 1.5977 - YT_acc: 0.8343 - YP_acc: 0.4466 - val_loss: 2.0839 - val_YT_loss: 0.5037 - val_YP_loss: 1.5802 - val_YT_acc: 0.8235 - val_YP_acc: 0.4506
# Epoch 165/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 2.0830 - YT_loss: 0.4863 - YP_loss: 1.5968 - YT_acc: 0.8343 - YP_acc: 0.4473 - val_loss: 2.0819 - val_YT_loss: 0.5032 - val_YP_loss: 1.5787 - val_YT_acc: 0.8240 - val_YP_acc: 0.4508
# Epoch 166/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.0814 - YT_loss: 0.4862 - YP_loss: 1.5952 - YT_acc: 0.8342 - YP_acc: 0.4477 - val_loss: 2.0825 - val_YT_loss: 0.5035 - val_YP_loss: 1.5790 - val_YT_acc: 0.8234 - val_YP_acc: 0.4511
# Epoch 167/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.0793 - YT_loss: 0.4855 - YP_loss: 1.5938 - YT_acc: 0.8343 - YP_acc: 0.4479 - val_loss: 2.0791 - val_YT_loss: 0.5027 - val_YP_loss: 1.5764 - val_YT_acc: 0.8238 - val_YP_acc: 0.4516
# Epoch 168/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0772 - YT_loss: 0.4856 - YP_loss: 1.5916 - YT_acc: 0.8343 - YP_acc: 0.4491 - val_loss: 2.0789 - val_YT_loss: 0.5031 - val_YP_loss: 1.5759 - val_YT_acc: 0.8231 - val_YP_acc: 0.4527
# Epoch 169/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.0736 - YT_loss: 0.4844 - YP_loss: 1.5892 - YT_acc: 0.8346 - YP_acc: 0.4497 - val_loss: 2.0749 - val_YT_loss: 0.5025 - val_YP_loss: 1.5725 - val_YT_acc: 0.8241 - val_YP_acc: 0.4533
# Epoch 170/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.0721 - YT_loss: 0.4845 - YP_loss: 1.5876 - YT_acc: 0.8348 - YP_acc: 0.4505 - val_loss: 2.0761 - val_YT_loss: 0.5023 - val_YP_loss: 1.5738 - val_YT_acc: 0.8233 - val_YP_acc: 0.4537
# Epoch 171/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0703 - YT_loss: 0.4845 - YP_loss: 1.5858 - YT_acc: 0.8346 - YP_acc: 0.4512 - val_loss: 2.0733 - val_YT_loss: 0.5016 - val_YP_loss: 1.5717 - val_YT_acc: 0.8240 - val_YP_acc: 0.4531
# Epoch 172/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.0701 - YT_loss: 0.4843 - YP_loss: 1.5858 - YT_acc: 0.8348 - YP_acc: 0.4511 - val_loss: 2.0738 - val_YT_loss: 0.5022 - val_YP_loss: 1.5716 - val_YT_acc: 0.8232 - val_YP_acc: 0.4535
# Epoch 173/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0669 - YT_loss: 0.4835 - YP_loss: 1.5833 - YT_acc: 0.8348 - YP_acc: 0.4521 - val_loss: 2.0699 - val_YT_loss: 0.5011 - val_YP_loss: 1.5688 - val_YT_acc: 0.8244 - val_YP_acc: 0.4544
# Epoch 174/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.0653 - YT_loss: 0.4831 - YP_loss: 1.5821 - YT_acc: 0.8350 - YP_acc: 0.4526 - val_loss: 2.0698 - val_YT_loss: 0.5014 - val_YP_loss: 1.5683 - val_YT_acc: 0.8235 - val_YP_acc: 0.4549
# Epoch 175/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 2.0622 - YT_loss: 0.4824 - YP_loss: 1.5799 - YT_acc: 0.8347 - YP_acc: 0.4532 - val_loss: 2.0696 - val_YT_loss: 0.5016 - val_YP_loss: 1.5680 - val_YT_acc: 0.8244 - val_YP_acc: 0.4560
# Epoch 176/250
# 3503/3503 [==============================] - 30s 8ms/step - loss: 2.0610 - YT_loss: 0.4827 - YP_loss: 1.5784 - YT_acc: 0.8356 - YP_acc: 0.4543 - val_loss: 2.0678 - val_YT_loss: 0.5013 - val_YP_loss: 1.5666 - val_YT_acc: 0.8235 - val_YP_acc: 0.4558
# Epoch 177/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0598 - YT_loss: 0.4819 - YP_loss: 1.5779 - YT_acc: 0.8353 - YP_acc: 0.4543 - val_loss: 2.0669 - val_YT_loss: 0.5005 - val_YP_loss: 1.5663 - val_YT_acc: 0.8244 - val_YP_acc: 0.4563
# Epoch 178/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.0570 - YT_loss: 0.4815 - YP_loss: 1.5754 - YT_acc: 0.8353 - YP_acc: 0.4553 - val_loss: 2.0656 - val_YT_loss: 0.5003 - val_YP_loss: 1.5653 - val_YT_acc: 0.8242 - val_YP_acc: 0.4564
# Epoch 179/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.0565 - YT_loss: 0.4815 - YP_loss: 1.5750 - YT_acc: 0.8347 - YP_acc: 0.4551 - val_loss: 2.0639 - val_YT_loss: 0.5003 - val_YP_loss: 1.5636 - val_YT_acc: 0.8244 - val_YP_acc: 0.4574
# Epoch 180/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0535 - YT_loss: 0.4808 - YP_loss: 1.5726 - YT_acc: 0.8353 - YP_acc: 0.4562 - val_loss: 2.0633 - val_YT_loss: 0.5001 - val_YP_loss: 1.5632 - val_YT_acc: 0.8241 - val_YP_acc: 0.4564
# Epoch 181/250
# 3503/3503 [==============================] - 30s 8ms/step - loss: 2.0538 - YT_loss: 0.4813 - YP_loss: 1.5725 - YT_acc: 0.8353 - YP_acc: 0.4567 - val_loss: 2.0648 - val_YT_loss: 0.5007 - val_YP_loss: 1.5641 - val_YT_acc: 0.8243 - val_YP_acc: 0.4565
# Epoch 182/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0513 - YT_loss: 0.4810 - YP_loss: 1.5703 - YT_acc: 0.8356 - YP_acc: 0.4569 - val_loss: 2.0608 - val_YT_loss: 0.5002 - val_YP_loss: 1.5606 - val_YT_acc: 0.8245 - val_YP_acc: 0.4582
# Epoch 183/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0494 - YT_loss: 0.4808 - YP_loss: 1.5686 - YT_acc: 0.8353 - YP_acc: 0.4584 - val_loss: 2.0605 - val_YT_loss: 0.4997 - val_YP_loss: 1.5608 - val_YT_acc: 0.8238 - val_YP_acc: 0.4576
# Epoch 184/250
# ...
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.0367 - YT_loss: 0.4777 - YP_loss: 1.5590 - YT_acc: 0.8360 - YP_acc: 0.4620 - val_loss: 2.0535 - val_YT_loss: 0.4986 - val_YP_loss: 1.5549 - val_YT_acc: 0.8246 - val_YP_acc: 0.4603
# Epoch 191/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.0358 - YT_loss: 0.4778 - YP_loss: 1.5580 - YT_acc: 0.8359 - YP_acc: 0.4617 - val_loss: 2.0528 - val_YT_loss: 0.4986 - val_YP_loss: 1.5542 - val_YT_acc: 0.8244 - val_YP_acc: 0.4595
# Epoch 192/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0349 - YT_loss: 0.4778 - YP_loss: 1.5571 - YT_acc: 0.8358 - YP_acc: 0.4618 - val_loss: 2.0529 - val_YT_loss: 0.4986 - val_YP_loss: 1.5543 - val_YT_acc: 0.8244 - val_YP_acc: 0.4602
# Epoch 193/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 2.0330 - YT_loss: 0.4777 - YP_loss: 1.5553 - YT_acc: 0.8356 - YP_acc: 0.4631 - val_loss: 2.0497 - val_YT_loss: 0.4980 - val_YP_loss: 1.5518 - val_YT_acc: 0.8244 - val_YP_acc: 0.4604
# Epoch 194/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0301 - YT_loss: 0.4770 - YP_loss: 1.5531 - YT_acc: 0.8360 - YP_acc: 0.4636 - val_loss: 2.0492 - val_YT_loss: 0.4981 - val_YP_loss: 1.5511 - val_YT_acc: 0.8244 - val_YP_acc: 0.4615
# Epoch 195/250
# 3503/3503 [==============================] - 30s 8ms/step - loss: 2.0282 - YT_loss: 0.4767 - YP_loss: 1.5515 - YT_acc: 0.8359 - YP_acc: 0.4643 - val_loss: 2.0494 - val_YT_loss: 0.4981 - val_YP_loss: 1.5513 - val_YT_acc: 0.8247 - val_YP_acc: 0.4606
# Epoch 196/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.0272 - YT_loss: 0.4761 - YP_loss: 1.5511 - YT_acc: 0.8361 - YP_acc: 0.4643 - val_loss: 2.0487 - val_YT_loss: 0.4980 - val_YP_loss: 1.5507 - val_YT_acc: 0.8239 - val_YP_acc: 0.4613
# Epoch 197/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 2.0243 - YT_loss: 0.4761 - YP_loss: 1.5482 - YT_acc: 0.8364 - YP_acc: 0.4649 - val_loss: 2.0468 - val_YT_loss: 0.4976 - val_YP_loss: 1.5492 - val_YT_acc: 0.8248 - val_YP_acc: 0.4614
# Epoch 198/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 2.0238 - YT_loss: 0.4757 - YP_loss: 1.5481 - YT_acc: 0.8365 - YP_acc: 0.4656 - val_loss: 2.0488 - val_YT_loss: 0.4981 - val_YP_loss: 1.5507 - val_YT_acc: 0.8245 - val_YP_acc: 0.4610
# Epoch 199/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.0211 - YT_loss: 0.4750 - YP_loss: 1.5460 - YT_acc: 0.8362 - YP_acc: 0.4667 - val_loss: 2.0460 - val_YT_loss: 0.4978 - val_YP_loss: 1.5482 - val_YT_acc: 0.8247 - val_YP_acc: 0.4621
# Epoch 200/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.0200 - YT_loss: 0.4750 - YP_loss: 1.5450 - YT_acc: 0.8364 - YP_acc: 0.4668 - val_loss: 2.0445 - val_YT_loss: 0.4972 - val_YP_loss: 1.5473 - val_YT_acc: 0.8247 - val_YP_acc: 0.4626
# Epoch 201/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.0199 - YT_loss: 0.4755 - YP_loss: 1.5444 - YT_acc: 0.8367 - YP_acc: 0.4665 - val_loss: 2.0450 - val_YT_loss: 0.4975 - val_YP_loss: 1.5474 - val_YT_acc: 0.8243 - val_YP_acc: 0.4627
# Epoch 202/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 2.0182 - YT_loss: 0.4749 - YP_loss: 1.5433 - YT_acc: 0.8366 - YP_acc: 0.4673 - val_loss: 2.0431 - val_YT_loss: 0.4970 - val_YP_loss: 1.5461 - val_YT_acc: 0.8241 - val_YP_acc: 0.4623
# Epoch 203/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.0154 - YT_loss: 0.4741 - YP_loss: 1.5413 - YT_acc: 0.8362 - YP_acc: 0.4686 - val_loss: 2.0439 - val_YT_loss: 0.4974 - val_YP_loss: 1.5465 - val_YT_acc: 0.8244 - val_YP_acc: 0.4632
# Epoch 204/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0159 - YT_loss: 0.4744 - YP_loss: 1.5415 - YT_acc: 0.8365 - YP_acc: 0.4681 - val_loss: 2.0425 - val_YT_loss: 0.4970 - val_YP_loss: 1.5455 - val_YT_acc: 0.8243 - val_YP_acc: 0.4637
# Epoch 205/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.0122 - YT_loss: 0.4733 - YP_loss: 1.5388 - YT_acc: 0.8368 - YP_acc: 0.4693 - val_loss: 2.0418 - val_YT_loss: 0.4978 - val_YP_loss: 1.5439 - val_YT_acc: 0.8247 - val_YP_acc: 0.4638
# Epoch 206/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.0115 - YT_loss: 0.4741 - YP_loss: 1.5374 - YT_acc: 0.8366 - YP_acc: 0.4696 - val_loss: 2.0424 - val_YT_loss: 0.4973 - val_YP_loss: 1.5451 - val_YT_acc: 0.8244 - val_YP_acc: 0.4637
# Epoch 207/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 2.0096 - YT_loss: 0.4735 - YP_loss: 1.5361 - YT_acc: 0.8364 - YP_acc: 0.4699 - val_loss: 2.0396 - val_YT_loss: 0.4970 - val_YP_loss: 1.5426 - val_YT_acc: 0.8249 - val_YP_acc: 0.4645
# Epoch 208/250
# 3503/3503 [==============================] - 30s 8ms/step - loss: 2.0077 - YT_loss: 0.4727 - YP_loss: 1.5349 - YT_acc: 0.8371 - YP_acc: 0.4700 - val_loss: 2.0389 - val_YT_loss: 0.4967 - val_YP_loss: 1.5421 - val_YT_acc: 0.8241 - val_YP_acc: 0.4654
# Epoch 209/250
# 3503/3503 [==============================] - 26s 8ms/step - loss: 2.0080 - YT_loss: 0.4729 - YP_loss: 1.5352 - YT_acc: 0.8370 - YP_acc: 0.4697 - val_loss: 2.0376 - val_YT_loss: 0.4964 - val_YP_loss: 1.5412 - val_YT_acc: 0.8246 - val_YP_acc: 0.4653
# Epoch 210/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 2.0057 - YT_loss: 0.4730 - YP_loss: 1.5328 - YT_acc: 0.8371 - YP_acc: 0.4717 - val_loss: 2.0388 - val_YT_loss: 0.4972 - val_YP_loss: 1.5416 - val_YT_acc: 0.8250 - val_YP_acc: 0.4652
# Epoch 211/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 2.0044 - YT_loss: 0.4729 - YP_loss: 1.5316 - YT_acc: 0.8367 - YP_acc: 0.4709 - val_loss: 2.0367 - val_YT_loss: 0.4962 - val_YP_loss: 1.5405 - val_YT_acc: 0.8245 - val_YP_acc: 0.4658
# Epoch 212/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0029 - YT_loss: 0.4722 - YP_loss: 1.5307 - YT_acc: 0.8368 - YP_acc: 0.4726 - val_loss: 2.0373 - val_YT_loss: 0.4967 - val_YP_loss: 1.5405 - val_YT_acc: 0.8249 - val_YP_acc: 0.4660
# Epoch 213/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 2.0007 - YT_loss: 0.4717 - YP_loss: 1.5290 - YT_acc: 0.8371 - YP_acc: 0.4724 - val_loss: 2.0368 - val_YT_loss: 0.4969 - val_YP_loss: 1.5399 - val_YT_acc: 0.8251 - val_YP_acc: 0.4657
# Epoch 214/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 2.0001 - YT_loss: 0.4713 - YP_loss: 1.5288 - YT_acc: 0.8370 - YP_acc: 0.4727 - val_loss: 2.0350 - val_YT_loss: 0.4962 - val_YP_loss: 1.5388 - val_YT_acc: 0.8240 - val_YP_acc: 0.4663
# Epoch 215/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 1.9991 - YT_loss: 0.4716 - YP_loss: 1.5275 - YT_acc: 0.8372 - YP_acc: 0.4732 - val_loss: 2.0355 - val_YT_loss: 0.4962 - val_YP_loss: 1.5393 - val_YT_acc: 0.8250 - val_YP_acc: 0.4665
# Epoch 216/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 1.9963 - YT_loss: 0.4709 - YP_loss: 1.5254 - YT_acc: 0.8374 - YP_acc: 0.4742 - val_loss: 2.0336 - val_YT_loss: 0.4959 - val_YP_loss: 1.5377 - val_YT_acc: 0.8251 - val_YP_acc: 0.4666
# Epoch 217/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 1.9950 - YT_loss: 0.4709 - YP_loss: 1.5241 - YT_acc: 0.8372 - YP_acc: 0.4746 - val_loss: 2.0338 - val_YT_loss: 0.4961 - val_YP_loss: 1.5376 - val_YT_acc: 0.8246 - val_YP_acc: 0.4667
# Epoch 218/250
# 3503/3503 [==============================] - 30s 8ms/step - loss: 1.9941 - YT_loss: 0.4705 - YP_loss: 1.5236 - YT_acc: 0.8372 - YP_acc: 0.4747 - val_loss: 2.0331 - val_YT_loss: 0.4960 - val_YP_loss: 1.5371 - val_YT_acc: 0.8247 - val_YP_acc: 0.4675
# Epoch 219/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 1.9921 - YT_loss: 0.4699 - YP_loss: 1.5222 - YT_acc: 0.8374 - YP_acc: 0.4750 - val_loss: 2.0321 - val_YT_loss: 0.4959 - val_YP_loss: 1.5363 - val_YT_acc: 0.8246 - val_YP_acc: 0.4675
# Epoch 220/250
# 3503/3503 [==============================] - 22s 6ms/step - loss: 1.9900 - YT_loss: 0.4700 - YP_loss: 1.5200 - YT_acc: 0.8371 - YP_acc: 0.4760 - val_loss: 2.0331 - val_YT_loss: 0.4962 - val_YP_loss: 1.5369 - val_YT_acc: 0.8251 - val_YP_acc: 0.4672
# Epoch 221/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 1.9895 - YT_loss: 0.4698 - YP_loss: 1.5197 - YT_acc: 0.8377 - YP_acc: 0.4761 - val_loss: 2.0305 - val_YT_loss: 0.4955 - val_YP_loss: 1.5350 - val_YT_acc: 0.8246 - val_YP_acc: 0.4673
# Epoch 222/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 1.9886 - YT_loss: 0.4696 - YP_loss: 1.5190 - YT_acc: 0.8373 - YP_acc: 0.4767 - val_loss: 2.0306 - val_YT_loss: 0.4958 - val_YP_loss: 1.5348 - val_YT_acc: 0.8252 - val_YP_acc: 0.4681
# Epoch 223/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 1.9866 - YT_loss: 0.4692 - YP_loss: 1.5174 - YT_acc: 0.8377 - YP_acc: 0.4768 - val_loss: 2.0310 - val_YT_loss: 0.4958 - val_YP_loss: 1.5352 - val_YT_acc: 0.8244 - val_YP_acc: 0.4681
# Epoch 224/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 1.9858 - YT_loss: 0.4695 - YP_loss: 1.5164 - YT_acc: 0.8371 - YP_acc: 0.4769 - val_loss: 2.0315 - val_YT_loss: 0.4962 - val_YP_loss: 1.5353 - val_YT_acc: 0.8252 - val_YP_acc: 0.4681
# Epoch 225/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 1.9842 - YT_loss: 0.4687 - YP_loss: 1.5155 - YT_acc: 0.8378 - YP_acc: 0.4775 - val_loss: 2.0298 - val_YT_loss: 0.4955 - val_YP_loss: 1.5343 - val_YT_acc: 0.8251 - val_YP_acc: 0.4681
# Epoch 226/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 1.9841 - YT_loss: 0.4687 - YP_loss: 1.5154 - YT_acc: 0.8377 - YP_acc: 0.4772 - val_loss: 2.0294 - val_YT_loss: 0.4960 - val_YP_loss: 1.5334 - val_YT_acc: 0.8247 - val_YP_acc: 0.4693
# Epoch 227/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 1.9805 - YT_loss: 0.4678 - YP_loss: 1.5127 - YT_acc: 0.8383 - YP_acc: 0.4784 - val_loss: 2.0273 - val_YT_loss: 0.4952 - val_YP_loss: 1.5320 - val_YT_acc: 0.8252 - val_YP_acc: 0.4695
# Epoch 228/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 1.9788 - YT_loss: 0.4683 - YP_loss: 1.5105 - YT_acc: 0.8378 - YP_acc: 0.4791 - val_loss: 2.0284 - val_YT_loss: 0.4958 - val_YP_loss: 1.5327 - val_YT_acc: 0.8252 - val_YP_acc: 0.4694
# Epoch 229/250
# 3503/3503 [==============================] - 23s 7ms/step - loss: 1.9781 - YT_loss: 0.4675 - YP_loss: 1.5106 - YT_acc: 0.8381 - YP_acc: 0.4791 - val_loss: 2.0268 - val_YT_loss: 0.4951 - val_YP_loss: 1.5316 - val_YT_acc: 0.8250 - val_YP_acc: 0.4694
# Epoch 230/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 1.9759 - YT_loss: 0.4675 - YP_loss: 1.5084 - YT_acc: 0.8377 - YP_acc: 0.4802 - val_loss: 2.0265 - val_YT_loss: 0.4953 - val_YP_loss: 1.5313 - val_YT_acc: 0.8254 - val_YP_acc: 0.4699
# Epoch 231/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 1.9750 - YT_loss: 0.4669 - YP_loss: 1.5080 - YT_acc: 0.8376 - YP_acc: 0.4797 - val_loss: 2.0266 - val_YT_loss: 0.4953 - val_YP_loss: 1.5313 - val_YT_acc: 0.8250 - val_YP_acc: 0.4695
# Epoch 232/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 1.9748 - YT_loss: 0.4673 - YP_loss: 1.5075 - YT_acc: 0.8381 - YP_acc: 0.4802 - val_loss: 2.0266 - val_YT_loss: 0.4957 - val_YP_loss: 1.5309 - val_YT_acc: 0.8250 - val_YP_acc: 0.4694
# Epoch 233/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 1.9745 - YT_loss: 0.4674 - YP_loss: 1.5071 - YT_acc: 0.8378 - YP_acc: 0.4804 - val_loss: 2.0239 - val_YT_loss: 0.4951 - val_YP_loss: 1.5288 - val_YT_acc: 0.8252 - val_YP_acc: 0.4700
# Epoch 234/250
# 3503/3503 [==============================] - 26s 8ms/step - loss: 1.9722 - YT_loss: 0.4673 - YP_loss: 1.5048 - YT_acc: 0.8380 - YP_acc: 0.4813 - val_loss: 2.0256 - val_YT_loss: 0.4952 - val_YP_loss: 1.5304 - val_YT_acc: 0.8252 - val_YP_acc: 0.4705
# Epoch 235/250
# 3503/3503 [==============================] - 29s 8ms/step - loss: 1.9716 - YT_loss: 0.4673 - YP_loss: 1.5043 - YT_acc: 0.8379 - YP_acc: 0.4815 - val_loss: 2.0236 - val_YT_loss: 0.4952 - val_YP_loss: 1.5285 - val_YT_acc: 0.8250 - val_YP_acc: 0.4715
# Epoch 236/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 1.9693 - YT_loss: 0.4657 - YP_loss: 1.5036 - YT_acc: 0.8381 - YP_acc: 0.4819 - val_loss: 2.0244 - val_YT_loss: 0.4954 - val_YP_loss: 1.5290 - val_YT_acc: 0.8250 - val_YP_acc: 0.4707
# Epoch 237/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 1.9686 - YT_loss: 0.4665 - YP_loss: 1.5022 - YT_acc: 0.8383 - YP_acc: 0.4825 - val_loss: 2.0249 - val_YT_loss: 0.4954 - val_YP_loss: 1.5296 - val_YT_acc: 0.8249 - val_YP_acc: 0.4703
# Epoch 238/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 1.9668 - YT_loss: 0.4665 - YP_loss: 1.5003 - YT_acc: 0.8379 - YP_acc: 0.4830 - val_loss: 2.0226 - val_YT_loss: 0.4952 - val_YP_loss: 1.5273 - val_YT_acc: 0.8253 - val_YP_acc: 0.4713
# Epoch 239/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 1.9651 - YT_loss: 0.4660 - YP_loss: 1.4991 - YT_acc: 0.8383 - YP_acc: 0.4837 - val_loss: 2.0228 - val_YT_loss: 0.4952 - val_YP_loss: 1.5277 - val_YT_acc: 0.8245 - val_YP_acc: 0.4710
# Epoch 240/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 1.9633 - YT_loss: 0.4652 - YP_loss: 1.4981 - YT_acc: 0.8382 - YP_acc: 0.4841 - val_loss: 2.0230 - val_YT_loss: 0.4948 - val_YP_loss: 1.5282 - val_YT_acc: 0.8250 - val_YP_acc: 0.4708
# Epoch 241/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 1.9623 - YT_loss: 0.4647 - YP_loss: 1.4977 - YT_acc: 0.8384 - YP_acc: 0.4843 - val_loss: 2.0210 - val_YT_loss: 0.4944 - val_YP_loss: 1.5266 - val_YT_acc: 0.8251 - val_YP_acc: 0.4707
# Epoch 242/250
# 3503/3503 [==============================] - 23s 6ms/step - loss: 1.9608 - YT_loss: 0.4648 - YP_loss: 1.4959 - YT_acc: 0.8384 - YP_acc: 0.4846 - val_loss: 2.0201 - val_YT_loss: 0.4947 - val_YP_loss: 1.5254 - val_YT_acc: 0.8254 - val_YP_acc: 0.4715
# Epoch 243/250
# 3503/3503 [==============================] - 27s 8ms/step - loss: 1.9586 - YT_loss: 0.4644 - YP_loss: 1.4942 - YT_acc: 0.8385 - YP_acc: 0.4849 - val_loss: 2.0220 - val_YT_loss: 0.4951 - val_YP_loss: 1.5270 - val_YT_acc: 0.8248 - val_YP_acc: 0.4712
# Epoch 244/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 1.9594 - YT_loss: 0.4649 - YP_loss: 1.4945 - YT_acc: 0.8384 - YP_acc: 0.4841 - val_loss: 2.0209 - val_YT_loss: 0.4948 - val_YP_loss: 1.5261 - val_YT_acc: 0.8251 - val_YP_acc: 0.4712
# Epoch 245/250
# 3503/3503 [==============================] - 26s 7ms/step - loss: 1.9568 - YT_loss: 0.4640 - YP_loss: 1.4928 - YT_acc: 0.8388 - YP_acc: 0.4859 - val_loss: 2.0204 - val_YT_loss: 0.4948 - val_YP_loss: 1.5257 - val_YT_acc: 0.8253 - val_YP_acc: 0.4716
# Epoch 246/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 1.9566 - YT_loss: 0.4644 - YP_loss: 1.4922 - YT_acc: 0.8384 - YP_acc: 0.4862 - val_loss: 2.0193 - val_YT_loss: 0.4945 - val_YP_loss: 1.5249 - val_YT_acc: 0.8249 - val_YP_acc: 0.4725
# Epoch 247/250
# 3503/3503 [==============================] - 25s 7ms/step - loss: 1.9553 - YT_loss: 0.4640 - YP_loss: 1.4913 - YT_acc: 0.8388 - YP_acc: 0.4858 - val_loss: 2.0191 - val_YT_loss: 0.4947 - val_YP_loss: 1.5244 - val_YT_acc: 0.8251 - val_YP_acc: 0.4721
# Epoch 248/250
# 3503/3503 [==============================] - 24s 7ms/step - loss: 1.9544 - YT_loss: 0.4636 - YP_loss: 1.4908 - YT_acc: 0.8391 - YP_acc: 0.4862 - val_loss: 2.0183 - val_YT_loss: 0.4945 - val_YP_loss: 1.5238 - val_YT_acc: 0.8250 - val_YP_acc: 0.4721
# Epoch 249/250
# 3503/3503 [==============================] - 30s 9ms/step - loss: 1.9521 - YT_loss: 0.4634 - YP_loss: 1.4888 - YT_acc: 0.8385 - YP_acc: 0.4875 - val_loss: 2.0203 - val_YT_loss: 0.4947 - val_YP_loss: 1.5256 - val_YT_acc: 0.8252 - val_YP_acc: 0.4723
# Epoch 250/250
# 3503/3503 [==============================] - 28s 8ms/step - loss: 1.9510 - YT_loss: 0.4629 - YP_loss: 1.4880 - YT_acc: 0.8387 - YP_acc: 0.4872 - val_loss: 2.0182 - val_YT_loss: 0.4944 - val_YP_loss: 1.5237 - val_YT_acc: 0.8251 - val_YP_acc: 0.4730
# Saved gru model to disk

# %% [markdown]
# **Question**: What are the best prediction accuracies you obtained? With which model?
#
# **Answer**: We obtained 43%/82% using the GRU model.
#
# **Question**: In a few sentences, comment on the plot comparing learning curves for the two activation function.
#
# **Answer**:

# %%
plotLearningCurves(history)

# %%
plotLearningCurves(history2)

# %% [markdown]
# ## Exercise 6: Visualizing the model
# ### Description
#
# 1. Using the model.predict and plotMelody functions, show the outputs of your best model when fed with 4 randomly selected melodies. Report the prediction accuracies as well.
# 2. For the same melodies, plot the hidden state evolution accross time steps. Construct a 2 dimensional matrix with the first dimension being time and the second the concatenation of all hidden unit activations and plot it using the provided `plotMelody` function. To get the hidden states of your network, you can modify the `buildModel` function so that you have another computation graph (another model with the same layers, but the output layer) returning you the hidden states. However, other approaches are equally valid.
# 3. For each hidden unit $i$ and accross the entire dataset, compute the average absolute change in activation $\Delta A_i$. Be careful not to take masked timesteps into account. Plot the histogram (50 bins) of this average for the RNN and GRU models on the same figure.

# %% [markdown]
# ### Solution

# %% [markdown]
# ### 1.

# %%
random_melodies = np.random.choice(range(len(data['XT'])), 2)

# %%
for i in random_melodies:
    random_melody = {'XT': x['XT'][i].reshape((1, n_notes-1, dim_t)),
                     'XP': x['XP'][i].reshape((1, n_notes-1, dim_p))}

    pred = GRUmodel.predict(random_melody)

    plotMelody(random_melody['XP'][0], random_melody['XT'][0], dicts, PrP=pred[1][0], PrT=pred[0][0])

# %% [markdown]
# ### 2.

# %%
hidden_state_rnn_model = Model(inputs=RNNmodel.inputs,
                            outputs=[RNNmodel.get_layer('simple_rnn_1').output, RNNmodel.get_layer('simple_rnn_2').output])

# %%
hidden_state_gru_model = Model(inputs=GRUmodel.inputs,
                            outputs=[GRUmodel.get_layer('gru_1').output, GRUmodel.get_layer('gru_2').output])

# %%
for i in random_melodies:
    random_melody = {'XT': x['XT'][i].reshape((1, n_notes-1, dim_t)),
                     'XP': x['XP'][i].reshape((1, n_notes-1, dim_p))}

    pred = np.array(hidden_state_gru_model.predict(random_melody))
    plotMelody(random_melody['XP'][0], random_melody['XT'][0], dicts, H=np.concatenate((pred[0], pred[1]), axis=-1)[0])

# %% [markdown]
# ### 3.

# %% [markdown]
# **Question**: How does the hidden state dynamics explain the performance of the RNN vs GRU models? Explain in term of temporal dependencies and base your explanation on figures obtained in 6.2 and 6.3.
#
# **Answer**:

# %% [markdown]
# ## Exercise 7: Generation of new melodies
# ### Description
#
# 1. Use your trained best model to generate new melodies. You can do that by starting with a random note, feeding it to your network and sample the output predictions in order to select the next note. Then add this note to your iteratively growing melodies. For your convenience, we provided the `sample` and `writeMIDI` functions. You can use the first in order to perform temperature sampling. The `writeMIDI` function allows you to write a MIDI file from the integer representation.
# 2. Try different sampling temperatures (e.g. 0.5, 1., 1.5) and observe the effect on your generated melodies.
# 3. Generate 32 melodies with both the RNN and GRU models
# 4. Listen to 4 randomly chosen melodies (2 from the GRU model and 2 from the RNN model). To play in a notebook, use a similar approach as the one shown below assuming you have the files `GRU_1.mid` and `RNN_1.mid` at the same level as this notebook. For your own curiosity, you can also directly listen to the MIDI files with your favorite MIDI player but make sure that we can listen to the 4 extracts directly from this notebook (without rerunning it). You might have to use the "Trust notebook" button (in the top right corner) to see the players. This currently only works in jupyter notebook (not jupyter lab). If you have trouble achieving that, upload the MIDI files with your submission.
# 5. (Optional) If you have a big enough computing power, try adding multiple and bigger layers. You could also try to improve your model with different add-ons, e.g. make your model learn when a melody ends, extend it to other datasets, ...
# 6. (Optional) If you are happy with your results submit a 1 hour long generated MIDI file to the [AI-generated music challenge](https://www.crowdai.org/challenges/ai-generated-music-challenge).

# %% [markdown]
# ### Solution

# %%
def generate_melody(random_note, length, model, temp=1.0):

    current_melody = random_note
    for i in range(length):
        prediction = model.predict(current_melody)
        T = np.zeros((1, dim_t))
        T[0][sample(prediction[0][0][i], temperature=temp)] = 1
        P = np.zeros((1, dim_p))
        P[0][sample(prediction[1][0][i], temperature=temp)] = 1
        
        current_melody['XT'][0][i+1] = T
        current_melody['XP'][0][i+1] = P
        
    current_melody['XT'] = np.argmax(current_melody['XT'][0][:1+np.max(list(np.where(np.sum(current_melody['XT'][0], axis=1) != 0)[0]))], axis=1)  
    current_melody['XP'] = np.argmax(current_melody['XP'][0][:1+np.max(list(np.where(np.sum(current_melody['XP'][0], axis=1) != 0)[0]))], axis=1)
    return current_melody

# %%
random_t = np.zeros((1, dim_t))
random_t[0][sample(np.array([1/dim_t]*dim_t))] = 1

random_p = np.zeros((1, dim_p))
random_p[0][sample(np.array([1/dim_p]*dim_p))] = 1
random_note = {'XT': pad_sequences(random_t.reshape((1, 1, dim_t)).T, maxlen=n_notes-1, padding='post', truncating='post').T,
               'XP': pad_sequences(random_p.reshape((1, 1, dim_p)).T, maxlen=n_notes-1, padding='post', truncating='post').T}

# %%
current_melody = generate_melody(random_note, 100, RNNmodel, 1.)
plotMelody(current_melody['XP'], current_melody['XT'], dicts)

# %%
writeMIDI(current_melody['XP'], current_melody['XT'], dicts, 'GRU_2.mid')

# %%
print('GRU')
music21.midi.translate.midiFilePathToStream('chorpus/sessiontune100.mid').show('midi')
# Out:
# GRU
#                 <div id='midiPlayerDiv4387959'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv4387959');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
writeMIDI(current_melody['XP'], current_melody['XT'], dicts, 'test.mid')

# %%
print('RNN')
music21.midi.translate.midiFilePathToStream('test.mid').show('midi')
# Out:
# RNN
#                 <div id='midiPlayerDiv4389005'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv4389005');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# **Question**: What is the effect of the sampling temperature on the generated melodies?
#
# **Answer**:
#
# **Question**: Are the generated melodies from the RNN model different from the one generated by the GRU model? If yes, what are the main differences?
#
# **Answer**:
